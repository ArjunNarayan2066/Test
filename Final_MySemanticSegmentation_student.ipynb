# %% [markdown]
# <a href="https://colab.research.google.com/github/ArjunNarayan2066/Test/blob/master/Final_MySemanticSegmentation_student.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# drive.flush_and_unmount()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from os.path import exists
if (exists('images') == False):
    print('Copying Images')
    # !cp -r "drive/My Drive/cs484/images/" .
if (exists('lib') == False):
    print('Copying Lib')
    # !cp -r "drive/My Drive/cs484/lib/" .

# %% [markdown]
# ### CS 484/684 Computational Vision
# #### credits: many thanks for the design of this assignemnt go to <a href="https://tovacinni.github.io/" target = "_blank">Towaki Takikawa</a>
#
# # Homework Assignment #5 - Supervised Deep Learning for Segmentation
#
# This assignment will test your understanding of applying deep learning by having you apply (fully supervised) deep learning to semantic segmentation, a well studied problem in computer vision.
#
# You can get most of the work done using only CPU, however, the use of GPU will be helpful in later parts. Programming and debugging everything upto and including problem 5c should be fine on CPU. You will notice the benefit of GPU mostly in later parts (d-h) of problem 5, but they are mainly implemenmted and test your code written and debugged earlier. If you do not have a GPU readily accesible to you, we recommend that you use Google Colaboratory to get access to a GPU. Once you are satisfied with your code upto and including 5(c), simply upload this Jupyter Notebook to Google Colaboratory to run the tests in later parts of Problem 5.
#
# Proficiency with PyTorch is required. Working through the PyTorch tutorials will make this assignment significantly easier. https://pytorch.org/tutorials/

# %%
# Python Libraries
import random
import math
import numbers
import platform
import copy
from IPython.core.debugger import set_trace

# Importing essential libraries for basic image manipulations.
import numpy as np
import PIL
from PIL import Image, ImageOps
import matplotlib.pyplot as plt
from tqdm import tqdm

# We import some of the main PyTorch and TorchVision libraries used for HW4.
# Detailed installation instructions are here: https://pytorch.org/get-started/locally/
# That web site should help you to select the right 'conda install' command to be run in 'Anaconda Prompt'.
# In particular, select the right version of CUDA. Note that prior to installing PyTorch, you should  
# install the latest driver for your GPU and CUDA (9.2 or 10.1), assuming your GPU supports it. 
# For more information about pytorch refer to 
# https://pytorch.org/docs/stable/nn.functional.html
# https://pytorch.org/docs/stable/data.html.
# and https://pytorch.org/docs/stable/torchvision/transforms.html
import torch
import torch.nn.functional as F
from torch import nn
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
import torchvision.transforms.functional as tF
import torch.optim as optim

# !export CUDA_LAUNCH_BLOCKING=1
print(torch.cuda.is_available())
print(torch.cuda.get_device_name())

# Note class labels used in Pascal dataset:
# 0:    background,
# 1-20: aeroplane, bicycle, bird, boat, bottle, bus, car, cat, chair, cow, diningtable, dog, horse, motorbike,
#       person, pottedplant, sheep, sofa, train, TV_monitor
# 255: "void", which means class for pixel is undefined
# Out:
# True
# Tesla K80

# %%
# %matplotlib inline

# It is best to start with USE_GPU = False (implying CPU). Switch USE_GPU to True only if you want to use GPU. However... 
# we strongly recommend to wait until you are absolutely sure your CPU-based code works (at least on single image dataset)
USE_GPU = torch.cuda.is_available()

# %%
# !pip install chainercv # Need to manualy install this in the colab environment

# ChainerCV is a library similar to TorchVision, created and maintained by Preferred Networks. 
# Chainer, the base library, inspired and led to the creation of PyTorch! 
# Although Chainer and PyTorch are different, there are some nice functionalities in ChainerCV 
# that are useful, so we include it as an excersice on learning other libraries.
# To install ChainerCV, normally it suffices to run "pip install chainercv" inside "Anaconda Prompt".
# For more detailed installation instructions, see https://chainercv.readthedocs.io/en/stable/install.html
# For other information about ChainerCV library, refer to https://chainercv.readthedocs.io/en/stable/ 
from chainercv.evaluations import eval_semantic_segmentation
from chainercv.datasets import VOCSemanticSegmentationDataset
# Out:
# Requirement already satisfied: chainercv in /usr/local/lib/python3.6/dist-packages (0.13.1)
# Requirement already satisfied: chainer>=6.0 in /usr/local/lib/python3.6/dist-packages (from chainercv) (7.4.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (from chainercv) (7.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from chainer>=6.0->chainercv) (50.3.2)
# Requirement already satisfied: protobuf>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from chainer>=6.0->chainercv) (3.12.4)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from chainer>=6.0->chainercv) (1.18.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/dist-packages (from chainer>=6.0->chainercv) (3.0.12)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from chainer>=6.0->chainercv) (1.15.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from chainer>=6.0->chainercv) (3.7.4.3)

# %%
# This colorize_mask class takes in a numpy segmentation mask,
#  and then converts it to a PIL Image for visualization.
#  Since by default the numpy matrix contains integers from
#  0,1,...,num_classes, we need to apply some color to this
#  so we can visualize easier! Refer to:
#  https://pillow.readthedocs.io/en/4.1.x/reference/Image.html#PIL.Image.Image.putpalette
palette = [0, 0, 0, 128, 0, 0, 0, 128, 0, 128, 128, 0, 0, 0, 128, 128, 0, 128, 0, 128, 128,
           128, 128, 128, 64, 0, 0, 192, 0, 0, 64, 128, 0, 192, 128, 0, 64, 0, 128, 192, 0, 128,
           64, 128, 128, 192, 128, 128, 0, 64, 0, 128, 64, 0, 0, 192, 0, 128, 192, 0, 0, 64, 128]

def colorize_mask(mask):
    new_mask = Image.fromarray(mask.astype(np.uint8)).convert('P')
    new_mask.putpalette(palette)

    return new_mask

# %%
# Below we will use a sample image-target pair from VOC training dataset to test your joint transforms. 
# Running this block will automatically download the PASCAL VOC Dataset (3.7GB) to DATASET_PATH if "download = True".
# The code below creates subdirectory "datasets" in the same location as the notebook file, but
# you can modify DATASET_PATH to download the dataset to any custom directory. Download takes a few minutes.
# On subsequent runs you may save time by setting "download = False" (the default value of this flag)

# We provide our own implementation of torchvision.datasets.voc (containing popular "Pascal" dataset)
# that allows us to easily create single-image datasets
from lib.voc import VOCSegmentation

# Reading the dataset directly from my mounted google drive since VOC link broken
DATASET_PATH = 'drive/My Drive/cs484/dataset'

# Here, we obtain and visualize one sample (img, target) pair from VOC training dataset and one from validation dataset. 
# Note that operator [...] extracts the sample corresponding to the specified index. 
# Also, note the parameter download = True. Set this to False after you download to save time on later runs.
sample1 = VOCSegmentation(DATASET_PATH, image_set='train', download = False)[200]
sample2 = VOCSegmentation(DATASET_PATH, image_set='val')[20]

# We demonstrate two different (equivalent) ways to access image and target inside the samples.
img1, target1 = sample1
img2 = sample2[0]
target2 = sample2[1]

fig = plt.figure(figsize=(14,10))
ax1 = fig.add_subplot(2,2,1)
plt.title('sample1 - image')
ax1.imshow(img1)
ax2 = fig.add_subplot(2,2,2)
plt.title('sample1 - target')
ax2.imshow(target1)
ax3 = fig.add_subplot(2,2,3)
plt.title('sample2 - image')
ax3.imshow(img2)
ax4 = fig.add_subplot(2,2,4)
plt.title('sample2 - target')
ax4.imshow(target2)
# Out:
# VOC Root: drive/My Drive/cs484/dataset
# VOC Root: drive/My Drive/cs484/dataset

# %%
some_img = VOCSegmentation(DATASET_PATH, image_set='train', download = False)[300]
fig = plt.figure(figsize=(14,10))
ax1 = fig.add_subplot(1,2,1)
plt.title('sample1 - image')
ax1.imshow(some_img[0])
ax2 = fig.add_subplot(1,2,2)
plt.title('sample1 - target')
ax2.imshow(some_img[1])
# Out:
# VOC Root: drive/My Drive/cs484/dataset

# %% [markdown]
# # Problem 1
#
# #### Implement a set of "Joint Transform" functions to perform data augmentation in your dataset.
#
# Neural networks are typically applied to transformed images. There are several important reasons for this:
#
# 1. The image data should is in certain required format (i.e. consistent spacial resolution to batch). The images should also be normalized and converted to the "tensor" data format expected by pytorch libraries.
#
# 2. Some transforms are used to perform randomized image domain transformations with the purpose of "data augmentation".
#
# In this exercise, you will implement a set of different transform functions to do both of these things. Note that unlike classification nets, training semantic segmentation networks requires that some of the transforms are applied to both image and the corresponding "target" (Ground Truth segmentation mask). We refer to such transforms and their compositions as "Joint". In general, your Transform classes should take as the input both the image and the target, and return a tuple of the transformed input image and target. Be sure to use critical thinking to determine if you can apply the same transform function to both the input and the output.
#
# For this problem you may use any of the `torchvision.transforms.functional` functions. For inspiration, refer to:
# #### https://pytorch.org/tutorials/beginner/data_loading_tutorial.html
# #### https://pytorch.org/docs/stable/torchvision/transforms.html#module-torchvision.transforms.functional

# %% [markdown]
# #### Example 1
#
# This class takes a img, target pair, and then transform the pair such that they are in `Torch.Tensor()` format.
#
# #### Solution:

# %%
class JointToTensor(object):
    def __call__(self, img, target):
        # print(target.max())
        return tF.to_tensor(img), torch.from_numpy(np.array(target.convert('P'), dtype=np.int32)).long()

# %%
# Check the transform by passing the image-target sample.

img, target = JointToTensor()(*sample2)
print(target[target!=255].max())
fig = plt.figure(figsize=(12,6))
ax1 = fig.add_subplot(2,2,1)
ax1.imshow(img.permute(1,2,0))
ax2 = fig.add_subplot(2,2,2)
ax2.imshow(colorize_mask(target.numpy()))
# Out:
# tensor(17)

# %% [markdown]
# #### Example 2:
#
# This class implements CenterCrop that takes an img, target pair, and then apply a crop about the center of the image such that the output resolution is $\mbox{size} \times \mbox{size}$.
#
# #### Solution:

# %%
class JointCenterCrop(object):
    def __init__(self, size):
        """
        params:
            size (int) : size of the center crop
        """
        self.size = size
        
    def __call__(self, img, target):
        return (tF.five_crop(img, self.size)[4], 
                tF.five_crop(target, self.size)[4])
    
img, target = JointCenterCrop(100)(*sample1)
fig = plt.figure(figsize=(12,6))
ax1 = fig.add_subplot(2,2,1)
ax1.imshow(img)
ax2 = fig.add_subplot(2,2,2)
ax2.imshow(target)

# %% [markdown]
# #### (a) Implement RandomFlip
#
# This class should take a img, target pair and then apply a horizontal flip across the vertical axis at random.
#
# #### Solution:

# %%
class JointRandomFlip(object): 
    def __call__(self, img, target):
        if not isinstance(img, torch.Tensor):
            img, target = JointToTensor()(img, target)

        if np.random.randint(2):
            return (tF.hflip(img), tF.hflip(target))
        else:
            return (img, target)

# %%
img, target = JointRandomFlip()(*sample2)
print(target[target!=255].max())
fig = plt.figure(figsize=(12,6))
ax1 = fig.add_subplot(2,2,1)
ax1.imshow(img.permute(1,2,0))
ax2 = fig.add_subplot(2,2,2)
ax2.imshow(colorize_mask(target.numpy()))
# Out:
# tensor(17)

# %% [markdown]
# #### (b) Implement RandomResizeCrop
#
# This class should take a img, target pair and then resize the images by a random scale between $[\mbox{minimum_scale}, \mbox{maximum_scale}]$, crop a random location of the image by $\min(\mbox{size}, \mbox{image_height}, \mbox{image_width})$ (where the size is passed in as an integer in the constructor), and then resize to $\mbox{size} \times \mbox{size}$ (again, the size passed in). The crop box should fit within the image.
#
# #### Solution:

# %%
class JointRandomResizeCrop(object):
    def __init__(self, min_scale, max_scale, size):
        self.min_scale = min_scale
        self.max_scale = max_scale
        if isinstance(size, tuple):
            self.size = size
        else:
            self.size = (size,size)

        self.scale_len = self.max_scale - self.min_scale

    def __call__(self, img, target):
        if not isinstance(img, PIL.Image.Image):
            target = transforms.ToPILImage()(target.type(torch.IntTensor))
            img = transforms.ToPILImage()(img)

        # Select Random Resize Scale
        scale = (np.random.rand() * (self.scale_len)) + self.min_scale
        rescaled_size = (int(img.size[0]*scale), int(img.size[1]*scale))
        rescaled_img = tF.resize(img, rescaled_size[::-1])
        rescaled_target = tF.resize(target, rescaled_size[::-1], interpolation=PIL.Image.NEAREST)

        # Crop Then Resize
        crop_size = min((self.size[0],self.size[1], rescaled_img.size[0]-1, rescaled_img.size[1]-1))
        crop_c = np.random.randint(0, rescaled_img.size[0] - crop_size)
        crop_r = np.random.randint(0, rescaled_img.size[1] - crop_size)

        final_img = tF.resized_crop(rescaled_img, crop_r, crop_c, crop_size, crop_size, size=self.size)
        final_target= tF.resized_crop(rescaled_target, crop_r, crop_c, crop_size, crop_size, size=self.size, interpolation=PIL.Image.NEAREST)

        final_img, final_target = JointToTensor()(final_img, final_target)
        return final_img, final_target.type(torch.LongTensor)

# %%
# print(sample1[0].size)
final_img, final_target = JointRandomResizeCrop(0.5, 1.5, 256)(*JointToTensor()(*sample2))
print(final_target[final_target!=255].max())
print(final_img.size())
fig = plt.figure(figsize=(12,6))
ax1 = fig.add_subplot(2,2,1)
# ax1.imshow(colorize_mask(target.numpy()))
ax1.imshow(final_img.permute(1,2,0))
ax2 = fig.add_subplot(2,2,2)
ax2.imshow(colorize_mask(final_target.numpy()))
# plt.show()
# Out:
# tensor(17)
# torch.Size([3, 256, 256])

# %% [markdown]
# #### (c) Implement Normalize

# %% [markdown]
# This class should take a img, target pair and then normalize the images by subtracting the mean and dividing variance.
#
# #### Solution:

# %%
class JointResize(object):
    def __init__(self, size):
        self.size = size
    
    def __call__(self, img, target):
        if not isinstance(img, torch.Tensor):
            img, target = JointToTensor()(img, target)

        img = tF.resize(img[None], self.size)[0]
        target = tF.resize(target[None], size=self.size, interpolation=PIL.Image.NEAREST)[0]

        return img, target

# %%
norm = ([0.485, 0.456, 0.406], 
        [0.229, 0.224, 0.225]) 


class JointNormalize(object): 
    def __init__(self, mean, std):
        self.mean = mean
        self.std = std
          
    def __call__(self, img, target):
        if not isinstance(img, torch.Tensor):
            img, target = JointToTensor()(img, target)

        # Normalize
        norm_img = tF.normalize(img, self.mean, self.std)
        # Rescale to 0-1
        norm_img -= norm_img.min()
        norm_img /= norm_img.max()

        return norm_img, target

# %%
fixed_img, fixed_target = JointResize((375,500))(*sample2)
print(fixed_target[fixed_target!=255].max())
fig = plt.figure(figsize=(12,6))
ax1 = fig.add_subplot(2,2,1)
ax1.imshow(fixed_img.permute(1,2,0))
ax2 = fig.add_subplot(2,2,2)
ax2.imshow(colorize_mask(fixed_target.numpy()))
# Out:
# tensor(17)

# %% [markdown]
# #### (d) Compose the transforms together:
# ##### Use `JointCompose` (fully implemeted below) to compose the implemented transforms together in some random order. Verify the output makes sense and visualize it.

# %%
# This class composes transofrmations from a given list of image transforms (expected in the argument). Such compositions 
# will be applied to the dataset during training. This cell is fully implemented.

class JointCompose(object):
    def __init__(self, transforms):
        """
        params: 
           transforms (list) : list of transforms
        """
        self.transforms = transforms

    # We override the __call__ function such that this class can be
    # called as a function i.e. JointCompose(transforms)(img, target)
    # Such classes are known as "functors"
    def __call__(self, img, target):
        """
        params:
            img (PIL.Image)    : input image
            target (PIL.Image) : ground truth label 
        """
        assert img.size == target.size
        for t in self.transforms:
            img, target = t(img, target)
        return img, target

# %%
# Student Answer:
tfs = [JointToTensor(), JointRandomResizeCrop(0.5, 0.8, 100), JointRandomFlip()]

img, target = JointCompose(tfs)(*sample1)
print(img.size)
fig = plt.figure(figsize=(12,6))
ax1 = fig.add_subplot(2,2,1)
ax1.imshow(img.permute(1,2,0))
ax2 = fig.add_subplot(2,2,2)
ax2.imshow(colorize_mask(target.numpy()))
# Out:
# <built-in method size of Tensor object at 0x7fa61d0892d0>

# %% [markdown]
# #### (e) Compose the transforms together: use `JointCompose` to compose the implemented transforms for:
# #### 1. A sanity dataset that will contain 1 single image. Your objective is to overfit on this 1 image, so choose your transforms and parameters accordingly.
# #### 2. A training dataset that will contain the training images. The goal here is to generalize to the validation set, which is unseen.
# #### 3. A validation dataset that will contain the validation images. The goal here is to measure the 'true' performance.

# %%
# Student Answer:

sanity_joint_transform  = JointCompose([JointNormalize(*norm), JointResize((375,500))])

train_joint_transform   = JointCompose([JointNormalize(*norm), JointRandomFlip(), JointResize((375,500))])#JointRandomResizeCrop(0.5, 1.5, (375,500))])

val_joint_transform     = JointCompose([JointRandomFlip(), JointResize((375,500))])

# %% [markdown]
# This code below will then apply `train_joint_transform` to the entire dataset.

# %%
# Apply the Joint-Compose transformations above to create three datasets and the corresponding Data-Loaders.
# This cell is fully implemented.

# This single image data(sub)set can help to better understand and to debug the network training process. 
# Optional integer parameter 'sanity_check' specifies the index of the image-target pair and creates a single image dataset.
# Note that we use the same image (index=200) as used for sample1.
sanity_data = VOCSegmentation(
    DATASET_PATH, 
    image_set = 'train',
    transforms = sanity_joint_transform,
    sanity_check = 200
)

# This is a standard VOC data(sub)set used for training semantic segmentation networks
train_data = VOCSegmentation(
    DATASET_PATH, 
    image_set = 'train', 
    transforms = train_joint_transform,
)

# This is a standard VOC data(sub)set used for validating semantic segmentation networks
val_data = VOCSegmentation(
    DATASET_PATH, 
    image_set='val',
    transforms = val_joint_transform
)

# Increase TRAIN_BATCH_SIZE if you are using GPU to speed up training. 
# When batch size changes, the learning rate may also need to be adjusted. 
# Note that batch size maybe limited by your GPU memory, so adjust if you get "run out of GPU memory" error.
TRAIN_BATCH_SIZE = 32 # 1 default

# If you are NOT using Windows, set NUM_WORKERS to anything you want, e.g. NUM_WORKERS = 4,
# but Windows has issues with multi-process dataloaders, so NUM_WORKERS must be 0 for Windows.
NUM_WORKERS =  4 # default

sanity_loader = DataLoader(sanity_data, batch_size=1, num_workers=NUM_WORKERS, shuffle=False)
train_loader = DataLoader(train_data, batch_size=TRAIN_BATCH_SIZE, num_workers=NUM_WORKERS, shuffle=True)
val_loader = DataLoader(val_data, batch_size=1, num_workers=NUM_WORKERS, shuffle=False)
# Out:
# VOC Root: drive/My Drive/cs484/dataset
# VOC Root: drive/My Drive/cs484/dataset
# VOC Root: drive/My Drive/cs484/dataset

# %% [markdown]
# # Problem 2
#
# #### (a) Implement encoder/decoder segmentation CNN using PyTorch.
#
# You must follow the general network architecture specified in the image below. Note that since convolutional layers are the main building blocks in common network architectures for image analysis, the corresponding blocks are typically unlabeled in the network diagrams. The network should have 5 (pre-trained) convolutional layers (residual blocks) from "resnet" in the encoder part, two upsampling layers, and one skip connection. For the layer before the final upsampling layer, lightly experiment with some combination of Conv, ReLU, BatchNorm, and/or other layers to see how it affects performance.
#
# #### The image was removed so the Colab Latex PDF print would work
#
# You should choose specific parameters for all layers, but the overall structure should be restricted to what is shown in the illustration above. For inspiration, you can refer to papers in the citation section of the following link to DeepLab (e.g. specific parameters for each layer): http://liangchiehchen.com/projects/DeepLab.html. The first two papers in the citation section are particularly relevant.
#
# In your implementation, you can use a base model of choice (you can use `torchvision.models` as a starting point), but we suggest that you learn the properties of each base model and choose one according to the computational resources available to you.
#
# ##### Note: do not apply any post-processing (such as DenseCRF) to the output of your net.
#
# #### Solution:

# %%
import torchvision.models as models

class MyNet(nn.Module):
    def __init__(self, num_classes, img_size, criterion=None):
        super(MyNet, self).__init__()
        # Implement me

        # Get initial few layers + 6 res blocks in packs of 2
        self.encoder1 = nn.Sequential(*list(models.resnet18(pretrained=True).children())[:5])
        self.encoder2 = nn.Sequential(*list(models.resnet18(pretrained=True).children())[5:7])

        self.up1 = nn.ConvTranspose2d(256, 256, kernel_size=(7,8), stride=(3,3), dilation=(5,5), padding=(3,2))
        self.relu = nn.ReLU()

        self.conv1 = nn.Conv2d(320,256,kernel_size=3,stride=2,dilation=2)
        self.conv2 = nn.Conv2d(256,128,kernel_size=3,stride=2,dilation=2)
        self.up2 = nn.ConvTranspose2d(128, 64, kernel_size=7,stride=3,dilation=3,padding=2)
        self.bn1 = nn.BatchNorm2d(128)
        self.bn2 = nn.BatchNorm2d(64)

        self.conv3 = nn.Conv2d(64,num_classes, kernel_size=4,stride=2,dilation=2)
        self.final_up = nn.Upsample(size=img_size, mode='bilinear', align_corners=True)

    def forward(self, inp, gts=None):

        # Assuming using GPU on colab

        ## Encoder
        x = self.encoder1(inp) # batch x 64 x 94 x 125
        skip = x
        x = self.encoder2(x) # batch x 256 x 24 x 32

        ## Decoder Step 1
        x = self.up1(x) # batch x 256 x 94 x 125
        x = torch.cat((x, skip), dim=1) # Skip Connection; batch x 320 x 94 x 125
        x = self.relu(self.conv1(x)) # batch x 256 x 91 x 122
        x = self.relu(self.conv2(x)) # batch x 128 x 88 x 119
        x = self.bn1(x)

        ## Decoder Step 2
        x = self.up2(x) # Transpose conv, 64 channels now
        x = self.bn2(x)
        x = self.relu(self.conv3(x)) # 21 channels

        ## Final Decoder Step
        lfinal = self.final_up(x) # batch x 21 x 375 x 500

        return lfinal

# %%
# list(models.resnet18(pretrained=True).children())[:5]

# %% [markdown]
# #### (b) Create UNTRAINED_NET and run on a sample image

# %%
print(torch.cuda.get_device_name())

untrained_net = MyNet(21, (375,500)).eval()
sample_img, sample_target = sanity_joint_transform(*sample1)
untrained_output = untrained_net.forward(sample_img[None])

# Convert to 375 x 500 image of int classes
sample_output = torch.argmax(untrained_output, dim=1).numpy()

fig = plt.figure(figsize=(14,10))
ax = fig.add_subplot(1,3,1)
plt.title('image sample')
ax.imshow(sample1[0])
ax = fig.add_subplot(1,3,2)
plt.title('ground truth (target)')
ax.imshow(sample1[1])
ax = fig.add_subplot(1,3,3)
plt.title('UNTRAINED_NET output/prediction')
print(untrained_output.size())
ax.imshow(colorize_mask(sample_output[0]))
# Out:
# Tesla K80
# torch.Size([1, 21, 375, 500])

# %% [markdown]
# # Problem 3
#
# #### (a) Implement the loss function (Cross Entropy Loss). Do not use already implemented versions of this loss function.
#
# Feel free to use functions like `F.log_softmax` and `F.nll_loss` (if you want to, or you can just implement the math).

# %%
# Student Answer:

class MyCrossEntropyLoss(object):
    def __init__(self, ignore_index):
        self.ignore = ignore_index
    
    def __call__(self, output, mask):
        return F.nll_loss(F.log_softmax(output, 1), mask, ignore_index=self.ignore)

# %% [markdown]
# #### (b) Compare against the existing CrossEntropyLoss function on your sample output from your neural network.

# %%
criterion = nn.CrossEntropyLoss(ignore_index=255)
print(criterion)
print(sample_target[None].size())
print(untrained_output[0].size())
print(sample_target.size())
print(criterion(untrained_output, sample_target[None]))

my_criterion = MyCrossEntropyLoss(ignore_index=255)

print(my_criterion(untrained_output, sample_target[None]))
# Out:
# CrossEntropyLoss()
# torch.Size([1, 375, 500])
# torch.Size([21, 375, 500])
# torch.Size([375, 500])
# tensor(3.0550, grad_fn=<NllLoss2DBackward>)
# tensor(3.0550, grad_fn=<NllLoss2DBackward>)

# %% [markdown]
# # Problem 4
#
# #### (a) Use standard function `eval_semantic_segmentation` (already imported from chainerCV) to compute "mean intersection over union" for the output of UNTRAINED_NET on sample1 (`untrained_output`) using the target for sample1. Read documentations for function  `eval_semantic_segmentation` to properly set its input parameters.

# %%
# Write code to propely compute 'pred' and 'gts' as arguments for function 'eval_semantic_segemntation'

np_target = sample_target.numpy().astype(np.int32)
np_target[np_target==255] = -1
initial_gts = np.array([np_target])

initial_pred = sample_output
print(initial_pred.shape)
initial_conf = eval_semantic_segmentation(initial_pred, initial_gts)

print("mIoU for the sample image / ground truth pair: {}".format(initial_conf['miou']))
# Out:
# (1, 375, 500)
# mIoU for the sample image / ground truth pair: 0.0
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:91: RuntimeWarning: invalid value encountered in true_divide
#   iou = np.diag(confusion) / iou_denominator
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:168: RuntimeWarning: invalid value encountered in true_divide
#   class_accuracy = np.diag(confusion) / np.sum(confusion, axis=1)

# %% [markdown]
# #### (b) Write the validation loop.

# %%
def validate(val_data_loader, net):
    iou_arr = []
    val_loss = []
    
    with torch.no_grad():
        for i, data in enumerate(val_data_loader):
            # print("Tick: {}".format(i))
            inputs, masks = data

            if USE_GPU:
                net = net.cuda()
                masks = masks.cuda()
                inputs = inputs.cuda()

            outputs = net(inputs)

            np_target = masks[0].cpu().numpy().astype(np.int32)
            np_target[np_target == 255] = -1

            gts = np.array([np_target])
            preds = torch.argmax(outputs, dim=1).cpu().numpy()

            val_loss.append(criterion(outputs, masks))
            conf = eval_semantic_segmentation(preds, gts)

            iou_arr.append(conf['miou'])
    
    return val_loss, (sum(iou_arr) / len(iou_arr))

# %% [markdown]
# #### (c) Run the validation loop for UNTRAINED_NET against the sanity validation dataset.

# %%
# %%time
print("mIoU over the sanity dataset:{}".format(validate(sanity_loader, untrained_net)[1]))
# Out:
# mIoU over the sanity dataset:0.0
# CPU times: user 1.71 s, sys: 909 ms, total: 2.62 s
# Wall time: 2.69 s
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:91: RuntimeWarning: invalid value encountered in true_divide
#   iou = np.diag(confusion) / iou_denominator
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:168: RuntimeWarning: invalid value encountered in true_divide
#   class_accuracy = np.diag(confusion) / np.sum(confusion, axis=1)

# %% [markdown]
# # Problem 5
#
# #### (a) Define an optimizer to train the given loss function.
#
# Feel free to choose your optimizer of choice from https://pytorch.org/docs/stable/optim.html.

# %%
def get_optimizer(net):
    optimizer = optim.Adam(net.parameters(), lr=1e-3)
    return optimizer

# %% [markdown]
# #### (b) Write the training loop to train the network.

# %%
import time

def train(train_data_loader, net, optimizer, loss_graph):
    for i, data in enumerate(train_data_loader):
        inputs, masks = data
    
        if USE_GPU:
            net = net.cuda()
            inputs = inputs.cuda()
            masks = masks.cuda()
        
        # Write me
        outputs = net(inputs)
        loss = net.criterion(outputs, masks)
        print("Training: On Tick: {} loss {}".format(i, loss))
        loss_graph.append(loss.item())

        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
    
    return (sum(loss_graph) / len(loss_graph))

# %% [markdown]
# #### (c) Create OVERFIT_NET and train it on the single image dataset.
# ##### Single image training is helpful for debugging and hyper-parameter tuning (e.g. learning rate, etc.) as it is fast even on a single CPU. In particular, you can work with a single image until your loss function is consistently decreasing during training loop and the network starts producing a reasonable output for this training image. Training on a single image also teaches about overfitting, particualrly when comparing it with more thorough forms of network training.

# %%
# %%time
# %matplotlib notebook
import time

# The whole training on a single image (20-40 epochs) should take only a minute or two on a CPU (and a few seconds on GPU). 
# Below we create a (deep) copy of untrained_net and train it on a single training image (leading to gross overfitting).
# Later, we will create a separate (deep) copy of untrained_net to be trained on full training dataset.
# NOTE: Normally, one can create a new net via declaration new_net = MyNet(21). But, randomization of weights when new nets 
# are declared that way creates *different* untrained nets. This notebook compares different versions of network training. 
# For this comparison to be direct and fair, it is better to train (deep) copies of the exact same untrained_net. 
overfit_net = copy.deepcopy(untrained_net)

# set loss function for the net
overfit_net.criterion = nn.CrossEntropyLoss(ignore_index=255)

# You can change the number of EPOCHS
EPOCH = 100

# switch to train mode (original untrained_net was set to eval mode)
overfit_net.train()

optimizer = get_optimizer(overfit_net)

print("Starting Training...")

loss_graph = []

# fig = plt.figure(figsize=(12,6))
# plt.subplots_adjust(bottom=0.2,right=0.85,top=0.95)
# ax = fig.add_subplot(1,1,1)

for e in range(EPOCH):
    new_loss_graph = []
    loss = train(sanity_loader, overfit_net, optimizer, new_loss_graph)
    loss_graph += new_loss_graph
    # ax.clear()
    # ax.set_xlabel('iterations')
    # ax.set_ylabel('loss value')
    # ax.set_title('Training loss curve for OVERFIT_NET')
    # ax.plot(loss_graph, label='training loss')
    # ax.legend(loc='upper right')
    # fig.canvas.draw()
    print("Epoch: {} Loss: {}".format(e, loss))
print("Final Loss: {}".format(loss))
# %matplotlib inline
# Out:
# Starting Training...
# Training: On Tick: 0 loss 3.0810275077819824
# Epoch: 0 Loss: 3.0810275077819824
# Training: On Tick: 0 loss 2.489602565765381
# Epoch: 1 Loss: 2.489602565765381
# Training: On Tick: 0 loss 1.9219743013381958
# Epoch: 2 Loss: 1.9219743013381958
# Training: On Tick: 0 loss 1.2977207899093628
# Epoch: 3 Loss: 1.2977207899093628
# Training: On Tick: 0 loss 0.970544159412384
# Epoch: 4 Loss: 0.970544159412384
# Training: On Tick: 0 loss 0.6685242056846619
# Epoch: 5 Loss: 0.6685242056846619
# Training: On Tick: 0 loss 0.5007609128952026
# Epoch: 6 Loss: 0.5007609128952026
# Training: On Tick: 0 loss 0.3607073426246643
# Epoch: 7 Loss: 0.3607073426246643
# Training: On Tick: 0 loss 0.2871873378753662
# Epoch: 8 Loss: 0.2871873378753662
# Training: On Tick: 0 loss 0.22709381580352783
# Epoch: 9 Loss: 0.22709381580352783
# Training: On Tick: 0 loss 0.1799343079328537
# Epoch: 10 Loss: 0.1799343079328537
# Training: On Tick: 0 loss 0.14979790151119232
# Epoch: 11 Loss: 0.14979790151119232
# Training: On Tick: 0 loss 0.12386900931596756
# Epoch: 12 Loss: 0.12386900931596756
# Training: On Tick: 0 loss 0.10746723413467407
# Epoch: 13 Loss: 0.10746723413467407
# Training: On Tick: 0 loss 0.09260597079992294
# Epoch: 14 Loss: 0.09260597079992294
# Training: On Tick: 0 loss 0.07678399235010147
# Epoch: 15 Loss: 0.07678399235010147
# Training: On Tick: 0 loss 0.060459379106760025
# Epoch: 16 Loss: 0.060459379106760025
# Training: On Tick: 0 loss 0.049396075308322906
# Epoch: 17 Loss: 0.049396075308322906
# Training: On Tick: 0 loss 0.044090211391448975
# Epoch: 18 Loss: 0.044090211391448975
# Training: On Tick: 0 loss 0.04109949618577957
# Epoch: 19 Loss: 0.04109949618577957
# Training: On Tick: 0 loss 0.03811613842844963
# Epoch: 20 Loss: 0.03811613842844963
# Training: On Tick: 0 loss 0.03296477347612381
# Epoch: 21 Loss: 0.03296477347612381
# Training: On Tick: 0 loss 0.028895873576402664
# Epoch: 22 Loss: 0.028895873576402664
# Training: On Tick: 0 loss 0.026745446026325226
# Epoch: 23 Loss: 0.026745446026325226
# Training: On Tick: 0 loss 0.02523897960782051
# Epoch: 24 Loss: 0.02523897960782051
# Training: On Tick: 0 loss 0.023746894672513008
# Epoch: 25 Loss: 0.023746894672513008
# Training: On Tick: 0 loss 0.022043365985155106
# Epoch: 26 Loss: 0.022043365985155106
# Training: On Tick: 0 loss 0.020315034314990044
# Epoch: 27 Loss: 0.020315034314990044
# Training: On Tick: 0 loss 0.018900960683822632
# Epoch: 28 Loss: 0.018900960683822632
# Training: On Tick: 0 loss 0.017632082104682922
# Epoch: 29 Loss: 0.017632082104682922
# Training: On Tick: 0 loss 0.01683308742940426
# Epoch: 30 Loss: 0.01683308742940426
# Training: On Tick: 0 loss 0.015929145738482475
# Epoch: 31 Loss: 0.015929145738482475
# Training: On Tick: 0 loss 0.014799379743635654
# Epoch: 32 Loss: 0.014799379743635654
# Training: On Tick: 0 loss 0.013982579112052917
# Epoch: 33 Loss: 0.013982579112052917
# Training: On Tick: 0 loss 0.013376709073781967
# Epoch: 34 Loss: 0.013376709073781967
# Training: On Tick: 0 loss 0.01287738885730505
# Epoch: 35 Loss: 0.01287738885730505
# Training: On Tick: 0 loss 0.012459037825465202
# Epoch: 36 Loss: 0.012459037825465202
# Training: On Tick: 0 loss 0.011923972517251968
# Epoch: 37 Loss: 0.011923972517251968
# Training: On Tick: 0 loss 0.01132697332650423
# Epoch: 38 Loss: 0.01132697332650423
# Training: On Tick: 0 loss 0.010782401077449322
# Epoch: 39 Loss: 0.010782401077449322
# Training: On Tick: 0 loss 0.010279513895511627
# Epoch: 40 Loss: 0.010279513895511627
# Training: On Tick: 0 loss 0.00987350195646286
# Epoch: 41 Loss: 0.00987350195646286
# Training: On Tick: 0 loss 0.009572278708219528
# Epoch: 42 Loss: 0.009572278708219528
# Training: On Tick: 0 loss 0.009235014207661152
# Epoch: 43 Loss: 0.009235014207661152
# Training: On Tick: 0 loss 0.008858272805809975
# Epoch: 44 Loss: 0.008858272805809975
# Training: On Tick: 0 loss 0.008525055833160877
# Epoch: 45 Loss: 0.008525055833160877
# Training: On Tick: 0 loss 0.008209228515625
# Epoch: 46 Loss: 0.008209228515625
# Training: On Tick: 0 loss 0.00791463628411293
# Epoch: 47 Loss: 0.00791463628411293
# Training: On Tick: 0 loss 0.007688669487833977
# Epoch: 48 Loss: 0.007688669487833977
# Training: On Tick: 0 loss 0.007489106617867947
# Epoch: 49 Loss: 0.007489106617867947
# Training: On Tick: 0 loss 0.007264259736984968
# Epoch: 50 Loss: 0.007264259736984968
# Training: On Tick: 0 loss 0.00703914649784565
# Epoch: 51 Loss: 0.00703914649784565
# Training: On Tick: 0 loss 0.006825963966548443
# Epoch: 52 Loss: 0.006825963966548443
# Training: On Tick: 0 loss 0.006620754487812519
# Epoch: 53 Loss: 0.006620754487812519
# Training: On Tick: 0 loss 0.006434231530874968
# Epoch: 54 Loss: 0.006434231530874968
# Training: On Tick: 0 loss 0.006263215560466051
# Epoch: 55 Loss: 0.006263215560466051
# Training: On Tick: 0 loss 0.006094519980251789
# Epoch: 56 Loss: 0.006094519980251789
# Training: On Tick: 0 loss 0.0059303538873791695
# Epoch: 57 Loss: 0.0059303538873791695
# Training: On Tick: 0 loss 0.0057739075273275375
# Epoch: 58 Loss: 0.0057739075273275375
# Training: On Tick: 0 loss 0.005621648859232664
# Epoch: 59 Loss: 0.005621648859232664
# Training: On Tick: 0 loss 0.005478545557707548
# Epoch: 60 Loss: 0.005478545557707548
# Training: On Tick: 0 loss 0.005350908264517784
# Epoch: 61 Loss: 0.005350908264517784
# Training: On Tick: 0 loss 0.005229006987065077
# Epoch: 62 Loss: 0.005229006987065077
# Training: On Tick: 0 loss 0.00510465307161212
# Epoch: 63 Loss: 0.00510465307161212
# Training: On Tick: 0 loss 0.004984245169907808
# Epoch: 64 Loss: 0.004984245169907808
# Training: On Tick: 0 loss 0.004870133008807898
# Epoch: 65 Loss: 0.004870133008807898
# Training: On Tick: 0 loss 0.0047592055052518845
# Epoch: 66 Loss: 0.0047592055052518845
# Training: On Tick: 0 loss 0.0046553704887628555
# Epoch: 67 Loss: 0.0046553704887628555
# Training: On Tick: 0 loss 0.004559331573545933
# Epoch: 68 Loss: 0.004559331573545933
# Training: On Tick: 0 loss 0.004466520622372627
# Epoch: 69 Loss: 0.004466520622372627
# Training: On Tick: 0 loss 0.004374060779809952
# Epoch: 70 Loss: 0.004374060779809952
# Training: On Tick: 0 loss 0.004285798408091068
# Epoch: 71 Loss: 0.004285798408091068
# Training: On Tick: 0 loss 0.004202560056000948
# Epoch: 72 Loss: 0.004202560056000948
# Training: On Tick: 0 loss 0.004124388098716736
# Epoch: 73 Loss: 0.004124388098716736
# Training: On Tick: 0 loss 0.004051594529300928
# Epoch: 74 Loss: 0.004051594529300928
# Training: On Tick: 0 loss 0.003980462905019522
# Epoch: 75 Loss: 0.003980462905019522
# Training: On Tick: 0 loss 0.003909446764737368
# Epoch: 76 Loss: 0.003909446764737368
# Training: On Tick: 0 loss 0.003840471850708127
# Epoch: 77 Loss: 0.003840471850708127
# Training: On Tick: 0 loss 0.0037736801896244287
# Epoch: 78 Loss: 0.0037736801896244287
# Training: On Tick: 0 loss 0.0037090955302119255
# Epoch: 79 Loss: 0.0037090955302119255
# Training: On Tick: 0 loss 0.0036480834241956472
# Epoch: 80 Loss: 0.0036480834241956472
# Training: On Tick: 0 loss 0.003589641535654664
# Epoch: 81 Loss: 0.003589641535654664
# Training: On Tick: 0 loss 0.0035331756807863712
# Epoch: 82 Loss: 0.0035331756807863712
# Training: On Tick: 0 loss 0.0034791494254022837
# Epoch: 83 Loss: 0.0034791494254022837
# Training: On Tick: 0 loss 0.0034266833681613207
# Epoch: 84 Loss: 0.0034266833681613207
# Training: On Tick: 0 loss 0.003375080181285739
# Epoch: 85 Loss: 0.003375080181285739
# Training: On Tick: 0 loss 0.003325708908960223
# Epoch: 86 Loss: 0.003325708908960223
# Training: On Tick: 0 loss 0.0032789353281259537
# Epoch: 87 Loss: 0.0032789353281259537
# Training: On Tick: 0 loss 0.003233620198443532
# Epoch: 88 Loss: 0.003233620198443532
# Training: On Tick: 0 loss 0.0031892454717308283
# Epoch: 89 Loss: 0.0031892454717308283
# Training: On Tick: 0 loss 0.003146165981888771
# Epoch: 90 Loss: 0.003146165981888771
# Training: On Tick: 0 loss 0.003104124218225479
# Epoch: 91 Loss: 0.003104124218225479
# Training: On Tick: 0 loss 0.003062792355194688
# Epoch: 92 Loss: 0.003062792355194688
# Training: On Tick: 0 loss 0.003022723598405719
# Epoch: 93 Loss: 0.003022723598405719
# Training: On Tick: 0 loss 0.0029840413480997086
# Epoch: 94 Loss: 0.0029840413480997086
# Training: On Tick: 0 loss 0.002946325344964862
# Epoch: 95 Loss: 0.002946325344964862
# Training: On Tick: 0 loss 0.002909470582380891
# Epoch: 96 Loss: 0.002909470582380891
# Training: On Tick: 0 loss 0.0028735569212585688
# Epoch: 97 Loss: 0.0028735569212585688
# Training: On Tick: 0 loss 0.002838506130501628
# Epoch: 98 Loss: 0.002838506130501628
# Training: On Tick: 0 loss 0.002804303541779518
# Epoch: 99 Loss: 0.002804303541779518
# Final Loss: 0.002804303541779518
# CPU times: user 5.9 s, sys: 12.4 s, total: 18.3 s
# Wall time: 29.2 s

# %% [markdown]
# #### Qualitative and quantitative evaluation of predictions (untrained vs overfit nets) - fully implemented.

# %%
# switch back to evaluation mode
overfit_net.eval()

sample_img, sample_target = sanity_joint_transform(*sample1)
if USE_GPU:
    sample_img = sample_img.cuda()
sample_output_O = overfit_net.forward(sample_img[None])
sample_output_U = untrained_net.forward(sample_img[None])

# computing mIOU (quantitative measure of accuracy for network predictions)
if USE_GPU:
    pred_O = torch.argmax(sample_output_O, dim=1).cpu().numpy()[0]
    pred_U = torch.argmax(sample_output_U, dim=1).cpu().numpy()[0]
else:
    pred_O = torch.argmax(sample_output_O, dim=1).numpy()[0]
    pred_U = torch.argmax(sample_output_U, dim=1).numpy()[0]

gts = sample_target.cpu().numpy()
gts[gts == 255] = -1
print(pred_O[None].shape)
conf_O = eval_semantic_segmentation(pred_O[None], gts[None])
conf_U = eval_semantic_segmentation(pred_U[None], gts[None])


fig = plt.figure(figsize=(14,10))
ax1 = fig.add_subplot(2,2,1)
plt.title('image sample')
ax1.imshow(sample1[0])
ax2 = fig.add_subplot(2,2,2)
plt.title('ground truth (target)')
ax2.imshow(sample1[1])
ax3 = fig.add_subplot(2,2,3)
plt.title('UNTRAINED_NET prediction')
ax3.text(10, 25, 'mIoU = {:_>8.6f}'.format(conf_U['miou']), fontsize=20, color='white')
ax3.imshow(colorize_mask(torch.argmax(sample_output_U, dim=1).cpu().numpy()[0]))
ax4 = fig.add_subplot(2,2,4)
plt.title('OVERFIT_NET prediction (for its training image)')
ax4.text(10, 25, 'mIoU = {:_>8.6f}'.format(conf_O['miou']), fontsize=20, color='white')
ax4.imshow(colorize_mask(torch.argmax(sample_output_O, dim=1).cpu().numpy()[0]))
# Out:
# (1, 375, 500)
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:91: RuntimeWarning: invalid value encountered in true_divide
#   iou = np.diag(confusion) / iou_denominator
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:168: RuntimeWarning: invalid value encountered in true_divide
#   class_accuracy = np.diag(confusion) / np.sum(confusion, axis=1)

# %%
# img, target = JointResize((375,500))(*sample2)
sample_img, sample_target = sanity_joint_transform(*sample2)
if USE_GPU:
    sample_img = sample_img.cuda()
sample_output_O = overfit_net.forward(sample_img[None])
sample_output_U = untrained_net.forward(sample_img[None])

# computing mIOU (quantitative measure of accuracy for network predictions)
if USE_GPU:
    pred_O = torch.argmax(sample_output_O, dim=1).cpu().numpy()[0]
    pred_U = torch.argmax(sample_output_U, dim=1).cpu().numpy()[0]
else:
    pred_O = torch.argmax(sample_output_O, dim=1).numpy()[0]
    pred_U = torch.argmax(sample_output_U, dim=1).numpy()[0]

# gts = target.numpy()#torch.from_numpy(np.array(target.convert('P'), dtype=np.int32)).long().numpy()
gts = sample_target.cpu().numpy()
gts[gts == 255] = -1
conf_O = eval_semantic_segmentation(pred_O[None], gts[None])
conf_U = eval_semantic_segmentation(pred_U[None], gts[None])

fig = plt.figure(figsize=(14,10))
ax1 = fig.add_subplot(2,2,1)
plt.title('image sample')
ax1.imshow(sample2[0])
ax2 = fig.add_subplot(2,2,2)
plt.title('ground truth (target)')
ax2.imshow(sample2[1])
ax3 = fig.add_subplot(2,2,3)
plt.title('UNTRAINED_NET prediction')
ax3.text(10, 25, 'mIoU = {:_>8.6f}'.format(conf_U['miou']), fontsize=20, color='white')
ax3.imshow(colorize_mask(torch.argmax(sample_output_U, dim=1).cpu().numpy()[0]))
ax4 = fig.add_subplot(2,2,4)
plt.title('OVERFIT_NET prediction (for image it has not seen)')
ax4.text(10, 25, 'mIoU = {:_>8.6f}'.format(conf_O['miou']), fontsize=20, color='white')
ax4.imshow(colorize_mask(torch.argmax(sample_output_O, dim=1).cpu().numpy()[0]))
# Out:
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:91: RuntimeWarning: invalid value encountered in true_divide
#   iou = np.diag(confusion) / iou_denominator
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:168: RuntimeWarning: invalid value encountered in true_divide
#   class_accuracy = np.diag(confusion) / np.sum(confusion, axis=1)

# %% [markdown]
# #### Run the validation loop for OVERFIT_NET against the sanity dataset (an image it was trained on) - fully implemented

# %%
# %%time
print("mIoU for OVERFIT_NET over its training image:{}".format(validate(sanity_loader, overfit_net)[1]))
# Out:
# mIoU for OVERFIT_NET over its training image:0.9996947213937591
# CPU times: user 34.3 ms, sys: 161 ms, total: 195 ms
# Wall time: 344 ms
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:91: RuntimeWarning: invalid value encountered in true_divide
#   iou = np.diag(confusion) / iou_denominator
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:168: RuntimeWarning: invalid value encountered in true_divide
#   class_accuracy = np.diag(confusion) / np.sum(confusion, axis=1)

# %% [markdown]
# ### WARNING: For the remaining part of the assignment (below) it is advisable to switch to GPU mode as running each validation and training loop on the whole training set takes over an hour on CPU (there are several such loops below). Note that GPU mode is helpful only if you have a sufficiently good NVIDIA gpu (not older than 2-3 years) and cuda installed on your computer. If you do not have a sufficiently good graphics card available, you can still finish the remaining part in CPU mode (takes a few hours), as the cells below are mostly implemented and test your code written and debugged in the earlier parts above. You can also switch to Google Colaboratory to run the remaining parts below.
#
# ### You can use validation-data experiments below to tune your hyper-parameters. Normally, validation data is used exactly for this purpose. For actual competitions, testing data is not public and you can not tune hyper-parameters on in.

# %% [markdown]
# #### (d) Evaluate UNTRAINED_NET and OVERFIT_NET on validation dataset.
# ##### Run the validation loop for UNTRAINED_NET against the validation dataset:

# %%
# %%time
# This will be slow on CPU (around 1 hour or more). On GPU it should take only a few minutes (depending on your GPU).
print("mIoU for UNTRAINED_NET over the entire dataset:{}".format(validate(val_loader, untrained_net)[1]))
# Out:
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:91: RuntimeWarning: invalid value encountered in true_divide
#   iou = np.diag(confusion) / iou_denominator
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:168: RuntimeWarning: invalid value encountered in true_divide
#   class_accuracy = np.diag(confusion) / np.sum(confusion, axis=1)
# mIoU for UNTRAINED_NET over the entire dataset:0.0030736019867348445
# CPU times: user 32.7 s, sys: 7.95 s, total: 40.7 s
# Wall time: 59.4 s

# %% [markdown]
# ##### Run the validation loop for OVERFIT_NET against the validation dataset (it has not seen):

# %%
# %%time
# This will be slow on CPU (around 1 hour or more). On GPU it should take only a few minutes (depending on your GPU).
print("mIoU for OVERFIT_NET over the validation dataset:{}".format(validate(val_loader, overfit_net)[1]))
# Out:
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:91: RuntimeWarning: invalid value encountered in true_divide
#   iou = np.diag(confusion) / iou_denominator
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:168: RuntimeWarning: invalid value encountered in true_divide
#   class_accuracy = np.diag(confusion) / np.sum(confusion, axis=1)
# mIoU for OVERFIT_NET over the validation dataset:0.08657569245053524
# CPU times: user 36.5 s, sys: 8.41 s, total: 44.9 s
# Wall time: 1min 2s

# %% [markdown]
# #### (e) Explain in a few sentences the quantitative results observed in (c) and (d):

# %% [markdown]
# Student answer:
#
# In part c we overfit the network to a single image.
# This provides very fast training, and excellent performance on that single image.
# The mIoU for it is > 0.999. However, when evaluated on other images the performance is quite bad.
# This makes sense as the network was highly specialized to a single form of data.
#
# However, these are compared with the untrained networks visually too, which all have even worse perfomance.
# This makes sense as the weights are completely random in those cases.
#
# In part d we evaluate the untrained and overfit networks against the full validation set.
# We would expect the overfit network to perform better than the untrained network, since it is atleast trained on 1 image/class.
# We find that the overfit mIoU is a factor of 25 greater than untrained, however is still only about ~0.13, which is not very good.
# So the assumption holds that overfit is better than untrained, but still not useful practically.

# %% [markdown]
# #### (f) Create TRAINED_NET and train it on the full training dataset:

# %%
# %%time
# %matplotlib notebook

torch.cuda.empty_cache()

# This training will be very slow on a CPU (>1hour per epoch). Ideally, this should be run in GPU mode (USE_GPU=True) 
# taking only a few minutes per epoch (depending on your GPU and batch size). Thus, before proceeding with this excercise,
# it is highly advisable that you first finish debugging your net code. In particular, make sure that OVERFIT_NET behaves 
# reasonably, e.g. its loss monotonically decreases during training and its output is OK (for the image it was trained on). 
# Below we create another (deep) copy of untrained_net. Unlike OVERFIT_NET it will be trained on a full training dataset.
trained_net = copy.deepcopy(untrained_net)
# overfit_net = copy.deepcopy(untrained_net)

# set loss function for the net
trained_net.criterion = nn.CrossEntropyLoss(ignore_index=255)

# You can change the number of EPOCHS below. Since each epoch for TRAINED_NET iterates over all training dataset images,
# the number of required epochs could be smaller compared to OFERFIT_NET where each epoch iterates over one-image-dataset)
EPOCH = 30

# switch to train mode (original untrained_net was set to eval mode)
trained_net.train()

optimizer = get_optimizer(trained_net)
# optimizer = optim.SGD(trained_net.parameters(), lr=0.002, momentum=0.9)

print("Starting Training...")

loss_graph = []

# Graph plotting not really working well in Google Colab
# fig = plt.figure(figsize=(12,6))
# plt.subplots_adjust(bottom=0.2,right=0.85,top=0.95)
# ax = fig.add_subplot(1,1,1)

for e in range(EPOCH):
    print("Starting Epoch {}".format(e))
    new_loss_graph = []
    loss = train(train_loader, trained_net, optimizer, new_loss_graph)
    loss_graph += new_loss_graph
    # ax.clear()
    # ax.set_xlabel('iterations')
    # ax.set_ylabel('loss value')
    # ax.set_title('Training loss curve for TRAINED_NET')
    # ax.plot(loss_graph, label='training loss')
    # ax.legend(loc='upper right')
    # fig.canvas.draw()
    # plt.show()
    print("Epoch: {} Loss: {}".format(e, loss))
    
# %matplotlib inline
# Out:
# Starting Training...
# Starting Epoch 0
# Training: On Tick: 0 loss 3.080984115600586
# Training: On Tick: 1 loss 2.8993072509765625
# Training: On Tick: 2 loss 2.4984281063079834
# Training: On Tick: 3 loss 2.0259618759155273
# Training: On Tick: 4 loss 1.7628746032714844
# Training: On Tick: 5 loss 1.764441967010498
# Training: On Tick: 6 loss 1.3722832202911377
# Training: On Tick: 7 loss 1.5172582864761353
# Training: On Tick: 8 loss 1.3939279317855835
# Training: On Tick: 9 loss 1.2442725896835327
# Training: On Tick: 10 loss 1.389338731765747
# Training: On Tick: 11 loss 1.5362637042999268
# Training: On Tick: 12 loss 1.340749979019165
# Training: On Tick: 13 loss 1.052463173866272
# Training: On Tick: 14 loss 1.4242491722106934
# Training: On Tick: 15 loss 1.3148424625396729
# Training: On Tick: 16 loss 1.1349053382873535
# Training: On Tick: 17 loss 1.2619494199752808
# Training: On Tick: 18 loss 1.0913755893707275
# Training: On Tick: 19 loss 1.1815844774246216
# Training: On Tick: 20 loss 1.091737985610962
# Training: On Tick: 21 loss 1.0827289819717407
# Training: On Tick: 22 loss 1.3121538162231445
# Training: On Tick: 23 loss 1.0901613235473633
# Training: On Tick: 24 loss 1.0734723806381226
# Training: On Tick: 25 loss 1.1040380001068115
# Training: On Tick: 26 loss 1.075827956199646
# Training: On Tick: 27 loss 1.1084591150283813
# Training: On Tick: 28 loss 0.975541353225708
# Training: On Tick: 29 loss 0.9960734844207764
# Training: On Tick: 30 loss 1.1681280136108398
# Training: On Tick: 31 loss 1.1842705011367798
# Training: On Tick: 32 loss 1.2110517024993896
# Training: On Tick: 33 loss 1.201366901397705
# Training: On Tick: 34 loss 1.27260422706604
# Training: On Tick: 35 loss 1.124169945716858
# Training: On Tick: 36 loss 1.0533993244171143
# Training: On Tick: 37 loss 1.0100951194763184
# Training: On Tick: 38 loss 1.092494249343872
# Training: On Tick: 39 loss 0.8576744198799133
# Training: On Tick: 40 loss 1.416274905204773
# Training: On Tick: 41 loss 1.1423319578170776
# Training: On Tick: 42 loss 1.0907996892929077
# Training: On Tick: 43 loss 1.1822916269302368
# Training: On Tick: 44 loss 1.0614861249923706
# Training: On Tick: 45 loss 1.3692021369934082
# Epoch: 0 Loss: 1.339897766061451
# Starting Epoch 1
# Training: On Tick: 0 loss 1.1878215074539185
# Training: On Tick: 1 loss 0.9268467426300049
# Training: On Tick: 2 loss 1.093059778213501
# Training: On Tick: 3 loss 1.0480248928070068
# Training: On Tick: 4 loss 0.9300573468208313
# Training: On Tick: 5 loss 0.9431760311126709
# Training: On Tick: 6 loss 0.9597432613372803
# Training: On Tick: 7 loss 1.1391065120697021
# Training: On Tick: 8 loss 1.2564764022827148
# Training: On Tick: 9 loss 1.1732560396194458
# Training: On Tick: 10 loss 1.3028427362442017
# Training: On Tick: 11 loss 1.0046907663345337
# Training: On Tick: 12 loss 1.0875300168991089
# Training: On Tick: 13 loss 1.3633822202682495
# Training: On Tick: 14 loss 0.8890922665596008
# Training: On Tick: 15 loss 0.9504338502883911
# Training: On Tick: 16 loss 0.9957098364830017
# Training: On Tick: 17 loss 1.1011669635772705
# Training: On Tick: 18 loss 1.2476674318313599
# Training: On Tick: 19 loss 1.2326027154922485
# Training: On Tick: 20 loss 1.1929008960723877
# Training: On Tick: 21 loss 1.1151143312454224
# Training: On Tick: 22 loss 1.0171070098876953
# Training: On Tick: 23 loss 1.009642243385315
# Training: On Tick: 24 loss 0.9913446307182312
# Training: On Tick: 25 loss 1.1152898073196411
# Training: On Tick: 26 loss 0.7499939203262329
# Training: On Tick: 27 loss 0.9512484669685364
# Training: On Tick: 28 loss 1.033135175704956
# Training: On Tick: 29 loss 1.026477336883545
# Training: On Tick: 30 loss 0.8664280772209167
# Training: On Tick: 31 loss 1.309172511100769
# Training: On Tick: 32 loss 0.647973895072937
# Training: On Tick: 33 loss 1.133937954902649
# Training: On Tick: 34 loss 1.3744372129440308
# Training: On Tick: 35 loss 1.0717177391052246
# Training: On Tick: 36 loss 1.0855618715286255
# Training: On Tick: 37 loss 0.9258223176002502
# Training: On Tick: 38 loss 0.8736898899078369
# Training: On Tick: 39 loss 1.045896053314209
# Training: On Tick: 40 loss 1.280824899673462
# Training: On Tick: 41 loss 0.9261488318443298
# Training: On Tick: 42 loss 1.0402328968048096
# Training: On Tick: 43 loss 0.7877124547958374
# Training: On Tick: 44 loss 1.1119654178619385
# Training: On Tick: 45 loss 0.809816300868988
# Epoch: 1 Loss: 1.0505712926387787
# Starting Epoch 2
# Training: On Tick: 0 loss 1.0802743434906006
# Training: On Tick: 1 loss 0.9278402924537659
# Training: On Tick: 2 loss 0.9309078454971313
# Training: On Tick: 3 loss 0.8569251298904419
# Training: On Tick: 4 loss 1.0650913715362549
# Training: On Tick: 5 loss 1.2475664615631104
# Training: On Tick: 6 loss 0.7977239489555359
# Training: On Tick: 7 loss 0.9711214900016785
# Training: On Tick: 8 loss 0.998347282409668
# Training: On Tick: 9 loss 1.0841224193572998
# Training: On Tick: 10 loss 0.8740196824073792
# Training: On Tick: 11 loss 0.9344354867935181
# Training: On Tick: 12 loss 1.0337421894073486
# Training: On Tick: 13 loss 0.9443380832672119
# Training: On Tick: 14 loss 0.8561525940895081
# Training: On Tick: 15 loss 0.9927335381507874
# Training: On Tick: 16 loss 1.2152881622314453
# Training: On Tick: 17 loss 0.8728363513946533
# Training: On Tick: 18 loss 1.1626108884811401
# Training: On Tick: 19 loss 0.9502294063568115
# Training: On Tick: 20 loss 0.9736491441726685
# Training: On Tick: 21 loss 0.8383200168609619
# Training: On Tick: 22 loss 1.1489440202713013
# Training: On Tick: 23 loss 0.8684773445129395
# Training: On Tick: 24 loss 0.7719253897666931
# Training: On Tick: 25 loss 1.0554955005645752
# Training: On Tick: 26 loss 0.794548511505127
# Training: On Tick: 27 loss 1.074790596961975
# Training: On Tick: 28 loss 0.9692310690879822
# Training: On Tick: 29 loss 0.7733078598976135
# Training: On Tick: 30 loss 0.9321032762527466
# Training: On Tick: 31 loss 1.0789072513580322
# Training: On Tick: 32 loss 0.8002109527587891
# Training: On Tick: 33 loss 0.9181610941886902
# Training: On Tick: 34 loss 1.0885190963745117
# Training: On Tick: 35 loss 1.132447361946106
# Training: On Tick: 36 loss 0.9362988471984863
# Training: On Tick: 37 loss 1.1498411893844604
# Training: On Tick: 38 loss 0.8655205368995667
# Training: On Tick: 39 loss 0.8293125629425049
# Training: On Tick: 40 loss 0.8022185564041138
# Training: On Tick: 41 loss 1.1183414459228516
# Training: On Tick: 42 loss 0.7512410283088684
# Training: On Tick: 43 loss 0.8390242457389832
# Training: On Tick: 44 loss 0.8678627610206604
# Training: On Tick: 45 loss 1.229164958000183
# Epoch: 2 Loss: 0.9653080779573192
# Starting Epoch 3
# Training: On Tick: 0 loss 1.08926522731781
# Training: On Tick: 1 loss 0.935370683670044
# Training: On Tick: 2 loss 1.0091514587402344
# Training: On Tick: 3 loss 1.2113341093063354
# Training: On Tick: 4 loss 1.0557823181152344
# Training: On Tick: 5 loss 1.007175087928772
# Training: On Tick: 6 loss 0.8726907968521118
# Training: On Tick: 7 loss 0.8714528679847717
# Training: On Tick: 8 loss 0.8417689204216003
# Training: On Tick: 9 loss 0.9146891832351685
# Training: On Tick: 10 loss 0.8258116245269775
# Training: On Tick: 11 loss 0.6958405375480652
# Training: On Tick: 12 loss 0.9188521504402161
# Training: On Tick: 13 loss 0.892924427986145
# Training: On Tick: 14 loss 1.0519849061965942
# Training: On Tick: 15 loss 0.8920590281486511
# Training: On Tick: 16 loss 0.7143530249595642
# Training: On Tick: 17 loss 0.8095582127571106
# Training: On Tick: 18 loss 0.8022502660751343
# Training: On Tick: 19 loss 0.8434892892837524
# Training: On Tick: 20 loss 0.8993310332298279
# Training: On Tick: 21 loss 0.8746654391288757
# Training: On Tick: 22 loss 1.190544843673706
# Training: On Tick: 23 loss 0.8543105721473694
# Training: On Tick: 24 loss 0.9515495300292969
# Training: On Tick: 25 loss 0.7525228261947632
# Training: On Tick: 26 loss 0.8035829663276672
# Training: On Tick: 27 loss 1.1258134841918945
# Training: On Tick: 28 loss 0.6849029064178467
# Training: On Tick: 29 loss 0.9404454827308655
# Training: On Tick: 30 loss 1.082423210144043
# Training: On Tick: 31 loss 0.7333272695541382
# Training: On Tick: 32 loss 0.6328162550926208
# Training: On Tick: 33 loss 0.9936522245407104
# Training: On Tick: 34 loss 0.737682044506073
# Training: On Tick: 35 loss 0.7174966931343079
# Training: On Tick: 36 loss 0.887698233127594
# Training: On Tick: 37 loss 0.8573879599571228
# Training: On Tick: 38 loss 0.6714844703674316
# Training: On Tick: 39 loss 1.1314398050308228
# Training: On Tick: 40 loss 0.8053820133209229
# Training: On Tick: 41 loss 0.8184198141098022
# Training: On Tick: 42 loss 0.7358322143554688
# Training: On Tick: 43 loss 1.0906703472137451
# Training: On Tick: 44 loss 0.7109286785125732
# Training: On Tick: 45 loss 0.8741359114646912
# Epoch: 3 Loss: 0.8872663119564885
# Starting Epoch 4
# Training: On Tick: 0 loss 0.9373857975006104
# Training: On Tick: 1 loss 0.679162859916687
# Training: On Tick: 2 loss 0.8864775896072388
# Training: On Tick: 3 loss 0.7963718771934509
# Training: On Tick: 4 loss 0.8848857283592224
# Training: On Tick: 5 loss 1.0053632259368896
# Training: On Tick: 6 loss 0.7997844219207764
# Training: On Tick: 7 loss 0.8324169516563416
# Training: On Tick: 8 loss 0.7381521463394165
# Training: On Tick: 9 loss 0.7476813793182373
# Training: On Tick: 10 loss 0.9416089057922363
# Training: On Tick: 11 loss 0.6903102993965149
# Training: On Tick: 12 loss 0.9116751551628113
# Training: On Tick: 13 loss 0.6253157258033752
# Training: On Tick: 14 loss 0.7337274551391602
# Training: On Tick: 15 loss 0.9718483090400696
# Training: On Tick: 16 loss 0.7517396211624146
# Training: On Tick: 17 loss 0.8034194111824036
# Training: On Tick: 18 loss 0.982879638671875
# Training: On Tick: 19 loss 0.9613670706748962
# Training: On Tick: 20 loss 0.8557428121566772
# Training: On Tick: 21 loss 0.6866359710693359
# Training: On Tick: 22 loss 0.8233165144920349
# Training: On Tick: 23 loss 0.9572603702545166
# Training: On Tick: 24 loss 0.8062891364097595
# Training: On Tick: 25 loss 0.9547326564788818
# Training: On Tick: 26 loss 0.8239231705665588
# Training: On Tick: 27 loss 0.8127731680870056
# Training: On Tick: 28 loss 0.883812665939331
# Training: On Tick: 29 loss 0.8511295318603516
# Training: On Tick: 30 loss 0.7301579713821411
# Training: On Tick: 31 loss 0.7308866381645203
# Training: On Tick: 32 loss 0.8276851773262024
# Training: On Tick: 33 loss 0.7064540982246399
# Training: On Tick: 34 loss 0.8039560914039612
# Training: On Tick: 35 loss 0.6802006363868713
# Training: On Tick: 36 loss 0.7967568039894104
# Training: On Tick: 37 loss 0.7689576745033264
# Training: On Tick: 38 loss 0.8661172389984131
# Training: On Tick: 39 loss 0.8771466016769409
# Training: On Tick: 40 loss 0.8513674736022949
# Training: On Tick: 41 loss 0.65328049659729
# Training: On Tick: 42 loss 0.8495703339576721
# Training: On Tick: 43 loss 1.046610713005066
# Training: On Tick: 44 loss 0.8000688552856445
# Training: On Tick: 45 loss 1.0807613134384155
# Epoch: 4 Loss: 0.8305906018485194
# Starting Epoch 5
# Training: On Tick: 0 loss 0.778043270111084
# Training: On Tick: 1 loss 0.8265638947486877
# Training: On Tick: 2 loss 0.857452929019928
# Training: On Tick: 3 loss 0.6251651048660278
# Training: On Tick: 4 loss 0.9077672958374023
# Training: On Tick: 5 loss 0.6977807879447937
# Training: On Tick: 6 loss 0.6656553745269775
# Training: On Tick: 7 loss 0.7050219178199768
# Training: On Tick: 8 loss 1.0489941835403442
# Training: On Tick: 9 loss 0.7901723384857178
# Training: On Tick: 10 loss 0.8077295422554016
# Training: On Tick: 11 loss 0.8909319043159485
# Training: On Tick: 12 loss 1.002217411994934
# Training: On Tick: 13 loss 0.6982166767120361
# Training: On Tick: 14 loss 0.8032903075218201
# Training: On Tick: 15 loss 0.617954671382904
# Training: On Tick: 16 loss 0.7553105354309082
# Training: On Tick: 17 loss 0.9261215925216675
# Training: On Tick: 18 loss 1.070845127105713
# Training: On Tick: 19 loss 0.7970377802848816
# Training: On Tick: 20 loss 0.6676076650619507
# Training: On Tick: 21 loss 0.6221924424171448
# Training: On Tick: 22 loss 0.6651900410652161
# Training: On Tick: 23 loss 0.7545333504676819
# Training: On Tick: 24 loss 0.7655162215232849
# Training: On Tick: 25 loss 0.6981041431427002
# Training: On Tick: 26 loss 0.8430697917938232
# Training: On Tick: 27 loss 0.7274186611175537
# Training: On Tick: 28 loss 0.6208842396736145
# Training: On Tick: 29 loss 0.6548604369163513
# Training: On Tick: 30 loss 0.7863357663154602
# Training: On Tick: 31 loss 0.7658287286758423
# Training: On Tick: 32 loss 0.7320665717124939
# Training: On Tick: 33 loss 0.6706785559654236
# Training: On Tick: 34 loss 0.812046229839325
# Training: On Tick: 35 loss 0.8488624691963196
# Training: On Tick: 36 loss 0.5903764367103577
# Training: On Tick: 37 loss 0.7333275675773621
# Training: On Tick: 38 loss 0.6768750548362732
# Training: On Tick: 39 loss 0.9363538026809692
# Training: On Tick: 40 loss 0.8359825015068054
# Training: On Tick: 41 loss 1.0031647682189941
# Training: On Tick: 42 loss 0.7915773391723633
# Training: On Tick: 43 loss 0.771605908870697
# Training: On Tick: 44 loss 0.7265343070030212
# Training: On Tick: 45 loss 0.8250705003738403
# Epoch: 5 Loss: 0.7782246988752614
# Starting Epoch 6
# Training: On Tick: 0 loss 0.7886571884155273
# Training: On Tick: 1 loss 0.9178860187530518
# Training: On Tick: 2 loss 0.9712504744529724
# Training: On Tick: 3 loss 0.7276599407196045
# Training: On Tick: 4 loss 0.5937294363975525
# Training: On Tick: 5 loss 0.7227449417114258
# Training: On Tick: 6 loss 0.6405820250511169
# Training: On Tick: 7 loss 0.931992769241333
# Training: On Tick: 8 loss 0.8022488951683044
# Training: On Tick: 9 loss 0.808594286441803
# Training: On Tick: 10 loss 0.7453077435493469
# Training: On Tick: 11 loss 0.6656311750411987
# Training: On Tick: 12 loss 0.6296143531799316
# Training: On Tick: 13 loss 0.8945513367652893
# Training: On Tick: 14 loss 0.6913743019104004
# Training: On Tick: 15 loss 0.6844351887702942
# Training: On Tick: 16 loss 0.723400890827179
# Training: On Tick: 17 loss 0.6368829011917114
# Training: On Tick: 18 loss 0.6847408413887024
# Training: On Tick: 19 loss 0.578183650970459
# Training: On Tick: 20 loss 0.708793044090271
# Training: On Tick: 21 loss 0.6122468113899231
# Training: On Tick: 22 loss 0.5984176993370056
# Training: On Tick: 23 loss 0.7805235385894775
# Training: On Tick: 24 loss 0.7958611249923706
# Training: On Tick: 25 loss 0.6671581268310547
# Training: On Tick: 26 loss 0.6226691007614136
# Training: On Tick: 27 loss 0.5646668672561646
# Training: On Tick: 28 loss 0.7164363265037537
# Training: On Tick: 29 loss 0.6965258717536926
# Training: On Tick: 30 loss 0.668921947479248
# Training: On Tick: 31 loss 0.7606349587440491
# Training: On Tick: 32 loss 0.6997305154800415
# Training: On Tick: 33 loss 0.5298677682876587
# Training: On Tick: 34 loss 0.6738520264625549
# Training: On Tick: 35 loss 0.8090798258781433
# Training: On Tick: 36 loss 1.039953351020813
# Training: On Tick: 37 loss 0.742344081401825
# Training: On Tick: 38 loss 0.641030490398407
# Training: On Tick: 39 loss 0.6430125832557678
# Training: On Tick: 40 loss 0.7181656956672668
# Training: On Tick: 41 loss 0.7789432406425476
# Training: On Tick: 42 loss 0.6520399451255798
# Training: On Tick: 43 loss 0.5192731618881226
# Training: On Tick: 44 loss 0.8104052543640137
# Training: On Tick: 45 loss 0.8908925652503967
# Epoch: 6 Loss: 0.7213242235391036
# Starting Epoch 7
# Training: On Tick: 0 loss 0.7536900639533997
# Training: On Tick: 1 loss 0.6444514393806458
# Training: On Tick: 2 loss 0.6220982670783997
# Training: On Tick: 3 loss 0.7878053188323975
# Training: On Tick: 4 loss 0.7434752583503723
# Training: On Tick: 5 loss 0.7002221941947937
# Training: On Tick: 6 loss 0.6198997497558594
# Training: On Tick: 7 loss 0.8010995984077454
# Training: On Tick: 8 loss 1.0506237745285034
# Training: On Tick: 9 loss 0.5430032014846802
# Training: On Tick: 10 loss 0.6980518102645874
# Training: On Tick: 11 loss 0.5665577054023743
# Training: On Tick: 12 loss 0.5872392058372498
# Training: On Tick: 13 loss 0.64755779504776
# Training: On Tick: 14 loss 0.47890424728393555
# Training: On Tick: 15 loss 0.7293249368667603
# Training: On Tick: 16 loss 0.6533867716789246
# Training: On Tick: 17 loss 0.7985630035400391
# Training: On Tick: 18 loss 0.8165069818496704
# Training: On Tick: 19 loss 0.6074345707893372
# Training: On Tick: 20 loss 0.5843725204467773
# Training: On Tick: 21 loss 0.7495850920677185
# Training: On Tick: 22 loss 0.5993280410766602
# Training: On Tick: 23 loss 0.7720396518707275
# Training: On Tick: 24 loss 0.569018542766571
# Training: On Tick: 25 loss 0.795266330242157
# Training: On Tick: 26 loss 0.6187847256660461
# Training: On Tick: 27 loss 1.0790033340454102
# Training: On Tick: 28 loss 0.7744193077087402
# Training: On Tick: 29 loss 0.7023495435714722
# Training: On Tick: 30 loss 0.6822279095649719
# Training: On Tick: 31 loss 0.5384286046028137
# Training: On Tick: 32 loss 0.6749898791313171
# Training: On Tick: 33 loss 0.6123182773590088
# Training: On Tick: 34 loss 0.6336774230003357
# Training: On Tick: 35 loss 0.5378809571266174
# Training: On Tick: 36 loss 0.6690638065338135
# Training: On Tick: 37 loss 0.5844014286994934
# Training: On Tick: 38 loss 0.8320478796958923
# Training: On Tick: 39 loss 0.689965546131134
# Training: On Tick: 40 loss 0.7237503528594971
# Training: On Tick: 41 loss 0.7463182210922241
# Training: On Tick: 42 loss 0.7379982471466064
# Training: On Tick: 43 loss 0.6994227766990662
# Training: On Tick: 44 loss 0.5961381196975708
# Training: On Tick: 45 loss 0.7450692653656006
# Epoch: 7 Loss: 0.6912556886672974
# Starting Epoch 8
# Training: On Tick: 0 loss 0.5810521841049194
# Training: On Tick: 1 loss 0.7680173516273499
# Training: On Tick: 2 loss 0.643969714641571
# Training: On Tick: 3 loss 0.5847058296203613
# Training: On Tick: 4 loss 0.6274298429489136
# Training: On Tick: 5 loss 0.4516311287879944
# Training: On Tick: 6 loss 0.7079171538352966
# Training: On Tick: 7 loss 0.6449392437934875
# Training: On Tick: 8 loss 0.5360748171806335
# Training: On Tick: 9 loss 0.49637430906295776
# Training: On Tick: 10 loss 0.7974908947944641
# Training: On Tick: 11 loss 0.5843261480331421
# Training: On Tick: 12 loss 0.5380503535270691
# Training: On Tick: 13 loss 0.6452929973602295
# Training: On Tick: 14 loss 0.47937989234924316
# Training: On Tick: 15 loss 0.5590510368347168
# Training: On Tick: 16 loss 0.6384073495864868
# Training: On Tick: 17 loss 0.4580341875553131
# Training: On Tick: 18 loss 0.5859636664390564
# Training: On Tick: 19 loss 0.6655838489532471
# Training: On Tick: 20 loss 0.6220843195915222
# Training: On Tick: 21 loss 0.59259033203125
# Training: On Tick: 22 loss 0.6326485872268677
# Training: On Tick: 23 loss 0.5596523880958557
# Training: On Tick: 24 loss 0.4875253438949585
# Training: On Tick: 25 loss 0.6744900345802307
# Training: On Tick: 26 loss 0.6947840452194214
# Training: On Tick: 27 loss 0.5400811433792114
# Training: On Tick: 28 loss 0.6129729747772217
# Training: On Tick: 29 loss 0.7002817988395691
# Training: On Tick: 30 loss 0.5754750370979309
# Training: On Tick: 31 loss 0.6651941537857056
# Training: On Tick: 32 loss 0.8034387826919556
# Training: On Tick: 33 loss 0.5571644902229309
# Training: On Tick: 34 loss 0.8870309591293335
# Training: On Tick: 35 loss 0.8321187496185303
# Training: On Tick: 36 loss 0.61969393491745
# Training: On Tick: 37 loss 0.6946309804916382
# Training: On Tick: 38 loss 0.6594827175140381
# Training: On Tick: 39 loss 0.6525240540504456
# Training: On Tick: 40 loss 0.6800164580345154
# Training: On Tick: 41 loss 0.8001644015312195
# Training: On Tick: 42 loss 0.6380804181098938
# Training: On Tick: 43 loss 0.6309377551078796
# Training: On Tick: 44 loss 0.6310755014419556
# Training: On Tick: 45 loss 0.683986485004425
# Epoch: 8 Loss: 0.6330829955961393
# Starting Epoch 9
# Training: On Tick: 0 loss 0.5394349694252014
# Training: On Tick: 1 loss 0.9472765922546387
# Training: On Tick: 2 loss 0.5665254592895508
# Training: On Tick: 3 loss 0.5402264595031738
# Training: On Tick: 4 loss 0.42730942368507385
# Training: On Tick: 5 loss 0.7253962159156799
# Training: On Tick: 6 loss 0.6586355566978455
# Training: On Tick: 7 loss 0.5963349938392639
# Training: On Tick: 8 loss 0.39978310465812683
# Training: On Tick: 9 loss 0.49271160364151
# Training: On Tick: 10 loss 0.4562795162200928
# Training: On Tick: 11 loss 0.6873093843460083
# Training: On Tick: 12 loss 0.7619079351425171
# Training: On Tick: 13 loss 0.581790566444397
# Training: On Tick: 14 loss 0.5189841389656067
# Training: On Tick: 15 loss 0.618934690952301
# Training: On Tick: 16 loss 0.6991039514541626
# Training: On Tick: 17 loss 0.633428156375885
# Training: On Tick: 18 loss 0.8848783373832703
# Training: On Tick: 19 loss 0.5124960541725159
# Training: On Tick: 20 loss 0.5887565612792969
# Training: On Tick: 21 loss 0.5135069489479065
# Training: On Tick: 22 loss 0.5296347141265869
# Training: On Tick: 23 loss 0.574988067150116
# Training: On Tick: 24 loss 0.7593806385993958
# Training: On Tick: 25 loss 0.5958291888237
# Training: On Tick: 26 loss 0.5594900250434875
# Training: On Tick: 27 loss 0.6513376832008362
# Training: On Tick: 28 loss 0.6058487296104431
# Training: On Tick: 29 loss 0.5841780304908752
# Training: On Tick: 30 loss 0.4712812602519989
# Training: On Tick: 31 loss 0.649380624294281
# Training: On Tick: 32 loss 0.6188353300094604
# Training: On Tick: 33 loss 0.6805801391601562
# Training: On Tick: 34 loss 0.6265210509300232
# Training: On Tick: 35 loss 0.525577187538147
# Training: On Tick: 36 loss 0.566540002822876
# Training: On Tick: 37 loss 0.5564409494400024
# Training: On Tick: 38 loss 0.6053034663200378
# Training: On Tick: 39 loss 0.7594253420829773
# Training: On Tick: 40 loss 0.5616419315338135
# Training: On Tick: 41 loss 0.6151003837585449
# Training: On Tick: 42 loss 0.44959592819213867
# Training: On Tick: 43 loss 0.6841102838516235
# Training: On Tick: 44 loss 0.6966489553451538
# Training: On Tick: 45 loss 0.47847628593444824
# Epoch: 9 Loss: 0.6034164525892424
# Starting Epoch 10
# Training: On Tick: 0 loss 0.46081700921058655
# Training: On Tick: 1 loss 0.49788346886634827
# Training: On Tick: 2 loss 0.42718884348869324
# Training: On Tick: 3 loss 0.5304373502731323
# Training: On Tick: 4 loss 0.6361966133117676
# Training: On Tick: 5 loss 0.5500540137290955
# Training: On Tick: 6 loss 0.588388979434967
# Training: On Tick: 7 loss 0.5514571070671082
# Training: On Tick: 8 loss 0.5507266521453857
# Training: On Tick: 9 loss 0.5096144080162048
# Training: On Tick: 10 loss 0.5756580233573914
# Training: On Tick: 11 loss 0.5546172857284546
# Training: On Tick: 12 loss 0.5507419109344482
# Training: On Tick: 13 loss 0.469455361366272
# Training: On Tick: 14 loss 0.4689502716064453
# Training: On Tick: 15 loss 0.5127286911010742
# Training: On Tick: 16 loss 0.5235428810119629
# Training: On Tick: 17 loss 0.6683509349822998
# Training: On Tick: 18 loss 0.4764203131198883
# Training: On Tick: 19 loss 0.6171688437461853
# Training: On Tick: 20 loss 0.42072468996047974
# Training: On Tick: 21 loss 0.5784993767738342
# Training: On Tick: 22 loss 0.3721073269844055
# Training: On Tick: 23 loss 0.4763985574245453
# Training: On Tick: 24 loss 0.6078283786773682
# Training: On Tick: 25 loss 0.6174672245979309
# Training: On Tick: 26 loss 0.5744621753692627
# Training: On Tick: 27 loss 0.5641127824783325
# Training: On Tick: 28 loss 0.4276283085346222
# Training: On Tick: 29 loss 0.6128876805305481
# Training: On Tick: 30 loss 0.5675338506698608
# Training: On Tick: 31 loss 0.4726189076900482
# Training: On Tick: 32 loss 0.6027205586433411
# Training: On Tick: 33 loss 0.688826322555542
# Training: On Tick: 34 loss 0.5383931994438171
# Training: On Tick: 35 loss 0.640600323677063
# Training: On Tick: 36 loss 0.5162230730056763
# Training: On Tick: 37 loss 0.664150595664978
# Training: On Tick: 38 loss 0.5973390340805054
# Training: On Tick: 39 loss 0.5714556574821472
# Training: On Tick: 40 loss 0.5051541328430176
# Training: On Tick: 41 loss 0.4646177291870117
# Training: On Tick: 42 loss 0.581050455570221
# Training: On Tick: 43 loss 0.5873067378997803
# Training: On Tick: 44 loss 0.5340048670768738
# Training: On Tick: 45 loss 0.6897587776184082
# Epoch: 10 Loss: 0.5477015149334202
# Starting Epoch 11
# Training: On Tick: 0 loss 0.3815288543701172
# Training: On Tick: 1 loss 0.525519073009491
# Training: On Tick: 2 loss 0.45303213596343994
# Training: On Tick: 3 loss 0.5524715185165405
# Training: On Tick: 4 loss 0.6312767267227173
# Training: On Tick: 5 loss 0.7188825607299805
# Training: On Tick: 6 loss 0.4630199372768402
# Training: On Tick: 7 loss 0.5966174006462097
# Training: On Tick: 8 loss 0.5353149771690369
# Training: On Tick: 9 loss 0.5911207795143127
# Training: On Tick: 10 loss 0.4548320472240448
# Training: On Tick: 11 loss 0.40501663088798523
# Training: On Tick: 12 loss 0.5339975357055664
# Training: On Tick: 13 loss 0.3103574216365814
# Training: On Tick: 14 loss 0.5383936166763306
# Training: On Tick: 15 loss 0.6045348644256592
# Training: On Tick: 16 loss 0.509875476360321
# Training: On Tick: 17 loss 0.5001586675643921
# Training: On Tick: 18 loss 0.5695363879203796
# Training: On Tick: 19 loss 0.593096137046814
# Training: On Tick: 20 loss 0.43788382411003113
# Training: On Tick: 21 loss 0.43122392892837524
# Training: On Tick: 22 loss 0.6249672770500183
# Training: On Tick: 23 loss 0.38629814982414246
# Training: On Tick: 24 loss 0.41905677318573
# Training: On Tick: 25 loss 0.5019240975379944
# Training: On Tick: 26 loss 0.623864471912384
# Training: On Tick: 27 loss 0.4917788803577423
# Training: On Tick: 28 loss 0.46776488423347473
# Training: On Tick: 29 loss 0.38577595353126526
# Training: On Tick: 30 loss 0.5795937776565552
# Training: On Tick: 31 loss 0.44255825877189636
# Training: On Tick: 32 loss 0.514742374420166
# Training: On Tick: 33 loss 0.4978560209274292
# Training: On Tick: 34 loss 0.3576124608516693
# Training: On Tick: 35 loss 0.5249325633049011
# Training: On Tick: 36 loss 0.5688688158988953
# Training: On Tick: 37 loss 0.4686870872974396
# Training: On Tick: 38 loss 0.6354387998580933
# Training: On Tick: 39 loss 0.42336881160736084
# Training: On Tick: 40 loss 0.5002350807189941
# Training: On Tick: 41 loss 0.4804820120334625
# Training: On Tick: 42 loss 0.5389273762702942
# Training: On Tick: 43 loss 0.5051825046539307
# Training: On Tick: 44 loss 0.5304897427558899
# Training: On Tick: 45 loss 0.6568934321403503
# Epoch: 11 Loss: 0.5101084806348967
# Starting Epoch 12
# Training: On Tick: 0 loss 0.5787461996078491
# Training: On Tick: 1 loss 0.40279456973075867
# Training: On Tick: 2 loss 0.48513558506965637
# Training: On Tick: 3 loss 0.4749513566493988
# Training: On Tick: 4 loss 0.38859841227531433
# Training: On Tick: 5 loss 0.34569862484931946
# Training: On Tick: 6 loss 0.4163929522037506
# Training: On Tick: 7 loss 0.506969690322876
# Training: On Tick: 8 loss 0.44011205434799194
# Training: On Tick: 9 loss 0.37256988883018494
# Training: On Tick: 10 loss 0.42572763562202454
# Training: On Tick: 11 loss 0.35484778881073
# Training: On Tick: 12 loss 0.37162476778030396
# Training: On Tick: 13 loss 0.44715622067451477
# Training: On Tick: 14 loss 0.5013867020606995
# Training: On Tick: 15 loss 0.4981536269187927
# Training: On Tick: 16 loss 0.4137057363986969
# Training: On Tick: 17 loss 0.4080215394496918
# Training: On Tick: 18 loss 0.37330496311187744
# Training: On Tick: 19 loss 0.4509362578392029
# Training: On Tick: 20 loss 0.49781280755996704
# Training: On Tick: 21 loss 0.40299955010414124
# Training: On Tick: 22 loss 0.3806700110435486
# Training: On Tick: 23 loss 0.3551596701145172
# Training: On Tick: 24 loss 0.48430314660072327
# Training: On Tick: 25 loss 0.5111943483352661
# Training: On Tick: 26 loss 0.4984527826309204
# Training: On Tick: 27 loss 0.3898232579231262
# Training: On Tick: 28 loss 0.4352041184902191
# Training: On Tick: 29 loss 0.45116132497787476
# Training: On Tick: 30 loss 0.4823533892631531
# Training: On Tick: 31 loss 0.44696909189224243
# Training: On Tick: 32 loss 0.47387224435806274
# Training: On Tick: 33 loss 0.4494149088859558
# Training: On Tick: 34 loss 0.4868885576725006
# Training: On Tick: 35 loss 0.37975871562957764
# Training: On Tick: 36 loss 0.5049139261245728
# Training: On Tick: 37 loss 0.442779541015625
# Training: On Tick: 38 loss 0.4697625935077667
# Training: On Tick: 39 loss 0.401393324136734
# Training: On Tick: 40 loss 0.44573652744293213
# Training: On Tick: 41 loss 0.36454930901527405
# Training: On Tick: 42 loss 0.5069085955619812
# Training: On Tick: 43 loss 0.49403470754623413
# Training: On Tick: 44 loss 0.46953555941581726
# Training: On Tick: 45 loss 0.5634042024612427
# Epoch: 12 Loss: 0.44447588661442633
# Starting Epoch 13
# Training: On Tick: 0 loss 0.3691267967224121
# Training: On Tick: 1 loss 0.4519415497779846
# Training: On Tick: 2 loss 0.3838527202606201
# Training: On Tick: 3 loss 0.41651278734207153
# Training: On Tick: 4 loss 0.550552487373352
# Training: On Tick: 5 loss 0.47358250617980957
# Training: On Tick: 6 loss 0.3458053767681122
# Training: On Tick: 7 loss 0.4829482138156891
# Training: On Tick: 8 loss 0.44271746277809143
# Training: On Tick: 9 loss 0.42032116651535034
# Training: On Tick: 10 loss 0.38490229845046997
# Training: On Tick: 11 loss 0.5336627960205078
# Training: On Tick: 12 loss 0.3054894506931305
# Training: On Tick: 13 loss 0.40280765295028687
# Training: On Tick: 14 loss 0.3575027883052826
# Training: On Tick: 15 loss 0.4676198661327362
# Training: On Tick: 16 loss 0.542023241519928
# Training: On Tick: 17 loss 0.46806567907333374
# Training: On Tick: 18 loss 0.30223891139030457
# Training: On Tick: 19 loss 0.4039633572101593
# Training: On Tick: 20 loss 0.38996970653533936
# Training: On Tick: 21 loss 0.46738654375076294
# Training: On Tick: 22 loss 0.41600272059440613
# Training: On Tick: 23 loss 0.39299511909484863
# Training: On Tick: 24 loss 0.4517378807067871
# Training: On Tick: 25 loss 0.42640653252601624
# Training: On Tick: 26 loss 0.34685075283050537
# Training: On Tick: 27 loss 0.42057064175605774
# Training: On Tick: 28 loss 0.3646959662437439
# Training: On Tick: 29 loss 0.4062236249446869
# Training: On Tick: 30 loss 0.4391528367996216
# Training: On Tick: 31 loss 0.5245047211647034
# Training: On Tick: 32 loss 0.34840619564056396
# Training: On Tick: 33 loss 0.3560865819454193
# Training: On Tick: 34 loss 0.44568827748298645
# Training: On Tick: 35 loss 0.3049476146697998
# Training: On Tick: 36 loss 0.4872988164424896
# Training: On Tick: 37 loss 0.49740222096443176
# Training: On Tick: 38 loss 0.3482217490673065
# Training: On Tick: 39 loss 0.37839701771736145
# Training: On Tick: 40 loss 0.5982202887535095
# Training: On Tick: 41 loss 0.48273855447769165
# Training: On Tick: 42 loss 0.4133787751197815
# Training: On Tick: 43 loss 0.5058729648590088
# Training: On Tick: 44 loss 0.45185357332229614
# Training: On Tick: 45 loss 0.5877446532249451
# Epoch: 13 Loss: 0.4295302486937979
# Starting Epoch 14
# Training: On Tick: 0 loss 0.3501560091972351
# Training: On Tick: 1 loss 0.36630767583847046
# Training: On Tick: 2 loss 0.34909337759017944
# Training: On Tick: 3 loss 0.2987978160381317
# Training: On Tick: 4 loss 0.42916810512542725
# Training: On Tick: 5 loss 0.47219860553741455
# Training: On Tick: 6 loss 0.37085863947868347
# Training: On Tick: 7 loss 0.34137386083602905
# Training: On Tick: 8 loss 0.4341064691543579
# Training: On Tick: 9 loss 0.5519289970397949
# Training: On Tick: 10 loss 0.33380651473999023
# Training: On Tick: 11 loss 0.4013857841491699
# Training: On Tick: 12 loss 0.41861584782600403
# Training: On Tick: 13 loss 0.3139694333076477
# Training: On Tick: 14 loss 0.46242907643318176
# Training: On Tick: 15 loss 0.4919975697994232
# Training: On Tick: 16 loss 0.36380183696746826
# Training: On Tick: 17 loss 0.46355172991752625
# Training: On Tick: 18 loss 0.46782946586608887
# Training: On Tick: 19 loss 0.3568892776966095
# Training: On Tick: 20 loss 0.39221858978271484
# Training: On Tick: 21 loss 0.38895633816719055
# Training: On Tick: 22 loss 0.3894161581993103
# Training: On Tick: 23 loss 0.4311153292655945
# Training: On Tick: 24 loss 0.4797898232936859
# Training: On Tick: 25 loss 0.39080026745796204
# Training: On Tick: 26 loss 0.5146976113319397
# Training: On Tick: 27 loss 0.42930084466934204
# Training: On Tick: 28 loss 0.32731157541275024
# Training: On Tick: 29 loss 0.6148731112480164
# Training: On Tick: 30 loss 0.48924699425697327
# Training: On Tick: 31 loss 0.30789801478385925
# Training: On Tick: 32 loss 0.4570710361003876
# Training: On Tick: 33 loss 0.3338077664375305
# Training: On Tick: 34 loss 0.39010876417160034
# Training: On Tick: 35 loss 0.3861202001571655
# Training: On Tick: 36 loss 0.4644622206687927
# Training: On Tick: 37 loss 0.3482031226158142
# Training: On Tick: 38 loss 0.41213908791542053
# Training: On Tick: 39 loss 0.331448495388031
# Training: On Tick: 40 loss 0.38399502635002136
# Training: On Tick: 41 loss 0.30206117033958435
# Training: On Tick: 42 loss 0.49810051918029785
# Training: On Tick: 43 loss 0.3630669414997101
# Training: On Tick: 44 loss 0.48403400182724
# Training: On Tick: 45 loss 0.4754357933998108
# Epoch: 14 Loss: 0.4092161934012952
# Starting Epoch 15
# Training: On Tick: 0 loss 0.48479852080345154
# Training: On Tick: 1 loss 0.39672011137008667
# Training: On Tick: 2 loss 0.2945188879966736
# Training: On Tick: 3 loss 0.36550307273864746
# Training: On Tick: 4 loss 0.4318532347679138
# Training: On Tick: 5 loss 0.3378480076789856
# Training: On Tick: 6 loss 0.3306257426738739
# Training: On Tick: 7 loss 0.37036430835723877
# Training: On Tick: 8 loss 0.4231303334236145
# Training: On Tick: 9 loss 0.37087497115135193
# Training: On Tick: 10 loss 0.2780722677707672
# Training: On Tick: 11 loss 0.37916281819343567
# Training: On Tick: 12 loss 0.36814576387405396
# Training: On Tick: 13 loss 0.446135014295578
# Training: On Tick: 14 loss 0.35755234956741333
# Training: On Tick: 15 loss 0.40151363611221313
# Training: On Tick: 16 loss 0.3732646703720093
# Training: On Tick: 17 loss 0.25552061200141907
# Training: On Tick: 18 loss 0.2908798158168793
# Training: On Tick: 19 loss 0.3739880919456482
# Training: On Tick: 20 loss 0.45077791810035706
# Training: On Tick: 21 loss 0.4192018508911133
# Training: On Tick: 22 loss 0.2908954322338104
# Training: On Tick: 23 loss 0.38838836550712585
# Training: On Tick: 24 loss 0.3231391906738281
# Training: On Tick: 25 loss 0.282941073179245
# Training: On Tick: 26 loss 0.28287452459335327
# Training: On Tick: 27 loss 0.3827976882457733
# Training: On Tick: 28 loss 0.251935750246048
# Training: On Tick: 29 loss 0.25294554233551025
# Training: On Tick: 30 loss 0.3674931526184082
# Training: On Tick: 31 loss 0.2882847189903259
# Training: On Tick: 32 loss 0.3829660415649414
# Training: On Tick: 33 loss 0.32714587450027466
# Training: On Tick: 34 loss 0.2936447262763977
# Training: On Tick: 35 loss 0.27658501267433167
# Training: On Tick: 36 loss 0.4045345187187195
# Training: On Tick: 37 loss 0.41892775893211365
# Training: On Tick: 38 loss 0.41827714443206787
# Training: On Tick: 39 loss 0.38723471760749817
# Training: On Tick: 40 loss 0.4054764211177826
# Training: On Tick: 41 loss 0.39417722821235657
# Training: On Tick: 42 loss 0.38201484084129333
# Training: On Tick: 43 loss 0.35317128896713257
# Training: On Tick: 44 loss 0.3348662257194519
# Training: On Tick: 45 loss 0.405066579580307
# Epoch: 15 Loss: 0.35861382212327875
# Starting Epoch 16
# Training: On Tick: 0 loss 0.31504586338996887
# Training: On Tick: 1 loss 0.24152426421642303
# Training: On Tick: 2 loss 0.36136531829833984
# Training: On Tick: 3 loss 0.40867796540260315
# Training: On Tick: 4 loss 0.3441224992275238
# Training: On Tick: 5 loss 0.4239371418952942
# Training: On Tick: 6 loss 0.30585551261901855
# Training: On Tick: 7 loss 0.31338492035865784
# Training: On Tick: 8 loss 0.25049537420272827
# Training: On Tick: 9 loss 0.34005749225616455
# Training: On Tick: 10 loss 0.3031735122203827
# Training: On Tick: 11 loss 0.34003162384033203
# Training: On Tick: 12 loss 0.2921506464481354
# Training: On Tick: 13 loss 0.30750346183776855
# Training: On Tick: 14 loss 0.39372265338897705
# Training: On Tick: 15 loss 0.22840212285518646
# Training: On Tick: 16 loss 0.30109161138534546
# Training: On Tick: 17 loss 0.34924420714378357
# Training: On Tick: 18 loss 0.29643160104751587
# Training: On Tick: 19 loss 0.2960262596607208
# Training: On Tick: 20 loss 0.37696540355682373
# Training: On Tick: 21 loss 0.3518446683883667
# Training: On Tick: 22 loss 0.30632898211479187
# Training: On Tick: 23 loss 0.3080635368824005
# Training: On Tick: 24 loss 0.3348879814147949
# Training: On Tick: 25 loss 0.34774747490882874
# Training: On Tick: 26 loss 0.3005886971950531
# Training: On Tick: 27 loss 0.34567955136299133
# Training: On Tick: 28 loss 0.35658758878707886
# Training: On Tick: 29 loss 0.3551878035068512
# Training: On Tick: 30 loss 0.46711140871047974
# Training: On Tick: 31 loss 0.34194228053092957
# Training: On Tick: 32 loss 0.27917996048927307
# Training: On Tick: 33 loss 0.2894286811351776
# Training: On Tick: 34 loss 0.3004932403564453
# Training: On Tick: 35 loss 0.3306579291820526
# Training: On Tick: 36 loss 0.273934006690979
# Training: On Tick: 37 loss 0.2860064208507538
# Training: On Tick: 38 loss 0.27730780839920044
# Training: On Tick: 39 loss 0.3013959228992462
# Training: On Tick: 40 loss 0.2818909287452698
# Training: On Tick: 41 loss 0.36370542645454407
# Training: On Tick: 42 loss 0.30533546209335327
# Training: On Tick: 43 loss 0.22135791182518005
# Training: On Tick: 44 loss 0.3932846188545227
# Training: On Tick: 45 loss 0.39585092663764954
# Epoch: 16 Loss: 0.3240219276884328
# Starting Epoch 17
# Training: On Tick: 0 loss 0.3011340796947479
# Training: On Tick: 1 loss 0.32096487283706665
# Training: On Tick: 2 loss 0.36681467294692993
# Training: On Tick: 3 loss 0.23384572565555573
# Training: On Tick: 4 loss 0.27037036418914795
# Training: On Tick: 5 loss 0.35149097442626953
# Training: On Tick: 6 loss 0.2740170657634735
# Training: On Tick: 7 loss 0.4052213430404663
# Training: On Tick: 8 loss 0.2543434202671051
# Training: On Tick: 9 loss 0.3645099401473999
# Training: On Tick: 10 loss 0.26091909408569336
# Training: On Tick: 11 loss 0.2324904054403305
# Training: On Tick: 12 loss 0.333162397146225
# Training: On Tick: 13 loss 0.23619747161865234
# Training: On Tick: 14 loss 0.35661613941192627
# Training: On Tick: 15 loss 0.4061499238014221
# Training: On Tick: 16 loss 0.3336348533630371
# Training: On Tick: 17 loss 0.29494285583496094
# Training: On Tick: 18 loss 0.30108726024627686
# Training: On Tick: 19 loss 0.31848910450935364
# Training: On Tick: 20 loss 0.29169467091560364
# Training: On Tick: 21 loss 0.3730368912220001
# Training: On Tick: 22 loss 0.35916975140571594
# Training: On Tick: 23 loss 0.27565234899520874
# Training: On Tick: 24 loss 0.27734217047691345
# Training: On Tick: 25 loss 0.3635106384754181
# Training: On Tick: 26 loss 0.2670612335205078
# Training: On Tick: 27 loss 0.34195342659950256
# Training: On Tick: 28 loss 0.2894848883152008
# Training: On Tick: 29 loss 0.31475868821144104
# Training: On Tick: 30 loss 0.3517672121524811
# Training: On Tick: 31 loss 0.30136311054229736
# Training: On Tick: 32 loss 0.3565712869167328
# Training: On Tick: 33 loss 0.29047489166259766
# Training: On Tick: 34 loss 0.2926757037639618
# Training: On Tick: 35 loss 0.26814910769462585
# Training: On Tick: 36 loss 0.4983655512332916
# Training: On Tick: 37 loss 0.41700512170791626
# Training: On Tick: 38 loss 0.36880871653556824
# Training: On Tick: 39 loss 0.3401866853237152
# Training: On Tick: 40 loss 0.2677949070930481
# Training: On Tick: 41 loss 0.2813287377357483
# Training: On Tick: 42 loss 0.27361616492271423
# Training: On Tick: 43 loss 0.3966446816921234
# Training: On Tick: 44 loss 0.3401145040988922
# Training: On Tick: 45 loss 0.31468966603279114
# Epoch: 17 Loss: 0.32020918960156647
# Starting Epoch 18
# Training: On Tick: 0 loss 0.32334381341934204
# Training: On Tick: 1 loss 0.4153585731983185
# Training: On Tick: 2 loss 0.3666934072971344
# Training: On Tick: 3 loss 0.258309543132782
# Training: On Tick: 4 loss 0.2901919186115265
# Training: On Tick: 5 loss 0.2511638402938843
# Training: On Tick: 6 loss 0.3193884491920471
# Training: On Tick: 7 loss 0.3232751190662384
# Training: On Tick: 8 loss 0.30316266417503357
# Training: On Tick: 9 loss 0.3336893320083618
# Training: On Tick: 10 loss 0.2586367726325989
# Training: On Tick: 11 loss 0.32161280512809753
# Training: On Tick: 12 loss 0.33575329184532166
# Training: On Tick: 13 loss 0.32174715399742126
# Training: On Tick: 14 loss 0.37673839926719666
# Training: On Tick: 15 loss 0.29071927070617676
# Training: On Tick: 16 loss 0.2681445777416229
# Training: On Tick: 17 loss 0.29658085107803345
# Training: On Tick: 18 loss 0.3150990903377533
# Training: On Tick: 19 loss 0.42586660385131836
# Training: On Tick: 20 loss 0.24308505654335022
# Training: On Tick: 21 loss 0.27197325229644775
# Training: On Tick: 22 loss 0.27514442801475525
# Training: On Tick: 23 loss 0.2444755882024765
# Training: On Tick: 24 loss 0.25136929750442505
# Training: On Tick: 25 loss 0.43187621235847473
# Training: On Tick: 26 loss 0.25566616654396057
# Training: On Tick: 27 loss 0.2751495838165283
# Training: On Tick: 28 loss 0.2764098644256592
# Training: On Tick: 29 loss 0.18751570582389832
# Training: On Tick: 30 loss 0.2540680170059204
# Training: On Tick: 31 loss 0.3099001348018646
# Training: On Tick: 32 loss 0.3657354712486267
# Training: On Tick: 33 loss 0.33928191661834717
# Training: On Tick: 34 loss 0.31640535593032837
# Training: On Tick: 35 loss 0.29145875573158264
# Training: On Tick: 36 loss 0.26616284251213074
# Training: On Tick: 37 loss 0.302264004945755
# Training: On Tick: 38 loss 0.2882958948612213
# Training: On Tick: 39 loss 0.2752039134502411
# Training: On Tick: 40 loss 0.2443871647119522
# Training: On Tick: 41 loss 0.2652304470539093
# Training: On Tick: 42 loss 0.3072076141834259
# Training: On Tick: 43 loss 0.3462647795677185
# Training: On Tick: 44 loss 0.37533363699913025
# Training: On Tick: 45 loss 0.32777008414268494
# Epoch: 18 Loss: 0.3039806666581527
# Starting Epoch 19
# Training: On Tick: 0 loss 0.28768783807754517
# Training: On Tick: 1 loss 0.26197871565818787
# Training: On Tick: 2 loss 0.2655414938926697
# Training: On Tick: 3 loss 0.3102867305278778
# Training: On Tick: 4 loss 0.3503238558769226
# Training: On Tick: 5 loss 0.2229301482439041
# Training: On Tick: 6 loss 0.21259719133377075
# Training: On Tick: 7 loss 0.2522692084312439
# Training: On Tick: 8 loss 0.35552868247032166
# Training: On Tick: 9 loss 0.32257744669914246
# Training: On Tick: 10 loss 0.2489069253206253
# Training: On Tick: 11 loss 0.25284698605537415
# Training: On Tick: 12 loss 0.23481768369674683
# Training: On Tick: 13 loss 0.34601595997810364
# Training: On Tick: 14 loss 0.338908851146698
# Training: On Tick: 15 loss 0.2720155715942383
# Training: On Tick: 16 loss 0.2342788577079773
# Training: On Tick: 17 loss 0.21642175316810608
# Training: On Tick: 18 loss 0.25747156143188477
# Training: On Tick: 19 loss 0.26307302713394165
# Training: On Tick: 20 loss 0.30822262167930603
# Training: On Tick: 21 loss 0.2525949478149414
# Training: On Tick: 22 loss 0.296966552734375
# Training: On Tick: 23 loss 0.3581998348236084
# Training: On Tick: 24 loss 0.2976784408092499
# Training: On Tick: 25 loss 0.2683476209640503
# Training: On Tick: 26 loss 0.24737109243869781
# Training: On Tick: 27 loss 0.2772013247013092
# Training: On Tick: 28 loss 0.2115461677312851
# Training: On Tick: 29 loss 0.27068451046943665
# Training: On Tick: 30 loss 0.24825310707092285
# Training: On Tick: 31 loss 0.2524331510066986
# Training: On Tick: 32 loss 0.371269166469574
# Training: On Tick: 33 loss 0.3681732714176178
# Training: On Tick: 34 loss 0.22924205660820007
# Training: On Tick: 35 loss 0.2426920235157013
# Training: On Tick: 36 loss 0.3063908517360687
# Training: On Tick: 37 loss 0.2621547281742096
# Training: On Tick: 38 loss 0.38844868540763855
# Training: On Tick: 39 loss 0.32454609870910645
# Training: On Tick: 40 loss 0.3015560507774353
# Training: On Tick: 41 loss 0.26604142785072327
# Training: On Tick: 42 loss 0.2536381483078003
# Training: On Tick: 43 loss 0.3508565425872803
# Training: On Tick: 44 loss 0.2731359601020813
# Training: On Tick: 45 loss 0.2920529842376709
# Epoch: 19 Loss: 0.28317773601283197
# Starting Epoch 20
# Training: On Tick: 0 loss 0.25811266899108887
# Training: On Tick: 1 loss 0.35866791009902954
# Training: On Tick: 2 loss 0.19782361388206482
# Training: On Tick: 3 loss 0.3565348982810974
# Training: On Tick: 4 loss 0.2601769268512726
# Training: On Tick: 5 loss 0.346473753452301
# Training: On Tick: 6 loss 0.26688215136528015
# Training: On Tick: 7 loss 0.2647457718849182
# Training: On Tick: 8 loss 0.24583463370800018
# Training: On Tick: 9 loss 0.25971531867980957
# Training: On Tick: 10 loss 0.2572169005870819
# Training: On Tick: 11 loss 0.2535773515701294
# Training: On Tick: 12 loss 0.17593780159950256
# Training: On Tick: 13 loss 0.21135519444942474
# Training: On Tick: 14 loss 0.31028997898101807
# Training: On Tick: 15 loss 0.25852465629577637
# Training: On Tick: 16 loss 0.25304725766181946
# Training: On Tick: 17 loss 0.2624867856502533
# Training: On Tick: 18 loss 0.20843341946601868
# Training: On Tick: 19 loss 0.2312271147966385
# Training: On Tick: 20 loss 0.3126157522201538
# Training: On Tick: 21 loss 0.22554509341716766
# Training: On Tick: 22 loss 0.23543097078800201
# Training: On Tick: 23 loss 0.2205810546875
# Training: On Tick: 24 loss 0.2576383650302887
# Training: On Tick: 25 loss 0.18787626922130585
# Training: On Tick: 26 loss 0.2750226557254791
# Training: On Tick: 27 loss 0.4043499231338501
# Training: On Tick: 28 loss 0.2677052915096283
# Training: On Tick: 29 loss 0.2784755229949951
# Training: On Tick: 30 loss 0.21610262989997864
# Training: On Tick: 31 loss 0.192943274974823
# Training: On Tick: 32 loss 0.2975431978702545
# Training: On Tick: 33 loss 0.3120020925998688
# Training: On Tick: 34 loss 0.3585023880004883
# Training: On Tick: 35 loss 0.2553183436393738
# Training: On Tick: 36 loss 0.25854215025901794
# Training: On Tick: 37 loss 0.3153749108314514
# Training: On Tick: 38 loss 0.275824636220932
# Training: On Tick: 39 loss 0.2651714086532593
# Training: On Tick: 40 loss 0.3535211980342865
# Training: On Tick: 41 loss 0.2986394464969635
# Training: On Tick: 42 loss 0.21599504351615906
# Training: On Tick: 43 loss 0.26221275329589844
# Training: On Tick: 44 loss 0.27416670322418213
# Training: On Tick: 45 loss 0.20894739031791687
# Epoch: 20 Loss: 0.2665894038003424
# Starting Epoch 21
# Training: On Tick: 0 loss 0.2413731813430786
# Training: On Tick: 1 loss 0.257397323846817
# Training: On Tick: 2 loss 0.185563325881958
# Training: On Tick: 3 loss 0.18990492820739746
# Training: On Tick: 4 loss 0.24684828519821167
# Training: On Tick: 5 loss 0.2500460147857666
# Training: On Tick: 6 loss 0.2080809473991394
# Training: On Tick: 7 loss 0.20685771107673645
# Training: On Tick: 8 loss 0.24643245339393616
# Training: On Tick: 9 loss 0.2203555703163147
# Training: On Tick: 10 loss 0.18989285826683044
# Training: On Tick: 11 loss 0.29343917965888977
# Training: On Tick: 12 loss 0.2006998509168625
# Training: On Tick: 13 loss 0.18133367598056793
# Training: On Tick: 14 loss 0.22903230786323547
# Training: On Tick: 15 loss 0.2748107314109802
# Training: On Tick: 16 loss 0.21840044856071472
# Training: On Tick: 17 loss 0.201868936419487
# Training: On Tick: 18 loss 0.19902798533439636
# Training: On Tick: 19 loss 0.23473751544952393
# Training: On Tick: 20 loss 0.28584563732147217
# Training: On Tick: 21 loss 0.24621282517910004
# Training: On Tick: 22 loss 0.1758469045162201
# Training: On Tick: 23 loss 0.21888887882232666
# Training: On Tick: 24 loss 0.21454568207263947
# Training: On Tick: 25 loss 0.23779360949993134
# Training: On Tick: 26 loss 0.19466911256313324
# Training: On Tick: 27 loss 0.23577971756458282
# Training: On Tick: 28 loss 0.2072681039571762
# Training: On Tick: 29 loss 0.30145254731178284
# Training: On Tick: 30 loss 0.21093350648880005
# Training: On Tick: 31 loss 0.2422095388174057
# Training: On Tick: 32 loss 0.25102484226226807
# Training: On Tick: 33 loss 0.2091543972492218
# Training: On Tick: 34 loss 0.2599099278450012
# Training: On Tick: 35 loss 0.267527312040329
# Training: On Tick: 36 loss 0.29576724767684937
# Training: On Tick: 37 loss 0.24218536913394928
# Training: On Tick: 38 loss 0.29842329025268555
# Training: On Tick: 39 loss 0.21647226810455322
# Training: On Tick: 40 loss 0.2229357659816742
# Training: On Tick: 41 loss 0.326137900352478
# Training: On Tick: 42 loss 0.2633264660835266
# Training: On Tick: 43 loss 0.31066474318504333
# Training: On Tick: 44 loss 0.2538951337337494
# Training: On Tick: 45 loss 0.24433816969394684
# Epoch: 21 Loss: 0.23715895932653677
# Starting Epoch 22
# Training: On Tick: 0 loss 0.20929594337940216
# Training: On Tick: 1 loss 0.23782463371753693
# Training: On Tick: 2 loss 0.2439904808998108
# Training: On Tick: 3 loss 0.2166779339313507
# Training: On Tick: 4 loss 0.30628663301467896
# Training: On Tick: 5 loss 0.18440884351730347
# Training: On Tick: 6 loss 0.23098687827587128
# ...
# Training: On Tick: 35 loss 0.2082737237215042
# Training: On Tick: 36 loss 0.2635972201824188
# Training: On Tick: 37 loss 0.19081275165081024
# Training: On Tick: 38 loss 0.18498019874095917
# Training: On Tick: 39 loss 0.20207364857196808
# Training: On Tick: 40 loss 0.15537217259407043
# Training: On Tick: 41 loss 0.20760853588581085
# Training: On Tick: 42 loss 0.14343878626823425
# Training: On Tick: 43 loss 0.15865306556224823
# Training: On Tick: 44 loss 0.19786809384822845
# Training: On Tick: 45 loss 0.20563796162605286
# Epoch: 22 Loss: 0.21563286172307056
# Starting Epoch 23
# Training: On Tick: 0 loss 0.23431465029716492
# Training: On Tick: 1 loss 0.21830716729164124
# Training: On Tick: 2 loss 0.1891499161720276
# Training: On Tick: 3 loss 0.14404670894145966
# Training: On Tick: 4 loss 0.16491644084453583
# Training: On Tick: 5 loss 0.1929663121700287
# Training: On Tick: 6 loss 0.14145392179489136
# Training: On Tick: 7 loss 0.20331859588623047
# Training: On Tick: 8 loss 0.213991180062294
# Training: On Tick: 9 loss 0.15025745332241058
# Training: On Tick: 10 loss 0.1310635656118393
# Training: On Tick: 11 loss 0.1870843470096588
# Training: On Tick: 12 loss 0.20142300426959991
# Training: On Tick: 13 loss 0.14658449590206146
# Training: On Tick: 14 loss 0.23240359127521515
# Training: On Tick: 15 loss 0.17933957278728485
# Training: On Tick: 16 loss 0.17359288036823273
# Training: On Tick: 17 loss 0.2482316642999649
# Training: On Tick: 18 loss 0.1544000804424286
# Training: On Tick: 19 loss 0.2691514492034912
# Training: On Tick: 20 loss 0.1706068068742752
# Training: On Tick: 21 loss 0.23941504955291748
# Training: On Tick: 22 loss 0.21044319868087769
# Training: On Tick: 23 loss 0.20419146120548248
# Training: On Tick: 24 loss 0.17998956143856049
# Training: On Tick: 25 loss 0.1907651126384735
# Training: On Tick: 26 loss 0.18103496730327606
# Training: On Tick: 27 loss 0.2089725285768509
# Training: On Tick: 28 loss 0.15820418298244476
# Training: On Tick: 29 loss 0.20459164679050446
# Training: On Tick: 30 loss 0.15162548422813416
# Training: On Tick: 31 loss 0.16551700234413147
# Training: On Tick: 32 loss 0.16720908880233765
# Training: On Tick: 33 loss 0.23627972602844238
# Training: On Tick: 34 loss 0.16504855453968048
# Training: On Tick: 35 loss 0.2305401712656021
# Training: On Tick: 36 loss 0.20089516043663025
# Training: On Tick: 37 loss 0.1609201282262802
# Training: On Tick: 38 loss 0.20210880041122437
# Training: On Tick: 39 loss 0.25292426347732544
# Training: On Tick: 40 loss 0.18223299086093903
# Training: On Tick: 41 loss 0.21445517241954803
# Training: On Tick: 42 loss 0.18675479292869568
# Training: On Tick: 43 loss 0.18738725781440735
# Training: On Tick: 44 loss 0.12978748977184296
# Training: On Tick: 45 loss 0.14746792614459991
# Epoch: 23 Loss: 0.18924707660208578
# Starting Epoch 24
# Training: On Tick: 0 loss 0.17095999419689178
# Training: On Tick: 1 loss 0.17100335657596588
# Training: On Tick: 2 loss 0.13578245043754578
# Training: On Tick: 3 loss 0.16745072603225708
# Training: On Tick: 4 loss 0.15488192439079285
# Training: On Tick: 5 loss 0.22433817386627197
# Training: On Tick: 6 loss 0.20314985513687134
# Training: On Tick: 7 loss 0.19403280317783356
# Training: On Tick: 8 loss 0.1768013834953308
# Training: On Tick: 9 loss 0.20288950204849243
# Training: On Tick: 10 loss 0.1436966061592102
# Training: On Tick: 11 loss 0.17549778521060944
# Training: On Tick: 12 loss 0.1490519940853119
# Training: On Tick: 13 loss 0.2042655348777771
# Training: On Tick: 14 loss 0.16940376162528992
# Training: On Tick: 15 loss 0.18609312176704407
# Training: On Tick: 16 loss 0.15596547722816467
# Training: On Tick: 17 loss 0.1658557951450348
# Training: On Tick: 18 loss 0.19518223404884338
# Training: On Tick: 19 loss 0.1553432196378708
# Training: On Tick: 20 loss 0.17423780262470245
# Training: On Tick: 21 loss 0.20866169035434723
# Training: On Tick: 22 loss 0.2030772715806961
# Training: On Tick: 23 loss 0.16545481979846954
# Training: On Tick: 24 loss 0.1669125109910965
# Training: On Tick: 25 loss 0.1395861953496933
# Training: On Tick: 26 loss 0.16121059656143188
# Training: On Tick: 27 loss 0.21902120113372803
# Training: On Tick: 28 loss 0.2014380395412445
# Training: On Tick: 29 loss 0.27204787731170654
# Training: On Tick: 30 loss 0.16956637799739838
# Training: On Tick: 31 loss 0.1275416761636734
# Training: On Tick: 32 loss 0.2407839000225067
# Training: On Tick: 33 loss 0.19897256791591644
# Training: On Tick: 34 loss 0.16857603192329407
# Training: On Tick: 35 loss 0.17946651577949524
# Training: On Tick: 36 loss 0.18290460109710693
# Training: On Tick: 37 loss 0.12606681883335114
# Training: On Tick: 38 loss 0.15050581097602844
# Training: On Tick: 39 loss 0.18998582661151886
# Training: On Tick: 40 loss 0.13009995222091675
# Training: On Tick: 41 loss 0.18664515018463135
# Training: On Tick: 42 loss 0.21858999133110046
# Training: On Tick: 43 loss 0.16326913237571716
# Training: On Tick: 44 loss 0.1773301512002945
# Training: On Tick: 45 loss 0.18320132791996002
# Epoch: 24 Loss: 0.17840868558572687
# Starting Epoch 25
# Training: On Tick: 0 loss 0.11809670925140381
# Training: On Tick: 1 loss 0.16678518056869507
# Training: On Tick: 2 loss 0.134938582777977
# Training: On Tick: 3 loss 0.1433691680431366
# Training: On Tick: 4 loss 0.14578089118003845
# Training: On Tick: 5 loss 0.1935109943151474
# Training: On Tick: 6 loss 0.2601698935031891
# Training: On Tick: 7 loss 0.14855723083019257
# Training: On Tick: 8 loss 0.1691458821296692
# Training: On Tick: 9 loss 0.16910231113433838
# Training: On Tick: 10 loss 0.16829600930213928
# Training: On Tick: 11 loss 0.1556742787361145
# Training: On Tick: 12 loss 0.1686948835849762
# Training: On Tick: 13 loss 0.13324998319149017
# Training: On Tick: 14 loss 0.15752872824668884
# Training: On Tick: 15 loss 0.15289807319641113
# Training: On Tick: 16 loss 0.19560383260250092
# Training: On Tick: 17 loss 0.1570848822593689
# Training: On Tick: 18 loss 0.1906457394361496
# Training: On Tick: 19 loss 0.18406309187412262
# Training: On Tick: 20 loss 0.21731571853160858
# Training: On Tick: 21 loss 0.16852153837680817
# Training: On Tick: 22 loss 0.16932976245880127
# Training: On Tick: 23 loss 0.1642114520072937
# Training: On Tick: 24 loss 0.16691537201404572
# Training: On Tick: 25 loss 0.17828959226608276
# Training: On Tick: 26 loss 0.18347375094890594
# Training: On Tick: 27 loss 0.1684635877609253
# Training: On Tick: 28 loss 0.16484025120735168
# Training: On Tick: 29 loss 0.20858663320541382
# Training: On Tick: 30 loss 0.2003292441368103
# Training: On Tick: 31 loss 0.18980111181735992
# Training: On Tick: 32 loss 0.1594226211309433
# Training: On Tick: 33 loss 0.17805977165699005
# Training: On Tick: 34 loss 0.1948135942220688
# Training: On Tick: 35 loss 0.20588281750679016
# Training: On Tick: 36 loss 0.18148194253444672
# Training: On Tick: 37 loss 0.17241081595420837
# Training: On Tick: 38 loss 0.15548661351203918
# Training: On Tick: 39 loss 0.1660418063402176
# Training: On Tick: 40 loss 0.2559587061405182
# Training: On Tick: 41 loss 0.2312643826007843
# Training: On Tick: 42 loss 0.1778666377067566
# Training: On Tick: 43 loss 0.16608351469039917
# Training: On Tick: 44 loss 0.14908447861671448
# Training: On Tick: 45 loss 0.18397952616214752
# Epoch: 25 Loss: 0.17545894760152567
# Starting Epoch 26
# Training: On Tick: 0 loss 0.18289609253406525
# Training: On Tick: 1 loss 0.1759229451417923
# Training: On Tick: 2 loss 0.15961511433124542
# Training: On Tick: 3 loss 0.232976034283638
# Training: On Tick: 4 loss 0.136183500289917
# Training: On Tick: 5 loss 0.23407486081123352
# Training: On Tick: 6 loss 0.1630498766899109
# Training: On Tick: 7 loss 0.189663827419281
# Training: On Tick: 8 loss 0.17963390052318573
# Training: On Tick: 9 loss 0.15694434940814972
# Training: On Tick: 10 loss 0.17282027006149292
# Training: On Tick: 11 loss 0.19516678154468536
# Training: On Tick: 12 loss 0.15937359631061554
# Training: On Tick: 13 loss 0.12747663259506226
# Training: On Tick: 14 loss 0.17095257341861725
# Training: On Tick: 15 loss 0.1630537211894989
# Training: On Tick: 16 loss 0.18543069064617157
# Training: On Tick: 17 loss 0.1402747929096222
# Training: On Tick: 18 loss 0.16707763075828552
# Training: On Tick: 19 loss 0.1886964738368988
# Training: On Tick: 20 loss 0.18778453767299652
# Training: On Tick: 21 loss 0.1765095442533493
# Training: On Tick: 22 loss 0.18628381192684174
# Training: On Tick: 23 loss 0.12325619906187057
# Training: On Tick: 24 loss 0.12408558279275894
# Training: On Tick: 25 loss 0.13033410906791687
# Training: On Tick: 26 loss 0.18047907948493958
# Training: On Tick: 27 loss 0.15942040085792542
# Training: On Tick: 28 loss 0.1880216896533966
# Training: On Tick: 29 loss 0.16880805790424347
# Training: On Tick: 30 loss 0.16940559446811676
# Training: On Tick: 31 loss 0.15118984878063202
# Training: On Tick: 32 loss 0.16973045468330383
# Training: On Tick: 33 loss 0.1530398726463318
# Training: On Tick: 34 loss 0.20654736459255219
# Training: On Tick: 35 loss 0.19296015799045563
# Training: On Tick: 36 loss 0.1662755161523819
# Training: On Tick: 37 loss 0.158038929104805
# Training: On Tick: 38 loss 0.18785418570041656
# Training: On Tick: 39 loss 0.18585680425167084
# Training: On Tick: 40 loss 0.2058669924736023
# Training: On Tick: 41 loss 0.28081223368644714
# Training: On Tick: 42 loss 0.1684165894985199
# Training: On Tick: 43 loss 0.16502827405929565
# Training: On Tick: 44 loss 0.13815872371196747
# Training: On Tick: 45 loss 0.18786059319972992
# Epoch: 26 Loss: 0.17376758287782254
# Starting Epoch 27
# Training: On Tick: 0 loss 0.14450591802597046
# Training: On Tick: 1 loss 0.2513522505760193
# Training: On Tick: 2 loss 0.22951747477054596
# Training: On Tick: 3 loss 0.14450185000896454
# Training: On Tick: 4 loss 0.16795998811721802
# Training: On Tick: 5 loss 0.2217564731836319
# Training: On Tick: 6 loss 0.1957128494977951
# Training: On Tick: 7 loss 0.18146246671676636
# Training: On Tick: 8 loss 0.21178145706653595
# Training: On Tick: 9 loss 0.16365106403827667
# Training: On Tick: 10 loss 0.20228633284568787
# Training: On Tick: 11 loss 0.1668737530708313
# Training: On Tick: 12 loss 0.13863466680049896
# Training: On Tick: 13 loss 0.16269774734973907
# Training: On Tick: 14 loss 0.19703049957752228
# Training: On Tick: 15 loss 0.18827560544013977
# Training: On Tick: 16 loss 0.15892162919044495
# Training: On Tick: 17 loss 0.18020468950271606
# Training: On Tick: 18 loss 0.16812117397785187
# Training: On Tick: 19 loss 0.1472133994102478
# Training: On Tick: 20 loss 0.17622514069080353
# Training: On Tick: 21 loss 0.1456678807735443
# Training: On Tick: 22 loss 0.20803134143352509
# Training: On Tick: 23 loss 0.13914121687412262
# Training: On Tick: 24 loss 0.22671234607696533
# Training: On Tick: 25 loss 0.17348487675189972
# Training: On Tick: 26 loss 0.15978217124938965
# Training: On Tick: 27 loss 0.15954099595546722
# Training: On Tick: 28 loss 0.13930179178714752
# Training: On Tick: 29 loss 0.20850639045238495
# Training: On Tick: 30 loss 0.14520800113677979
# Training: On Tick: 31 loss 0.14228500425815582
# Training: On Tick: 32 loss 0.14314179122447968
# Training: On Tick: 33 loss 0.14553570747375488
# Training: On Tick: 34 loss 0.17288748919963837
# Training: On Tick: 35 loss 0.1782355010509491
# Training: On Tick: 36 loss 0.16042207181453705
# Training: On Tick: 37 loss 0.14570306241512299
# Training: On Tick: 38 loss 0.1276581734418869
# Training: On Tick: 39 loss 0.15259674191474915
# Training: On Tick: 40 loss 0.12804585695266724
# Training: On Tick: 41 loss 0.16276144981384277
# Training: On Tick: 42 loss 0.17860709130764008
# Training: On Tick: 43 loss 0.1523766666650772
# Training: On Tick: 44 loss 0.19594326615333557
# Training: On Tick: 45 loss 0.1620493084192276
# Epoch: 27 Loss: 0.17070244835770648
# Starting Epoch 28
# Training: On Tick: 0 loss 0.1729261577129364
# Training: On Tick: 1 loss 0.17866359651088715
# Training: On Tick: 2 loss 0.13382689654827118
# Training: On Tick: 3 loss 0.19046135246753693
# Training: On Tick: 4 loss 0.16881506145000458
# Training: On Tick: 5 loss 0.1338149607181549
# Training: On Tick: 6 loss 0.14173921942710876
# Training: On Tick: 7 loss 0.1539037823677063
# Training: On Tick: 8 loss 0.22227638959884644
# Training: On Tick: 9 loss 0.14197111129760742
# Training: On Tick: 10 loss 0.13762637972831726
# Training: On Tick: 11 loss 0.17630121111869812
# Training: On Tick: 12 loss 0.18487432599067688
# Training: On Tick: 13 loss 0.14662891626358032
# Training: On Tick: 14 loss 0.1969074308872223
# Training: On Tick: 15 loss 0.12941044569015503
# Training: On Tick: 16 loss 0.1125117689371109
# Training: On Tick: 17 loss 0.15288875997066498
# Training: On Tick: 18 loss 0.14845256507396698
# Training: On Tick: 19 loss 0.1663234978914261
# Training: On Tick: 20 loss 0.15594658255577087
# Training: On Tick: 21 loss 0.16442102193832397
# Training: On Tick: 22 loss 0.14427213370800018
# Training: On Tick: 23 loss 0.12326106429100037
# Training: On Tick: 24 loss 0.13792817294597626
# Training: On Tick: 25 loss 0.1452527940273285
# Training: On Tick: 26 loss 0.12164090573787689
# Training: On Tick: 27 loss 0.1350884735584259
# Training: On Tick: 28 loss 0.17123030126094818
# Training: On Tick: 29 loss 0.1611693650484085
# Training: On Tick: 30 loss 0.11481314897537231
# Training: On Tick: 31 loss 0.15269458293914795
# Training: On Tick: 32 loss 0.12381599098443985
# Training: On Tick: 33 loss 0.19526676833629608
# Training: On Tick: 34 loss 0.12741683423519135
# Training: On Tick: 35 loss 0.1287824511528015
# Training: On Tick: 36 loss 0.13879577815532684
# Training: On Tick: 37 loss 0.14726699888706207
# Training: On Tick: 38 loss 0.19104735553264618
# Training: On Tick: 39 loss 0.17853879928588867
# Training: On Tick: 40 loss 0.1688411831855774
# Training: On Tick: 41 loss 0.1393492966890335
# Training: On Tick: 42 loss 0.14098218083381653
# Training: On Tick: 43 loss 0.22633270919322968
# Training: On Tick: 44 loss 0.13767871260643005
# Training: On Tick: 45 loss 0.1743835210800171
# Epoch: 28 Loss: 0.15514219471293947
# Starting Epoch 29
# Training: On Tick: 0 loss 0.13723929226398468
# Training: On Tick: 1 loss 0.12522777915000916
# Training: On Tick: 2 loss 0.15876521170139313
# Training: On Tick: 3 loss 0.2054169476032257
# Training: On Tick: 4 loss 0.2456512302160263
# Training: On Tick: 5 loss 0.1332305371761322
# Training: On Tick: 6 loss 0.13917604088783264
# Training: On Tick: 7 loss 0.13370423018932343
# Training: On Tick: 8 loss 0.21506313979625702
# Training: On Tick: 9 loss 0.15373963117599487
# Training: On Tick: 10 loss 0.14271415770053864
# Training: On Tick: 11 loss 0.11647970974445343
# Training: On Tick: 12 loss 0.1601802408695221
# Training: On Tick: 13 loss 0.17892296612262726
# Training: On Tick: 14 loss 0.15398965775966644
# Training: On Tick: 15 loss 0.17191709578037262
# Training: On Tick: 16 loss 0.10214608162641525
# Training: On Tick: 17 loss 0.1696944236755371
# Training: On Tick: 18 loss 0.12313728034496307
# Training: On Tick: 19 loss 0.17670489847660065
# Training: On Tick: 20 loss 0.1575794368982315
# Training: On Tick: 21 loss 0.18888519704341888
# Training: On Tick: 22 loss 0.18001967668533325
# Training: On Tick: 23 loss 0.14165623486042023
# Training: On Tick: 24 loss 0.15826067328453064
# Training: On Tick: 25 loss 0.16775855422019958
# Training: On Tick: 26 loss 0.15843351185321808
# Training: On Tick: 27 loss 0.16404032707214355
# Training: On Tick: 28 loss 0.1310453861951828
# Training: On Tick: 29 loss 0.14626997709274292
# Training: On Tick: 30 loss 0.21768970787525177
# Training: On Tick: 31 loss 0.19172018766403198
# Training: On Tick: 32 loss 0.20476582646369934
# Training: On Tick: 33 loss 0.1628810167312622
# Training: On Tick: 34 loss 0.1415747106075287
# Training: On Tick: 35 loss 0.13521312177181244
# Training: On Tick: 36 loss 0.12115020304918289
# Training: On Tick: 37 loss 0.20597466826438904
# Training: On Tick: 38 loss 0.14343120157718658
# Training: On Tick: 39 loss 0.13963989913463593
# Training: On Tick: 40 loss 0.13215157389640808
# Training: On Tick: 41 loss 0.135875403881073
# Training: On Tick: 42 loss 0.15526843070983887
# Training: On Tick: 43 loss 0.1708878129720688
# Training: On Tick: 44 loss 0.1808384507894516
# Training: On Tick: 45 loss 0.13829189538955688
# Epoch: 29 Loss: 0.15900877474442773
# CPU times: user 18min 12s, sys: 12min 10s, total: 30min 22s
# Wall time: 37min 39s

# %% [markdown]
# #### (g) Qualitative and quantitative evaluation of predictions (OVERFIT_NET vs TRAINED_NET):

# %%
# switch back to evaluation mode
trained_net.eval()

sample_img, sample_target = sanity_joint_transform(*sample1)
if USE_GPU:
    sample_img = sample_img.cuda()
sample_output_O = overfit_net.forward(sample_img[None])
sample_output_T = trained_net.forward(sample_img[None])

print(sample_output_T.shape)

# computing mIOU (quantitative measure of accuracy for network predictions)
pred_T = torch.argmax(sample_output_T, dim=1).cpu().numpy()[0]
pred_O = torch.argmax(sample_output_O, dim=1).cpu().numpy()[0]
print(pred_T.max())
gts = torch.from_numpy(np.array(sample1[1].convert('P'), dtype=np.int32)).long().numpy()
gts[gts == 255] = -1
conf_T = eval_semantic_segmentation(pred_T[None], gts[None])
conf_O = eval_semantic_segmentation(pred_O[None], gts[None])


fig = plt.figure(figsize=(14,10))
ax1 = fig.add_subplot(2,2,1)
plt.title('image sample')
ax1.imshow(sample1[0])
ax2 = fig.add_subplot(2,2,2)
plt.title('ground truth (target)')
ax2.imshow(sample1[1])
ax3 = fig.add_subplot(2,2,3)
plt.title('OVERFIT_NET prediction (for its training image)')
ax3.text(10, 25, 'mIoU = {:_>8.6f}'.format(conf_O['miou']), fontsize=20, color='white')
ax3.imshow(colorize_mask(torch.argmax(sample_output_O, dim=1).cpu().numpy()[0]))
ax4 = fig.add_subplot(2,2,4)
plt.title('TRAINED_NET prediction (for one of its training images)')
ax4.text(10, 25, 'mIoU = {:_>8.6f}'.format(conf_T['miou']), fontsize=20, color='white')
ax4.imshow(colorize_mask(torch.argmax(sample_output_T, dim=1).cpu().numpy()[0]))
# Out:
# torch.Size([1, 21, 375, 500])
# 15
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:91: RuntimeWarning: invalid value encountered in true_divide
#   iou = np.diag(confusion) / iou_denominator
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:168: RuntimeWarning: invalid value encountered in true_divide
#   class_accuracy = np.diag(confusion) / np.sum(confusion, axis=1)

# %% [markdown]
# ### Above Results
# The results are significantly worse than the overfit case, but still does identify the general shape and class.

# %%
sample_img, sample_target = sanity_joint_transform(*sample2)
if USE_GPU:
    sample_img = sample_img.cuda()
sample_output_O = overfit_net.forward(sample_img[None])
sample_output_T = trained_net.forward(sample_img[None])

# computing mIOU (quantitative measure of accuracy for network predictions)
pred_O = torch.argmax(sample_output_O, dim=1).cpu().numpy()[0]
pred_T = torch.argmax(sample_output_T, dim=1).cpu().numpy()[0]
gts = torch.from_numpy(np.array(sample2[1].convert('P'), dtype=np.int32)).long().numpy()
gts[gts == 255] = -1
conf_O = eval_semantic_segmentation(pred_O[None], gts[None])
conf_T = eval_semantic_segmentation(pred_T[None], gts[None])


fig = plt.figure(figsize=(14,10))
ax1 = fig.add_subplot(2,2,1)
plt.title('image sample')
ax1.imshow(sample2[0])
ax2 = fig.add_subplot(2,2,2)
plt.title('ground truth (target)')
ax2.imshow(sample2[1])
ax3 = fig.add_subplot(2,2,3)
plt.title('OVERFIT_NET prediction (for image it has not seen)')
ax3.text(10, 25, 'mIoU = {:_>8.6f}'.format(conf_O['miou']), fontsize=20, color='white')
ax3.imshow(colorize_mask(torch.argmax(sample_output_O, dim=1).cpu().numpy()[0]))
ax4 = fig.add_subplot(2,2,4)
plt.title('TRAINED_NET prediction (for image it has not seen)')
ax4.text(10, 25, 'mIoU = {:_>8.6f}'.format(conf_T['miou']), fontsize=20, color='white')
ax4.imshow(colorize_mask(torch.argmax(sample_output_T, dim=1).cpu().numpy()[0]))
# Out:
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:91: RuntimeWarning: invalid value encountered in true_divide
#   iou = np.diag(confusion) / iou_denominator
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:168: RuntimeWarning: invalid value encountered in true_divide
#   class_accuracy = np.diag(confusion) / np.sum(confusion, axis=1)

# %% [markdown]
# ### Above Results
# The network is able to identify the rough shape, and so performance is better than the overfit network, but exact class matching it not great.

# %%
some_img = VOCSegmentation(DATASET_PATH, image_set='train', download = False)[500]

sample_img, sample_target = JointNormalize(*norm)(*JointToTensor()(*some_img))
if USE_GPU:
    sample_img = sample_img.cuda()
sample_output_O = overfit_net.forward(sample_img[None])
sample_output_T = trained_net.forward(sample_img[None])

# computing mIOU (quantitative measure of accuracy for network predictions)
pred_O = torch.argmax(sample_output_O, dim=1).cpu().numpy()[0]
pred_T = torch.argmax(sample_output_T, dim=1).cpu().numpy()[0]
gts = torch.from_numpy(np.array(some_img[1].convert('P'), dtype=np.int32)).long().numpy()
gts[gts == 255] = -1
conf_O = eval_semantic_segmentation(pred_O[None], gts[None])
conf_T = eval_semantic_segmentation(pred_T[None], gts[None])


fig = plt.figure(figsize=(14,10))
ax1 = fig.add_subplot(2,2,1)
plt.title('image sample')
ax1.imshow(some_img[0])
ax2 = fig.add_subplot(2,2,2)
plt.title('ground truth (target)')
ax2.imshow(some_img[1])
ax3 = fig.add_subplot(2,2,3)
plt.title('OVERFIT_NET prediction (for image it has not seen)')
ax3.text(10, 25, 'mIoU = {:_>8.6f}'.format(conf_O['miou']), fontsize=20, color='white')
ax3.imshow(colorize_mask(torch.argmax(sample_output_O, dim=1).cpu().numpy()[0]))
ax4 = fig.add_subplot(2,2,4)
plt.title('TRAINED_NET prediction (for image it has not seen)')
ax4.text(10, 25, 'mIoU = {:_>8.6f}'.format(conf_T['miou']), fontsize=20, color='white')
ax4.imshow(colorize_mask(torch.argmax(sample_output_T, dim=1).cpu().numpy()[0]))
# Out:
# VOC Root: drive/My Drive/cs484/dataset
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:91: RuntimeWarning: invalid value encountered in true_divide
#   iou = np.diag(confusion) / iou_denominator
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:168: RuntimeWarning: invalid value encountered in true_divide
#   class_accuracy = np.diag(confusion) / np.sum(confusion, axis=1)

# %% [markdown]
# ### Above Results
# The network is able to identify the people with quite good accuracy in comparison to other sanity checks for thr trained network. It does not identify the 2nd person as a different object very well, but does recognize something.

# %%
torch.save(trained_net, '/content/lib/model.pth')

# %% [markdown]
# #### (h) Evaluate TRAINED_NET on validation dataset.
# ##### Run the validation loop for TRAINED_NET against the validation dataset (it has not seen):

# %%
# %%time
# This will be slow on CPU (around 1 hour). On GPU it should take only a few minutes (depending on your GPU).
print("mIoU for TRAINED_NET over the validation dataset:{}".format(validate(val_loader, trained_net)[1]))

# %% [markdown]
# # Problem 6
#
# #### For the network that you implemented, write a paragraph or two about limitations / bottlenecks about the work. What could be improved? What seems to be some obvious issues with the existing works?

# %% [markdown]
# ### Student Answer
#
# The results achieved from the fully trained network were passable. They did not return the same level of detail as the overfit case, but an improvment over results of testing the overfit on random images. The first potential improvment would be to increase the scope of the network as a whole. This includes going deeper and having more layers, in other words increasing the dimension of the feature space the encoder outputs.
# This will help generate individually more detailed features, and give more room for the features to be re-arranged back into classes.
# Ideally this would be packaged with more skip connections to maintain spatial consistency, similar to the U-Net architecture. Adding more layers like so will add more parameters to the system, and thus increase computation time significantly.
# For the purpose of brevity of this assignment, compute resources were minimized where possible, creating a significant bottleneck. For a true production system, more time and compute would be needed.
#
# Expanding on the compute bottleneck, another likely improvement would be to increase the epoch count significantly. With a deeper network and more features to train, a longer training time will help improve results. Training time was similarly minimized where possible for brevity.
#
# Obvious issues with the current network are the rate of decoding. Only 3 upsampling layers are used (intermittent with regular convolutions, batch norms, and relu layers). Having a slower upsampling process will help maintain feature resolution over the conversion to spatial resolution, improving results.
# This would similarly require much more compute resources as the increased computation count, and parameter count too if adding more transpose convolutions.

# %%
# For printing to PDF nicely in colab
# !sudo apt-get install texlive-xetex texlive-fonts-recommended texlive-generic-recommended

# # change this path to where your colab is stored
# %cd "/content/drive/My Drive/Colab Notebooks"
# !pwd 

# # change path_planning_colab to your file name
# !jupyter nbconvert --to pdf Final_MySemanticSegmentation_student.ipynb
