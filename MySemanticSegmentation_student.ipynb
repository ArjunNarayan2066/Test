# %% [markdown]
# <a href="https://colab.research.google.com/github/ArjunNarayan2066/Test/blob/master/MySemanticSegmentation_student.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from os.path import exists
if (exists('images') == False):
    print('Copying Images')
    # !cp -r "drive/My Drive/cs484/images/" .
if (exists('lib') == False):
    print('Copying Lib')
    # !cp -r "drive/My Drive/cs484/lib/" .

# %% [markdown]
# ### CS 484/684 Computational Vision
# #### credits: many thanks for the design of this assignemnt go to <a href="https://tovacinni.github.io/" target = "_blank">Towaki Takikawa</a>
#
# # Homework Assignment #5 - Supervised Deep Learning for Segmentation
#
# This assignment will test your understanding of applying deep learning by having you apply (fully supervised) deep learning to semantic segmentation, a well studied problem in computer vision.
#
# You can get most of the work done using only CPU, however, the use of GPU will be helpful in later parts. Programming and debugging everything upto and including problem 5c should be fine on CPU. You will notice the benefit of GPU mostly in later parts (d-h) of problem 5, but they are mainly implemenmted and test your code written and debugged earlier. If you do not have a GPU readily accesible to you, we recommend that you use Google Colaboratory to get access to a GPU. Once you are satisfied with your code upto and including 5(c), simply upload this Jupyter Notebook to Google Colaboratory to run the tests in later parts of Problem 5.
#
# Proficiency with PyTorch is required. Working through the PyTorch tutorials will make this assignment significantly easier. https://pytorch.org/tutorials/

# %%
# %matplotlib inline

# It is best to start with USE_GPU = False (implying CPU). Switch USE_GPU to True only if you want to use GPU. However... 
# we strongly recommend to wait until you are absolutely sure your CPU-based code works (at least on single image dataset)
USE_GPU = True

# %%
# Python Libraries
import random
import math
import numbers
import platform
import copy
from IPython.core.debugger import set_trace

# Importing essential libraries for basic image manipulations.
import numpy as np
import PIL
from PIL import Image, ImageOps
import matplotlib.pyplot as plt
from tqdm import tqdm

# We import some of the main PyTorch and TorchVision libraries used for HW4.
# Detailed installation instructions are here: https://pytorch.org/get-started/locally/
# That web site should help you to select the right 'conda install' command to be run in 'Anaconda Prompt'.
# In particular, select the right version of CUDA. Note that prior to installing PyTorch, you should  
# install the latest driver for your GPU and CUDA (9.2 or 10.1), assuming your GPU supports it. 
# For more information about pytorch refer to 
# https://pytorch.org/docs/stable/nn.functional.html
# https://pytorch.org/docs/stable/data.html.
# and https://pytorch.org/docs/stable/torchvision/transforms.html
import torch
import torch.nn.functional as F
from torch import nn
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
import torchvision.transforms.functional as tF
import torch.optim as optim

# !export CUDA_LAUNCH_BLOCKING=1
print(torch.cuda.is_available())
print(torch.cuda.get_device_name())

# Note class labels used in Pascal dataset:
# 0:    background,
# 1-20: aeroplane, bicycle, bird, boat, bottle, bus, car, cat, chair, cow, diningtable, dog, horse, motorbike,
#       person, pottedplant, sheep, sofa, train, TV_monitor
# 255: "void", which means class for pixel is undefined
# Out:
# True
# Tesla P100-PCIE-16GB

# %%
# !pip install chainercv # Need to manualy install this in the colab environment

# ChainerCV is a library similar to TorchVision, created and maintained by Preferred Networks. 
# Chainer, the base library, inspired and led to the creation of PyTorch! 
# Although Chainer and PyTorch are different, there are some nice functionalities in ChainerCV 
# that are useful, so we include it as an excersice on learning other libraries.
# To install ChainerCV, normally it suffices to run "pip install chainercv" inside "Anaconda Prompt".
# For more detailed installation instructions, see https://chainercv.readthedocs.io/en/stable/install.html
# For other information about ChainerCV library, refer to https://chainercv.readthedocs.io/en/stable/ 
from chainercv.evaluations import eval_semantic_segmentation
from chainercv.datasets import VOCSemanticSegmentationDataset
# Out:
# Requirement already satisfied: chainercv in /usr/local/lib/python3.6/dist-packages (0.13.1)
# Requirement already satisfied: chainer>=6.0 in /usr/local/lib/python3.6/dist-packages (from chainercv) (7.4.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (from chainercv) (7.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/dist-packages (from chainer>=6.0->chainercv) (3.0.12)
# Requirement already satisfied: protobuf>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from chainer>=6.0->chainercv) (3.12.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from chainer>=6.0->chainercv) (50.3.2)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from chainer>=6.0->chainercv) (1.18.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from chainer>=6.0->chainercv) (1.15.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from chainer>=6.0->chainercv) (3.7.4.3)

# %%
# This colorize_mask class takes in a numpy segmentation mask,
#  and then converts it to a PIL Image for visualization.
#  Since by default the numpy matrix contains integers from
#  0,1,...,num_classes, we need to apply some color to this
#  so we can visualize easier! Refer to:
#  https://pillow.readthedocs.io/en/4.1.x/reference/Image.html#PIL.Image.Image.putpalette
palette = [0, 0, 0, 128, 0, 0, 0, 128, 0, 128, 128, 0, 0, 0, 128, 128, 0, 128, 0, 128, 128,
           128, 128, 128, 64, 0, 0, 192, 0, 0, 64, 128, 0, 192, 128, 0, 64, 0, 128, 192, 0, 128,
           64, 128, 128, 192, 128, 128, 0, 64, 0, 128, 64, 0, 0, 192, 0, 128, 192, 0, 0, 64, 128]

def colorize_mask(mask):
    new_mask = Image.fromarray(mask.astype(np.uint8)).convert('P')
    new_mask.putpalette(palette)

    return new_mask

# %%
# Below we will use a sample image-target pair from VOC training dataset to test your joint transforms. 
# Running this block will automatically download the PASCAL VOC Dataset (3.7GB) to DATASET_PATH if "download = True".
# The code below creates subdirectory "datasets" in the same location as the notebook file, but
# you can modify DATASET_PATH to download the dataset to any custom directory. Download takes a few minutes.
# On subsequent runs you may save time by setting "download = False" (the default value of this flag)

# We provide our own implementation of torchvision.datasets.voc (containing popular "Pascal" dataset)
# that allows us to easily create single-image datasets
from lib.voc import VOCSegmentation
DATASET_PATH = 'drive/My Drive/cs484/dataset'

# Here, we obtain and visualize one sample (img, target) pair from VOC training dataset and one from validation dataset. 
# Note that operator [...] extracts the sample corresponding to the specified index. 
# Also, note the parameter download = True. Set this to False after you download to save time on later runs.
sample1 = VOCSegmentation(DATASET_PATH, image_set='train', download = False)[200]
sample2 = VOCSegmentation(DATASET_PATH, image_set='val')[20]

# We demonstrate two different (equivalent) ways to access image and target inside the samples.
img1, target1 = sample1
img2 = sample2[0]
target2 = sample2[1]

fig = plt.figure(figsize=(14,10))
ax1 = fig.add_subplot(2,2,1)
plt.title('sample1 - image')
ax1.imshow(img1)
ax2 = fig.add_subplot(2,2,2)
plt.title('sample1 - target')
ax2.imshow(target1)
ax3 = fig.add_subplot(2,2,3)
plt.title('sample2 - image')
ax3.imshow(img2)
ax4 = fig.add_subplot(2,2,4)
plt.title('sample2 - target')
ax4.imshow(target2)
# Out:
# VOC Root: drive/My Drive/cs484/dataset
# VOC Root: drive/My Drive/cs484/dataset

# %%
some_img = VOCSegmentation(DATASET_PATH, image_set='train', download = False)[300]
fig = plt.figure(figsize=(14,10))
ax1 = fig.add_subplot(1,2,1)
plt.title('sample1 - image')
ax1.imshow(some_img[0])
ax2 = fig.add_subplot(1,2,2)
plt.title('sample1 - target')
ax2.imshow(some_img[1])
# Out:
# VOC Root: drive/My Drive/cs484/dataset

# %% [markdown]
# # Problem 1
#
# #### Implement a set of "Joint Transform" functions to perform data augmentation in your dataset.
#
# Neural networks are typically applied to transformed images. There are several important reasons for this:
#
# 1. The image data should is in certain required format (i.e. consistent spacial resolution to batch). The images should also be normalized and converted to the "tensor" data format expected by pytorch libraries.
#
# 2. Some transforms are used to perform randomized image domain transformations with the purpose of "data augmentation".
#
# In this exercise, you will implement a set of different transform functions to do both of these things. Note that unlike classification nets, training semantic segmentation networks requires that some of the transforms are applied to both image and the corresponding "target" (Ground Truth segmentation mask). We refer to such transforms and their compositions as "Joint". In general, your Transform classes should take as the input both the image and the target, and return a tuple of the transformed input image and target. Be sure to use critical thinking to determine if you can apply the same transform function to both the input and the output.
#
# For this problem you may use any of the `torchvision.transforms.functional` functions. For inspiration, refer to:
# #### https://pytorch.org/tutorials/beginner/data_loading_tutorial.html
# #### https://pytorch.org/docs/stable/torchvision/transforms.html#module-torchvision.transforms.functional

# %% [markdown]
# #### Example 1
#
# This class takes a img, target pair, and then transform the pair such that they are in `Torch.Tensor()` format.
#
# #### Solution:

# %%
class JointToTensor(object):
    def __call__(self, img, target):
        # print(target.max())
        return tF.to_tensor(img), torch.from_numpy(np.array(target.convert('P'), dtype=np.int32)).long()

# %%
# Check the transform by passing the image-target sample.

img, target = JointToTensor()(*sample2)
print(target[target!=255].max())
fig = plt.figure(figsize=(12,6))
ax1 = fig.add_subplot(2,2,1)
ax1.imshow(img.permute(1,2,0))
ax2 = fig.add_subplot(2,2,2)
ax2.imshow(colorize_mask(target.numpy()))
# Out:
# tensor(17)

# %% [markdown]
# #### Example 2:
#
# This class implements CenterCrop that takes an img, target pair, and then apply a crop about the center of the image such that the output resolution is $\mbox{size} \times \mbox{size}$.
#
# #### Solution:

# %%
class JointCenterCrop(object):
    def __init__(self, size):
        """
        params:
            size (int) : size of the center crop
        """
        self.size = size
        
    def __call__(self, img, target):
        return (tF.five_crop(img, self.size)[4], 
                tF.five_crop(target, self.size)[4])
    
img, target = JointCenterCrop(100)(*sample1)
fig = plt.figure(figsize=(12,6))
ax1 = fig.add_subplot(2,2,1)
ax1.imshow(img)
ax2 = fig.add_subplot(2,2,2)
ax2.imshow(target)

# %% [markdown]
# #### (a) Implement RandomFlip
#
# This class should take a img, target pair and then apply a horizontal flip across the vertical axis at random.
#
# #### Solution:

# %%
class JointRandomFlip(object): 
    def __call__(self, img, target):
        if not isinstance(img, torch.Tensor):
            img, target = JointToTensor()(img, target)

        if np.random.randint(2):
            return (tF.hflip(img), tF.hflip(target))
        else:
            return (img, target)

# %%
img, target = JointRandomFlip()(*sample2)
print(target[target!=255].max())
fig = plt.figure(figsize=(12,6))
ax1 = fig.add_subplot(2,2,1)
ax1.imshow(img.permute(1,2,0))
ax2 = fig.add_subplot(2,2,2)
ax2.imshow(colorize_mask(target.numpy()))
# Out:
# tensor(17)

# %% [markdown]
# #### (b) Implement RandomResizeCrop
#
# This class should take a img, target pair and then resize the images by a random scale between $[\mbox{minimum_scale}, \mbox{maximum_scale}]$, crop a random location of the image by $\min(\mbox{size}, \mbox{image_height}, \mbox{image_width})$ (where the size is passed in as an integer in the constructor), and then resize to $\mbox{size} \times \mbox{size}$ (again, the size passed in). The crop box should fit within the image.
#
# #### Solution:

# %%
class JointRandomResizeCrop(object):
    def __init__(self, min_scale, max_scale, size):
        self.min_scale = min_scale
        self.max_scale = max_scale
        self.size = size

        self.scale_len = self.max_scale - self.min_scale

    def __call__(self, img, target):
        if not isinstance(img, PIL.Image.Image):
            target = transforms.ToPILImage()(target.type(torch.IntTensor))
            img = transforms.ToPILImage()(img)

        # Select Random Resize Scale
        scale = (np.random.rand() * (self.scale_len)) + self.min_scale
        rescaled_size = (int(img.size[0]*scale), int(img.size[1]*scale))
        print(rescaled_size[::-1])
        rescaled_img = tF.resize(img, rescaled_size[::-1])
        rescaled_target = tF.resize(target, rescaled_size[::-1], interpolation=PIL.Image.NEAREST)

        # Crop Then Resize
        crop_size = min((self.size, rescaled_img.size[0]-1, rescaled_img.size[1]-1))
        crop_c = np.random.randint(0, rescaled_img.size[0] - crop_size)
        crop_r = np.random.randint(0, rescaled_img.size[1] - crop_size)

        final_img = tF.resized_crop(rescaled_img, crop_r, crop_c, crop_size, crop_size, self.size)
        final_target= tF.resized_crop(rescaled_target, crop_r, crop_c, crop_size, crop_size, self.size)

        final_img, final_target = JointToTensor()(final_img, final_target)
        return final_img, final_target.type(torch.LongTensor)

# %%
# print(sample1[0].size)
final_img, final_target = JointRandomResizeCrop(1.1, 1.4, 400)(*JointToTensor()(*sample2))
print(final_target[final_target!=255].max())
# print(final_img.size)
fig = plt.figure(figsize=(12,6))
ax1 = fig.add_subplot(2,2,1)
# ax1.imshow(colorize_mask(target.numpy()))
ax1.imshow(final_img.permute(1,2,0))
ax2 = fig.add_subplot(2,2,2)
ax2.imshow(colorize_mask(final_target.numpy()))
# Out:
# (496, 661)
# tensor(17)

# %% [markdown]
# #### (c) Implement Normalize

# %% [markdown]
# This class should take a img, target pair and then normalize the images by subtracting the mean and dividing variance.
#
# #### Solution:

# %%
class JointResize(object):
    def __init__(self, size):
        self.size = size
    
    def __call__(self, img, target):
        if not isinstance(img, torch.Tensor):
            img, target = JointToTensor()(img, target)

        # print(img[None].shape)
        img = tF.resize(img[None], self.size)[0]#self.size)
        target = tF.resize(target[None], self.size, interpolation=PIL.Image.NEAREST)[0]
        # print(img.shape)

        return img, target

# %%
norm = ([0.485, 0.456, 0.406], 
        [0.229, 0.224, 0.225]) 
# means = [0.485, 0.456, 0.406]
# std = [0.229, 0.224, 0.225] 

class JointNormalize(object): 
    def __init__(self, mean, std):
        self.mean = mean
        self.std = std
          
    def __call__(self, img, target):
        if not isinstance(img, torch.Tensor):
            img, target = JointToTensor()(img, target)
        # target = target.double()
        # img_means = [img[:,:,0].mean(), img[:,:,1].mean(), img[:,:,2].mean()]
        # img_std = [img[:,:,0].std(), img[:,:,1].std(), img[:,:,2].img_std()]
        # target_means = [target[:,:,0].mean(), target[:,:,1].mean(), target[:,:,2].mean()]
        # target_std = [target[:,:,0].std(), target[:,:,1].std(), target[:,:,2].std()]

        # Normalize
        norm_img = tF.normalize(img, self.mean, self.std)
        # Rescale to 0-1
        norm_img -= norm_img.min()
        norm_img /= norm_img.max()

        # norm_target = tF.normalize(target, target.mean(), target.std())
        # norm_target = ((target - target.mean()) / target.std()).long()
        # print(norm_target)

        return norm_img, target

# %%
# fixed_img, fixed_target = JointNormalize(*norm)(*sample1)
fixed_img, fixed_target = JointResize((375,500))(*sample2)
print(fixed_target[fixed_target!=255].max())
fig = plt.figure(figsize=(12,6))
ax1 = fig.add_subplot(2,2,1)
ax1.imshow(fixed_img.permute(1,2,0))
ax2 = fig.add_subplot(2,2,2)
ax2.imshow(colorize_mask(fixed_target.numpy()))
# Out:
# tensor(17)

# %% [markdown]
# #### (d) Compose the transforms together:
# ##### Use `JointCompose` (fully implemeted below) to compose the implemented transforms together in some random order. Verify the output makes sense and visualize it.

# %%
# This class composes transofrmations from a given list of image transforms (expected in the argument). Such compositions 
# will be applied to the dataset during training. This cell is fully implemented.

class JointCompose(object):
    def __init__(self, transforms):
        """
        params: 
           transforms (list) : list of transforms
        """
        self.transforms = transforms

    # We override the __call__ function such that this class can be
    # called as a function i.e. JointCompose(transforms)(img, target)
    # Such classes are known as "functors"
    def __call__(self, img, target):
        """
        params:
            img (PIL.Image)    : input image
            target (PIL.Image) : ground truth label 
        """
        assert img.size == target.size
        for t in self.transforms:
            img, target = t(img, target)
        return img, target

# %%
# Student Answer:
tfs = [JointToTensor(), JointRandomResizeCrop(0.5, 0.8, 100), JointRandomFlip()]

img, target = JointCompose(tfs)(*sample1)
print(img.size)
fig = plt.figure(figsize=(12,6))
ax1 = fig.add_subplot(2,2,1)
ax1.imshow(img.permute(1,2,0))
ax2 = fig.add_subplot(2,2,2)
ax2.imshow(colorize_mask(target.numpy()))
# Out:
# (248, 331)
# <built-in method size of Tensor object at 0x7f38c7817ab0>

# %% [markdown]
# #### (e) Compose the transforms together: use `JointCompose` to compose the implemented transforms for:
# #### 1. A sanity dataset that will contain 1 single image. Your objective is to overfit on this 1 image, so choose your transforms and parameters accordingly.
# #### 2. A training dataset that will contain the training images. The goal here is to generalize to the validation set, which is unseen.
# #### 3. A validation dataset that will contain the validation images. The goal here is to measure the 'true' performance.

# %%
# Student Answer:

sanity_joint_transform  = JointCompose([JointToTensor(), JointResize((375,500)), JointNormalize(*norm)])

train_joint_transform   = JointCompose([JointToTensor(), JointResize((375,500)), JointNormalize(*norm)])#, JointRandomFlip()])

val_joint_transform     = JointCompose([JointToTensor(), JointResize((375,500))])#, JointRandomFlip()])#, JointRandomResizeCrop(0.5, 1.5, 300)])

# %% [markdown]
# This code below will then apply `train_joint_transform` to the entire dataset.

# %%
# Apply the Joint-Compose transformations above to create three datasets and the corresponding Data-Loaders.
# This cell is fully implemented.

# This single image data(sub)set can help to better understand and to debug the network training process. 
# Optional integer parameter 'sanity_check' specifies the index of the image-target pair and creates a single image dataset.
# Note that we use the same image (index=200) as used for sample1.
sanity_data = VOCSegmentation(
    DATASET_PATH, 
    image_set = 'train',
    transforms = sanity_joint_transform,
    sanity_check = 200
)

# This is a standard VOC data(sub)set used for training semantic segmentation networks
train_data = VOCSegmentation(
    DATASET_PATH, 
    image_set = 'train', 
    transforms = sanity_joint_transform,
    # sanity_check=300,
)

# This is a standard VOC data(sub)set used for validating semantic segmentation networks
val_data = VOCSegmentation(
    DATASET_PATH, 
    image_set='val',
    transforms = val_joint_transform
)

# Increase TRAIN_BATCH_SIZE if you are using GPU to speed up training. 
# When batch size changes, the learning rate may also need to be adjusted. 
# Note that batch size maybe limited by your GPU memory, so adjust if you get "run out of GPU memory" error.
TRAIN_BATCH_SIZE = 1 # 4 default

# If you are NOT using Windows, set NUM_WORKERS to anything you want, e.g. NUM_WORKERS = 4,
# but Windows has issues with multi-process dataloaders, so NUM_WORKERS must be 0 for Windows.
NUM_WORKERS =  0# default

sanity_loader = DataLoader(sanity_data, batch_size=1, num_workers=NUM_WORKERS, shuffle=False)
train_loader = DataLoader(train_data, batch_size=64, num_workers=NUM_WORKERS, shuffle=False)
val_loader = DataLoader(val_data, batch_size=1, num_workers=NUM_WORKERS, shuffle=False)
# Out:
# VOC Root: drive/My Drive/cs484/dataset
# VOC Root: drive/My Drive/cs484/dataset
# VOC Root: drive/My Drive/cs484/dataset

# %% [markdown]
# # Problem 2
#
# #### (a) Implement encoder/decoder segmentation CNN using PyTorch.
#
# You must follow the general network architecture specified in the image below. Note that since convolutional layers are the main building blocks in common network architectures for image analysis, the corresponding blocks are typically unlabeled in the network diagrams. The network should have 5 (pre-trained) convolutional layers (residual blocks) from "resnet" in the encoder part, two upsampling layers, and one skip connection. For the layer before the final upsampling layer, lightly experiment with some combination of Conv, ReLU, BatchNorm, and/or other layers to see how it affects performance.
# <img src="images\deeplabv2_overview.png">
# You should choose specific parameters for all layers, but the overall structure should be restricted to what is shown in the illustration above. For inspiration, you can refer to papers in the citation section of the following link to DeepLab (e.g. specific parameters for each layer): http://liangchiehchen.com/projects/DeepLab.html. The first two papers in the citation section are particularly relevant.
#
# In your implementation, you can use a base model of choice (you can use `torchvision.models` as a starting point), but we suggest that you learn the properties of each base model and choose one according to the computational resources available to you.
#
# ##### Note: do not apply any post-processing (such as DenseCRF) to the output of your net.
#
# #### Solution:

# %%
import torchvision.models as models

class MyNet(nn.Module):
    def __init__(self, num_classes, img_size, criterion=None):
        super(MyNet, self).__init__()
        # Implement me

        # Get initial few layers + 6 res blocks in packs of 2
        self.encoder1 = nn.Sequential(*list(models.resnet18(pretrained=True).children())[:5])
        self.encoder2 = nn.Sequential(*list(models.resnet18(pretrained=True).children())[5:7])

        self.up1 = nn.ConvTranspose2d(256, 256, kernel_size=(6,5), stride=(4,4), dilation=(1,1), padding=(2,2))
        self.relu = nn.ReLU()

        self.conv1 = nn.Conv2d(320,256,kernel_size=3,stride=2,dilation=2)
        self.conv2 = nn.Conv2d(256,128,kernel_size=3,stride=2,dilation=2)
        self.up2 = nn.ConvTranspose2d(128, 64, kernel_size=7,stride=3,dilation=3,padding=2)
        self.bn1 = nn.BatchNorm2d(128)
        self.bn2 = nn.BatchNorm2d(64)

        self.conv3 = nn.Conv2d(64,num_classes, kernel_size=4,stride=2,dilation=2)
        self.final_up = nn.Upsample(size=img_size, mode='bilinear', align_corners=True)

        # self.sf = nn.Softmax(dim=1)

    def forward(self, inp, gts=None):

        # Assuming using GPU on colab

        ## Encoder
        x = self.encoder1(inp) # batch x 64 x 94 x 125
        skip = x
        x = self.encoder2(x) # batch x 256 x 24 x 32

        ## Decoder Step 1
        x = self.up1(x) # batch x 256 x 94 x 125

        # Skip Connection
        x = torch.cat((x, skip), dim=1) # batch x 320 x 94 x 125
        x = self.relu(self.conv1(x)) # batch x 256 x 91 x 122
        x = self.relu(self.conv2(x)) # batch x 128 x 88 x 119
        x = self.bn1(x)
        # print(x.size())

        ## Decoder Step 2
        x = self.up2(x) # Transpose conv, 64 channels now
        # print(x.size())

        x = self.bn2(x)
        x = self.conv3(x) # 21 channels

        ## Final Decoder Step
        lfinal = self.final_up(x) # batch x 21 x 375 x 500

        # lfinal = self.sf(x) # softmax, batch x 21 x 375 x 500

        test_val = torch.argmax(lfinal, dim=1)[0].cpu().numpy()
        print("max: {}".format(test_val.max()))

        # if self.training:
        #     # Return the loss if in training mode
        #     return self.criterion(lfinal, gts)              
        # else:
        #     # Return the actual prediction otherwise
        return lfinal

# %%
import torchvision.models as models

class MyOldNet(nn.Module):
    def __init__(self, num_classes, img_size, criterion=None):
        super(MyNet, self).__init__()
        # Implement me

        # Get initial few layers + 6 res blocks in packs of 2
        self.encoder1 = nn.Sequential(*list(models.resnet18(pretrained=True).children())[:5])
        self.encoder2 = nn.Sequential(*list(models.resnet18(pretrained=True).children())[5:7])

        self.up1 = nn.Upsample(size=(94, 125), mode='bilinear')
        self.relu = nn.ReLU()
        self.conv1 = nn.Conv2d(320,128,kernel_size=4)
        # self.bn1 = nn.BatchNorm2d(128)

        self.conv2 = nn.Conv2d(128,num_classes, kernel_size=4)
        self.final_up = nn.Upsample(size=img_size, mode='bilinear', align_corners=True)

        self.sf = nn.Softmax(dim=1)

    def forward(self, inp, gts=None):

        # Assuming using GPU on colab

        x = self.encoder1(inp) # batch x 64 x 94 x 125
        skip = x
        x = self.encoder2(x) # batch x 256 x 24 x 32

        x = self.relu(self.up1(x)) # batch x 256 x 94 x 125

        # Skip Connection
        x = torch.cat((x, skip), dim=1) # batch x 320 x 94 x 125

        x = self.relu(self.conv1(x)) # batch x 128 x 91 x 122

        x = self.relu(self.conv2(x)) # batch x 128 x 88 x 119

        x = self.relu(self.final_up(x)) # batch x 21 x 375 x 500

        lfinal = self.sf(x) # softmax, batch x 21 x 375 x 500

        test_val = torch.argmax(lfinal, dim=1)[0].cpu().numpy()
        print("max: {}".format(test_val.max()))

        # if self.training:
        #     # Return the loss if in training mode
        #     return self.criterion(lfinal, gts)              
        # else:
        #     # Return the actual prediction otherwise
        return lfinal

# %%
list(models.resnet18(pretrained=True).children())[:5]
# Out:
# [Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False),
#  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
#  ReLU(inplace=True),
#  MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False),
#  Sequential(
#    (0): BasicBlock(
#      (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#      (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      (relu): ReLU(inplace=True)
#      (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#      (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#    )
#    (1): BasicBlock(
#      (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#      (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      (relu): ReLU(inplace=True)
#      (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#      (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#    )
#  )]

# %% [markdown]
# #### (b) Create UNTRAINED_NET and run on a sample image

# %%
print(torch.cuda.get_device_name())

untrained_net = MyNet(21, (375,500)).eval()
sample_img, sample_target = JointNormalize(*norm)(*JointToTensor()(*sample1))
# sample_img, sample_target = JointCenterCrop(224)(sample_img, sample_target)
# print(sample_img[None].size())
untrained_output = untrained_net.forward(sample_img[None])

# Convert to 375 x 500 image of int classes
sample_output = torch.argmax(untrained_output, dim=1).numpy()

fig = plt.figure(figsize=(14,10))
ax = fig.add_subplot(1,3,1)
plt.title('image sample')
ax.imshow(sample1[0])
ax = fig.add_subplot(1,3,2)
plt.title('ground truth (target)')
ax.imshow(sample1[1])
ax = fig.add_subplot(1,3,3)
plt.title('UNTRAINED_NET output/prediction')
# print(untrained_output.size())
ax.imshow(colorize_mask(sample_output[0]))
# ax.imshow(colorize_mask(untrained_output.numpy()[0]))
# Out:
# Tesla P100-PCIE-16GB
# max: 18

# %% [markdown]
# # Problem 3
#
# #### (a) Implement the loss function (Cross Entropy Loss). Do not use already implemented versions of this loss function.
#
# Feel free to use functions like `F.log_softmax` and `F.nll_loss` (if you want to, or you can just implement the math).

# %%
# Student Answer:

# class MyCrossEntropyLoss(...):

# %% [markdown]
# #### (b) Compare against the existing CrossEntropyLoss function on your sample output from your neural network.

# %%
criterion = nn.CrossEntropyLoss(ignore_index=255)
print(criterion)
print(sample_target[None].size())
print(untrained_output[0].size())
print(sample_target.size())
print(criterion(untrained_output, sample_target[None]))

# my_criterion = MyCrossEntropyLoss(ignore_index=255)

# print(my_criterion(untrained_output, sample_target[None]))
# Out:
# CrossEntropyLoss()
# torch.Size([1, 375, 500])
# torch.Size([21, 375, 500])
# torch.Size([375, 500])
# tensor(3.0421, grad_fn=<NllLoss2DBackward>)

# %% [markdown]
# # Problem 4
#
# #### (a) Use standard function `eval_semantic_segmentation` (already imported from chainerCV) to compute "mean intersection over union" for the output of UNTRAINED_NET on sample1 (`untrained_output`) using the target for sample1. Read documentations for function  `eval_semantic_segmentation` to properly set its input parameters.

# %%
# Write code to propely compute 'pred' and 'gts' as arguments for function 'eval_semantic_segemntation'

np_target = sample_target.numpy().astype(np.int32)
np_target[np_target==255] = -1
initial_gts = np.array([np_target])

initial_pred = sample_output
print(initial_pred.shape)
initial_conf = eval_semantic_segmentation(initial_pred, initial_gts)

print("mIoU for the sample image / ground truth pair: {}".format(initial_conf['miou']))
# Out:
# (1, 375, 500)
# mIoU for the sample image / ground truth pair: 0.00039601940820595613
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:91: RuntimeWarning: invalid value encountered in true_divide
#   iou = np.diag(confusion) / iou_denominator
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:168: RuntimeWarning: invalid value encountered in true_divide
#   class_accuracy = np.diag(confusion) / np.sum(confusion, axis=1)

# %% [markdown]
# #### (b) Write the validation loop.

# %%
def validate(val_data_loader, net):
    iou_arr = []
    val_loss = []

    if USE_GPU:
        net = net.cuda()
    
    with torch.no_grad():
        for i, data in enumerate(val_data_loader):
            print("Tick: {}".format(i))
            inputs, masks = data

            print("shape: {}".format(masks.shape))

            if USE_GPU:
                masks = masks.cuda()
                inputs = inputs.cuda()

            outputs = net(inputs)

            np_target = masks[0].cpu().numpy().astype(np.int32)
            np_target[np_target == 255] = -1

            gts = np.array([np_target])
            preds = torch.argmax(outputs, dim=1).cpu().numpy()

            val_loss.append(criterion(outputs, masks))
            # Write menearest

            # Hint: make sure the range of values of the ground truth is what you expectg
            
            conf = eval_semantic_segmentation(preds, gts)

            iou_arr.append(conf['miou'])
    
    print(iou_arr)
    return val_loss, (sum(iou_arr) / len(iou_arr))

# %% [markdown]
# #### (c) Run the validation loop for UNTRAINED_NET against the sanity validation dataset.

# %%
# %%time
print("mIoU over the sanity dataset:{}".format(validate(sanity_loader, untrained_net)[1]))
# Out:
# Tick: 0
# shape: torch.Size([1, 375, 500])
# max: 18
# [0.00039601940820595613]
# mIoU over the sanity dataset:0.00039601940820595613
# CPU times: user 38.6 ms, sys: 3.94 ms, total: 42.6 ms
# Wall time: 47.2 ms
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:91: RuntimeWarning: invalid value encountered in true_divide
#   iou = np.diag(confusion) / iou_denominator
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:168: RuntimeWarning: invalid value encountered in true_divide
#   class_accuracy = np.diag(confusion) / np.sum(confusion, axis=1)

# %% [markdown]
# # Problem 5
#
# #### (a) Define an optimizer to train the given loss function.
#
# Feel free to choose your optimizer of choice from https://pytorch.org/docs/stable/optim.html.

# %%
def get_optimizer(net):
    optimizer = optim.Adam(net.parameters(), lr=1e-4)
    return optimizer

# %% [markdown]
# #### (b) Write the training loop to train the network.

# %%
import time

def train(train_data_loader, net, optimizer, loss_graph):
    for i, data in enumerate(train_data_loader):
        inputs, masks = data
    
        if USE_GPU:
            net = net.cuda()
            inputs = inputs.cuda()
            masks = masks.cuda()
        
        # Write me
        outputs = net(inputs)
        loss = net.criterion(outputs, masks)
        print("Training: On Tick: {} loss {}".format(i, loss))
        loss_graph.append(loss)

        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

        # loss_graph.append() Populate this list to graph the loss
    
    # print("All Loses: {},{} ".format(len(loss_graph), loss_graph))
    return (sum(loss_graph) / len(loss_graph))

# %% [markdown]
# #### (c) Create OVERFIT_NET and train it on the single image dataset.
# ##### Single image training is helpful for debugging and hyper-parameter tuning (e.g. learning rate, etc.) as it is fast even on a single CPU. In particular, you can work with a single image until your loss function is consistently decreasing during training loop and the network starts producing a reasonable output for this training image. Training on a single image also teaches about overfitting, particualrly when comparing it with more thorough forms of network training.

# %%
# %%time
# %matplotlib notebook
import time

# The whole training on a single image (20-40 epochs) should take only a minute or two on a CPU (and a few seconds on GPU). 
# Below we create a (deep) copy of untrained_net and train it on a single training image (leading to gross overfitting).
# Later, we will create a separate (deep) copy of untrained_net to be trained on full training dataset.
# NOTE: Normally, one can create a new net via declaration new_net = MyNet(21). But, randomization of weights when new nets 
# are declared that way creates *different* untrained nets. This notebook compares different versions of network training. 
# For this comparison to be direct and fair, it is better to train (deep) copies of the exact same untrained_net. 
overfit_net = copy.deepcopy(untrained_net)

# set loss function for the net
overfit_net.criterion = nn.CrossEntropyLoss(ignore_index=255)

# You can change the number of EPOCHS
EPOCH = 100

# switch to train mode (original untrained_net was set to eval mode)
overfit_net.train()

optimizer = get_optimizer(overfit_net)

print("Starting Training...")

loss_graph = []

fig = plt.figure(figsize=(12,6))
plt.subplots_adjust(bottom=0.2,right=0.85,top=0.95)
ax = fig.add_subplot(1,1,1)

for e in range(EPOCH):
    new_loss_graph = []
    loss = train(sanity_loader, overfit_net, optimizer, new_loss_graph)
    loss_graph += new_loss_graph
    ax.clear()
    ax.set_xlabel('iterations')
    ax.set_ylabel('loss value')
    ax.set_title('Training loss curve for OVERFIT_NET')
    ax.plot(loss_graph, label='training loss')
    ax.legend(loc='upper right')
    fig.canvas.draw()
    print("Epoch: {} Loss: {}".format(e, loss))
print("Final Loss: {}".format(loss))
# %matplotlib inline
plt.show()
# Out:
# Starting Training...
# <div id='c91983b2-13fc-452f-b3f6-7a083698f7d2'></div>
# max: 20
# Training: On Tick: 0 loss 3.1109561920166016
# Epoch: 0 Loss: 3.1109561920166016
# max: 20
# Training: On Tick: 0 loss 2.8371801376342773
# Epoch: 1 Loss: 2.8371801376342773
# max: 20
# Training: On Tick: 0 loss 2.604679822921753
# Epoch: 2 Loss: 2.604679822921753
# max: 20
# Training: On Tick: 0 loss 2.39963960647583
# Epoch: 3 Loss: 2.39963960647583
# max: 20
# Training: On Tick: 0 loss 2.2117059230804443
# Epoch: 4 Loss: 2.2117059230804443
# max: 20
# Training: On Tick: 0 loss 2.04232120513916
# Epoch: 5 Loss: 2.04232120513916
# max: 20
# Training: On Tick: 0 loss 1.890155553817749
# Epoch: 6 Loss: 1.890155553817749
# max: 20
# Training: On Tick: 0 loss 1.7528507709503174
# Epoch: 7 Loss: 1.7528507709503174
# max: 20
# Training: On Tick: 0 loss 1.6262229681015015
# Epoch: 8 Loss: 1.6262229681015015
# max: 20
# Training: On Tick: 0 loss 1.5090692043304443
# Epoch: 9 Loss: 1.5090692043304443
# max: 20
# Training: On Tick: 0 loss 1.3980146646499634
# Epoch: 10 Loss: 1.3980146646499634
# max: 20
# Training: On Tick: 0 loss 1.2927874326705933
# Epoch: 11 Loss: 1.2927874326705933
# max: 20
# Training: On Tick: 0 loss 1.1932673454284668
# Epoch: 12 Loss: 1.1932673454284668
# max: 20
# Training: On Tick: 0 loss 1.0991822481155396
# Epoch: 13 Loss: 1.0991822481155396
# max: 18
# Training: On Tick: 0 loss 1.0115405321121216
# Epoch: 14 Loss: 1.0115405321121216
# max: 18
# Training: On Tick: 0 loss 0.9312098026275635
# Epoch: 15 Loss: 0.9312098026275635
# max: 18
# Training: On Tick: 0 loss 0.8581941723823547
# Epoch: 16 Loss: 0.8581941723823547
# max: 18
# Training: On Tick: 0 loss 0.7925798892974854
# Epoch: 17 Loss: 0.7925798892974854
# max: 18
# Training: On Tick: 0 loss 0.7340612411499023
# Epoch: 18 Loss: 0.7340612411499023
# max: 15
# Training: On Tick: 0 loss 0.6814327836036682
# Epoch: 19 Loss: 0.6814327836036682
# max: 15
# Training: On Tick: 0 loss 0.6335415840148926
# Epoch: 20 Loss: 0.6335415840148926
# max: 15
# Training: On Tick: 0 loss 0.5896172523498535
# Epoch: 21 Loss: 0.5896172523498535
# max: 15
# Training: On Tick: 0 loss 0.5486246943473816
# Epoch: 22 Loss: 0.5486246943473816
# max: 15
# Training: On Tick: 0 loss 0.5106220841407776
# Epoch: 23 Loss: 0.5106220841407776
# max: 15
# Training: On Tick: 0 loss 0.4753665626049042
# Epoch: 24 Loss: 0.4753665626049042
# max: 15
# Training: On Tick: 0 loss 0.4428432285785675
# Epoch: 25 Loss: 0.4428432285785675
# max: 15
# Training: On Tick: 0 loss 0.4130772650241852
# Epoch: 26 Loss: 0.4130772650241852
# max: 15
# Training: On Tick: 0 loss 0.38595113158226013
# Epoch: 27 Loss: 0.38595113158226013
# max: 15
# Training: On Tick: 0 loss 0.36136338114738464
# Epoch: 28 Loss: 0.36136338114738464
# max: 15
# Training: On Tick: 0 loss 0.3390001356601715
# Epoch: 29 Loss: 0.3390001356601715
# max: 15
# Training: On Tick: 0 loss 0.31852346658706665
# Epoch: 30 Loss: 0.31852346658706665
# max: 15
# Training: On Tick: 0 loss 0.29968178272247314
# Epoch: 31 Loss: 0.29968178272247314
# max: 15
# Training: On Tick: 0 loss 0.2822176516056061
# Epoch: 32 Loss: 0.2822176516056061
# max: 15
# Training: On Tick: 0 loss 0.2661352753639221
# Epoch: 33 Loss: 0.2661352753639221
# max: 15
# Training: On Tick: 0 loss 0.25134050846099854
# Epoch: 34 Loss: 0.25134050846099854
# max: 15
# Training: On Tick: 0 loss 0.2377595752477646
# Epoch: 35 Loss: 0.2377595752477646
# max: 15
# Training: On Tick: 0 loss 0.22526724636554718
# Epoch: 36 Loss: 0.22526724636554718
# max: 15
# Training: On Tick: 0 loss 0.21373237669467926
# Epoch: 37 Loss: 0.21373237669467926
# max: 15
# Training: On Tick: 0 loss 0.2030460387468338
# Epoch: 38 Loss: 0.2030460387468338
# max: 15
# Training: On Tick: 0 loss 0.19312545657157898
# Epoch: 39 Loss: 0.19312545657157898
# max: 15
# Training: On Tick: 0 loss 0.1839005947113037
# Epoch: 40 Loss: 0.1839005947113037
# max: 15
# Training: On Tick: 0 loss 0.17533108592033386
# Epoch: 41 Loss: 0.17533108592033386
# max: 15
# Training: On Tick: 0 loss 0.16736683249473572
# Epoch: 42 Loss: 0.16736683249473572
# max: 15
# Training: On Tick: 0 loss 0.15997223556041718
# Epoch: 43 Loss: 0.15997223556041718
# max: 15
# Training: On Tick: 0 loss 0.15309853851795197
# Epoch: 44 Loss: 0.15309853851795197
# max: 15
# Training: On Tick: 0 loss 0.14669662714004517
# Epoch: 45 Loss: 0.14669662714004517
# max: 15
# Training: On Tick: 0 loss 0.14071694016456604
# Epoch: 46 Loss: 0.14071694016456604
# max: 15
# Training: On Tick: 0 loss 0.1351177990436554
# Epoch: 47 Loss: 0.1351177990436554
# max: 15
# Training: On Tick: 0 loss 0.12986716628074646
# Epoch: 48 Loss: 0.12986716628074646
# max: 15
# Training: On Tick: 0 loss 0.12494006007909775
# Epoch: 49 Loss: 0.12494006007909775
# max: 15
# Training: On Tick: 0 loss 0.12031801789999008
# Epoch: 50 Loss: 0.12031801789999008
# max: 15
# Training: On Tick: 0 loss 0.11598324775695801
# Epoch: 51 Loss: 0.11598324775695801
# max: 15
# Training: On Tick: 0 loss 0.11191833764314651
# Epoch: 52 Loss: 0.11191833764314651
# max: 15
# Training: On Tick: 0 loss 0.10810030251741409
# Epoch: 53 Loss: 0.10810030251741409
# max: 15
# Training: On Tick: 0 loss 0.10450884699821472
# Epoch: 54 Loss: 0.10450884699821472
# max: 15
# Training: On Tick: 0 loss 0.10112816840410233
# Epoch: 55 Loss: 0.10112816840410233
# max: 15
# Training: On Tick: 0 loss 0.09793975204229355
# Epoch: 56 Loss: 0.09793975204229355
# max: 15
# Training: On Tick: 0 loss 0.09492825716733932
# Epoch: 57 Loss: 0.09492825716733932
# max: 15
# Training: On Tick: 0 loss 0.09208095818758011
# Epoch: 58 Loss: 0.09208095818758011
# max: 15
# Training: On Tick: 0 loss 0.08938754349946976
# Epoch: 59 Loss: 0.08938754349946976
# max: 15
# Training: On Tick: 0 loss 0.08683792501688004
# Epoch: 60 Loss: 0.08683792501688004
# max: 15
# Training: On Tick: 0 loss 0.08442238718271255
# Epoch: 61 Loss: 0.08442238718271255
# max: 15
# Training: On Tick: 0 loss 0.08213091641664505
# Epoch: 62 Loss: 0.08213091641664505
# max: 15
# Training: On Tick: 0 loss 0.07995405048131943
# Epoch: 63 Loss: 0.07995405048131943
# max: 15
# Training: On Tick: 0 loss 0.07788382470607758
# Epoch: 64 Loss: 0.07788382470607758
# max: 15
# Training: On Tick: 0 loss 0.07591307908296585
# Epoch: 65 Loss: 0.07591307908296585
# max: 15
# Training: On Tick: 0 loss 0.07403594255447388
# Epoch: 66 Loss: 0.07403594255447388
# max: 15
# Training: On Tick: 0 loss 0.07224663347005844
# Epoch: 67 Loss: 0.07224663347005844
# max: 15
# Training: On Tick: 0 loss 0.0705392062664032
# Epoch: 68 Loss: 0.0705392062664032
# max: 15
# Training: On Tick: 0 loss 0.06890882551670074
# Epoch: 69 Loss: 0.06890882551670074
# max: 15
# Training: On Tick: 0 loss 0.0673503428697586
# Epoch: 70 Loss: 0.0673503428697586
# max: 15
# Training: On Tick: 0 loss 0.06585979461669922
# Epoch: 71 Loss: 0.06585979461669922
# max: 15
# Training: On Tick: 0 loss 0.06443267315626144
# Epoch: 72 Loss: 0.06443267315626144
# max: 15
# Training: On Tick: 0 loss 0.06306518614292145
# Epoch: 73 Loss: 0.06306518614292145
# max: 15
# Training: On Tick: 0 loss 0.06175335869193077
# Epoch: 74 Loss: 0.06175335869193077
# max: 15
# Training: On Tick: 0 loss 0.06049397215247154
# Epoch: 75 Loss: 0.06049397215247154
# max: 15
# Training: On Tick: 0 loss 0.0592840276658535
# Epoch: 76 Loss: 0.0592840276658535
# max: 15
# Training: On Tick: 0 loss 0.05812051147222519
# Epoch: 77 Loss: 0.05812051147222519
# max: 15
# Training: On Tick: 0 loss 0.05700112506747246
# Epoch: 78 Loss: 0.05700112506747246
# max: 15
# Training: On Tick: 0 loss 0.05592343583703041
# Epoch: 79 Loss: 0.05592343583703041
# max: 15
# Training: On Tick: 0 loss 0.05488472059369087
# Epoch: 80 Loss: 0.05488472059369087
# max: 15
# Training: On Tick: 0 loss 0.053883377462625504
# Epoch: 81 Loss: 0.053883377462625504
# max: 15
# Training: On Tick: 0 loss 0.05291721597313881
# Epoch: 82 Loss: 0.05291721597313881
# max: 15
# Training: On Tick: 0 loss 0.051984354853630066
# Epoch: 83 Loss: 0.051984354853630066
# max: 15
# Training: On Tick: 0 loss 0.05108321085572243
# Epoch: 84 Loss: 0.05108321085572243
# max: 15
# Training: On Tick: 0 loss 0.05021219700574875
# Epoch: 85 Loss: 0.05021219700574875
# max: 15
# Training: On Tick: 0 loss 0.049369774758815765
# Epoch: 86 Loss: 0.049369774758815765
# max: 15
# Training: On Tick: 0 loss 0.048554349690675735
# Epoch: 87 Loss: 0.048554349690675735
# max: 15
# Training: On Tick: 0 loss 0.04776491969823837
# Epoch: 88 Loss: 0.04776491969823837
# max: 15
# Training: On Tick: 0 loss 0.04700005054473877
# Epoch: 89 Loss: 0.04700005054473877
# max: 15
# Training: On Tick: 0 loss 0.04625869169831276
# Epoch: 90 Loss: 0.04625869169831276
# max: 15
# Training: On Tick: 0 loss 0.045539647340774536
# Epoch: 91 Loss: 0.045539647340774536
# max: 15
# Training: On Tick: 0 loss 0.044841982424259186
# Epoch: 92 Loss: 0.044841982424259186
# max: 15
# Training: On Tick: 0 loss 0.044164836406707764
# Epoch: 93 Loss: 0.044164836406707764
# max: 15
# Training: On Tick: 0 loss 0.04350712150335312
# Epoch: 94 Loss: 0.04350712150335312
# max: 15
# Training: On Tick: 0 loss 0.04286796972155571
# Epoch: 95 Loss: 0.04286796972155571
# max: 15
# Training: On Tick: 0 loss 0.04224662110209465
# Epoch: 96 Loss: 0.04224662110209465
# max: 15
# Training: On Tick: 0 loss 0.04164234921336174
# Epoch: 97 Loss: 0.04164234921336174
# max: 15
# Training: On Tick: 0 loss 0.041054416447877884
# Epoch: 98 Loss: 0.041054416447877884
# max: 15
# Training: On Tick: 0 loss 0.040482062846422195
# Epoch: 99 Loss: 0.040482062846422195
# Final Loss: 0.040482062846422195
# CPU times: user 9.79 s, sys: 285 ms, total: 10.1 s
# Wall time: 10.5 s

# %% [markdown]
# #### Qualitative and quantitative evaluation of predictions (untrained vs overfit nets) - fully implemented.

# %%
# switch back to evaluation mode
overfit_net.eval()

sample_img, sample_target = JointNormalize(*norm)(*JointToTensor()(*sample1))
if USE_GPU:
    sample_img = sample_img.cuda()
sample_output_O = overfit_net.forward(sample_img[None])
sample_output_U = untrained_net.forward(sample_img[None])

# computing mIOU (quantitative measure of accuracy for network predictions)
if USE_GPU:
    pred_O = torch.argmax(sample_output_O, dim=1).cpu().numpy()[0]
    pred_U = torch.argmax(sample_output_U, dim=1).cpu().numpy()[0]
else:
    pred_O = torch.argmax(sample_output_O, dim=1).numpy()[0]
    pred_U = torch.argmax(sample_output_U, dim=1).numpy()[0]

gts = torch.from_numpy(np.array(sample1[1].convert('P'), dtype=np.int32)).long().numpy()
gts[gts == 255] = -1
print(pred_O[None].shape)
conf_O = eval_semantic_segmentation(pred_O[None], gts[None])
conf_U = eval_semantic_segmentation(pred_U[None], gts[None])


fig = plt.figure(figsize=(14,10))
ax1 = fig.add_subplot(2,2,1)
plt.title('image sample')
ax1.imshow(sample1[0])
ax2 = fig.add_subplot(2,2,2)
plt.title('ground truth (target)')
ax2.imshow(sample1[1])
ax3 = fig.add_subplot(2,2,3)
plt.title('UNTRAINED_NET prediction')
ax3.text(10, 25, 'mIoU = {:_>8.6f}'.format(conf_U['miou']), fontsize=20, color='white')
ax3.imshow(colorize_mask(torch.argmax(sample_output_U, dim=1).cpu().numpy()[0]))
ax4 = fig.add_subplot(2,2,4)
plt.title('OVERFIT_NET prediction (for its training image)')
ax4.text(10, 25, 'mIoU = {:_>8.6f}'.format(conf_O['miou']), fontsize=20, color='white')
ax4.imshow(colorize_mask(torch.argmax(sample_output_O, dim=1).cpu().numpy()[0]))
# Out:
# max: 15
# max: 18
# (1, 375, 500)
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:91: RuntimeWarning: invalid value encountered in true_divide
#   iou = np.diag(confusion) / iou_denominator
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:168: RuntimeWarning: invalid value encountered in true_divide
#   class_accuracy = np.diag(confusion) / np.sum(confusion, axis=1)

# %%
img, target = JointResize((375,500))(*sample2)
sample_img, sample_target = JointNormalize(*norm)(img, target)
if USE_GPU:
    sample_img = sample_img.cuda()
sample_output_O = overfit_net.forward(sample_img[None])
sample_output_U = untrained_net.forward(sample_img[None])

# computing mIOU (quantitative measure of accuracy for network predictions)
if USE_GPU:
    pred_O = torch.argmax(sample_output_O, dim=1).cpu().numpy()[0]
    pred_U = torch.argmax(sample_output_U, dim=1).cpu().numpy()[0]
else:
    pred_O = torch.argmax(sample_output_O, dim=1).numpy()[0]
    pred_U = torch.argmax(sample_output_U, dim=1).numpy()[0]

gts = target.numpy()#torch.from_numpy(np.array(target.convert('P'), dtype=np.int32)).long().numpy()
gts[gts == 255] = -1
conf_O = eval_semantic_segmentation(pred_O[None], gts[None])
conf_U = eval_semantic_segmentation(pred_U[None], gts[None])

fig = plt.figure(figsize=(14,10))
ax1 = fig.add_subplot(2,2,1)
plt.title('image sample')
ax1.imshow(sample2[0])
ax2 = fig.add_subplot(2,2,2)
plt.title('ground truth (target)')
ax2.imshow(sample2[1])
ax3 = fig.add_subplot(2,2,3)
plt.title('UNTRAINED_NET prediction')
ax3.text(10, 25, 'mIoU = {:_>8.6f}'.format(conf_U['miou']), fontsize=20, color='white')
ax3.imshow(colorize_mask(torch.argmax(sample_output_U, dim=1).cpu().numpy()[0]))
ax4 = fig.add_subplot(2,2,4)
plt.title('OVERFIT_NET prediction (for image it has not seen)')
ax4.text(10, 25, 'mIoU = {:_>8.6f}'.format(conf_O['miou']), fontsize=20, color='white')
ax4.imshow(colorize_mask(torch.argmax(sample_output_O, dim=1).cpu().numpy()[0]))
# Out:
# max: 20
# max: 18
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:168: RuntimeWarning: invalid value encountered in true_divide
#   class_accuracy = np.diag(confusion) / np.sum(confusion, axis=1)
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:91: RuntimeWarning: invalid value encountered in true_divide
#   iou = np.diag(confusion) / iou_denominator

# %% [markdown]
# #### Run the validation loop for OVERFIT_NET against the sanity dataset (an image it was trained on) - fully implemented

# %%
# %%time
print("mIoU for OVERFIT_NET over its training image:{}".format(validate(sanity_loader, overfit_net)[1]))
# Out:
# Tick: 0
# shape: torch.Size([1, 375, 500])
# max: 15
# [0.997783300133263]
# mIoU for OVERFIT_NET over its training image:0.997783300133263
# CPU times: user 37.5 ms, sys: 2.04 ms, total: 39.5 ms
# Wall time: 55.4 ms
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:91: RuntimeWarning: invalid value encountered in true_divide
#   iou = np.diag(confusion) / iou_denominator
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:168: RuntimeWarning: invalid value encountered in true_divide
#   class_accuracy = np.diag(confusion) / np.sum(confusion, axis=1)

# %% [markdown]
# ### WARNING: For the remaining part of the assignment (below) it is advisable to switch to GPU mode as running each validation and training loop on the whole training set takes over an hour on CPU (there are several such loops below). Note that GPU mode is helpful only if you have a sufficiently good NVIDIA gpu (not older than 2-3 years) and cuda installed on your computer. If you do not have a sufficiently good graphics card available, you can still finish the remaining part in CPU mode (takes a few hours), as the cells below are mostly implemented and test your code written and debugged in the earlier parts above. You can also switch to Google Colaboratory to run the remaining parts below.
#
# ### You can use validation-data experiments below to tune your hyper-parameters. Normally, validation data is used exactly for this purpose. For actual competitions, testing data is not public and you can not tune hyper-parameters on in.

# %% [markdown]
# #### (d) Evaluate UNTRAINED_NET and OVERFIT_NET on validation dataset.
# ##### Run the validation loop for UNTRAINED_NET against the validation dataset:

# %%
# %%time
# This will be slow on CPU (around 1 hour or more). On GPU it should take only a few minutes (depending on your GPU).
# Takes 15min on Colab, 1500 images in validation set
# print("mIoU for UNTRAINED_NET over the entire dataset:{}".format(validate(val_loader, untrained_net)[1]))
# Out:
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.68 µs

# %% [markdown]
# ##### Run the validation loop for OVERFIT_NET against the validation dataset (it has not seen):

# %%
# %%time
# This will be slow on CPU (around 1 hour or more). On GPU it should take only a few minutes (depending on your GPU).
# print("mIoU for OVERFIT_NET over the validation dataset:{}".format(validate(val_loader, overfit_net)[1]))
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 5.48 µs

# %% [markdown]
# #### (e) Explain in a few sentences the quantitative results observed in (c) and (d):

# %% [markdown]
# Student answer:

# %% [markdown]
# #### (f) Create TRAINED_NET and train it on the full training dataset:

# %% [markdown]
# #### (g) Qualitative and quantitative evaluation of predictions (OVERFIT_NET vs TRAINED_NET):

# %%
# %%time
# %matplotlib notebook

# This training will be very slow on a CPU (>1hour per epoch). Ideally, this should be run in GPU mode (USE_GPU=True) 
# taking only a few minutes per epoch (depending on your GPU and batch size). Thus, before proceeding with this excercise,
# it is highly advisable that you first finish debugging your net code. In particular, make sure that OVERFIT_NET behaves 
# reasonably, e.g. its loss monotonically decreases during training and its output is OK (for the image it was trained on). 
# Below we create another (deep) copy of untrained_net. Unlike OVERFIT_NET it will be trained on a full training dataset.
trained_net = copy.deepcopy(untrained_net)
# overfit_net = copy.deepcopy(untrained_net)

# set loss function for the net
trained_net.criterion = nn.CrossEntropyLoss(ignore_index=255)

# You can change the number of EPOCHS below. Since each epoch for TRAINED_NET iterates over all training dataset images,
# the number of required epochs could be smaller compared to OFERFIT_NET where each epoch iterates over one-image-dataset)
EPOCH = 40

# switch to train mode (original untrained_net was set to eval mode)
trained_net.train()

optimizer = get_optimizer(trained_net)
# optimizer = optim.SGD(trained_net.parameters(), lr=0.002, momentum=0.9)

print("Starting Training...")

loss_graph = []

fig = plt.figure(figsize=(12,6))
plt.subplots_adjust(bottom=0.2,right=0.85,top=0.95)
ax = fig.add_subplot(1,1,1)

for e in range(EPOCH):
    print("Starting Epoch {}".format(e))
    new_loss_graph = []
    loss = train(train_loader, trained_net, optimizer, new_loss_graph)
    loss_graph += new_loss_graph
    ax.clear()
    ax.set_xlabel('iterations')
    ax.set_ylabel('loss value')
    ax.set_title('Training loss curve for TRAINED_NET')
    ax.plot(loss_graph, label='training loss')
    ax.legend(loc='upper right')
    fig.canvas.draw()
    plt.show()
    print("Epoch: {} Loss: {}".format(e, loss))
    
# %matplotlib inline
# Out:
# Starting Training...
# <div id='763e76a4-292b-4980-ba99-50056a398ce0'></div>
# Starting Epoch 0
# max: 20
# Training: On Tick: 0 loss 3.1127517223358154
# max: 20
# Training: On Tick: 1 loss 3.0601203441619873
# max: 20
# Training: On Tick: 2 loss 3.009861469268799
# max: 20
# Training: On Tick: 3 loss 2.9547340869903564
# max: 20
# Training: On Tick: 4 loss 2.911477565765381
# max: 20
# Training: On Tick: 5 loss 2.8562772274017334
# max: 20
# Training: On Tick: 6 loss 2.708273410797119
# max: 20
# Training: On Tick: 7 loss 2.6940691471099854
# max: 20
# Training: On Tick: 8 loss 2.5984127521514893
# max: 20
# Training: On Tick: 9 loss 2.5332186222076416
# max: 20
# Training: On Tick: 10 loss 2.3978524208068848
# max: 20
# Training: On Tick: 11 loss 2.364814519882202
# max: 20
# Training: On Tick: 12 loss 2.2879631519317627
# max: 20
# Training: On Tick: 13 loss 2.189567804336548
# max: 20
# Training: On Tick: 14 loss 2.097666025161743
# max: 20
# Training: On Tick: 15 loss 2.0322396755218506
# max: 20
# Training: On Tick: 16 loss 2.034719944000244
# max: 20
# Training: On Tick: 17 loss 1.9282585382461548
# max: 20
# Training: On Tick: 18 loss 1.8660627603530884
# max: 20
# Training: On Tick: 19 loss 1.86061692237854
# max: 20
# Training: On Tick: 20 loss 1.8518444299697876
# max: 20
# Training: On Tick: 21 loss 1.7793247699737549
# max: 20
# Training: On Tick: 22 loss 1.7628114223480225
# Epoch: 0 Loss: 2.3866493701934814
# Starting Epoch 1
# max: 20
# Training: On Tick: 0 loss 1.6646955013275146
# max: 19
# Training: On Tick: 1 loss 1.5884438753128052
# max: 20
# Training: On Tick: 2 loss 1.5392389297485352
# max: 20
# Training: On Tick: 3 loss 1.5468486547470093
# max: 20
# Training: On Tick: 4 loss 1.5168592929840088
# max: 20
# Training: On Tick: 5 loss 1.4133620262145996
# max: 20
# Training: On Tick: 6 loss 1.3228626251220703
# max: 20
# Training: On Tick: 7 loss 1.37955641746521
# max: 20
# Training: On Tick: 8 loss 1.4096559286117554
# max: 20
# Training: On Tick: 9 loss 1.2877784967422485
# max: 20
# Training: On Tick: 10 loss 1.206005573272705
# max: 20
# Training: On Tick: 11 loss 1.2609463930130005
# max: 19
# Training: On Tick: 12 loss 1.263285756111145
# max: 20
# Training: On Tick: 13 loss 1.2786493301391602
# max: 20
# Training: On Tick: 14 loss 1.264299750328064
# max: 20
# Training: On Tick: 15 loss 1.2054632902145386
# max: 20
# Training: On Tick: 16 loss 1.375953197479248
# max: 20
# Training: On Tick: 17 loss 1.247803807258606
# max: 0
# Training: On Tick: 18 loss 1.202602505683899
# max: 20
# Training: On Tick: 19 loss 1.2432358264923096
# max: 20
# Training: On Tick: 20 loss 1.3253341913223267
# max: 20
# Training: On Tick: 21 loss 1.2351232767105103
# max: 0
# Training: On Tick: 22 loss 1.2266560792922974
# Epoch: 1 Loss: 1.3480288982391357
# Starting Epoch 2
# max: 20
# Training: On Tick: 0 loss 1.1660292148590088
# max: 17
# Training: On Tick: 1 loss 1.0997905731201172
# max: 18
# Training: On Tick: 2 loss 1.0601145029067993
# max: 18
# Training: On Tick: 3 loss 1.121978998184204
# max: 18
# Training: On Tick: 4 loss 1.1131631135940552
# max: 20
# Training: On Tick: 5 loss 1.0009737014770508
# max: 20
# Training: On Tick: 6 loss 0.9037898778915405
# max: 20
# Training: On Tick: 7 loss 1.0176361799240112
# max: 20
# Training: On Tick: 8 loss 1.0960867404937744
# max: 20
# Training: On Tick: 9 loss 0.9625778198242188
# max: 17
# Training: On Tick: 10 loss 0.8966959714889526
# max: 20
# Training: On Tick: 11 loss 0.9843459129333496
# max: 17
# Training: On Tick: 12 loss 0.9869984984397888
# max: 20
# Training: On Tick: 13 loss 1.0162239074707031
# max: 20
# Training: On Tick: 14 loss 1.0248106718063354
# max: 15
# Training: On Tick: 15 loss 0.9409993886947632
# max: 20
# Training: On Tick: 16 loss 1.136993408203125
# max: 17
# Training: On Tick: 17 loss 1.0281368494033813
# max: 0
# Training: On Tick: 18 loss 0.9826708436012268
# max: 20
# Training: On Tick: 19 loss 1.0405949354171753
# max: 20
# Training: On Tick: 20 loss 1.1008411645889282
# max: 20
# Training: On Tick: 21 loss 1.0283310413360596
# max: 0
# Training: On Tick: 22 loss 1.0271934270858765
# Epoch: 2 Loss: 1.0320425033569336
# Starting Epoch 3
# max: 20
# Training: On Tick: 0 loss 0.9823703169822693
# max: 17
# Training: On Tick: 1 loss 0.902224063873291
# max: 15
# Training: On Tick: 2 loss 0.8671582341194153
# max: 17
# Training: On Tick: 3 loss 0.9318271279335022
# max: 18
# Training: On Tick: 4 loss 0.9442634582519531
# max: 20
# Training: On Tick: 5 loss 0.8221411108970642
# max: 20
# Training: On Tick: 6 loss 0.7259852886199951
# max: 20
# Training: On Tick: 7 loss 0.8769437670707703
# max: 20
# Training: On Tick: 8 loss 0.9605857729911804
# max: 20
# Training: On Tick: 9 loss 0.8202846050262451
# max: 17
# Training: On Tick: 10 loss 0.7592982053756714
# max: 20
# Training: On Tick: 11 loss 0.8587431311607361
# max: 17
# Training: On Tick: 12 loss 0.859316885471344
# max: 20
# Training: On Tick: 13 loss 0.8928474187850952
# max: 20
# Training: On Tick: 14 loss 0.9108043313026428
# max: 15
# Training: On Tick: 15 loss 0.8123105764389038
# max: 20
# Training: On Tick: 16 loss 0.9976080656051636
# max: 17
# Training: On Tick: 17 loss 0.9094840884208679
# max: 0
# Training: On Tick: 18 loss 0.8619160056114197
# max: 20
# Training: On Tick: 19 loss 0.9261371493339539
# max: 20
# Training: On Tick: 20 loss 0.9813778400421143
# max: 20
# Training: On Tick: 21 loss 0.9131571054458618
# max: 0
# Training: On Tick: 22 loss 0.910181999206543
# Epoch: 3 Loss: 0.8881290555000305
# Starting Epoch 4
# max: 20
# Training: On Tick: 0 loss 0.8719475865364075
# max: 15
# Training: On Tick: 1 loss 0.7858977913856506
# max: 15
# Training: On Tick: 2 loss 0.7621474862098694
# max: 15
# Training: On Tick: 3 loss 0.810878574848175
# max: 17
# Training: On Tick: 4 loss 0.8341453671455383
# max: 20
# Training: On Tick: 5 loss 0.7189145088195801
# max: 20
# Training: On Tick: 6 loss 0.622009813785553
# max: 20
# Training: On Tick: 7 loss 0.7901446223258972
# max: 20
# Training: On Tick: 8 loss 0.8730419874191284
# max: 20
# Training: On Tick: 9 loss 0.7327315211296082
# max: 17
# Training: On Tick: 10 loss 0.680382490158081
# max: 19
# Training: On Tick: 11 loss 0.7725973129272461
# max: 17
# Training: On Tick: 12 loss 0.7781826257705688
# max: 20
# Training: On Tick: 13 loss 0.8080834150314331
# max: 20
# Training: On Tick: 14 loss 0.8248116970062256
# max: 15
# Training: On Tick: 15 loss 0.7307578325271606
# max: 20
# Training: On Tick: 16 loss 0.8949325084686279
# max: 17
# Training: On Tick: 17 loss 0.8183666467666626
# max: 0
# Training: On Tick: 18 loss 0.7699333429336548
# max: 17
# Training: On Tick: 19 loss 0.8424171209335327
# max: 20
# Training: On Tick: 20 loss 0.889218270778656
# max: 19
# Training: On Tick: 21 loss 0.8322818875312805
# max: 0
# Training: On Tick: 22 loss 0.8259875774383545
# Epoch: 4 Loss: 0.794339656829834
# Starting Epoch 5
# max: 20
# Training: On Tick: 0 loss 0.7920814752578735
# max: 15
# Training: On Tick: 1 loss 0.7093750238418579
# max: 18
# Training: On Tick: 2 loss 0.6878266930580139
# max: 17
# Training: On Tick: 3 loss 0.7298163175582886
# max: 17
# Training: On Tick: 4 loss 0.7529844045639038
# max: 20
# Training: On Tick: 5 loss 0.6468297243118286
# max: 20
# Training: On Tick: 6 loss 0.5502236485481262
# max: 15
# Training: On Tick: 7 loss 0.7137789726257324
# max: 20
# Training: On Tick: 8 loss 0.7992938160896301
# max: 19
# Training: On Tick: 9 loss 0.6646756529808044
# max: 17
# Training: On Tick: 10 loss 0.6191527843475342
# max: 19
# Training: On Tick: 11 loss 0.707522988319397
# max: 15
# Training: On Tick: 12 loss 0.7163683176040649
# max: 20
# Training: On Tick: 13 loss 0.7445605993270874
# max: 20
# Training: On Tick: 14 loss 0.7555015087127686
# max: 15
# Training: On Tick: 15 loss 0.6684579253196716
# max: 20
# Training: On Tick: 16 loss 0.818964958190918
# max: 17
# Training: On Tick: 17 loss 0.7439648509025574
# max: 0
# Training: On Tick: 18 loss 0.6999125480651855
# max: 17
# Training: On Tick: 19 loss 0.766480028629303
# max: 20
# Training: On Tick: 20 loss 0.8088005185127258
# max: 19
# Training: On Tick: 21 loss 0.7650865912437439
# max: 0
# Training: On Tick: 22 loss 0.7495617866516113
# Epoch: 5 Loss: 0.7222270965576172
# Starting Epoch 6
# max: 20
# Training: On Tick: 0 loss 0.7248451113700867
# max: 18
# Training: On Tick: 1 loss 0.6449093222618103
# max: 18
# Training: On Tick: 2 loss 0.6286911368370056
# max: 18
# Training: On Tick: 3 loss 0.6606537103652954
# max: 17
# Training: On Tick: 4 loss 0.6878806948661804
# max: 15
# Training: On Tick: 5 loss 0.5935449600219727
# max: 20
# Training: On Tick: 6 loss 0.49442562460899353
# max: 16
# Training: On Tick: 7 loss 0.6488066911697388
# max: 19
# Training: On Tick: 8 loss 0.7313268184661865
# max: 19
# Training: On Tick: 9 loss 0.6051653623580933
# max: 18
# Training: On Tick: 10 loss 0.5640488266944885
# max: 19
# Training: On Tick: 11 loss 0.6421955823898315
# max: 17
# Training: On Tick: 12 loss 0.6593552231788635
# max: 20
# Training: On Tick: 13 loss 0.6831132173538208
# max: 20
# Training: On Tick: 14 loss 0.6895930171012878
# max: 20
# Training: On Tick: 15 loss 0.6143705248832703
# max: 20
# Training: On Tick: 16 loss 0.7555189728736877
# max: 17
# Training: On Tick: 17 loss 0.6793160438537598
# max: 0
# Training: On Tick: 18 loss 0.6331679224967957
# max: 17
# Training: On Tick: 19 loss 0.6986253261566162
# max: 20
# Training: On Tick: 20 loss 0.7369384765625
# max: 19
# Training: On Tick: 21 loss 0.7040234804153442
# max: 0
# Training: On Tick: 22 loss 0.6774240732192993
# Epoch: 6 Loss: 0.6590408682823181
# Starting Epoch 7
# max: 20
# Training: On Tick: 0 loss 0.6665475964546204
# max: 18
# Training: On Tick: 1 loss 0.5866160988807678
# max: 18
# Training: On Tick: 2 loss 0.5739309191703796
# max: 18
# Training: On Tick: 3 loss 0.5965350866317749
# max: 8
# Training: On Tick: 4 loss 0.635574221611023
# max: 15
# Training: On Tick: 5 loss 0.5475975871086121
# max: 19
# Training: On Tick: 6 loss 0.4484882652759552
# max: 15
# Training: On Tick: 7 loss 0.594425618648529
# max: 19
# Training: On Tick: 8 loss 0.6648505330085754
# max: 19
# Training: On Tick: 9 loss 0.5563139319419861
# max: 18
# Training: On Tick: 10 loss 0.5129708051681519
# max: 19
# Training: On Tick: 11 loss 0.5853902101516724
# max: 17
# Training: On Tick: 12 loss 0.605429470539093
# max: 20
# Training: On Tick: 13 loss 0.6281664371490479
# max: 15
# Training: On Tick: 14 loss 0.628979504108429
# max: 18
# Training: On Tick: 15 loss 0.5647678375244141
# max: 20
# Training: On Tick: 16 loss 0.6962063312530518
# max: 18
# Training: On Tick: 17 loss 0.6240494251251221
# max: 0
# Training: On Tick: 18 loss 0.576939582824707
# max: 17
# Training: On Tick: 19 loss 0.6361395120620728
# max: 18
# Training: On Tick: 20 loss 0.6707520484924316
# max: 19
# Training: On Tick: 21 loss 0.6480630040168762
# max: 0
# Training: On Tick: 22 loss 0.6188011169433594
# Epoch: 7 Loss: 0.602936327457428
# Starting Epoch 8
# max: 20
# Training: On Tick: 0 loss 0.6137679219245911
# max: 18
# Training: On Tick: 1 loss 0.5382311940193176
# max: 18
# Training: On Tick: 2 loss 0.5285974144935608
# max: 17
# Training: On Tick: 3 loss 0.5412904024124146
# max: 17
# Training: On Tick: 4 loss 0.592355489730835
# max: 15
# Training: On Tick: 5 loss 0.5098280310630798
# max: 19
# Training: On Tick: 6 loss 0.40916362404823303
# max: 15
# Training: On Tick: 7 loss 0.5457247495651245
# max: 19
# Training: On Tick: 8 loss 0.6021263599395752
# max: 19
# Training: On Tick: 9 loss 0.5134435892105103
# max: 18
# Training: On Tick: 10 loss 0.4717978239059448
# max: 19
# Training: On Tick: 11 loss 0.5367429256439209
# max: 17
# Training: On Tick: 12 loss 0.5582958459854126
# max: 20
# Training: On Tick: 13 loss 0.5789433717727661
# max: 16
# Training: On Tick: 14 loss 0.5728371739387512
# max: 20
# Training: On Tick: 15 loss 0.5196133852005005
# max: 20
# Training: On Tick: 16 loss 0.6384788751602173
# max: 18
# Training: On Tick: 17 loss 0.5791710615158081
# max: 0
# Training: On Tick: 18 loss 0.5440419912338257
# max: 17
# Training: On Tick: 19 loss 0.5813530683517456
# max: 18
# Training: On Tick: 20 loss 0.6127015948295593
# max: 19
# Training: On Tick: 21 loss 0.5903953313827515
# max: 0
# Training: On Tick: 22 loss 0.5714739561080933
# Epoch: 8 Loss: 0.5543641448020935
# Starting Epoch 9
# max: 20
# Training: On Tick: 0 loss 0.5649793148040771
# max: 18
# Training: On Tick: 1 loss 0.4983704388141632
# max: 18
# Training: On Tick: 2 loss 0.48974180221557617
# max: 17
# Training: On Tick: 3 loss 0.4996395409107208
# max: 17
# Training: On Tick: 4 loss 0.5512930750846863
# max: 15
# Training: On Tick: 5 loss 0.47698983550071716
# max: 19
# Training: On Tick: 6 loss 0.3819688856601715
# max: 15
# Training: On Tick: 7 loss 0.5011399984359741
# max: 19
# Training: On Tick: 8 loss 0.5438565611839294
# max: 15
# Training: On Tick: 9 loss 0.46985578536987305
# max: 18
# Training: On Tick: 10 loss 0.43500033020973206
# max: 19
# Training: On Tick: 11 loss 0.4932391941547394
# max: 15
# Training: On Tick: 12 loss 0.5207793712615967
# max: 20
# Training: On Tick: 13 loss 0.5275699496269226
# max: 15
# Training: On Tick: 14 loss 0.5162851214408875
# max: 20
# Training: On Tick: 15 loss 0.48122289776802063
# max: 20
# Training: On Tick: 16 loss 0.5849771499633789
# max: 18
# Training: On Tick: 17 loss 0.5330774188041687
# max: 0
# Training: On Tick: 18 loss 0.5034457445144653
# max: 17
# Training: On Tick: 19 loss 0.544799268245697
# max: 18
# Training: On Tick: 20 loss 0.5689908266067505
# max: 19
# Training: On Tick: 21 loss 0.5429650545120239
# max: 0
# Training: On Tick: 22 loss 0.5297443866729736
# Epoch: 9 Loss: 0.5113013386726379
# Starting Epoch 10
# max: 20
# Training: On Tick: 0 loss 0.5139979124069214
# max: 18
# Training: On Tick: 1 loss 0.46059587597846985
# max: 18
# Training: On Tick: 2 loss 0.45732417702674866
# max: 17
# Training: On Tick: 3 loss 0.47079163789749146
# max: 12
# Training: On Tick: 4 loss 0.5174406170845032
# max: 15
# Training: On Tick: 5 loss 0.43975523114204407
# max: 19
# Training: On Tick: 6 loss 0.3493479788303375
# max: 15
# Training: On Tick: 7 loss 0.4657111167907715
# max: 19
# Training: On Tick: 8 loss 0.5045128464698792
# max: 15
# Training: On Tick: 9 loss 0.44205060601234436
# max: 18
# Training: On Tick: 10 loss 0.4036449193954468
# max: 19
# Training: On Tick: 11 loss 0.44501787424087524
# max: 12
# Training: On Tick: 12 loss 0.47670868039131165
# max: 19
# Training: On Tick: 13 loss 0.48756709694862366
# max: 16
# Training: On Tick: 14 loss 0.4729842245578766
# max: 18
# Training: On Tick: 15 loss 0.450813889503479
# max: 20
# Training: On Tick: 16 loss 0.5409260988235474
# max: 18
# Training: On Tick: 17 loss 0.4893456995487213
# max: 0
# Training: On Tick: 18 loss 0.4624449610710144
# max: 17
# Training: On Tick: 19 loss 0.5120525360107422
# max: 18
# Training: On Tick: 20 loss 0.5330875515937805
# max: 19
# Training: On Tick: 21 loss 0.5163862705230713
# max: 0
# Training: On Tick: 22 loss 0.507636308670044
# Epoch: 10 Loss: 0.4747888743877411
# Starting Epoch 11
# max: 20
# Training: On Tick: 0 loss 0.47332680225372314
# max: 18
# Training: On Tick: 1 loss 0.42186877131462097
# max: 18
# Training: On Tick: 2 loss 0.43026697635650635
# max: 17
# Training: On Tick: 3 loss 0.44296813011169434
# max: 8
# Training: On Tick: 4 loss 0.4769850969314575
# max: 19
# Training: On Tick: 5 loss 0.408960223197937
# max: 19
# Training: On Tick: 6 loss 0.31839510798454285
# max: 15
# Training: On Tick: 7 loss 0.4467920660972595
# max: 19
# Training: On Tick: 8 loss 0.4575153887271881
# max: 20
# Training: On Tick: 9 loss 0.40283578634262085
# max: 18
# Training: On Tick: 10 loss 0.3746161460876465
# max: 19
# Training: On Tick: 11 loss 0.4116703271865845
# max: 12
# Training: On Tick: 12 loss 0.4415508508682251
# max: 20
# Training: On Tick: 13 loss 0.45413342118263245
# max: 15
# Training: On Tick: 14 loss 0.44293081760406494
# max: 17
# Training: On Tick: 15 loss 0.4214176833629608
# max: 20
# Training: On Tick: 16 loss 0.507051944732666
# max: 18
# Training: On Tick: 17 loss 0.45229870080947876
# max: 0
# Training: On Tick: 18 loss 0.4296269118785858
# max: 17
# Training: On Tick: 19 loss 0.47059231996536255
# max: 20
# Training: On Tick: 20 loss 0.4744088053703308
# max: 20
# Training: On Tick: 21 loss 0.4743671119213104
# max: 0
# Training: On Tick: 22 loss 0.4714038074016571
# Epoch: 11 Loss: 0.4393905997276306
# Starting Epoch 12
# max: 20
# Training: On Tick: 0 loss 0.45516282320022583
# max: 15
# Training: On Tick: 1 loss 0.3984297215938568
# max: 18
# Training: On Tick: 2 loss 0.397818386554718
# max: 17
# Training: On Tick: 3 loss 0.3999907970428467
# max: 8
# Training: On Tick: 4 loss 0.44243162870407104
# max: 15
# Training: On Tick: 5 loss 0.3790803551673889
# max: 19
# Training: On Tick: 6 loss 0.2881730794906616
# max: 15
# Training: On Tick: 7 loss 0.4044477939605713
# max: 19
# Training: On Tick: 8 loss 0.4195359945297241
# max: 20
# Training: On Tick: 9 loss 0.3673095405101776
# max: 18
# Training: On Tick: 10 loss 0.34419894218444824
# max: 19
# Training: On Tick: 11 loss 0.3860597014427185
# max: 17
# Training: On Tick: 12 loss 0.4135568141937256
# max: 20
# Training: On Tick: 13 loss 0.41776180267333984
# max: 15
# Training: On Tick: 14 loss 0.4185349643230438
# max: 18
# Training: On Tick: 15 loss 0.3853440284729004
# max: 20
# Training: On Tick: 16 loss 0.4585373103618622
# max: 18
# Training: On Tick: 17 loss 0.42182907462120056
# max: 0
# Training: On Tick: 18 loss 0.4193006157875061
# max: 17
# Training: On Tick: 19 loss 0.4354481101036072
# max: 18
# Training: On Tick: 20 loss 0.42802923917770386
# max: 19
# Training: On Tick: 21 loss 0.41820281744003296
# max: 0
# Training: On Tick: 22 loss 0.4232790172100067
# Epoch: 12 Loss: 0.40532445907592773
# Starting Epoch 13
# max: 20
# Training: On Tick: 0 loss 0.4149559736251831
# max: 18
# Training: On Tick: 1 loss 0.38541996479034424
# max: 18
# Training: On Tick: 2 loss 0.377819299697876
# max: 17
# Training: On Tick: 3 loss 0.36876559257507324
# max: 8
# Training: On Tick: 4 loss 0.40655413269996643
# max: 15
# Training: On Tick: 5 loss 0.35615190863609314
# max: 19
# Training: On Tick: 6 loss 0.2643066346645355
# max: 15
# Training: On Tick: 7 loss 0.3744432330131531
# max: 15
# Training: On Tick: 8 loss 0.3943844139575958
# max: 18
# Training: On Tick: 9 loss 0.33077290654182434
# max: 18
# Training: On Tick: 10 loss 0.316050261259079
# max: 19
# Training: On Tick: 11 loss 0.3412145972251892
# max: 17
# Training: On Tick: 12 loss 0.36955198645591736
# max: 20
# Training: On Tick: 13 loss 0.3843939006328583
# max: 15
# Training: On Tick: 14 loss 0.363939493894577
# max: 16
# Training: On Tick: 15 loss 0.356094628572464
# max: 20
# Training: On Tick: 16 loss 0.42466211318969727
# max: 15
# Training: On Tick: 17 loss 0.3823961615562439
# max: 0
# Training: On Tick: 18 loss 0.3634680211544037
# max: 17
# Training: On Tick: 19 loss 0.39167487621307373
# max: 18
# Training: On Tick: 20 loss 0.4068578779697418
# max: 20
# Training: On Tick: 21 loss 0.3914910852909088
# max: 0
# Training: On Tick: 22 loss 0.37095212936401367
# Epoch: 13 Loss: 0.3711444139480591
# Starting Epoch 14
# max: 15
# Training: On Tick: 0 loss 0.3538948595523834
# max: 18
# Training: On Tick: 1 loss 0.3383926451206207
# max: 18
# Training: On Tick: 2 loss 0.34799814224243164
# max: 17
# Training: On Tick: 3 loss 0.33926519751548767
# max: 8
# Training: On Tick: 4 loss 0.37408024072647095
# max: 19
# Training: On Tick: 5 loss 0.3190336525440216
# max: 19
# Training: On Tick: 6 loss 0.2350156009197235
# max: 15
# Training: On Tick: 7 loss 0.31511786580085754
# max: 15
# Training: On Tick: 8 loss 0.3479709029197693
# max: 18
# Training: On Tick: 9 loss 0.30939415097236633
# max: 15
# Training: On Tick: 10 loss 0.28503790497779846
# max: 19
# Training: On Tick: 11 loss 0.31198641657829285
# max: 15
# Training: On Tick: 12 loss 0.34106913208961487
# max: 19
# Training: On Tick: 13 loss 0.3532348871231079
# max: 15
# Training: On Tick: 14 loss 0.32548773288726807
# max: 20
# Training: On Tick: 15 loss 0.32260751724243164
# max: 20
# Training: On Tick: 16 loss 0.37090206146240234
# max: 18
# Training: On Tick: 17 loss 0.35029351711273193
# max: 0
# Training: On Tick: 18 loss 0.32760101556777954
# max: 17
# Training: On Tick: 19 loss 0.3456626832485199
# max: 18
# Training: On Tick: 20 loss 0.34314513206481934
# max: 19
# Training: On Tick: 21 loss 0.3294980525970459
# max: 0
# Training: On Tick: 22 loss 0.33358076214790344
# Epoch: 14 Loss: 0.33131611347198486
# Starting Epoch 15
# max: 15
# Training: On Tick: 0 loss 0.32458585500717163
# max: 15
# Training: On Tick: 1 loss 0.303178608417511
# max: 18
# Training: On Tick: 2 loss 0.3139840066432953
# max: 15
# Training: On Tick: 3 loss 0.2996179461479187
# max: 8
# Training: On Tick: 4 loss 0.32541993260383606
# max: 15
# Training: On Tick: 5 loss 0.2905961275100708
# max: 19
# Training: On Tick: 6 loss 0.20740388333797455
# max: 15
# Training: On Tick: 7 loss 0.2769722640514374
# max: 15
# Training: On Tick: 8 loss 0.300556480884552
# max: 20
# Training: On Tick: 9 loss 0.2608269155025482
# max: 15
# Training: On Tick: 10 loss 0.24557951092720032
# max: 19
# Training: On Tick: 11 loss 0.27193424105644226
# max: 17
# Training: On Tick: 12 loss 0.3056703805923462
# max: 7
# Training: On Tick: 13 loss 0.32519298791885376
# max: 15
# Training: On Tick: 14 loss 0.30176669359207153
# max: 16
# Training: On Tick: 15 loss 0.3015636205673218
# max: 20
# Training: On Tick: 16 loss 0.3442659378051758
# max: 18
# Training: On Tick: 17 loss 0.3219427466392517
# max: 0
# Training: On Tick: 18 loss 0.2919645607471466
# max: 17
# Training: On Tick: 19 loss 0.3085315525531769
# max: 18
# Training: On Tick: 20 loss 0.31693387031555176
# max: 19
# Training: On Tick: 21 loss 0.3026649057865143
# max: 0
# Training: On Tick: 22 loss 0.3012855052947998
# Epoch: 15 Loss: 0.29749733209609985
# Starting Epoch 16
# max: 19
# Training: On Tick: 0 loss 0.2920476794242859
# max: 15
# Training: On Tick: 1 loss 0.27110376954078674
# max: 18
# Training: On Tick: 2 loss 0.28381282091140747
# max: 15
# Training: On Tick: 3 loss 0.2679108679294586
# max: 8
# Training: On Tick: 4 loss 0.2911640405654907
# max: 15
# Training: On Tick: 5 loss 0.2558531165122986
# max: 19
# Training: On Tick: 6 loss 0.190914586186409
# max: 15
# Training: On Tick: 7 loss 0.2555474042892456
# max: 14
# Training: On Tick: 8 loss 0.2701203227043152
# max: 18
# Training: On Tick: 9 loss 0.22885312139987946
# max: 15
# Training: On Tick: 10 loss 0.22536605596542358
# max: 19
# Training: On Tick: 11 loss 0.24163582921028137
# max: 17
# Training: On Tick: 12 loss 0.273183673620224
# max: 7
# Training: On Tick: 13 loss 0.29550087451934814
# max: 15
# Training: On Tick: 14 loss 0.2770906388759613
# max: 17
# Training: On Tick: 15 loss 0.2808643877506256
# max: 20
# Training: On Tick: 16 loss 0.31958842277526855
# max: 15
# Training: On Tick: 17 loss 0.30038750171661377
# max: 0
# Training: On Tick: 18 loss 0.2692953646183014
# max: 13
# Training: On Tick: 19 loss 0.29266229271888733
# max: 18
# Training: On Tick: 20 loss 0.2923084497451782
# max: 19
# Training: On Tick: 21 loss 0.2822854816913605
# max: 0
# Training: On Tick: 22 loss 0.27378976345062256
# Epoch: 16 Loss: 0.27092549204826355
# Starting Epoch 17
# max: 20
# Training: On Tick: 0 loss 0.2707764208316803
# max: 15
# Training: On Tick: 1 loss 0.25247853994369507
# max: 18
# Training: On Tick: 2 loss 0.2695908844470978
# max: 15
# Training: On Tick: 3 loss 0.25072628259658813
# max: 8
# Training: On Tick: 4 loss 0.2657648026943207
# max: 15
# Training: On Tick: 5 loss 0.23910079896450043
# max: 19
# Training: On Tick: 6 loss 0.18540216982364655
# max: 15
# Training: On Tick: 7 loss 0.23852819204330444
# max: 14
# Training: On Tick: 8 loss 0.252032995223999
# max: 15
# Training: On Tick: 9 loss 0.21353140473365784
# max: 17
# Training: On Tick: 10 loss 0.21122966706752777
# max: 19
# Training: On Tick: 11 loss 0.21848216652870178
# max: 17
# Training: On Tick: 12 loss 0.24942012131214142
# max: 4
# Training: On Tick: 13 loss 0.2805870771408081
# max: 15
# Training: On Tick: 14 loss 0.2578616738319397
# max: 17
# Training: On Tick: 15 loss 0.2633049786090851
# max: 20
# Training: On Tick: 16 loss 0.3067513704299927
# max: 15
# Training: On Tick: 17 loss 0.2851562201976776
# max: 0
# Training: On Tick: 18 loss 0.24507710337638855
# max: 13
# Training: On Tick: 19 loss 0.27479037642478943
# max: 18
# Training: On Tick: 20 loss 0.26630330085754395
# max: 19
# Training: On Tick: 21 loss 0.2615746855735779
# max: 0
# Training: On Tick: 22 loss 0.24875995516777039
# Epoch: 17 Loss: 0.25248831510543823
# Starting Epoch 18
# max: 15
# Training: On Tick: 0 loss 0.24536100029945374
# max: 15
# Training: On Tick: 1 loss 0.2281460165977478
# max: 20
# Training: On Tick: 2 loss 0.2582843601703644
# max: 15
# Training: On Tick: 3 loss 0.2419382482767105
# max: 8
# Training: On Tick: 4 loss 0.24855409562587738
# max: 15
# Training: On Tick: 5 loss 0.22527921199798584
# max: 19
# Training: On Tick: 6 loss 0.1682904064655304
# max: 15
# Training: On Tick: 7 loss 0.2203071266412735
# max: 7
# Training: On Tick: 8 loss 0.23138265311717987
# max: 16
# Training: On Tick: 9 loss 0.18930968642234802
# max: 17
# Training: On Tick: 10 loss 0.1950884610414505
# max: 19
# Training: On Tick: 11 loss 0.20555280148983002
# max: 17
# Training: On Tick: 12 loss 0.23279951512813568
# max: 4
# Training: On Tick: 13 loss 0.26710233092308044
# max: 15
# Training: On Tick: 14 loss 0.23863078653812408
# max: 16
# Training: On Tick: 15 loss 0.24147385358810425
# max: 20
# Training: On Tick: 16 loss 0.28533440828323364
# max: 15
# Training: On Tick: 17 loss 0.27541419863700867
# max: 0
# Training: On Tick: 18 loss 0.2302950620651245
# max: 13
# Training: On Tick: 19 loss 0.266065776348114
# max: 18
# Training: On Tick: 20 loss 0.24545560777187347
# max: 19
# Training: On Tick: 21 loss 0.2353767603635788
# max: 0
# Training: On Tick: 22 loss 0.22824175655841827
# Epoch: 18 Loss: 0.23494279384613037
# Starting Epoch 19
# max: 19
# Training: On Tick: 0 loss 0.22940216958522797
# max: 18
# Training: On Tick: 1 loss 0.2153736650943756
# max: 20
# Training: On Tick: 2 loss 0.23351268470287323
# max: 15
# Training: On Tick: 3 loss 0.2186022400856018
# max: 8
# Training: On Tick: 4 loss 0.2258002907037735
# max: 15
# Training: On Tick: 5 loss 0.2016879767179489
# max: 19
# Training: On Tick: 6 loss 0.1591753214597702
# max: 15
# Training: On Tick: 7 loss 0.21450340747833252
# max: 14
# Training: On Tick: 8 loss 0.23222902417182922
# max: 15
# Training: On Tick: 9 loss 0.18064241111278534
# max: 17
# Training: On Tick: 10 loss 0.18760600686073303
# max: 19
# Training: On Tick: 11 loss 0.18243753910064697
# max: 17
# Training: On Tick: 12 loss 0.2110581398010254
# max: 4
# Training: On Tick: 13 loss 0.24410244822502136
# max: 15
# Training: On Tick: 14 loss 0.22321446239948273
# max: 16
# Training: On Tick: 15 loss 0.22638288140296936
# max: 20
# Training: On Tick: 16 loss 0.2532806694507599
# max: 15
# Training: On Tick: 17 loss 0.24697120487689972
# max: 0
# Training: On Tick: 18 loss 0.21804770827293396
# max: 19
# Training: On Tick: 19 loss 0.2604101300239563
# max: 18
# Training: On Tick: 20 loss 0.2456938773393631
# max: 19
# Training: On Tick: 21 loss 0.22624950110912323
# max: 0
# Training: On Tick: 22 loss 0.2224276214838028
# Epoch: 19 Loss: 0.21994833648204803
# Starting Epoch 20
# max: 19
# Training: On Tick: 0 loss 0.20934651792049408
# max: 18
# Training: On Tick: 1 loss 0.20279093086719513
# max: 20
# Training: On Tick: 2 loss 0.20969654619693756
# max: 15
# Training: On Tick: 3 loss 0.20323024690151215
# max: 8
# Training: On Tick: 4 loss 0.20841000974178314
# max: 15
# Training: On Tick: 5 loss 0.1816810965538025
# max: 19
# Training: On Tick: 6 loss 0.14282655715942383
# max: 15
# Training: On Tick: 7 loss 0.19005276262760162
# max: 14
# Training: On Tick: 8 loss 0.20839783549308777
# max: 15
# Training: On Tick: 9 loss 0.17669416964054108
# max: 12
# Training: On Tick: 10 loss 0.18482054769992828
# max: 7
# Training: On Tick: 11 loss 0.17732349038124084
# max: 17
# Training: On Tick: 12 loss 0.20212553441524506
# max: 4
# Training: On Tick: 13 loss 0.22605936229228973
# max: 15
# Training: On Tick: 14 loss 0.20499005913734436
# max: 16
# Training: On Tick: 15 loss 0.21129316091537476
# max: 20
# Training: On Tick: 16 loss 0.2330913096666336
# max: 12
# Training: On Tick: 17 loss 0.2166299670934677
# max: 0
# Training: On Tick: 18 loss 0.19435708224773407
# max: 13
# Training: On Tick: 19 loss 0.23845116794109344
# max: 18
# Training: On Tick: 20 loss 0.22739923000335693
# max: 20
# Training: On Tick: 21 loss 0.2243681699037552
# max: 0
# Training: On Tick: 22 loss 0.21803568303585052
# Epoch: 20 Loss: 0.20400312542915344
# Starting Epoch 21
# max: 15
# Training: On Tick: 0 loss 0.20212677121162415
# max: 15
# Training: On Tick: 1 loss 0.19394856691360474
# max: 18
# Training: On Tick: 2 loss 0.19821453094482422
# max: 15
# Training: On Tick: 3 loss 0.18997710943222046
# max: 8
# Training: On Tick: 4 loss 0.20307964086532593
# max: 15
# Training: On Tick: 5 loss 0.17327338457107544
# max: 19
# Training: On Tick: 6 loss 0.13253293931484222
# max: 15
# Training: On Tick: 7 loss 0.17424871027469635
# max: 15
# Training: On Tick: 8 loss 0.18212169408798218
# max: 15
# Training: On Tick: 9 loss 0.14943473041057587
# max: 12
# Training: On Tick: 10 loss 0.1655830591917038
# max: 7
# Training: On Tick: 11 loss 0.16860812902450562
# max: 8
# Training: On Tick: 12 loss 0.18765097856521606
# max: 15
# Training: On Tick: 13 loss 0.22303734719753265
# max: 15
# Training: On Tick: 14 loss 0.20341067016124725
# max: 16
# Training: On Tick: 15 loss 0.18586857616901398
# max: 20
# Training: On Tick: 16 loss 0.21535761654376984
# max: 13
# Training: On Tick: 17 loss 0.20887093245983124
# max: 0
# Training: On Tick: 18 loss 0.18144673109054565
# max: 13
# Training: On Tick: 19 loss 0.2068851888179779
# max: 18
# Training: On Tick: 20 loss 0.20032432675361633
# max: 19
# Training: On Tick: 21 loss 0.20289276540279388
# max: 0
# Training: On Tick: 22 loss 0.19204413890838623
# Epoch: 21 Loss: 0.1887364387512207
# Starting Epoch 22
# max: 15
# Training: On Tick: 0 loss 0.19261310994625092
# max: 15
# Training: On Tick: 1 loss 0.18274196982383728
# max: 20
# Training: On Tick: 2 loss 0.1890592724084854
# max: 15
# Training: On Tick: 3 loss 0.1798567771911621
# max: 8
# Training: On Tick: 4 loss 0.18634425103664398
# max: 15
# Training: On Tick: 5 loss 0.16563959419727325
# max: 19
# Training: On Tick: 6 loss 0.12960024178028107
# max: 15
# Training: On Tick: 7 loss 0.15591271221637726
# max: 7
# Training: On Tick: 8 loss 0.174998939037323
# max: 15
# Training: On Tick: 9 loss 0.14803975820541382
# max: 13
# Training: On Tick: 10 loss 0.15570172667503357
# max: 7
# Training: On Tick: 11 loss 0.14861249923706055
# max: 8
# Training: On Tick: 12 loss 0.17486527562141418
# max: 7
# Training: On Tick: 13 loss 0.20242030918598175
# max: 15
# Training: On Tick: 14 loss 0.18250201642513275
# max: 16
# Training: On Tick: 15 loss 0.17422348260879517
# max: 20
# Training: On Tick: 16 loss 0.20905068516731262
# max: 12
# Training: On Tick: 17 loss 0.199921652674675
# max: 0
# Training: On Tick: 18 loss 0.17177583277225494
# max: 13
# Training: On Tick: 19 loss 0.19146940112113953
# max: 18
# Training: On Tick: 20 loss 0.198892280459404
# max: 6
# Training: On Tick: 21 loss 0.18902884423732758
# max: 0
# Training: On Tick: 22 loss 0.18003568053245544
# Epoch: 22 Loss: 0.1775350570678711
# Starting Epoch 23
# max: 15
# Training: On Tick: 0 loss 0.17712265253067017
# max: 15
# Training: On Tick: 1 loss 0.1718982756137848
# max: 20
# Training: On Tick: 2 loss 0.17733134329319
# max: 15
# Training: On Tick: 3 loss 0.1722976714372635
# max: 8
# Training: On Tick: 4 loss 0.170982226729393
# max: 15
# Training: On Tick: 5 loss 0.15033483505249023
# max: 19
# Training: On Tick: 6 loss 0.11304076761007309
# max: 15
# Training: On Tick: 7 loss 0.15001550316810608
# max: 7
# Training: On Tick: 8 loss 0.16767695546150208
# max: 15
# Training: On Tick: 9 loss 0.14663420617580414
# max: 13
# Training: On Tick: 10 loss 0.14797356724739075
# max: 7
# Training: On Tick: 11 loss 0.1471322476863861
# max: 8
# Training: On Tick: 12 loss 0.17779144644737244
# max: 7
# Training: On Tick: 13 loss 0.19799703359603882
# max: 15
# Training: On Tick: 14 loss 0.17707203328609467
# max: 16
# Training: On Tick: 15 loss 0.1659613996744156
# max: 11
# Training: On Tick: 16 loss 0.1910976618528366
# max: 12
# Training: On Tick: 17 loss 0.1876571625471115
# max: 0
# Training: On Tick: 18 loss 0.16673757135868073
# max: 10
# Training: On Tick: 19 loss 0.19747288525104523
# max: 18
# Training: On Tick: 20 loss 0.19318318367004395
# max: 19
# Training: On Tick: 21 loss 0.18820743262767792
# max: 0
# Training: On Tick: 22 loss 0.17977473139762878
# Epoch: 23 Loss: 0.17023447155952454
# Starting Epoch 24
# max: 15
# Training: On Tick: 0 loss 0.1648368090391159
# max: 15
# Training: On Tick: 1 loss 0.16559669375419617
# max: 20
# Training: On Tick: 2 loss 0.18016491830348969
# max: 15
# Training: On Tick: 3 loss 0.17006488144397736
# max: 8
# Training: On Tick: 4 loss 0.16870398819446564
# max: 15
# Training: On Tick: 5 loss 0.1437530815601349
# max: 19
# Training: On Tick: 6 loss 0.11376527696847916
# max: 15
# Training: On Tick: 7 loss 0.15178507566452026
# max: 14
# Training: On Tick: 8 loss 0.164423868060112
# max: 15
# Training: On Tick: 9 loss 0.13376690447330475
# max: 13
# Training: On Tick: 10 loss 0.1399805098772049
# max: 7
# Training: On Tick: 11 loss 0.13296569883823395
# max: 8
# Training: On Tick: 12 loss 0.15940254926681519
# max: 7
# Training: On Tick: 13 loss 0.18672004342079163
# max: 15
# Training: On Tick: 14 loss 0.16949842870235443
# max: 16
# Training: On Tick: 15 loss 0.16413696110248566
# max: 20
# Training: On Tick: 16 loss 0.19022279977798462
# max: 13
# Training: On Tick: 17 loss 0.18750891089439392
# max: 0
# Training: On Tick: 18 loss 0.15737384557724
# max: 10
# Training: On Tick: 19 loss 0.19583772122859955
# max: 18
# Training: On Tick: 20 loss 0.193877175450325
# max: 7
# Training: On Tick: 21 loss 0.18902210891246796
# max: 0
# Training: On Tick: 22 loss 0.1727757304906845
# Epoch: 24 Loss: 0.16505147516727448
# Starting Epoch 25
# max: 15
# Training: On Tick: 0 loss 0.17312969267368317
# max: 15
# Training: On Tick: 1 loss 0.16590005159378052
# max: 20
# Training: On Tick: 2 loss 0.17250390350818634
# max: 15
# Training: On Tick: 3 loss 0.15954597294330597
# max: 8
# Training: On Tick: 4 loss 0.15616664290428162
# max: 15
# Training: On Tick: 5 loss 0.14288681745529175
# max: 19
# Training: On Tick: 6 loss 0.11375244706869125
# max: 15
# Training: On Tick: 7 loss 0.1499083787202835
# max: 14
# Training: On Tick: 8 loss 0.17582090198993683
# max: 15
# Training: On Tick: 9 loss 0.1401844322681427
# max: 15
# Training: On Tick: 10 loss 0.14627766609191895
# max: 7
# Training: On Tick: 11 loss 0.14222201704978943
# max: 17
# Training: On Tick: 12 loss 0.16420449316501617
# max: 7
# Training: On Tick: 13 loss 0.18217748403549194
# max: 15
# Training: On Tick: 14 loss 0.16060934960842133
# max: 16
# Training: On Tick: 15 loss 0.15608221292495728
# max: 11
# Training: On Tick: 16 loss 0.18267777562141418
# max: 12
# Training: On Tick: 17 loss 0.18106816709041595
# max: 0
# Training: On Tick: 18 loss 0.14917528629302979
# max: 10
# Training: On Tick: 19 loss 0.17723943293094635
# max: 18
# Training: On Tick: 20 loss 0.18125273287296295
# max: 6
# Training: On Tick: 21 loss 0.1801643818616867
# max: 0
# Training: On Tick: 22 loss 0.16810278594493866
# Epoch: 25 Loss: 0.16178491711616516
# Starting Epoch 26
# max: 15
# Training: On Tick: 0 loss 0.1715594381093979
# max: 15
# Training: On Tick: 1 loss 0.16667425632476807
# max: 18
# Training: On Tick: 2 loss 0.19481340050697327
# max: 15
# Training: On Tick: 3 loss 0.1802791953086853
# max: 8
# Training: On Tick: 4 loss 0.15278945863246918
# max: 15
# Training: On Tick: 5 loss 0.14128783345222473
# max: 19
# Training: On Tick: 6 loss 0.10171329975128174
# max: 15
# Training: On Tick: 7 loss 0.13102222979068756
# max: 14
# Training: On Tick: 8 loss 0.1529904305934906
# max: 15
# Training: On Tick: 9 loss 0.12980835139751434
# max: 18
# Training: On Tick: 10 loss 0.14313215017318726
# max: 19
# Training: On Tick: 11 loss 0.14858633279800415
# max: 3
# Training: On Tick: 12 loss 0.15560698509216309
# max: 7
# Training: On Tick: 13 loss 0.17846524715423584
# max: 15
# Training: On Tick: 14 loss 0.1601770967245102
# max: 16
# Training: On Tick: 15 loss 0.151632159948349
# max: 11
# Training: On Tick: 16 loss 0.2146008163690567
# max: 12
# Training: On Tick: 17 loss 0.19529487192630768
# max: 0
# Training: On Tick: 18 loss 0.14898967742919922
# max: 10
# Training: On Tick: 19 loss 0.1815364807844162
# max: 18
# Training: On Tick: 20 loss 0.18258550763130188
# max: 6
# Training: On Tick: 21 loss 0.1598188728094101
# max: 0
# Training: On Tick: 22 loss 0.15373893082141876
# Epoch: 26 Loss: 0.1607435941696167
# Starting Epoch 27
# max: 15
# Training: On Tick: 0 loss 0.1531694382429123
# max: 18
# Training: On Tick: 1 loss 0.15521354973316193
# max: 20
# Training: On Tick: 2 loss 0.16958469152450562
# max: 15
# Training: On Tick: 3 loss 0.16989505290985107
# max: 8
# Training: On Tick: 4 loss 0.16055071353912354
# max: 15
# Training: On Tick: 5 loss 0.12800617516040802
# max: 19
# Training: On Tick: 6 loss 0.09840937703847885
# max: 15
# Training: On Tick: 7 loss 0.13676553964614868
# max: 14
# Training: On Tick: 8 loss 0.15375839173793793
# max: 15
# Training: On Tick: 9 loss 0.11362773925065994
# max: 12
# Training: On Tick: 10 loss 0.13210922479629517
# max: 7
# Training: On Tick: 11 loss 0.12314040213823318
# max: 8
# Training: On Tick: 12 loss 0.14211075007915497
# max: 4
# Training: On Tick: 13 loss 0.17053042352199554
# max: 15
# Training: On Tick: 14 loss 0.1505167931318283
# max: 16
# Training: On Tick: 15 loss 0.14976046979427338
# max: 20
# Training: On Tick: 16 loss 0.17155730724334717
# max: 12
# Training: On Tick: 17 loss 0.17113594710826874
# max: 0
# Training: On Tick: 18 loss 0.14430207014083862
# max: 10
# Training: On Tick: 19 loss 0.17361322045326233
# max: 18
# Training: On Tick: 20 loss 0.19224528968334198
# max: 6
# Training: On Tick: 21 loss 0.16128091514110565
# max: 0
# Training: On Tick: 22 loss 0.1591780185699463
# Epoch: 27 Loss: 0.15132440626621246
# Starting Epoch 28
# max: 15
# Training: On Tick: 0 loss 0.1542532742023468
# max: 15
# Training: On Tick: 1 loss 0.14451006054878235
# max: 20
# Training: On Tick: 2 loss 0.15899820625782013
# max: 15
# Training: On Tick: 3 loss 0.15760831534862518
# max: 15
# Training: On Tick: 4 loss 0.146688774228096
# max: 15
# Training: On Tick: 5 loss 0.11907869577407837
# max: 19
# Training: On Tick: 6 loss 0.09301144629716873
# max: 15
# Training: On Tick: 7 loss 0.11613094806671143
# max: 14
# Training: On Tick: 8 loss 0.14475178718566895
# max: 6
# Training: On Tick: 9 loss 0.10886924713850021
# max: 13
# Training: On Tick: 10 loss 0.11241524666547775
# max: 19
# Training: On Tick: 11 loss 0.11403080075979233
# max: 8
# Training: On Tick: 12 loss 0.12821093201637268
# max: 1
# Training: On Tick: 13 loss 0.1562528759241104
# max: 15
# Training: On Tick: 14 loss 0.14255478978157043
# max: 16
# Training: On Tick: 15 loss 0.152470201253891
# max: 11
# Training: On Tick: 16 loss 0.16612599790096283
# max: 12
# Training: On Tick: 17 loss 0.1640956550836563
# max: 0
# Training: On Tick: 18 loss 0.1367075890302658
# max: 17
# Training: On Tick: 19 loss 0.15492263436317444
# max: 18
# Training: On Tick: 20 loss 0.1500445455312729
# max: 6
# Training: On Tick: 21 loss 0.133556067943573
# max: 0
# Training: On Tick: 22 loss 0.13952820003032684
# Epoch: 28 Loss: 0.13890504837036133
# Starting Epoch 29
# max: 15
# Training: On Tick: 0 loss 0.14675533771514893
# max: 15
# Training: On Tick: 1 loss 0.14781591296195984
# max: 18
# Training: On Tick: 2 loss 0.15531344711780548
# max: 15
# Training: On Tick: 3 loss 0.14185011386871338
# max: 8
# Training: On Tick: 4 loss 0.1446334272623062
# max: 15
# Training: On Tick: 5 loss 0.11928974092006683
# max: 19
# Training: On Tick: 6 loss 0.09178437292575836
# max: 15
# Training: On Tick: 7 loss 0.12199835479259491
# max: 14
# Training: On Tick: 8 loss 0.1371455192565918
# max: 15
# Training: On Tick: 9 loss 0.11183283478021622
# max: 15
# Training: On Tick: 10 loss 0.12202133238315582
# max: 7
# Training: On Tick: 11 loss 0.11054544895887375
# max: 8
# Training: On Tick: 12 loss 0.11600325256586075
# max: 4
# Training: On Tick: 13 loss 0.143828883767128
# max: 15
# Training: On Tick: 14 loss 0.13343922793865204
# max: 16
# Training: On Tick: 15 loss 0.1334291696548462
# max: 11
# Training: On Tick: 16 loss 0.15946786105632782
# max: 12
# Training: On Tick: 17 loss 0.14325177669525146
# max: 0
# Training: On Tick: 18 loss 0.12429656088352203
# max: 10
# Training: On Tick: 19 loss 0.1466197967529297
# max: 18
# Training: On Tick: 20 loss 0.1470671147108078
# max: 6
# Training: On Tick: 21 loss 0.13372191786766052
# max: 0
# Training: On Tick: 22 loss 0.13470570743083954
# Epoch: 29 Loss: 0.13333986699581146
# Starting Epoch 30
# max: 15
# Training: On Tick: 0 loss 0.13176830112934113
# max: 15
# Training: On Tick: 1 loss 0.1313435286283493
# max: 20
# Training: On Tick: 2 loss 0.13399823009967804
# max: 15
# Training: On Tick: 3 loss 0.1281934678554535
# max: 8
# Training: On Tick: 4 loss 0.12666024267673492
# max: 15
# Training: On Tick: 5 loss 0.10525419563055038
# max: 19
# Training: On Tick: 6 loss 0.08525626361370087
# max: 15
# Training: On Tick: 7 loss 0.1120283231139183
# max: 7
# Training: On Tick: 8 loss 0.12602023780345917
# max: 15
# Training: On Tick: 9 loss 0.10461021959781647
# max: 15
# Training: On Tick: 10 loss 0.12010141462087631
# max: 19
# Training: On Tick: 11 loss 0.10956865549087524
# max: 8
# Training: On Tick: 12 loss 0.12759004533290863
# max: 4
# Training: On Tick: 13 loss 0.15374140441417694
# max: 15
# Training: On Tick: 14 loss 0.12245665490627289
# max: 16
# Training: On Tick: 15 loss 0.12221566587686539
# max: 20
# Training: On Tick: 16 loss 0.13880768418312073
# max: 12
# Training: On Tick: 17 loss 0.1333778351545334
# max: 0
# Training: On Tick: 18 loss 0.1126769557595253
# max: 10
# Training: On Tick: 19 loss 0.13293421268463135
# max: 18
# Training: On Tick: 20 loss 0.14122435450553894
# max: 6
# Training: On Tick: 21 loss 0.14086446166038513
# max: 0
# Training: On Tick: 22 loss 0.14103110134601593
# Epoch: 30 Loss: 0.1252923160791397
# Starting Epoch 31
# max: 20
# Training: On Tick: 0 loss 0.12577003240585327
# max: 15
# Training: On Tick: 1 loss 0.12438853830099106
# max: 20
# Training: On Tick: 2 loss 0.12834545969963074
# max: 15
# Training: On Tick: 3 loss 0.12388715893030167
# max: 8
# Training: On Tick: 4 loss 0.12522031366825104
# max: 15
# Training: On Tick: 5 loss 0.10397415608167648
# max: 19
# Training: On Tick: 6 loss 0.07849551737308502
# max: 15
# Training: On Tick: 7 loss 0.09480483829975128
# max: 7
# Training: On Tick: 8 loss 0.11401184648275375
# max: 15
# Training: On Tick: 9 loss 0.09366676211357117
# max: 15
# Training: On Tick: 10 loss 0.10226067155599594
# max: 19
# Training: On Tick: 11 loss 0.098743736743927
# max: 3
# Training: On Tick: 12 loss 0.10812525451183319
# max: 1
# Training: On Tick: 13 loss 0.13852371275424957
# max: 15
# Training: On Tick: 14 loss 0.11107491701841354
# max: 16
# Training: On Tick: 15 loss 0.11371135711669922
# max: 11
# Training: On Tick: 16 loss 0.13328659534454346
# max: 12
# Training: On Tick: 17 loss 0.1234918087720871
# max: 0
# Training: On Tick: 18 loss 0.11073364317417145
# max: 17
# Training: On Tick: 19 loss 0.11936875432729721
# max: 18
# Training: On Tick: 20 loss 0.12067197263240814
# max: 6
# Training: On Tick: 21 loss 0.1254255175590515
# max: 0
# Training: On Tick: 22 loss 0.1269383579492569
# Epoch: 31 Loss: 0.11499656736850739
# Starting Epoch 32
# max: 4
# Training: On Tick: 0 loss 0.11388829350471497
# max: 15
# Training: On Tick: 1 loss 0.1198086217045784
# max: 20
# Training: On Tick: 2 loss 0.12622898817062378
# max: 15
# Training: On Tick: 3 loss 0.11704422533512115
# max: 8
# Training: On Tick: 4 loss 0.11369792371988297
# max: 15
# Training: On Tick: 5 loss 0.09518696367740631
# max: 19
# Training: On Tick: 6 loss 0.07289035618305206
# max: 15
# Training: On Tick: 7 loss 0.09578841179609299
# max: 7
# Training: On Tick: 8 loss 0.11262466013431549
# max: 15
# Training: On Tick: 9 loss 0.08894608169794083
# max: 15
# Training: On Tick: 10 loss 0.10024861991405487
# max: 7
# Training: On Tick: 11 loss 0.09281465411186218
# max: 3
# Training: On Tick: 12 loss 0.10337590426206589
# max: 1
# Training: On Tick: 13 loss 0.1249624565243721
# max: 15
# Training: On Tick: 14 loss 0.10680854320526123
# max: 16
# Training: On Tick: 15 loss 0.11246217787265778
# max: 11
# Training: On Tick: 16 loss 0.13102805614471436
# max: 12
# Training: On Tick: 17 loss 0.12056957185268402
# max: 0
# Training: On Tick: 18 loss 0.10372371971607208
# max: 10
# Training: On Tick: 19 loss 0.11821552366018295
# max: 18
# Training: On Tick: 20 loss 0.11611673980951309
# max: 6
# Training: On Tick: 21 loss 0.12087775021791458
# max: 3
# Training: On Tick: 22 loss 0.11930661648511887
# Epoch: 32 Loss: 0.10985282063484192
# Starting Epoch 33
# max: 15
# Training: On Tick: 0 loss 0.11055704951286316
# max: 15
# Training: On Tick: 1 loss 0.11050373315811157
# max: 20
# Training: On Tick: 2 loss 0.11939473450183868
# max: 15
# Training: On Tick: 3 loss 0.10425689816474915
# max: 8
# Training: On Tick: 4 loss 0.10497108101844788
# max: 15
# Training: On Tick: 5 loss 0.088885597884655
# max: 19
# Training: On Tick: 6 loss 0.06963307410478592
# max: 15
# Training: On Tick: 7 loss 0.08975730091333389
# max: 14
# Training: On Tick: 8 loss 0.10807691514492035
# max: 15
# Training: On Tick: 9 loss 0.08171865344047546
# max: 12
# Training: On Tick: 10 loss 0.09599331021308899
# max: 7
# Training: On Tick: 11 loss 0.08866725116968155
# max: 3
# Training: On Tick: 12 loss 0.09871666878461838
# max: 4
# Training: On Tick: 13 loss 0.12039727717638016
# max: 15
# Training: On Tick: 14 loss 0.10412199050188065
# max: 16
# Training: On Tick: 15 loss 0.10421482473611832
# max: 11
# Training: On Tick: 16 loss 0.1200568825006485
# max: 16
# Training: On Tick: 17 loss 0.1156640574336052
# max: 0
# Training: On Tick: 18 loss 0.10414226353168488
# max: 10
# Training: On Tick: 19 loss 0.11791776865720749
# max: 18
# Training: On Tick: 20 loss 0.1140025407075882
# max: 19
# Training: On Tick: 21 loss 0.11666662245988846
# max: 3
# Training: On Tick: 22 loss 0.11546968668699265
# Epoch: 33 Loss: 0.10451243072748184
# Starting Epoch 34
# max: 15
# Training: On Tick: 0 loss 0.10329005867242813
# max: 15
# Training: On Tick: 1 loss 0.10559961944818497
# max: 20
# Training: On Tick: 2 loss 0.11109635978937149
# max: 15
# Training: On Tick: 3 loss 0.10499857366085052
# max: 8
# Training: On Tick: 4 loss 0.10255628079175949
# max: 15
# Training: On Tick: 5 loss 0.08779928833246231
# max: 19
# Training: On Tick: 6 loss 0.06775426864624023
# max: 15
# Training: On Tick: 7 loss 0.08269445598125458
# max: 7
# Training: On Tick: 8 loss 0.10068800300359726
# max: 15
# Training: On Tick: 9 loss 0.07486186176538467
# max: 12
# Training: On Tick: 10 loss 0.08474195748567581
# max: 7
# Training: On Tick: 11 loss 0.08127959817647934
# max: 3
# Training: On Tick: 12 loss 0.09271876513957977
# max: 1
# Training: On Tick: 13 loss 0.11392633616924286
# max: 15
# Training: On Tick: 14 loss 0.0970849096775055
# max: 16
# Training: On Tick: 15 loss 0.09762268513441086
# max: 11
# Training: On Tick: 16 loss 0.111870676279068
# max: 12
# Training: On Tick: 17 loss 0.1119512990117073
# max: 0
# Training: On Tick: 18 loss 0.09829326719045639
# max: 10
# Training: On Tick: 19 loss 0.10884559899568558
# max: 18
# Training: On Tick: 20 loss 0.11605098843574524
# max: 19
# Training: On Tick: 21 loss 0.11277448385953903
# max: 0
# Training: On Tick: 22 loss 0.10686147958040237
# Epoch: 34 Loss: 0.09892873466014862
# Starting Epoch 35
# max: 15
# Training: On Tick: 0 loss 0.10275052487850189
# max: 15
# Training: On Tick: 1 loss 0.10609792917966843
# max: 20
# Training: On Tick: 2 loss 0.1160774752497673
# max: 15
# Training: On Tick: 3 loss 0.10342707484960556
# max: 8
# Training: On Tick: 4 loss 0.09101777523756027
# max: 15
# Training: On Tick: 5 loss 0.08076285570859909
# max: 19
# Training: On Tick: 6 loss 0.058558233082294464
# max: 15
# Training: On Tick: 7 loss 0.07670126855373383
# max: 7
# Training: On Tick: 8 loss 0.0979209616780281
# max: 15
# Training: On Tick: 9 loss 0.07622838765382767
# max: 12
# Training: On Tick: 10 loss 0.08408797532320023
# max: 7
# Training: On Tick: 11 loss 0.08295539021492004
# max: 3
# Training: On Tick: 12 loss 0.09485520422458649
# max: 1
# Training: On Tick: 13 loss 0.10974663496017456
# max: 15
# Training: On Tick: 14 loss 0.09225129336118698
# max: 16
# Training: On Tick: 15 loss 0.09398981928825378
# max: 11
# Training: On Tick: 16 loss 0.10658089071512222
# max: 12
# Training: On Tick: 17 loss 0.10306678712368011
# max: 0
# Training: On Tick: 18 loss 0.08908437937498093
# max: 10
# Training: On Tick: 19 loss 0.09989045560359955
# max: 18
# Training: On Tick: 20 loss 0.10445903986692429
# max: 6
# Training: On Tick: 21 loss 0.10401389747858047
# max: 3
# Training: On Tick: 22 loss 0.09841981530189514
# Epoch: 35 Loss: 0.09447584301233292
# Starting Epoch 36
# max: 15
# Training: On Tick: 0 loss 0.09677639603614807
# max: 15
# Training: On Tick: 1 loss 0.09988056123256683
# max: 20
# Training: On Tick: 2 loss 0.1097896620631218
# max: 15
# Training: On Tick: 3 loss 0.10165861248970032
# max: 8
# Training: On Tick: 4 loss 0.08966612815856934
# max: 15
# Training: On Tick: 5 loss 0.07765832543373108
# max: 19
# Training: On Tick: 6 loss 0.061485208570957184
# max: 15
# Training: On Tick: 7 loss 0.07080703228712082
# max: 7
# Training: On Tick: 8 loss 0.08394715189933777
# max: 15
# Training: On Tick: 9 loss 0.06845723092556
# max: 12
# Training: On Tick: 10 loss 0.07335196435451508
# max: 15
# Training: On Tick: 11 loss 0.07289887219667435
# max: 8
# Training: On Tick: 12 loss 0.08513838052749634
# max: 1
# Training: On Tick: 13 loss 0.10270300507545471
# max: 15
# Training: On Tick: 14 loss 0.09196683764457703
# max: 16
# Training: On Tick: 15 loss 0.08992546796798706
# max: 15
# Training: On Tick: 16 loss 0.09825222194194794
# max: 12
# Training: On Tick: 17 loss 0.09632176160812378
# max: 0
# Training: On Tick: 18 loss 0.08094416558742523
# max: 10
# Training: On Tick: 19 loss 0.09710171818733215
# max: 18
# Training: On Tick: 20 loss 0.09478180855512619
# max: 6
# Training: On Tick: 21 loss 0.09578435122966766
# max: 0
# Training: On Tick: 22 loss 0.09099985659122467
# Epoch: 36 Loss: 0.08827376365661621
# Starting Epoch 37
# max: 15
# Training: On Tick: 0 loss 0.09450255334377289
# max: 15
# Training: On Tick: 1 loss 0.09544212371110916
# max: 20
# Training: On Tick: 2 loss 0.09919288754463196
# max: 15
# Training: On Tick: 3 loss 0.09009519219398499
# max: 8
# Training: On Tick: 4 loss 0.08110552281141281
# max: 15
# Training: On Tick: 5 loss 0.07344530522823334
# max: 19
# Training: On Tick: 6 loss 0.060923971235752106
# max: 15
# Training: On Tick: 7 loss 0.07081884145736694
# max: 7
# Training: On Tick: 8 loss 0.08250176906585693
# max: 15
# Training: On Tick: 9 loss 0.06763933598995209
# max: 12
# Training: On Tick: 10 loss 0.07534640282392502
# max: 7
# Training: On Tick: 11 loss 0.07036644220352173
# max: 3
# Training: On Tick: 12 loss 0.07687531411647797
# max: 7
# Training: On Tick: 13 loss 0.09547922760248184
# max: 15
# Training: On Tick: 14 loss 0.08219485729932785
# max: 16
# Training: On Tick: 15 loss 0.08367092907428741
# max: 15
# Training: On Tick: 16 loss 0.09319417178630829
# max: 12
# Training: On Tick: 17 loss 0.09157605469226837
# max: 0
# Training: On Tick: 18 loss 0.07813037186861038
# max: 10
# Training: On Tick: 19 loss 0.09468827396631241
# max: 18
# Training: On Tick: 20 loss 0.08517561852931976
# max: 6
# Training: On Tick: 21 loss 0.09053468704223633
# max: 0
# Training: On Tick: 22 loss 0.08052421361207962
# Epoch: 37 Loss: 0.0831923559308052
# Starting Epoch 38
# max: 15
# Training: On Tick: 0 loss 0.08743099123239517
# max: 15
# Training: On Tick: 1 loss 0.0863833948969841
# max: 20
# Training: On Tick: 2 loss 0.09324374049901962
# max: 15
# Training: On Tick: 3 loss 0.090619757771492
# max: 8
# Training: On Tick: 4 loss 0.08106312900781631
# max: 15
# Training: On Tick: 5 loss 0.0718851089477539
# max: 19
# Training: On Tick: 6 loss 0.057006530463695526
# max: 15
# Training: On Tick: 7 loss 0.06590282171964645
# max: 7
# Training: On Tick: 8 loss 0.07881783694028854
# max: 14
# Training: On Tick: 9 loss 0.06375851482152939
# max: 12
# Training: On Tick: 10 loss 0.07432183623313904
# max: 7
# Training: On Tick: 11 loss 0.06646072864532471
# max: 3
# Training: On Tick: 12 loss 0.07819944620132446
# max: 1
# Training: On Tick: 13 loss 0.0931636318564415
# max: 15
# Training: On Tick: 14 loss 0.07829022407531738
# max: 16
# Training: On Tick: 15 loss 0.07892580330371857
# max: 15
# Training: On Tick: 16 loss 0.09045407921075821
# max: 12
# Training: On Tick: 17 loss 0.08950787037611008
# max: 0
# Training: On Tick: 18 loss 0.07791201770305634
# max: 10
# Training: On Tick: 19 loss 0.09448432922363281
# max: 18
# Training: On Tick: 20 loss 0.09648077934980392
# max: 6
# Training: On Tick: 21 loss 0.09426949918270111
# max: 0
# Training: On Tick: 22 loss 0.08478880673646927
# Epoch: 38 Loss: 0.08145090192556381
# Starting Epoch 39
# max: 15
# Training: On Tick: 0 loss 0.08485369384288788
# max: 15
# Training: On Tick: 1 loss 0.08274156600236893
# max: 20
# Training: On Tick: 2 loss 0.08892204612493515
# max: 15
# Training: On Tick: 3 loss 0.08213496953248978
# max: 8
# Training: On Tick: 4 loss 0.07426963746547699
# max: 15
# Training: On Tick: 5 loss 0.06508038192987442
# max: 19
# Training: On Tick: 6 loss 0.05443384870886803
# max: 15
# Training: On Tick: 7 loss 0.06549683213233948
# max: 14
# Training: On Tick: 8 loss 0.07688809186220169
# max: 14
# Training: On Tick: 9 loss 0.0592137947678566
# max: 12
# Training: On Tick: 10 loss 0.07010489702224731
# max: 7
# Training: On Tick: 11 loss 0.06486581265926361
# max: 3
# Training: On Tick: 12 loss 0.07446809113025665
# max: 1
# Training: On Tick: 13 loss 0.09360995888710022
# max: 15
# Training: On Tick: 14 loss 0.07876930385828018
# max: 16
# Training: On Tick: 15 loss 0.0774533823132515
# max: 15
# Training: On Tick: 16 loss 0.09019194543361664
# max: 12
# Training: On Tick: 17 loss 0.08539166301488876
# max: 0
# Training: On Tick: 18 loss 0.07268131524324417
# max: 10
# Training: On Tick: 19 loss 0.07946961373090744
# max: 18
# Training: On Tick: 20 loss 0.08260656148195267
# max: 6
# Training: On Tick: 21 loss 0.08407015353441238
# max: 3
# Training: On Tick: 22 loss 0.08213229477405548
# Epoch: 39 Loss: 0.07694999873638153
# CPU times: user 16min 10s, sys: 2min 5s, total: 18min 15s
# Wall time: 19min 32s

# %%
# switch back to evaluation mode
trained_net.eval()

sample_img, sample_target = JointNormalize(*norm)(*JointToTensor()(*sample1))
if USE_GPU:
    sample_img = sample_img.cuda()
sample_output_O = overfit_net.forward(sample_img[None])
sample_output_T = trained_net.forward(sample_img[None])

print(sample_output_T.shape)

# computing mIOU (quantitative measure of accuracy for network predictions)
pred_T = torch.argmax(sample_output_T, dim=1).cpu().numpy()[0]
pred_O = torch.argmax(sample_output_O, dim=1).cpu().numpy()[0]
print(pred_T.max())
gts = torch.from_numpy(np.array(sample1[1].convert('P'), dtype=np.int32)).long().numpy()
gts[gts == 255] = -1
conf_T = eval_semantic_segmentation(pred_T[None], gts[None])
conf_O = eval_semantic_segmentation(pred_O[None], gts[None])


fig = plt.figure(figsize=(14,10))
ax1 = fig.add_subplot(2,2,1)
plt.title('image sample')
ax1.imshow(sample1[0])
ax2 = fig.add_subplot(2,2,2)
plt.title('ground truth (target)')
ax2.imshow(sample1[1])
ax3 = fig.add_subplot(2,2,3)
plt.title('OVERFIT_NET prediction (for its training image)')
ax3.text(10, 25, 'mIoU = {:_>8.6f}'.format(conf_O['miou']), fontsize=20, color='white')
ax3.imshow(colorize_mask(torch.argmax(sample_output_O, dim=1).cpu().numpy()[0]))
ax4 = fig.add_subplot(2,2,4)
plt.title('TRAINED_NET prediction (for one of its training images)')
ax4.text(10, 25, 'mIoU = {:_>8.6f}'.format(conf_T['miou']), fontsize=20, color='white')
ax4.imshow(colorize_mask(torch.argmax(sample_output_T, dim=1).cpu().numpy()[0]))
# Out:
# max: 15
# max: 15
# torch.Size([1, 21, 375, 500])
# 15
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:91: RuntimeWarning: invalid value encountered in true_divide
#   iou = np.diag(confusion) / iou_denominator
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:168: RuntimeWarning: invalid value encountered in true_divide
#   class_accuracy = np.diag(confusion) / np.sum(confusion, axis=1)

# %%
sample_img, sample_target = JointNormalize(*norm)(*JointToTensor()(*sample2))
if USE_GPU:
    sample_img = sample_img.cuda()
sample_output_O = overfit_net.forward(sample_img[None])
sample_output_T = trained_net.forward(sample_img[None])

# computing mIOU (quantitative measure of accuracy for network predictions)
pred_O = torch.argmax(sample_output_O, dim=1).cpu().numpy()[0]
pred_T = torch.argmax(sample_output_T, dim=1).cpu().numpy()[0]
gts = torch.from_numpy(np.array(sample2[1].convert('P'), dtype=np.int32)).long().numpy()
gts[gts == 255] = -1
conf_O = eval_semantic_segmentation(pred_O[None], gts[None])
conf_T = eval_semantic_segmentation(pred_T[None], gts[None])


fig = plt.figure(figsize=(14,10))
ax1 = fig.add_subplot(2,2,1)
plt.title('image sample')
ax1.imshow(sample2[0])
ax2 = fig.add_subplot(2,2,2)
plt.title('ground truth (target)')
ax2.imshow(sample2[1])
ax3 = fig.add_subplot(2,2,3)
plt.title('OVERFIT_NET prediction (for image it has not seen)')
ax3.text(10, 25, 'mIoU = {:_>8.6f}'.format(conf_O['miou']), fontsize=20, color='white')
ax3.imshow(colorize_mask(torch.argmax(sample_output_O, dim=1).cpu().numpy()[0]))
ax4 = fig.add_subplot(2,2,4)
plt.title('TRAINED_NET prediction (for image it has not seen)')
ax4.text(10, 25, 'mIoU = {:_>8.6f}'.format(conf_T['miou']), fontsize=20, color='white')
ax4.imshow(colorize_mask(torch.argmax(sample_output_T, dim=1).cpu().numpy()[0]))
# Out:
# max: 20
# max: 17
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:168: RuntimeWarning: invalid value encountered in true_divide
#   class_accuracy = np.diag(confusion) / np.sum(confusion, axis=1)
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:91: RuntimeWarning: invalid value encountered in true_divide
#   iou = np.diag(confusion) / iou_denominator

# %% [markdown]
# #### (h) Evaluate TRAINED_NET on validation dataset.
# ##### Run the validation loop for TRAINED_NET against the validation dataset (it has not seen):

# %%
# %%time
# This will be slow on CPU (around 1 hour). On GPU it should take only a few minutes (depending on your GPU).
print("mIoU for TRAINED_NET over the validation dataset:{}".format(validate(val_loader, trained_net)[1]))

# %%
# !pip install torchviz
# from torchviz import make_dot
# output = trained_net(JointToTensor()(*sample1)[0].unsqueeze(0))
# make_dot()

# %% [markdown]
# # Problem 6
#
# #### For the network that you implemented, write a paragraph or two about limitations / bottlenecks about the work. What could be improved? What seems to be some obvious issues with the existing works?
