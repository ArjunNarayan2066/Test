# %% [markdown]
# <a href="https://colab.research.google.com/github/ArjunNarayan2066/Test/blob/master/MySemanticSegmentation_student.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from os.path import exists
if (exists('images') == False):
    print('Copying Images')
    # !cp -r "drive/My Drive/cs484/images/" .
if (exists('lib') == False):
    print('Copying Lib')
    # !cp -r "drive/My Drive/cs484/lib/" .
# if (exists('dataset') == False):
#     print('Copying Dataset')
#     !cp -r "drive/My Drive/cs484/dataset" .

# %% [markdown]
# ### CS 484/684 Computational Vision
# #### credits: many thanks for the design of this assignemnt go to <a href="https://tovacinni.github.io/" target = "_blank">Towaki Takikawa</a>
#
# # Homework Assignment #5 - Supervised Deep Learning for Segmentation
#
# This assignment will test your understanding of applying deep learning by having you apply (fully supervised) deep learning to semantic segmentation, a well studied problem in computer vision.
#
# You can get most of the work done using only CPU, however, the use of GPU will be helpful in later parts. Programming and debugging everything upto and including problem 5c should be fine on CPU. You will notice the benefit of GPU mostly in later parts (d-h) of problem 5, but they are mainly implemenmted and test your code written and debugged earlier. If you do not have a GPU readily accesible to you, we recommend that you use Google Colaboratory to get access to a GPU. Once you are satisfied with your code upto and including 5(c), simply upload this Jupyter Notebook to Google Colaboratory to run the tests in later parts of Problem 5.
#
# Proficiency with PyTorch is required. Working through the PyTorch tutorials will make this assignment significantly easier. https://pytorch.org/tutorials/

# %%
# Python Libraries
import random
import math
import numbers
import platform
import copy
from IPython.core.debugger import set_trace

# Importing essential libraries for basic image manipulations.
import numpy as np
import PIL
from PIL import Image, ImageOps
import matplotlib.pyplot as plt
from tqdm import tqdm

# We import some of the main PyTorch and TorchVision libraries used for HW4.
# Detailed installation instructions are here: https://pytorch.org/get-started/locally/
# That web site should help you to select the right 'conda install' command to be run in 'Anaconda Prompt'.
# In particular, select the right version of CUDA. Note that prior to installing PyTorch, you should  
# install the latest driver for your GPU and CUDA (9.2 or 10.1), assuming your GPU supports it. 
# For more information about pytorch refer to 
# https://pytorch.org/docs/stable/nn.functional.html
# https://pytorch.org/docs/stable/data.html.
# and https://pytorch.org/docs/stable/torchvision/transforms.html
import torch
import torch.nn.functional as F
from torch import nn
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
import torchvision.transforms.functional as tF
import torch.optim as optim

# !export CUDA_LAUNCH_BLOCKING=1
print(torch.cuda.is_available())
# print(torch.cuda.get_device_name())

# Note class labels used in Pascal dataset:
# 0:    background,
# 1-20: aeroplane, bicycle, bird, boat, bottle, bus, car, cat, chair, cow, diningtable, dog, horse, motorbike,
#       person, pottedplant, sheep, sofa, train, TV_monitor
# 255: "void", which means class for pixel is undefined
# Out:
# True

# %%
# %matplotlib inline

# It is best to start with USE_GPU = False (implying CPU). Switch USE_GPU to True only if you want to use GPU. However... 
# we strongly recommend to wait until you are absolutely sure your CPU-based code works (at least on single image dataset)
USE_GPU = torch.cuda.is_available()

# %%
# !pip install chainercv # Need to manualy install this in the colab environment

# ChainerCV is a library similar to TorchVision, created and maintained by Preferred Networks. 
# Chainer, the base library, inspired and led to the creation of PyTorch! 
# Although Chainer and PyTorch are different, there are some nice functionalities in ChainerCV 
# that are useful, so we include it as an excersice on learning other libraries.
# To install ChainerCV, normally it suffices to run "pip install chainercv" inside "Anaconda Prompt".
# For more detailed installation instructions, see https://chainercv.readthedocs.io/en/stable/install.html
# For other information about ChainerCV library, refer to https://chainercv.readthedocs.io/en/stable/ 
from chainercv.evaluations import eval_semantic_segmentation
from chainercv.datasets import VOCSemanticSegmentationDataset
# Out:
# Requirement already satisfied: chainercv in /usr/local/lib/python3.6/dist-packages (0.13.1)
# Requirement already satisfied: chainer>=6.0 in /usr/local/lib/python3.6/dist-packages (from chainercv) (7.4.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (from chainercv) (7.0.0)
# Requirement already satisfied: protobuf>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from chainer>=6.0->chainercv) (3.12.4)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from chainer>=6.0->chainercv) (1.15.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from chainer>=6.0->chainercv) (3.7.4.3)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from chainer>=6.0->chainercv) (1.18.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/dist-packages (from chainer>=6.0->chainercv) (3.0.12)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from chainer>=6.0->chainercv) (50.3.2)

# %%
# This colorize_mask class takes in a numpy segmentation mask,
#  and then converts it to a PIL Image for visualization.
#  Since by default the numpy matrix contains integers from
#  0,1,...,num_classes, we need to apply some color to this
#  so we can visualize easier! Refer to:
#  https://pillow.readthedocs.io/en/4.1.x/reference/Image.html#PIL.Image.Image.putpalette
palette = [0, 0, 0, 128, 0, 0, 0, 128, 0, 128, 128, 0, 0, 0, 128, 128, 0, 128, 0, 128, 128,
           128, 128, 128, 64, 0, 0, 192, 0, 0, 64, 128, 0, 192, 128, 0, 64, 0, 128, 192, 0, 128,
           64, 128, 128, 192, 128, 128, 0, 64, 0, 128, 64, 0, 0, 192, 0, 128, 192, 0, 0, 64, 128]

def colorize_mask(mask):
    new_mask = Image.fromarray(mask.astype(np.uint8)).convert('P')
    new_mask.putpalette(palette)

    return new_mask

# %%
# Below we will use a sample image-target pair from VOC training dataset to test your joint transforms. 
# Running this block will automatically download the PASCAL VOC Dataset (3.7GB) to DATASET_PATH if "download = True".
# The code below creates subdirectory "datasets" in the same location as the notebook file, but
# you can modify DATASET_PATH to download the dataset to any custom directory. Download takes a few minutes.
# On subsequent runs you may save time by setting "download = False" (the default value of this flag)

# We provide our own implementation of torchvision.datasets.voc (containing popular "Pascal" dataset)
# that allows us to easily create single-image datasets
from lib.voc import VOCSegmentation
DATASET_PATH = 'drive/My Drive/cs484/dataset'

# Here, we obtain and visualize one sample (img, target) pair from VOC training dataset and one from validation dataset. 
# Note that operator [...] extracts the sample corresponding to the specified index. 
# Also, note the parameter download = True. Set this to False after you download to save time on later runs.
sample1 = VOCSegmentation(DATASET_PATH, image_set='train', download = False)[200]
sample2 = VOCSegmentation(DATASET_PATH, image_set='val')[20]

# We demonstrate two different (equivalent) ways to access image and target inside the samples.
img1, target1 = sample1
img2 = sample2[0]
target2 = sample2[1]

fig = plt.figure(figsize=(14,10))
ax1 = fig.add_subplot(2,2,1)
plt.title('sample1 - image')
ax1.imshow(img1)
ax2 = fig.add_subplot(2,2,2)
plt.title('sample1 - target')
ax2.imshow(target1)
ax3 = fig.add_subplot(2,2,3)
plt.title('sample2 - image')
ax3.imshow(img2)
ax4 = fig.add_subplot(2,2,4)
plt.title('sample2 - target')
ax4.imshow(target2)
# Out:
# VOC Root: drive/My Drive/cs484/dataset
# VOC Root: drive/My Drive/cs484/dataset

# %%
some_img = VOCSegmentation(DATASET_PATH, image_set='train', download = False)[300]
fig = plt.figure(figsize=(14,10))
ax1 = fig.add_subplot(1,2,1)
plt.title('sample1 - image')
ax1.imshow(some_img[0])
ax2 = fig.add_subplot(1,2,2)
plt.title('sample1 - target')
ax2.imshow(some_img[1])
# Out:
# VOC Root: drive/My Drive/cs484/dataset

# %% [markdown]
# # Problem 1
#
# #### Implement a set of "Joint Transform" functions to perform data augmentation in your dataset.
#
# Neural networks are typically applied to transformed images. There are several important reasons for this:
#
# 1. The image data should is in certain required format (i.e. consistent spacial resolution to batch). The images should also be normalized and converted to the "tensor" data format expected by pytorch libraries.
#
# 2. Some transforms are used to perform randomized image domain transformations with the purpose of "data augmentation".
#
# In this exercise, you will implement a set of different transform functions to do both of these things. Note that unlike classification nets, training semantic segmentation networks requires that some of the transforms are applied to both image and the corresponding "target" (Ground Truth segmentation mask). We refer to such transforms and their compositions as "Joint". In general, your Transform classes should take as the input both the image and the target, and return a tuple of the transformed input image and target. Be sure to use critical thinking to determine if you can apply the same transform function to both the input and the output.
#
# For this problem you may use any of the `torchvision.transforms.functional` functions. For inspiration, refer to:
# #### https://pytorch.org/tutorials/beginner/data_loading_tutorial.html
# #### https://pytorch.org/docs/stable/torchvision/transforms.html#module-torchvision.transforms.functional

# %% [markdown]
# #### Example 1
#
# This class takes a img, target pair, and then transform the pair such that they are in `Torch.Tensor()` format.
#
# #### Solution:

# %%
class JointToTensor(object):
    def __call__(self, img, target):
        # print(target.max())
        return tF.to_tensor(img), torch.from_numpy(np.array(target.convert('P'), dtype=np.int32)).long()

# %%
# Check the transform by passing the image-target sample.

img, target = JointToTensor()(*sample2)
print(target[target!=255].max())
fig = plt.figure(figsize=(12,6))
ax1 = fig.add_subplot(2,2,1)
ax1.imshow(img.permute(1,2,0))
ax2 = fig.add_subplot(2,2,2)
ax2.imshow(colorize_mask(target.numpy()))
# Out:
# tensor(17)

# %% [markdown]
# #### Example 2:
#
# This class implements CenterCrop that takes an img, target pair, and then apply a crop about the center of the image such that the output resolution is $\mbox{size} \times \mbox{size}$.
#
# #### Solution:

# %%
class JointCenterCrop(object):
    def __init__(self, size):
        """
        params:
            size (int) : size of the center crop
        """
        self.size = size
        
    def __call__(self, img, target):
        return (tF.five_crop(img, self.size)[4], 
                tF.five_crop(target, self.size)[4])
    
img, target = JointCenterCrop(100)(*sample1)
fig = plt.figure(figsize=(12,6))
ax1 = fig.add_subplot(2,2,1)
ax1.imshow(img)
ax2 = fig.add_subplot(2,2,2)
ax2.imshow(target)

# %% [markdown]
# #### (a) Implement RandomFlip
#
# This class should take a img, target pair and then apply a horizontal flip across the vertical axis at random.
#
# #### Solution:

# %%
class JointRandomFlip(object): 
    def __call__(self, img, target):
        if not isinstance(img, torch.Tensor):
            img, target = JointToTensor()(img, target)

        if np.random.randint(2):
            return (tF.hflip(img), tF.hflip(target))
        else:
            return (img, target)

# %%
img, target = JointRandomFlip()(*sample2)
print(target[target!=255].max())
fig = plt.figure(figsize=(12,6))
ax1 = fig.add_subplot(2,2,1)
ax1.imshow(img.permute(1,2,0))
ax2 = fig.add_subplot(2,2,2)
ax2.imshow(colorize_mask(target.numpy()))
# Out:
# tensor(17)

# %% [markdown]
# #### (b) Implement RandomResizeCrop
#
# This class should take a img, target pair and then resize the images by a random scale between $[\mbox{minimum_scale}, \mbox{maximum_scale}]$, crop a random location of the image by $\min(\mbox{size}, \mbox{image_height}, \mbox{image_width})$ (where the size is passed in as an integer in the constructor), and then resize to $\mbox{size} \times \mbox{size}$ (again, the size passed in). The crop box should fit within the image.
#
# #### Solution:

# %%
class JointRandomResizeCrop(object):
    def __init__(self, min_scale, max_scale, size):
        self.min_scale = min_scale
        self.max_scale = max_scale
        if isinstance(size, tuple):
            self.size = size
        else:
            self.size = (size,size)

        self.scale_len = self.max_scale - self.min_scale

    def __call__(self, img, target):
        if not isinstance(img, PIL.Image.Image):
            target = transforms.ToPILImage()(target.type(torch.IntTensor))
            img = transforms.ToPILImage()(img)

        # Select Random Resize Scale
        scale = (np.random.rand() * (self.scale_len)) + self.min_scale
        rescaled_size = (int(img.size[0]*scale), int(img.size[1]*scale))
        rescaled_img = tF.resize(img, rescaled_size[::-1])
        rescaled_target = tF.resize(target, rescaled_size[::-1], interpolation=PIL.Image.NEAREST)

        # Crop Then Resize
        crop_size = min((self.size[0],self.size[1], rescaled_img.size[0]-1, rescaled_img.size[1]-1))
        crop_c = np.random.randint(0, rescaled_img.size[0] - crop_size)
        crop_r = np.random.randint(0, rescaled_img.size[1] - crop_size)

        final_img = tF.resized_crop(rescaled_img, crop_r, crop_c, crop_size, crop_size, size=self.size)
        final_target= tF.resized_crop(rescaled_target, crop_r, crop_c, crop_size, crop_size, size=self.size, interpolation=PIL.Image.NEAREST)

        final_img, final_target = JointToTensor()(final_img, final_target)
        return final_img, final_target.type(torch.LongTensor)

# %%
# print(sample1[0].size)
final_img, final_target = JointRandomResizeCrop(0.5, 1.5, 256)(*JointToTensor()(*sample2))
print(final_target[final_target!=255].max())
print(final_img.size())
fig = plt.figure(figsize=(12,6))
ax1 = fig.add_subplot(2,2,1)
# ax1.imshow(colorize_mask(target.numpy()))
ax1.imshow(final_img.permute(1,2,0))
ax2 = fig.add_subplot(2,2,2)
ax2.imshow(colorize_mask(final_target.numpy()))
# plt.show()
# Out:
# tensor(17)
# torch.Size([3, 256, 256])

# %% [markdown]
# #### (c) Implement Normalize

# %% [markdown]
# This class should take a img, target pair and then normalize the images by subtracting the mean and dividing variance.
#
# #### Solution:

# %%
class JointResize(object):
    def __init__(self, size):
        self.size = size
    
    def __call__(self, img, target):
        if not isinstance(img, torch.Tensor):
            img, target = JointToTensor()(img, target)

        # print(img[None].shape)
        img = tF.resize(img[None], self.size)[0]#self.size)
        target = tF.resize(target[None], size=self.size, interpolation=PIL.Image.NEAREST)[0]
        # print(img.shape)

        return img, target

# %%
norm = ([0.485, 0.456, 0.406], 
        [0.229, 0.224, 0.225]) 
# means = [0.485, 0.456, 0.406]
# std = [0.229, 0.224, 0.225] 

class JointNormalize(object): 
    def __init__(self, mean, std):
        self.mean = mean
        self.std = std
          
    def __call__(self, img, target):
        if not isinstance(img, torch.Tensor):
            img, target = JointToTensor()(img, target)
        # target = target.double()
        # img_means = [img[:,:,0].mean(), img[:,:,1].mean(), img[:,:,2].mean()]
        # img_std = [img[:,:,0].std(), img[:,:,1].std(), img[:,:,2].img_std()]
        # target_means = [target[:,:,0].mean(), target[:,:,1].mean(), target[:,:,2].mean()]
        # target_std = [target[:,:,0].std(), target[:,:,1].std(), target[:,:,2].std()]

        # Normalize
        norm_img = tF.normalize(img, self.mean, self.std)
        # Rescale to 0-1
        norm_img -= norm_img.min()
        norm_img /= norm_img.max()

        # norm_target = tF.normalize(target, target.mean(), target.std())
        # norm_target = ((target - target.mean()) / target.std()).long()
        # print(norm_target)

        return norm_img, target

# %%
# fixed_img, fixed_target = JointNormalize(*norm)(*sample1)
fixed_img, fixed_target = JointResize((375,500))(*sample2)
print(fixed_target[fixed_target!=255].max())
fig = plt.figure(figsize=(12,6))
ax1 = fig.add_subplot(2,2,1)
ax1.imshow(fixed_img.permute(1,2,0))
ax2 = fig.add_subplot(2,2,2)
ax2.imshow(colorize_mask(fixed_target.numpy()))
# Out:
# tensor(17)

# %% [markdown]
# #### (d) Compose the transforms together:
# ##### Use `JointCompose` (fully implemeted below) to compose the implemented transforms together in some random order. Verify the output makes sense and visualize it.

# %%
# This class composes transofrmations from a given list of image transforms (expected in the argument). Such compositions 
# will be applied to the dataset during training. This cell is fully implemented.

class JointCompose(object):
    def __init__(self, transforms):
        """
        params: 
           transforms (list) : list of transforms
        """
        self.transforms = transforms

    # We override the __call__ function such that this class can be
    # called as a function i.e. JointCompose(transforms)(img, target)
    # Such classes are known as "functors"
    def __call__(self, img, target):
        """
        params:
            img (PIL.Image)    : input image
            target (PIL.Image) : ground truth label 
        """
        assert img.size == target.size
        for t in self.transforms:
            img, target = t(img, target)
        return img, target

# %%
# Student Answer:
tfs = [JointToTensor(), JointRandomResizeCrop(0.5, 0.8, 100), JointRandomFlip()]

img, target = JointCompose(tfs)(*sample1)
print(img.size)
fig = plt.figure(figsize=(12,6))
ax1 = fig.add_subplot(2,2,1)
ax1.imshow(img.permute(1,2,0))
ax2 = fig.add_subplot(2,2,2)
ax2.imshow(colorize_mask(target.numpy()))
# Out:
# <built-in method size of Tensor object at 0x7f03ec593828>

# %% [markdown]
# #### (e) Compose the transforms together: use `JointCompose` to compose the implemented transforms for:
# #### 1. A sanity dataset that will contain 1 single image. Your objective is to overfit on this 1 image, so choose your transforms and parameters accordingly.
# #### 2. A training dataset that will contain the training images. The goal here is to generalize to the validation set, which is unseen.
# #### 3. A validation dataset that will contain the validation images. The goal here is to measure the 'true' performance.

# %%
# Student Answer:

sanity_joint_transform  = JointCompose([JointToTensor(), JointNormalize(*norm)])#, JointRandomResizeCrop(0.5, 1.5, (375,500))])

train_joint_transform   = JointCompose([JointToTensor(), JointNormalize(*norm), JointRandomFlip(), JointRandomResizeCrop(0.5, 1.5, (375,500))])

val_joint_transform     = JointCompose([JointToTensor(), JointRandomFlip()])

# %% [markdown]
# This code below will then apply `train_joint_transform` to the entire dataset.

# %%
# Apply the Joint-Compose transformations above to create three datasets and the corresponding Data-Loaders.
# This cell is fully implemented.

# This single image data(sub)set can help to better understand and to debug the network training process. 
# Optional integer parameter 'sanity_check' specifies the index of the image-target pair and creates a single image dataset.
# Note that we use the same image (index=200) as used for sample1.
sanity_data = VOCSegmentation(
    DATASET_PATH, 
    image_set = 'train',
    transforms = sanity_joint_transform,
    sanity_check = 200
)

# This is a standard VOC data(sub)set used for training semantic segmentation networks
train_data = VOCSegmentation(
    DATASET_PATH, 
    image_set = 'train', 
    transforms = train_joint_transform,
)

# This is a standard VOC data(sub)set used for validating semantic segmentation networks
val_data = VOCSegmentation(
    DATASET_PATH, 
    image_set='val',
    transforms = val_joint_transform
)

# Increase TRAIN_BATCH_SIZE if you are using GPU to speed up training. 
# When batch size changes, the learning rate may also need to be adjusted. 
# Note that batch size maybe limited by your GPU memory, so adjust if you get "run out of GPU memory" error.
TRAIN_BATCH_SIZE = 64 # 1 default

# If you are NOT using Windows, set NUM_WORKERS to anything you want, e.g. NUM_WORKERS = 4,
# but Windows has issues with multi-process dataloaders, so NUM_WORKERS must be 0 for Windows.
NUM_WORKERS =  4 # default

sanity_loader = DataLoader(sanity_data, batch_size=1, num_workers=NUM_WORKERS, shuffle=False)
train_loader = DataLoader(train_data, batch_size=TRAIN_BATCH_SIZE, num_workers=NUM_WORKERS, shuffle=True)
val_loader = DataLoader(val_data, batch_size=1, num_workers=NUM_WORKERS, shuffle=False)
# Out:
# VOC Root: drive/My Drive/cs484/dataset
# VOC Root: drive/My Drive/cs484/dataset
# VOC Root: drive/My Drive/cs484/dataset

# %% [markdown]
# # Problem 2
#
# #### (a) Implement encoder/decoder segmentation CNN using PyTorch.
#
# You must follow the general network architecture specified in the image below. Note that since convolutional layers are the main building blocks in common network architectures for image analysis, the corresponding blocks are typically unlabeled in the network diagrams. The network should have 5 (pre-trained) convolutional layers (residual blocks) from "resnet" in the encoder part, two upsampling layers, and one skip connection. For the layer before the final upsampling layer, lightly experiment with some combination of Conv, ReLU, BatchNorm, and/or other layers to see how it affects performance.
# <img src="images\deeplabv2_overview.png">
# You should choose specific parameters for all layers, but the overall structure should be restricted to what is shown in the illustration above. For inspiration, you can refer to papers in the citation section of the following link to DeepLab (e.g. specific parameters for each layer): http://liangchiehchen.com/projects/DeepLab.html. The first two papers in the citation section are particularly relevant.
#
# In your implementation, you can use a base model of choice (you can use `torchvision.models` as a starting point), but we suggest that you learn the properties of each base model and choose one according to the computational resources available to you.
#
# ##### Note: do not apply any post-processing (such as DenseCRF) to the output of your net.
#
# #### Solution:

# %%
#@title Default title text
import torchvision.models as models

class MyBadNet(nn.Module):
    def __init__(self, num_classes, img_size, criterion=None):
        super(MyNet, self).__init__()
        # Implement me
        self.relu = nn.ReLU()

        # Get initial few layers + 6 res blocks in packs of 2
        self.encoder1 = nn.Sequential(*list(models.resnet18(pretrained=True).children())[:5])
        self.encoder2 = nn.Sequential(*list(models.resnet18(pretrained=True).children())[5:7])

        # Decoder Part 1
        self.up1 = nn.ConvTranspose2d(256, 128, kernel_size=5, stride=3, dilation=5, padding=1)
        self.conv1 = nn.Conv2d(192,128,kernel_size=2,stride=1,dilation=2)
        self.bn1 = nn.BatchNorm2d(128)

        # Decoder Part 2
        self.up2 = nn.ConvTranspose2d(128, num_classes, kernel_size=(4,4), stride=(4,4), dilation=(3,3), padding=(2,2))
        # self.conv2 = nn.Conv2d(64,num_classes, kernel_size=2,stride=1,dilation=2)
        self.bn2 = nn.BatchNorm2d(num_classes)

        # Decoder Part 3
        # self.final_up = nn.ConvTranspose2d(num_classes, num_classes, kernel_size=(4,4), stride=(1,1), dilation=(4,4), padding=(2,2))

        self.final_up = nn.Upsample(size=(256,256), mode='bilinear', align_corners=True)

        # self.sf = nn.Softmax(dim=1)

    def forward(self, inp, gts=None):

        # Assuming using GPU on colab

        ## Encoder
        x = self.encoder1(inp) # batch x 64 x 64 x 64
        skip = x
        x = self.encoder2(x) # batch x 256 x 16 x 16
        # print(x.size())

        ## Decoder Step 1
        x = self.up1(x) # batch x 256 x ?
        x = torch.cat((x, skip), dim=1) # Skip Connection, batch x 192 x ?
        x = self.relu(self.conv1(x))
        x = self.bn1(x)                 # batch x 128 x 62 x 62

        ## Decoder Step 2
        x = self.up2(x) # Transpose conv, 64 channels now, batch x 64 x ?
        # print(x.size())
        # x = self.relu(self.conv2(x))
        x = self.bn2(x)                 # batch x 21 x 248 x 248
        # print(x.size())

        ## Final Decoder Step
        lfinal = self.final_up(x) # batch x 21 x ?

        test_val = torch.argmax(lfinal, dim=1)[0].cpu().numpy()
        print("max: {}".format(test_val.max()))

        return lfinal

# %%
#@title
import torchvision.models as models

class MyNet_TooBeeg(nn.Module):
    def __init__(self, num_classes, img_size, criterion=None):
        super(MyNet, self).__init__()
        # Implement me
        self.relu = nn.ReLU()

        # Get initial few layers + 6 res blocks in packs of 2
        self.encoder1 = nn.Sequential(*list(models.resnet18(pretrained=True).children())[:5])
        self.encoder2 = nn.Sequential(*list(models.resnet18(pretrained=True).children())[5:7])

        # Decoder Part 1
        self.up1 = nn.ConvTranspose2d(256, 256, kernel_size=5, stride=3, dilation=5, padding=1)
        self.conv1 = nn.Conv2d(320,256,kernel_size=2,stride=1,dilation=2)
        self.conv2 = nn.Conv2d(256,128,kernel_size=2,stride=1,dilation=2)
        self.bn1 = nn.BatchNorm2d(128)

        # Decoder Part 2
        self.up2 = nn.ConvTranspose2d(128, 64, kernel_size=(6,6), stride=(2,2), dilation=(3,3), padding=(2,2))
        self.conv3 = nn.Conv2d(64,32, kernel_size=2,stride=1,dilation=2)
        self.conv4 = nn.Conv2d(32,num_classes, kernel_size=2,stride=1,dilation=2)
        self.bn2 = nn.BatchNorm2d(num_classes)

        # Decoder Part 3
        self.final_up = nn.ConvTranspose2d(num_classes, num_classes, kernel_size=(4,4), stride=(2,2), dilation=(3,3), padding=(2,2))

        # self.final_up = nn.Upsample(size=img_size, mode='bilinear', align_corners=True)

        # self.sf = nn.Softmax(dim=1)

    def forward(self, inp, gts=None):

        # Assuming using GPU on colab

        ## Encoder
        x = self.encoder1(inp) # batch x 64 x 64 x 64
        skip = x
        x = self.encoder2(x) # batch x 256 x 16 x 16
        print(x.size())

        ## Decoder Step 1
        x = self.up1(x) # batch x 256 x 64 x 64
        x = torch.cat((x, skip), dim=1) # Skip Connection, batch x 320 x 64 x 64
        x = self.relu(self.conv1(x))
        x = self.relu(self.conv2(x))
        x = self.bn1(x)                 # batch x 128 x 60 x 60
        print(x.size())

        ## Decoder Step 2
        x = self.up2(x) # Transpose conv, 64 channels now, batch x 64 x 130 x 130
        x = self.relu(self.conv3(x))
        x = self.relu(self.conv4(x))
        x = self.bn2(x)                 # batch x 21 x 128 x 128
        print(x.size())

        ## Final Decoder Step
        lfinal = self.final_up(x) # batch x 21 x 256 x 256

        # lfinal = self.sf(x) # softmax, batch x 21 x 375 x 500

        test_val = torch.argmax(lfinal, dim=1)[0].cpu().numpy()
        print("max: {}".format(test_val.max()))

        return lfinal

# %%
#@older net
import torchvision.models as models

class MyNet(nn.Module):
    def __init__(self, num_classes, img_size, criterion=None):
        super(MyNet, self).__init__()
        # Implement me

        # Get initial few layers + 6 res blocks in packs of 2
        self.encoder1 = nn.Sequential(*list(models.resnet18(pretrained=True).children())[:5])
        self.encoder2 = nn.Sequential(*list(models.resnet18(pretrained=True).children())[5:7])

        self.up1 = nn.ConvTranspose2d(256, 256, kernel_size=(7,8), stride=(3,3), dilation=(5,5), padding=(3,2))
        self.relu = nn.ReLU()

        self.conv1 = nn.Conv2d(320,256,kernel_size=3,stride=2,dilation=2)
        self.conv2 = nn.Conv2d(256,128,kernel_size=3,stride=2,dilation=2)
        self.up2 = nn.ConvTranspose2d(128, 64, kernel_size=7,stride=3,dilation=3,padding=2)
        self.bn1 = nn.BatchNorm2d(128)
        self.bn2 = nn.BatchNorm2d(64)

        self.conv3 = nn.Conv2d(64,num_classes, kernel_size=4,stride=2,dilation=2)
        self.final_up = nn.Upsample(size=img_size, mode='bilinear', align_corners=True)

    def forward(self, inp, gts=None):

        # Assuming using GPU on colab

        ## Encoder
        x = self.encoder1(inp) # batch x 64 x 94 x 125
        skip = x
        x = self.encoder2(x) # batch x 256 x 24 x 32

        ## Decoder Step 1
        x = self.up1(x) # batch x 256 x 94 x 125
        x = torch.cat((x, skip), dim=1) # Skip Connection; batch x 320 x 94 x 125
        x = self.relu(self.conv1(x)) # batch x 256 x 91 x 122
        x = self.relu(self.conv2(x)) # batch x 128 x 88 x 119
        x = self.bn1(x)

        ## Decoder Step 2
        x = self.up2(x) # Transpose conv, 64 channels now
        x = self.bn2(x)
        x = self.relu(self.conv3(x)) # 21 channels

        ## Final Decoder Step
        lfinal = self.final_up(x) # batch x 21 x 375 x 500

        test_val = torch.argmax(lfinal, dim=1)[0].cpu().numpy()
        print("max: {}".format(test_val.max()))

        return lfinal

# %%
# list(models.resnet18(pretrained=True).children())[:5]

# %% [markdown]
# #### (b) Create UNTRAINED_NET and run on a sample image

# %%
print(torch.cuda.get_device_name())

untrained_net = MyNet(21, (375,500)).eval()
sample_img, sample_target = sanity_joint_transform(*sample1)
# sample_img, sample_target = JointCenterCrop(256)(sample_img, sample_target)
# print(sample_img[None].size())
untrained_output = untrained_net.forward(sample_img[None])

# Convert to 375 x 500 image of int classes
sample_output = torch.argmax(untrained_output, dim=1).numpy()

fig = plt.figure(figsize=(14,10))
ax = fig.add_subplot(1,3,1)
plt.title('image sample')
ax.imshow(sample1[0])
ax = fig.add_subplot(1,3,2)
plt.title('ground truth (target)')
ax.imshow(sample1[1])
ax = fig.add_subplot(1,3,3)
plt.title('UNTRAINED_NET output/prediction')
print(untrained_output.size())
ax.imshow(colorize_mask(sample_output[0]))
# ax.imshow(colorize_mask(untrained_output.numpy()[0]))
# Out:
# Tesla P100-PCIE-16GB
# max: 20
# torch.Size([1, 21, 375, 500])

# %% [markdown]
# # Problem 3
#
# #### (a) Implement the loss function (Cross Entropy Loss). Do not use already implemented versions of this loss function.
#
# Feel free to use functions like `F.log_softmax` and `F.nll_loss` (if you want to, or you can just implement the math).

# %%
# Student Answer:

# class MyCrossEntropyLoss(...):

# %% [markdown]
# #### (b) Compare against the existing CrossEntropyLoss function on your sample output from your neural network.

# %%
criterion = nn.CrossEntropyLoss(ignore_index=255)
print(criterion)
print(sample_target[None].size())
print(untrained_output[0].size())
print(sample_target.size())
print(criterion(untrained_output, sample_target[None]))

# my_criterion = MyCrossEntropyLoss(ignore_index=255)

# print(my_criterion(untrained_output, sample_target[None]))
# Out:
# CrossEntropyLoss()
# torch.Size([1, 375, 500])
# torch.Size([21, 375, 500])
# torch.Size([375, 500])
# tensor(3.0413, grad_fn=<NllLoss2DBackward>)

# %% [markdown]
# # Problem 4
#
# #### (a) Use standard function `eval_semantic_segmentation` (already imported from chainerCV) to compute "mean intersection over union" for the output of UNTRAINED_NET on sample1 (`untrained_output`) using the target for sample1. Read documentations for function  `eval_semantic_segmentation` to properly set its input parameters.

# %%
# Write code to propely compute 'pred' and 'gts' as arguments for function 'eval_semantic_segemntation'

np_target = sample_target.numpy().astype(np.int32)
np_target[np_target==255] = -1
initial_gts = np.array([np_target])

initial_pred = sample_output
print(initial_pred.shape)
initial_conf = eval_semantic_segmentation(initial_pred, initial_gts)

print("mIoU for the sample image / ground truth pair: {}".format(initial_conf['miou']))
# Out:
# (1, 375, 500)
# mIoU for the sample image / ground truth pair: 0.008049473963645509
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:91: RuntimeWarning: invalid value encountered in true_divide
#   iou = np.diag(confusion) / iou_denominator
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:168: RuntimeWarning: invalid value encountered in true_divide
#   class_accuracy = np.diag(confusion) / np.sum(confusion, axis=1)

# %% [markdown]
# #### (b) Write the validation loop.

# %%
def validate(val_data_loader, net):
    iou_arr = []
    val_loss = []
    
    with torch.no_grad():
        for i, data in enumerate(val_data_loader):
            print("Tick: {}".format(i))
            inputs, masks = data

            print("shape: {}".format(masks.shape))

            if USE_GPU:
                net = net.cuda()
                masks = masks.cuda()
                inputs = inputs.cuda()

            outputs = net(inputs)

            np_target = masks[0].cpu().numpy().astype(np.int32)
            np_target[np_target == 255] = -1

            gts = np.array([np_target])
            preds = torch.argmax(outputs, dim=1).cpu().numpy()

            val_loss.append(criterion(outputs, masks))
            # Write menearest

            # Hint: make sure the range of values of the ground truth is what you expectg

            conf = eval_semantic_segmentation(preds, gts)

            iou_arr.append(conf['miou'])
    
    print(iou_arr)
    return val_loss, (sum(iou_arr) / len(iou_arr))

# %% [markdown]
# #### (c) Run the validation loop for UNTRAINED_NET against the sanity validation dataset.

# %%
# %%time
print("mIoU over the sanity dataset:{}".format(validate(sanity_loader, untrained_net)[1]))
# Out:
# Tick: 0
# shape: torch.Size([1, 375, 500])
# max: 20
# [0.008049473963645509]
# mIoU over the sanity dataset:0.008049473963645509
# CPU times: user 36.3 ms, sys: 193 ms, total: 229 ms
# Wall time: 376 ms
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:91: RuntimeWarning: invalid value encountered in true_divide
#   iou = np.diag(confusion) / iou_denominator
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:168: RuntimeWarning: invalid value encountered in true_divide
#   class_accuracy = np.diag(confusion) / np.sum(confusion, axis=1)

# %% [markdown]
# # Problem 5
#
# #### (a) Define an optimizer to train the given loss function.
#
# Feel free to choose your optimizer of choice from https://pytorch.org/docs/stable/optim.html.

# %%
def get_optimizer(net):
    optimizer = optim.Adam(net.parameters(), lr=1e-3)
    return optimizer

# %% [markdown]
# #### (b) Write the training loop to train the network.

# %%
import time

def train(train_data_loader, net, optimizer, loss_graph):
    for i, data in enumerate(train_data_loader):
        inputs, masks = data
    
        if USE_GPU:
            net = net.cuda()
            inputs = inputs.cuda()
            masks = masks.cuda()
        
        # Write me
        outputs = net(inputs)
        loss = net.criterion(outputs, masks)
        print("Training: On Tick: {} loss {}".format(i, loss))
        loss_graph.append(loss.item())

        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

        # loss_graph.append() Populate this list to graph the loss
    
    return (sum(loss_graph) / len(loss_graph))

# %% [markdown]
# #### (c) Create OVERFIT_NET and train it on the single image dataset.
# ##### Single image training is helpful for debugging and hyper-parameter tuning (e.g. learning rate, etc.) as it is fast even on a single CPU. In particular, you can work with a single image until your loss function is consistently decreasing during training loop and the network starts producing a reasonable output for this training image. Training on a single image also teaches about overfitting, particualrly when comparing it with more thorough forms of network training.

# %%
# %%time
# %matplotlib notebook
import time

# The whole training on a single image (20-40 epochs) should take only a minute or two on a CPU (and a few seconds on GPU). 
# Below we create a (deep) copy of untrained_net and train it on a single training image (leading to gross overfitting).
# Later, we will create a separate (deep) copy of untrained_net to be trained on full training dataset.
# NOTE: Normally, one can create a new net via declaration new_net = MyNet(21). But, randomization of weights when new nets 
# are declared that way creates *different* untrained nets. This notebook compares different versions of network training. 
# For this comparison to be direct and fair, it is better to train (deep) copies of the exact same untrained_net. 
overfit_net = copy.deepcopy(untrained_net)

# set loss function for the net
overfit_net.criterion = nn.CrossEntropyLoss(ignore_index=255)

# You can change the number of EPOCHS
EPOCH = 100

# switch to train mode (original untrained_net was set to eval mode)
overfit_net.train()

optimizer = get_optimizer(overfit_net)

print("Starting Training...")

loss_graph = []

fig = plt.figure(figsize=(12,6))
plt.subplots_adjust(bottom=0.2,right=0.85,top=0.95)
ax = fig.add_subplot(1,1,1)

for e in range(EPOCH):
    new_loss_graph = []
    loss = train(sanity_loader, overfit_net, optimizer, new_loss_graph)
    loss_graph += new_loss_graph
    ax.clear()
    ax.set_xlabel('iterations')
    ax.set_ylabel('loss value')
    ax.set_title('Training loss curve for OVERFIT_NET')
    ax.plot(loss_graph, label='training loss')
    ax.legend(loc='upper right')
    fig.canvas.draw()
    print("Epoch: {} Loss: {}".format(e, loss))
print("Final Loss: {}".format(loss))
# %matplotlib inline
plt.show()
# Out:
# Starting Training...
# <div id='c79259ce-b2db-4a00-b8ad-e9452334f581'></div>
# max: 20
# Training: On Tick: 0 loss 3.1255505084991455
# Epoch: 0 Loss: 3.1255505084991455
# max: 20
# Training: On Tick: 0 loss 2.237344264984131
# Epoch: 1 Loss: 2.237344264984131
# max: 20
# Training: On Tick: 0 loss 1.5843485593795776
# Epoch: 2 Loss: 1.5843485593795776
# max: 20
# Training: On Tick: 0 loss 1.0719529390335083
# Epoch: 3 Loss: 1.0719529390335083
# max: 20
# Training: On Tick: 0 loss 0.7100151181221008
# Epoch: 4 Loss: 0.7100151181221008
# max: 15
# Training: On Tick: 0 loss 0.459166020154953
# Epoch: 5 Loss: 0.459166020154953
# max: 15
# Training: On Tick: 0 loss 0.30693313479423523
# Epoch: 6 Loss: 0.30693313479423523
# max: 15
# Training: On Tick: 0 loss 0.21972154080867767
# Epoch: 7 Loss: 0.21972154080867767
# max: 15
# Training: On Tick: 0 loss 0.15131515264511108
# Epoch: 8 Loss: 0.15131515264511108
# max: 15
# Training: On Tick: 0 loss 0.10976369678974152
# Epoch: 9 Loss: 0.10976369678974152
# max: 15
# Training: On Tick: 0 loss 0.07942379266023636
# Epoch: 10 Loss: 0.07942379266023636
# max: 15
# Training: On Tick: 0 loss 0.05962154269218445
# Epoch: 11 Loss: 0.05962154269218445
# max: 15
# Training: On Tick: 0 loss 0.04974459856748581
# Epoch: 12 Loss: 0.04974459856748581
# max: 15
# Training: On Tick: 0 loss 0.0423138365149498
# Epoch: 13 Loss: 0.0423138365149498
# max: 15
# Training: On Tick: 0 loss 0.03600103035569191
# Epoch: 14 Loss: 0.03600103035569191
# max: 15
# Training: On Tick: 0 loss 0.031871598213911057
# Epoch: 15 Loss: 0.031871598213911057
# max: 15
# Training: On Tick: 0 loss 0.027933016419410706
# Epoch: 16 Loss: 0.027933016419410706
# max: 15
# Training: On Tick: 0 loss 0.024897681549191475
# Epoch: 17 Loss: 0.024897681549191475
# max: 15
# Training: On Tick: 0 loss 0.02305617742240429
# Epoch: 18 Loss: 0.02305617742240429
# max: 15
# Training: On Tick: 0 loss 0.02147040143609047
# Epoch: 19 Loss: 0.02147040143609047
# max: 15
# Training: On Tick: 0 loss 0.01913457363843918
# Epoch: 20 Loss: 0.01913457363843918
# max: 15
# Training: On Tick: 0 loss 0.017491931095719337
# Epoch: 21 Loss: 0.017491931095719337
# max: 15
# Training: On Tick: 0 loss 0.016258031129837036
# Epoch: 22 Loss: 0.016258031129837036
# max: 15
# Training: On Tick: 0 loss 0.015346923843026161
# Epoch: 23 Loss: 0.015346923843026161
# max: 15
# Training: On Tick: 0 loss 0.014349297620356083
# Epoch: 24 Loss: 0.014349297620356083
# max: 15
# Training: On Tick: 0 loss 0.013387000188231468
# Epoch: 25 Loss: 0.013387000188231468
# max: 15
# Training: On Tick: 0 loss 0.012536395341157913
# Epoch: 26 Loss: 0.012536395341157913
# max: 15
# Training: On Tick: 0 loss 0.011752229183912277
# Epoch: 27 Loss: 0.011752229183912277
# max: 15
# Training: On Tick: 0 loss 0.011170923709869385
# Epoch: 28 Loss: 0.011170923709869385
# max: 15
# Training: On Tick: 0 loss 0.01060947123914957
# Epoch: 29 Loss: 0.01060947123914957
# max: 15
# Training: On Tick: 0 loss 0.010150844231247902
# Epoch: 30 Loss: 0.010150844231247902
# max: 15
# Training: On Tick: 0 loss 0.009705585427582264
# Epoch: 31 Loss: 0.009705585427582264
# max: 15
# Training: On Tick: 0 loss 0.009215909987688065
# Epoch: 32 Loss: 0.009215909987688065
# max: 15
# Training: On Tick: 0 loss 0.008778665214776993
# Epoch: 33 Loss: 0.008778665214776993
# max: 15
# Training: On Tick: 0 loss 0.00833739060908556
# Epoch: 34 Loss: 0.00833739060908556
# max: 15
# Training: On Tick: 0 loss 0.007996990345418453
# Epoch: 35 Loss: 0.007996990345418453
# max: 15
# Training: On Tick: 0 loss 0.007733664009720087
# Epoch: 36 Loss: 0.007733664009720087
# max: 15
# Training: On Tick: 0 loss 0.007538689766079187
# Epoch: 37 Loss: 0.007538689766079187
# max: 15
# Training: On Tick: 0 loss 0.0071334815584123135
# Epoch: 38 Loss: 0.0071334815584123135
# max: 15
# Training: On Tick: 0 loss 0.006881816312670708
# Epoch: 39 Loss: 0.006881816312670708
# max: 15
# Training: On Tick: 0 loss 0.0065743750892579556
# Epoch: 40 Loss: 0.0065743750892579556
# max: 15
# Training: On Tick: 0 loss 0.006353462114930153
# Epoch: 41 Loss: 0.006353462114930153
# max: 15
# Training: On Tick: 0 loss 0.006085619330406189
# Epoch: 42 Loss: 0.006085619330406189
# max: 15
# Training: On Tick: 0 loss 0.005862044636160135
# Epoch: 43 Loss: 0.005862044636160135
# max: 15
# Training: On Tick: 0 loss 0.005629376042634249
# Epoch: 44 Loss: 0.005629376042634249
# max: 15
# Training: On Tick: 0 loss 0.005432994104921818
# Epoch: 45 Loss: 0.005432994104921818
# max: 15
# Training: On Tick: 0 loss 0.005248371046036482
# Epoch: 46 Loss: 0.005248371046036482
# max: 15
# Training: On Tick: 0 loss 0.0050820657052099705
# Epoch: 47 Loss: 0.0050820657052099705
# max: 15
# Training: On Tick: 0 loss 0.004929729737341404
# Epoch: 48 Loss: 0.004929729737341404
# max: 15
# Training: On Tick: 0 loss 0.004769370891153812
# Epoch: 49 Loss: 0.004769370891153812
# max: 15
# Training: On Tick: 0 loss 0.004608373623341322
# Epoch: 50 Loss: 0.004608373623341322
# max: 15
# Training: On Tick: 0 loss 0.00446399487555027
# Epoch: 51 Loss: 0.00446399487555027
# max: 15
# Training: On Tick: 0 loss 0.004330228082835674
# Epoch: 52 Loss: 0.004330228082835674
# max: 15
# Training: On Tick: 0 loss 0.0041931066662073135
# Epoch: 53 Loss: 0.0041931066662073135
# max: 15
# Training: On Tick: 0 loss 0.0040640453808009624
# Epoch: 54 Loss: 0.0040640453808009624
# max: 15
# Training: On Tick: 0 loss 0.003936332184821367
# Epoch: 55 Loss: 0.003936332184821367
# max: 15
# Training: On Tick: 0 loss 0.0038108029402792454
# Epoch: 56 Loss: 0.0038108029402792454
# max: 15
# Training: On Tick: 0 loss 0.0036977208219468594
# Epoch: 57 Loss: 0.0036977208219468594
# max: 15
# Training: On Tick: 0 loss 0.0035874214954674244
# Epoch: 58 Loss: 0.0035874214954674244
# max: 15
# Training: On Tick: 0 loss 0.003478243248537183
# Epoch: 59 Loss: 0.003478243248537183
# max: 15
# Training: On Tick: 0 loss 0.003381214337423444
# Epoch: 60 Loss: 0.003381214337423444
# max: 15
# Training: On Tick: 0 loss 0.0032869167625904083
# Epoch: 61 Loss: 0.0032869167625904083
# max: 15
# Training: On Tick: 0 loss 0.003201435785740614
# Epoch: 62 Loss: 0.003201435785740614
# max: 15
# Training: On Tick: 0 loss 0.003115697531029582
# Epoch: 63 Loss: 0.003115697531029582
# max: 15
# Training: On Tick: 0 loss 0.00303057418204844
# Epoch: 64 Loss: 0.00303057418204844
# max: 15
# Training: On Tick: 0 loss 0.0029498038347810507
# Epoch: 65 Loss: 0.0029498038347810507
# max: 15
# Training: On Tick: 0 loss 0.0028726300224661827
# Epoch: 66 Loss: 0.0028726300224661827
# max: 15
# Training: On Tick: 0 loss 0.00280181597918272
# Epoch: 67 Loss: 0.00280181597918272
# max: 15
# Training: On Tick: 0 loss 0.0027367989532649517
# Epoch: 68 Loss: 0.0027367989532649517
# max: 15
# Training: On Tick: 0 loss 0.002670343965291977
# Epoch: 69 Loss: 0.002670343965291977
# max: 15
# Training: On Tick: 0 loss 0.0026106343138962984
# Epoch: 70 Loss: 0.0026106343138962984
# max: 15
# Training: On Tick: 0 loss 0.0025520194321870804
# Epoch: 71 Loss: 0.0025520194321870804
# max: 15
# Training: On Tick: 0 loss 0.0024961151648312807
# Epoch: 72 Loss: 0.0024961151648312807
# max: 15
# Training: On Tick: 0 loss 0.0024427196476608515
# Epoch: 73 Loss: 0.0024427196476608515
# max: 15
# Training: On Tick: 0 loss 0.0023905436974018812
# Epoch: 74 Loss: 0.0023905436974018812
# max: 15
# Training: On Tick: 0 loss 0.002342530759051442
# Epoch: 75 Loss: 0.002342530759051442
# max: 15
# Training: On Tick: 0 loss 0.002296088496223092
# Epoch: 76 Loss: 0.002296088496223092
# max: 15
# Training: On Tick: 0 loss 0.0022512301802635193
# Epoch: 77 Loss: 0.0022512301802635193
# max: 15
# Training: On Tick: 0 loss 0.002208142541348934
# Epoch: 78 Loss: 0.002208142541348934
# max: 15
# Training: On Tick: 0 loss 0.002165967132896185
# Epoch: 79 Loss: 0.002165967132896185
# max: 15
# Training: On Tick: 0 loss 0.0021267228294163942
# Epoch: 80 Loss: 0.0021267228294163942
# max: 15
# Training: On Tick: 0 loss 0.0020889390725642443
# Epoch: 81 Loss: 0.0020889390725642443
# max: 15
# Training: On Tick: 0 loss 0.002051957882940769
# Epoch: 82 Loss: 0.002051957882940769
# max: 15
# Training: On Tick: 0 loss 0.0020170146599411964
# Epoch: 83 Loss: 0.0020170146599411964
# max: 15
# Training: On Tick: 0 loss 0.001983380177989602
# Epoch: 84 Loss: 0.001983380177989602
# max: 15
# Training: On Tick: 0 loss 0.0019509391859173775
# Epoch: 85 Loss: 0.0019509391859173775
# max: 15
# Training: On Tick: 0 loss 0.0019197436049580574
# Epoch: 86 Loss: 0.0019197436049580574
# max: 15
# Training: On Tick: 0 loss 0.001889514271169901
# Epoch: 87 Loss: 0.001889514271169901
# max: 15
# Training: On Tick: 0 loss 0.001860318472608924
# Epoch: 88 Loss: 0.001860318472608924
# max: 15
# Training: On Tick: 0 loss 0.0018322068499401212
# Epoch: 89 Loss: 0.0018322068499401212
# max: 15
# Training: On Tick: 0 loss 0.0018052986124530435
# Epoch: 90 Loss: 0.0018052986124530435
# max: 15
# Training: On Tick: 0 loss 0.0017798516200855374
# Epoch: 91 Loss: 0.0017798516200855374
# max: 15
# Training: On Tick: 0 loss 0.001754831406287849
# Epoch: 92 Loss: 0.001754831406287849
# max: 15
# Training: On Tick: 0 loss 0.0017309444956481457
# Epoch: 93 Loss: 0.0017309444956481457
# max: 15
# Training: On Tick: 0 loss 0.0017078728415071964
# Epoch: 94 Loss: 0.0017078728415071964
# max: 15
# Training: On Tick: 0 loss 0.0016856411239132285
# Epoch: 95 Loss: 0.0016856411239132285
# max: 15
# Training: On Tick: 0 loss 0.0016637592343613505
# Epoch: 96 Loss: 0.0016637592343613505
# max: 15
# Training: On Tick: 0 loss 0.0016424647765234113
# Epoch: 97 Loss: 0.0016424647765234113
# max: 15
# Training: On Tick: 0 loss 0.0016219973331317306
# Epoch: 98 Loss: 0.0016219973331317306
# max: 15
# Training: On Tick: 0 loss 0.0016022343188524246
# Epoch: 99 Loss: 0.0016022343188524246
# Final Loss: 0.0016022343188524246
# CPU times: user 9.95 s, sys: 16.4 s, total: 26.4 s
# Wall time: 40.9 s

# %% [markdown]
# #### Qualitative and quantitative evaluation of predictions (untrained vs overfit nets) - fully implemented.

# %%
# switch back to evaluation mode
overfit_net.eval()

sample_img, sample_target = sanity_joint_transform(*sample1)
if USE_GPU:
    sample_img = sample_img.cuda()
sample_output_O = overfit_net.forward(sample_img[None])
sample_output_U = untrained_net.forward(sample_img[None])

# computing mIOU (quantitative measure of accuracy for network predictions)
if USE_GPU:
    pred_O = torch.argmax(sample_output_O, dim=1).cpu().numpy()[0]
    pred_U = torch.argmax(sample_output_U, dim=1).cpu().numpy()[0]
else:
    pred_O = torch.argmax(sample_output_O, dim=1).numpy()[0]
    pred_U = torch.argmax(sample_output_U, dim=1).numpy()[0]

# gts = torch.from_numpy(np.array(sample1[1].convert('P'), dtype=np.int32)).long().numpy()
gts = sample_target.cpu().numpy()
gts[gts == 255] = -1
print(pred_O[None].shape)
conf_O = eval_semantic_segmentation(pred_O[None], gts[None])
conf_U = eval_semantic_segmentation(pred_U[None], gts[None])


fig = plt.figure(figsize=(14,10))
ax1 = fig.add_subplot(2,2,1)
plt.title('image sample')
ax1.imshow(sample1[0])
ax2 = fig.add_subplot(2,2,2)
plt.title('ground truth (target)')
ax2.imshow(sample1[1])
ax3 = fig.add_subplot(2,2,3)
plt.title('UNTRAINED_NET prediction')
ax3.text(10, 25, 'mIoU = {:_>8.6f}'.format(conf_U['miou']), fontsize=20, color='white')
ax3.imshow(colorize_mask(torch.argmax(sample_output_U, dim=1).cpu().numpy()[0]))
ax4 = fig.add_subplot(2,2,4)
plt.title('OVERFIT_NET prediction (for its training image)')
ax4.text(10, 25, 'mIoU = {:_>8.6f}'.format(conf_O['miou']), fontsize=20, color='white')
ax4.imshow(colorize_mask(torch.argmax(sample_output_O, dim=1).cpu().numpy()[0]))
# Out:
# max: 15
# max: 20
# (1, 375, 500)
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:91: RuntimeWarning: invalid value encountered in true_divide
#   iou = np.diag(confusion) / iou_denominator
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:168: RuntimeWarning: invalid value encountered in true_divide
#   class_accuracy = np.diag(confusion) / np.sum(confusion, axis=1)

# %%
# img, target = JointResize((375,500))(*sample2)
sample_img, sample_target = sanity_joint_transform(*sample2)
if USE_GPU:
    sample_img = sample_img.cuda()
sample_output_O = overfit_net.forward(sample_img[None])
sample_output_U = untrained_net.forward(sample_img[None])

# computing mIOU (quantitative measure of accuracy for network predictions)
if USE_GPU:
    pred_O = torch.argmax(sample_output_O, dim=1).cpu().numpy()[0]
    pred_U = torch.argmax(sample_output_U, dim=1).cpu().numpy()[0]
else:
    pred_O = torch.argmax(sample_output_O, dim=1).numpy()[0]
    pred_U = torch.argmax(sample_output_U, dim=1).numpy()[0]

# gts = target.numpy()#torch.from_numpy(np.array(target.convert('P'), dtype=np.int32)).long().numpy()
gts = sample_target.cpu().numpy()
gts[gts == 255] = -1
conf_O = eval_semantic_segmentation(pred_O[None], gts[None])
conf_U = eval_semantic_segmentation(pred_U[None], gts[None])

fig = plt.figure(figsize=(14,10))
ax1 = fig.add_subplot(2,2,1)
plt.title('image sample')
ax1.imshow(sample2[0])
ax2 = fig.add_subplot(2,2,2)
plt.title('ground truth (target)')
ax2.imshow(sample2[1])
ax3 = fig.add_subplot(2,2,3)
plt.title('UNTRAINED_NET prediction')
ax3.text(10, 25, 'mIoU = {:_>8.6f}'.format(conf_U['miou']), fontsize=20, color='white')
ax3.imshow(colorize_mask(torch.argmax(sample_output_U, dim=1).cpu().numpy()[0]))
ax4 = fig.add_subplot(2,2,4)
plt.title('OVERFIT_NET prediction (for image it has not seen)')
ax4.text(10, 25, 'mIoU = {:_>8.6f}'.format(conf_O['miou']), fontsize=20, color='white')
ax4.imshow(colorize_mask(torch.argmax(sample_output_O, dim=1).cpu().numpy()[0]))
# Out:
# max: 20
# max: 20
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:168: RuntimeWarning: invalid value encountered in true_divide
#   class_accuracy = np.diag(confusion) / np.sum(confusion, axis=1)
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:91: RuntimeWarning: invalid value encountered in true_divide
#   iou = np.diag(confusion) / iou_denominator

# %% [markdown]
# #### Run the validation loop for OVERFIT_NET against the sanity dataset (an image it was trained on) - fully implemented

# %%
# %%time
print("mIoU for OVERFIT_NET over its training image:{}".format(validate(sanity_loader, overfit_net)[1]))
# Out:
# Tick: 0
# shape: torch.Size([1, 375, 500])
# max: 15
# [0.8920658430787738]
# mIoU for OVERFIT_NET over its training image:0.8920658430787738
# CPU times: user 27.4 ms, sys: 191 ms, total: 219 ms
# Wall time: 368 ms
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:91: RuntimeWarning: invalid value encountered in true_divide
#   iou = np.diag(confusion) / iou_denominator
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:168: RuntimeWarning: invalid value encountered in true_divide
#   class_accuracy = np.diag(confusion) / np.sum(confusion, axis=1)

# %% [markdown]
# ### WARNING: For the remaining part of the assignment (below) it is advisable to switch to GPU mode as running each validation and training loop on the whole training set takes over an hour on CPU (there are several such loops below). Note that GPU mode is helpful only if you have a sufficiently good NVIDIA gpu (not older than 2-3 years) and cuda installed on your computer. If you do not have a sufficiently good graphics card available, you can still finish the remaining part in CPU mode (takes a few hours), as the cells below are mostly implemented and test your code written and debugged in the earlier parts above. You can also switch to Google Colaboratory to run the remaining parts below.
#
# ### You can use validation-data experiments below to tune your hyper-parameters. Normally, validation data is used exactly for this purpose. For actual competitions, testing data is not public and you can not tune hyper-parameters on in.

# %% [markdown]
# #### (d) Evaluate UNTRAINED_NET and OVERFIT_NET on validation dataset.
# ##### Run the validation loop for UNTRAINED_NET against the validation dataset:

# %%
# %%time
# This will be slow on CPU (around 1 hour or more). On GPU it should take only a few minutes (depending on your GPU).
# Takes 15min on Colab, 1500 images in validation set
# print("mIoU for UNTRAINED_NET over the entire dataset:{}".format(validate(val_loader, untrained_net)[1]))
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.44 µs

# %% [markdown]
# ##### Run the validation loop for OVERFIT_NET against the validation dataset (it has not seen):

# %%
# %%time
# This will be slow on CPU (around 1 hour or more). On GPU it should take only a few minutes (depending on your GPU).
# print("mIoU for OVERFIT_NET over the validation dataset:{}".format(validate(val_loader, overfit_net)[1]))
# Out:
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 6.2 µs

# %% [markdown]
# #### (e) Explain in a few sentences the quantitative results observed in (c) and (d):

# %% [markdown]
# Student answer:

# %% [markdown]
# #### (f) Create TRAINED_NET and train it on the full training dataset:

# %%
# %%time
# %matplotlib notebook

# torch.cuda.empty_cache()

# This training will be very slow on a CPU (>1hour per epoch). Ideally, this should be run in GPU mode (USE_GPU=True) 
# taking only a few minutes per epoch (depending on your GPU and batch size). Thus, before proceeding with this excercise,
# it is highly advisable that you first finish debugging your net code. In particular, make sure that OVERFIT_NET behaves 
# reasonably, e.g. its loss monotonically decreases during training and its output is OK (for the image it was trained on). 
# Below we create another (deep) copy of untrained_net. Unlike OVERFIT_NET it will be trained on a full training dataset.
trained_net = copy.deepcopy(untrained_net)
# overfit_net = copy.deepcopy(untrained_net)

# set loss function for the net
trained_net.criterion = nn.CrossEntropyLoss(ignore_index=255)

# You can change the number of EPOCHS below. Since each epoch for TRAINED_NET iterates over all training dataset images,
# the number of required epochs could be smaller compared to OFERFIT_NET where each epoch iterates over one-image-dataset)
EPOCH = 30

# switch to train mode (original untrained_net was set to eval mode)
trained_net.train()

optimizer = get_optimizer(trained_net)
# optimizer = optim.SGD(trained_net.parameters(), lr=0.002, momentum=0.9)

print("Starting Training...")

loss_graph = []

# fig = plt.figure(figsize=(12,6))
# plt.subplots_adjust(bottom=0.2,right=0.85,top=0.95)
# ax = fig.add_subplot(1,1,1)

for e in range(EPOCH):
    print("Starting Epoch {}".format(e))
    new_loss_graph = []
    loss = train(train_loader, trained_net, optimizer, new_loss_graph)
    loss_graph += new_loss_graph
    # ax.clear()
    # ax.set_xlabel('iterations')
    # ax.set_ylabel('loss value')
    # ax.set_title('Training loss curve for TRAINED_NET')
    # ax.plot(loss_graph, label='training loss')
    # ax.legend(loc='upper right')
    # fig.canvas.draw()
    # plt.show()
    print("Epoch: {} Loss: {}".format(e, loss))
    
# %matplotlib inline
# Out:
# Starting Training...
# Starting Epoch 0
# max: 20
# Training: On Tick: 0 loss 3.1158158779144287
# max: 20
# Training: On Tick: 1 loss 2.785062551498413
# max: 20
# Training: On Tick: 2 loss 2.19210147857666
# max: 20
# Training: On Tick: 3 loss 2.0062015056610107
# max: 18
# Training: On Tick: 4 loss 1.5812275409698486
# max: 18
# Training: On Tick: 5 loss 1.6920326948165894
# max: 19
# Training: On Tick: 6 loss 1.6090527772903442
# max: 15
# Training: On Tick: 7 loss 1.4174072742462158
# max: 15
# Training: On Tick: 8 loss 1.4076223373413086
# max: 19
# Training: On Tick: 9 loss 1.3567227125167847
# max: 15
# Training: On Tick: 10 loss 1.4562236070632935
# max: 0
# Training: On Tick: 11 loss 1.1726374626159668
# max: 15
# Training: On Tick: 12 loss 1.3825024366378784
# max: 0
# Training: On Tick: 13 loss 1.314728856086731
# max: 0
# Training: On Tick: 14 loss 1.1762686967849731
# max: 15
# Training: On Tick: 15 loss 1.1434962749481201
# max: 19
# Training: On Tick: 16 loss 1.4560813903808594
# max: 15
# Training: On Tick: 17 loss 1.3561022281646729
# max: 0
# Training: On Tick: 18 loss 1.3221606016159058
# max: 19
# Training: On Tick: 19 loss 1.449721336364746
# max: 0
# Training: On Tick: 20 loss 1.3112343549728394
# max: 19
# Training: On Tick: 21 loss 1.2156232595443726
# max: 19
# Training: On Tick: 22 loss 1.2858877182006836
# Epoch: 0 Loss: 1.574170216270115
# Starting Epoch 1
# max: 0
# Training: On Tick: 0 loss 1.1995402574539185
# max: 15
# Training: On Tick: 1 loss 1.314684271812439
# max: 0
# Training: On Tick: 2 loss 1.0612965822219849
# max: 19
# Training: On Tick: 3 loss 1.1315895318984985
# max: 15
# Training: On Tick: 4 loss 1.0739116668701172
# max: 15
# Training: On Tick: 5 loss 1.1638011932373047
# max: 0
# Training: On Tick: 6 loss 1.0220619440078735
# max: 19
# Training: On Tick: 7 loss 1.0749365091323853
# max: 15
# Training: On Tick: 8 loss 1.0597158670425415
# max: 12
# Training: On Tick: 9 loss 1.075626015663147
# max: 0
# Training: On Tick: 10 loss 1.0894372463226318
# max: 19
# Training: On Tick: 11 loss 1.0590274333953857
# max: 15
# Training: On Tick: 12 loss 1.3188092708587646
# max: 15
# Training: On Tick: 13 loss 1.1594696044921875
# max: 15
# Training: On Tick: 14 loss 1.1477704048156738
# max: 17
# Training: On Tick: 15 loss 1.1218273639678955
# max: 17
# Training: On Tick: 16 loss 1.1839898824691772
# max: 15
# Training: On Tick: 17 loss 1.1056427955627441
# max: 15
# Training: On Tick: 18 loss 1.215648889541626
# max: 15
# Training: On Tick: 19 loss 1.1182746887207031
# max: 0
# Training: On Tick: 20 loss 1.1634997129440308
# max: 15
# Training: On Tick: 21 loss 1.0106645822525024
# max: 0
# Training: On Tick: 22 loss 1.0165058374404907
# Epoch: 1 Loss: 1.1255535457445227
# Starting Epoch 2
# max: 15
# Training: On Tick: 0 loss 1.0602632761001587
# max: 0
# Training: On Tick: 1 loss 0.988662838935852
# max: 0
# Training: On Tick: 2 loss 1.087734580039978
# max: 15
# Training: On Tick: 3 loss 1.0175470113754272
# max: 15
# Training: On Tick: 4 loss 1.0204640626907349
# max: 15
# Training: On Tick: 5 loss 1.003477692604065
# max: 17
# Training: On Tick: 6 loss 1.031785249710083
# max: 15
# Training: On Tick: 7 loss 1.0663695335388184
# max: 15
# Training: On Tick: 8 loss 1.202256679534912
# max: 19
# Training: On Tick: 9 loss 1.039170265197754
# max: 15
# Training: On Tick: 10 loss 0.9425036907196045
# max: 19
# Training: On Tick: 11 loss 0.9374784827232361
# max: 17
# Training: On Tick: 12 loss 0.9438794255256653
# max: 0
# Training: On Tick: 13 loss 1.0199922323226929
# max: 15
# Training: On Tick: 14 loss 0.9892257452011108
# max: 0
# Training: On Tick: 15 loss 0.8792286515235901
# max: 15
# Training: On Tick: 16 loss 1.0412263870239258
# max: 6
# Training: On Tick: 17 loss 1.0237902402877808
# max: 15
# Training: On Tick: 18 loss 0.9626209139823914
# max: 15
# Training: On Tick: 19 loss 1.1797497272491455
# max: 6
# Training: On Tick: 20 loss 1.1297441720962524
# max: 0
# Training: On Tick: 21 loss 1.0341815948486328
# max: 15
# Training: On Tick: 22 loss 0.9255697727203369
# Epoch: 2 Loss: 1.0229096619979194
# Starting Epoch 3
# max: 15
# Training: On Tick: 0 loss 1.0500619411468506
# max: 15
# Training: On Tick: 1 loss 0.9213405847549438
# max: 12
# Training: On Tick: 2 loss 1.0946543216705322
# max: 14
# Training: On Tick: 3 loss 0.9694843888282776
# max: 0
# Training: On Tick: 4 loss 1.0202633142471313
# max: 15
# Training: On Tick: 5 loss 1.115652322769165
# max: 15
# Training: On Tick: 6 loss 0.8910018801689148
# max: 15
# Training: On Tick: 7 loss 0.8333393335342407
# max: 0
# Training: On Tick: 8 loss 0.9344026446342468
# max: 19
# Training: On Tick: 9 loss 1.0914535522460938
# max: 15
# Training: On Tick: 10 loss 0.9639586806297302
# max: 19
# Training: On Tick: 11 loss 0.956488311290741
# max: 15
# Training: On Tick: 12 loss 1.0530688762664795
# max: 15
# Training: On Tick: 13 loss 0.9934465885162354
# max: 14
# Training: On Tick: 14 loss 0.9344969987869263
# max: 15
# Training: On Tick: 15 loss 0.8979234099388123
# max: 15
# Training: On Tick: 16 loss 0.9095396399497986
# max: 15
# Training: On Tick: 17 loss 0.9215870499610901
# max: 19
# Training: On Tick: 18 loss 1.1513266563415527
# max: 15
# Training: On Tick: 19 loss 1.0418810844421387
# max: 15
# Training: On Tick: 20 loss 0.9625791907310486
# max: 4
# Training: On Tick: 21 loss 0.9814061522483826
# max: 17
# Training: On Tick: 22 loss 0.8788153529167175
# Epoch: 3 Loss: 0.9812248815660891
# Starting Epoch 4
# max: 0
# Training: On Tick: 0 loss 0.7917011380195618
# max: 15
# Training: On Tick: 1 loss 1.0154249668121338
# max: 0
# Training: On Tick: 2 loss 0.7769039869308472
# max: 19
# Training: On Tick: 3 loss 0.9544051885604858
# max: 15
# Training: On Tick: 4 loss 1.0725332498550415
# max: 19
# Training: On Tick: 5 loss 0.8954952359199524
# max: 19
# Training: On Tick: 6 loss 0.8305705189704895
# max: 19
# Training: On Tick: 7 loss 0.9264901280403137
# max: 19
# Training: On Tick: 8 loss 0.9756247997283936
# max: 19
# Training: On Tick: 9 loss 0.959147036075592
# max: 15
# Training: On Tick: 10 loss 1.0018390417099
# max: 17
# Training: On Tick: 11 loss 0.911100447177887
# max: 19
# Training: On Tick: 12 loss 0.9607974290847778
# max: 15
# Training: On Tick: 13 loss 0.8701145052909851
# max: 19
# Training: On Tick: 14 loss 0.9726710915565491
# max: 18
# Training: On Tick: 15 loss 0.8956243395805359
# max: 0
# Training: On Tick: 16 loss 0.9733625650405884
# max: 19
# Training: On Tick: 17 loss 0.8410853147506714
# max: 15
# Training: On Tick: 18 loss 0.8555045127868652
# max: 15
# Training: On Tick: 19 loss 0.8953596949577332
# max: 0
# Training: On Tick: 20 loss 1.0115360021591187
# max: 16
# Training: On Tick: 21 loss 0.9618194699287415
# max: 17
# Training: On Tick: 22 loss 1.0237760543823242
# Epoch: 4 Loss: 0.9292559442312821
# Starting Epoch 5
# max: 0
# Training: On Tick: 0 loss 0.9584616422653198
# max: 0
# Training: On Tick: 1 loss 0.7985296249389648
# max: 15
# Training: On Tick: 2 loss 0.9572790265083313
# max: 15
# Training: On Tick: 3 loss 0.9954902529716492
# max: 8
# Training: On Tick: 4 loss 0.8892550468444824
# max: 19
# Training: On Tick: 5 loss 0.8993731141090393
# max: 15
# Training: On Tick: 6 loss 0.9420205950737
# max: 0
# Training: On Tick: 7 loss 1.0125281810760498
# max: 20
# Training: On Tick: 8 loss 0.9132822155952454
# max: 0
# Training: On Tick: 9 loss 0.8249920010566711
# max: 15
# Training: On Tick: 10 loss 1.148267149925232
# max: 20
# Training: On Tick: 11 loss 0.8403026461601257
# max: 17
# Training: On Tick: 12 loss 0.8953496813774109
# max: 17
# Training: On Tick: 13 loss 0.9102137088775635
# max: 15
# Training: On Tick: 14 loss 0.930149495601654
# max: 15
# Training: On Tick: 15 loss 0.9207637906074524
# max: 15
# Training: On Tick: 16 loss 0.9024826288223267
# max: 19
# Training: On Tick: 17 loss 0.9861574172973633
# max: 15
# Training: On Tick: 18 loss 0.927518367767334
# max: 7
# Training: On Tick: 19 loss 0.8181123733520508
# max: 0
# Training: On Tick: 20 loss 1.0829033851623535
# max: 15
# Training: On Tick: 21 loss 0.7416576743125916
# max: 1
# Training: On Tick: 22 loss 0.695210337638855
# Epoch: 5 Loss: 0.9126217546670333
# Starting Epoch 6
# max: 19
# Training: On Tick: 0 loss 0.8790223002433777
# max: 19
# Training: On Tick: 1 loss 0.8564534783363342
# max: 0
# Training: On Tick: 2 loss 0.9118461012840271
# max: 19
# Training: On Tick: 3 loss 0.7591598629951477
# max: 19
# Training: On Tick: 4 loss 0.9081355333328247
# max: 15
# Training: On Tick: 5 loss 0.8185604810714722
# max: 15
# Training: On Tick: 6 loss 0.8159760236740112
# max: 15
# Training: On Tick: 7 loss 0.7204269766807556
# max: 13
# Training: On Tick: 8 loss 0.8817234635353088
# max: 15
# Training: On Tick: 9 loss 0.9198925495147705
# max: 19
# Training: On Tick: 10 loss 0.7738099098205566
# max: 15
# Training: On Tick: 11 loss 0.8231098055839539
# max: 17
# Training: On Tick: 12 loss 1.0629550218582153
# max: 14
# Training: On Tick: 13 loss 0.9740506410598755
# max: 7
# Training: On Tick: 14 loss 1.0249358415603638
# max: 14
# Training: On Tick: 15 loss 0.8000948429107666
# max: 15
# Training: On Tick: 16 loss 0.794840931892395
# max: 15
# Training: On Tick: 17 loss 0.8239172101020813
# max: 17
# Training: On Tick: 18 loss 0.8711840510368347
# max: 15
# Training: On Tick: 19 loss 0.8495003581047058
# max: 13
# Training: On Tick: 20 loss 0.7959209084510803
# max: 19
# Training: On Tick: 21 loss 0.8503649830818176
# max: 15
# Training: On Tick: 22 loss 0.9408355951309204
# Epoch: 6 Loss: 0.8633355161418086
# Starting Epoch 7
# max: 0
# Training: On Tick: 0 loss 0.8267884254455566
# max: 19
# Training: On Tick: 1 loss 0.733649730682373
# max: 12
# Training: On Tick: 2 loss 0.7545053958892822
# max: 0
# Training: On Tick: 3 loss 0.7611913084983826
# max: 19
# Training: On Tick: 4 loss 0.9665262699127197
# max: 0
# Training: On Tick: 5 loss 0.783470630645752
# max: 15
# Training: On Tick: 6 loss 0.8828961849212646
# max: 19
# Training: On Tick: 7 loss 0.8895952701568604
# max: 15
# Training: On Tick: 8 loss 0.8356858491897583
# max: 12
# Training: On Tick: 9 loss 0.8244216442108154
# max: 20
# Training: On Tick: 10 loss 0.8579011559486389
# max: 18
# Training: On Tick: 11 loss 0.7743149995803833
# max: 0
# Training: On Tick: 12 loss 0.8799605369567871
# max: 17
# Training: On Tick: 13 loss 0.730372428894043
# max: 19
# Training: On Tick: 14 loss 0.9820182919502258
# max: 17
# Training: On Tick: 15 loss 0.8546654582023621
# max: 0
# Training: On Tick: 16 loss 0.7120603919029236
# max: 19
# Training: On Tick: 17 loss 0.7361224889755249
# max: 17
# Training: On Tick: 18 loss 0.8572392463684082
# max: 15
# Training: On Tick: 19 loss 0.7614311575889587
# max: 19
# Training: On Tick: 20 loss 0.8461670279502869
# max: 0
# Training: On Tick: 21 loss 0.8185043931007385
# max: 15
# Training: On Tick: 22 loss 0.8468475937843323
# Epoch: 7 Loss: 0.8224493861198425
# Starting Epoch 8
# max: 15
# Training: On Tick: 0 loss 0.8666016459465027
# max: 7
# Training: On Tick: 1 loss 0.7496827244758606
# max: 14
# Training: On Tick: 2 loss 0.7469908595085144
# max: 20
# Training: On Tick: 3 loss 0.7575502395629883
# max: 0
# Training: On Tick: 4 loss 0.8576380014419556
# max: 20
# Training: On Tick: 5 loss 0.731914758682251
# max: 4
# Training: On Tick: 6 loss 0.8255422711372375
# max: 15
# Training: On Tick: 7 loss 0.7883480787277222
# max: 15
# Training: On Tick: 8 loss 0.5816752910614014
# max: 8
# Training: On Tick: 9 loss 0.8043619990348816
# max: 15
# Training: On Tick: 10 loss 0.7083576917648315
# max: 11
# Training: On Tick: 11 loss 0.7989007234573364
# max: 20
# Training: On Tick: 12 loss 0.8264026641845703
# max: 15
# Training: On Tick: 13 loss 0.8721553087234497
# max: 19
# Training: On Tick: 14 loss 0.8085903525352478
# max: 17
# Training: On Tick: 15 loss 0.9447141289710999
# max: 20
# Training: On Tick: 16 loss 0.7338231205940247
# max: 18
# Training: On Tick: 17 loss 0.9058180451393127
# max: 15
# Training: On Tick: 18 loss 0.6989377737045288
# max: 17
# Training: On Tick: 19 loss 0.9724856615066528
# max: 0
# Training: On Tick: 20 loss 0.9390915036201477
# max: 20
# Training: On Tick: 21 loss 0.7505848407745361
# max: 15
# Training: On Tick: 22 loss 0.9335536956787109
# Epoch: 8 Loss: 0.8088574513145115
# Starting Epoch 9
# max: 19
# Training: On Tick: 0 loss 0.772486686706543
# max: 8
# Training: On Tick: 1 loss 0.8237748742103577
# max: 19
# Training: On Tick: 2 loss 0.6621153354644775
# max: 15
# Training: On Tick: 3 loss 0.7767792344093323
# max: 19
# Training: On Tick: 4 loss 0.6308367252349854
# max: 19
# Training: On Tick: 5 loss 0.7869164347648621
# max: 20
# Training: On Tick: 6 loss 0.7837247252464294
# max: 17
# Training: On Tick: 7 loss 0.898756742477417
# max: 0
# Training: On Tick: 8 loss 0.8170493841171265
# max: 20
# Training: On Tick: 9 loss 0.7338841557502747
# max: 15
# Training: On Tick: 10 loss 0.663240909576416
# max: 19
# Training: On Tick: 11 loss 0.6915013194084167
# max: 19
# Training: On Tick: 12 loss 0.6433023810386658
# max: 17
# Training: On Tick: 13 loss 0.7026905417442322
# max: 7
# Training: On Tick: 14 loss 0.6598362922668457
# max: 15
# Training: On Tick: 15 loss 0.8117470741271973
# max: 12
# Training: On Tick: 16 loss 0.9305716156959534
# max: 18
# Training: On Tick: 17 loss 0.717100977897644
# max: 15
# Training: On Tick: 18 loss 0.8785775899887085
# max: 20
# Training: On Tick: 19 loss 0.8344721794128418
# max: 15
# Training: On Tick: 20 loss 0.6757568120956421
# max: 12
# Training: On Tick: 21 loss 0.9782846570014954
# max: 19
# Training: On Tick: 22 loss 0.9369783401489258
# Epoch: 9 Loss: 0.7743645647297734
# Starting Epoch 10
# max: 15
# Training: On Tick: 0 loss 0.80138099193573
# max: 15
# Training: On Tick: 1 loss 0.6915337443351746
# max: 19
# Training: On Tick: 2 loss 0.6738852858543396
# max: 15
# Training: On Tick: 3 loss 0.7092771530151367
# max: 15
# Training: On Tick: 4 loss 0.7669324278831482
# max: 12
# Training: On Tick: 5 loss 0.7590225338935852
# max: 0
# Training: On Tick: 6 loss 0.7482060194015503
# max: 13
# Training: On Tick: 7 loss 0.8442320823669434
# max: 13
# Training: On Tick: 8 loss 0.6696882843971252
# max: 19
# Training: On Tick: 9 loss 0.8204857707023621
# max: 15
# Training: On Tick: 10 loss 0.790968656539917
# max: 15
# Training: On Tick: 11 loss 0.7582337260246277
# max: 15
# Training: On Tick: 12 loss 0.6521036028862
# max: 15
# Training: On Tick: 13 loss 0.7498273849487305
# max: 19
# Training: On Tick: 14 loss 0.7805231809616089
# max: 0
# Training: On Tick: 15 loss 0.7392199635505676
# max: 12
# Training: On Tick: 16 loss 0.7730177640914917
# max: 18
# Training: On Tick: 17 loss 0.6989367604255676
# max: 18
# Training: On Tick: 18 loss 0.7231134176254272
# max: 20
# Training: On Tick: 19 loss 0.8729480504989624
# max: 7
# Training: On Tick: 20 loss 0.6951367259025574
# max: 20
# Training: On Tick: 21 loss 0.8155525326728821
# max: 20
# Training: On Tick: 22 loss 0.6441939473152161
# Epoch: 10 Loss: 0.7468878264012544
# Starting Epoch 11
# max: 17
# Training: On Tick: 0 loss 0.7681512832641602
# max: 8
# Training: On Tick: 1 loss 0.7892929911613464
# max: 15
# Training: On Tick: 2 loss 0.6844868063926697
# max: 18
# Training: On Tick: 3 loss 0.7332327961921692
# max: 12
# Training: On Tick: 4 loss 0.6978181600570679
# max: 13
# Training: On Tick: 5 loss 0.7654334902763367
# max: 0
# Training: On Tick: 6 loss 0.8017845153808594
# max: 0
# Training: On Tick: 7 loss 0.8106402158737183
# max: 20
# Training: On Tick: 8 loss 0.7016463279724121
# max: 15
# Training: On Tick: 9 loss 0.768099308013916
# max: 0
# Training: On Tick: 10 loss 0.7658780813217163
# max: 15
# Training: On Tick: 11 loss 0.7178279757499695
# max: 15
# Training: On Tick: 12 loss 0.6611016392707825
# max: 0
# Training: On Tick: 13 loss 0.6237822771072388
# max: 7
# Training: On Tick: 14 loss 0.7658380270004272
# max: 12
# Training: On Tick: 15 loss 0.6614980101585388
# max: 18
# Training: On Tick: 16 loss 0.6318336129188538
# max: 19
# Training: On Tick: 17 loss 0.7462053298950195
# max: 19
# Training: On Tick: 18 loss 0.7559201121330261
# max: 7
# Training: On Tick: 19 loss 0.625281810760498
# max: 19
# Training: On Tick: 20 loss 0.7314131259918213
# max: 14
# Training: On Tick: 21 loss 0.8916535973548889
# max: 15
# Training: On Tick: 22 loss 0.6569420695304871
# Epoch: 11 Loss: 0.7285113723381705
# Starting Epoch 12
# max: 0
# Training: On Tick: 0 loss 0.5498128533363342
# max: 20
# Training: On Tick: 1 loss 0.7613540887832642
# max: 19
# Training: On Tick: 2 loss 0.6420807242393494
# max: 13
# Training: On Tick: 3 loss 0.6309734582901001
# max: 15
# Training: On Tick: 4 loss 0.6866664886474609
# max: 15
# Training: On Tick: 5 loss 0.7306743860244751
# max: 19
# Training: On Tick: 6 loss 0.7965019345283508
# max: 19
# Training: On Tick: 7 loss 0.8110121488571167
# max: 15
# Training: On Tick: 8 loss 0.6759098172187805
# max: 20
# Training: On Tick: 9 loss 0.5935465097427368
# max: 5
# Training: On Tick: 10 loss 0.6428913474082947
# max: 14
# Training: On Tick: 11 loss 0.7934844493865967
# max: 18
# Training: On Tick: 12 loss 0.6988891363143921
# max: 17
# Training: On Tick: 13 loss 0.6402531862258911
# max: 14
# Training: On Tick: 14 loss 0.5526660680770874
# max: 17
# Training: On Tick: 15 loss 0.6912785172462463
# max: 19
# Training: On Tick: 16 loss 0.635673463344574
# max: 14
# Training: On Tick: 17 loss 0.6890865564346313
# max: 15
# Training: On Tick: 18 loss 0.6537505984306335
# max: 16
# Training: On Tick: 19 loss 0.6754979491233826
# max: 19
# Training: On Tick: 20 loss 0.7185488939285278
# max: 17
# Training: On Tick: 21 loss 0.5720492005348206
# max: 15
# Training: On Tick: 22 loss 0.6834662556648254
# Epoch: 12 Loss: 0.6750464361646901
# Starting Epoch 13
# max: 19
# Training: On Tick: 0 loss 0.6705887317657471
# max: 15
# Training: On Tick: 1 loss 0.6881790161132812
# max: 15
# Training: On Tick: 2 loss 0.7474409341812134
# max: 18
# Training: On Tick: 3 loss 0.5755160450935364
# max: 18
# Training: On Tick: 4 loss 0.6170282363891602
# max: 15
# Training: On Tick: 5 loss 0.5527464747428894
# max: 18
# Training: On Tick: 6 loss 0.6384644508361816
# max: 18
# Training: On Tick: 7 loss 0.5724308490753174
# max: 7
# Training: On Tick: 8 loss 0.6391217708587646
# max: 18
# Training: On Tick: 9 loss 0.6856822967529297
# max: 20
# Training: On Tick: 10 loss 0.5705661773681641
# max: 1
# Training: On Tick: 11 loss 0.7670016884803772
# max: 15
# Training: On Tick: 12 loss 0.5695084929466248
# max: 15
# Training: On Tick: 13 loss 0.5774732828140259
# max: 19
# Training: On Tick: 14 loss 0.680691659450531
# max: 19
# Training: On Tick: 15 loss 0.6905629634857178
# max: 15
# Training: On Tick: 16 loss 0.6792637705802917
# max: 13
# Training: On Tick: 17 loss 0.5429902672767639
# max: 19
# Training: On Tick: 18 loss 0.6316247582435608
# max: 13
# Training: On Tick: 19 loss 0.6405218243598938
# max: 17
# Training: On Tick: 20 loss 0.6554158926010132
# max: 19
# Training: On Tick: 21 loss 0.6884453296661377
# max: 15
# Training: On Tick: 22 loss 0.48202404379844666
# Epoch: 13 Loss: 0.6331864763861117
# Starting Epoch 14
# max: 15
# Training: On Tick: 0 loss 0.6156937479972839
# max: 17
# Training: On Tick: 1 loss 0.5857007503509521
# max: 6
# Training: On Tick: 2 loss 0.6049913763999939
# max: 18
# Training: On Tick: 3 loss 0.6290870308876038
# max: 7
# Training: On Tick: 4 loss 0.6028627753257751
# max: 14
# Training: On Tick: 5 loss 0.6645326018333435
# max: 17
# Training: On Tick: 6 loss 0.6164290904998779
# max: 8
# Training: On Tick: 7 loss 0.6220985651016235
# max: 1
# Training: On Tick: 8 loss 0.6173732876777649
# max: 13
# Training: On Tick: 9 loss 0.494586318731308
# max: 8
# Training: On Tick: 10 loss 0.580687403678894
# max: 17
# Training: On Tick: 11 loss 0.7644733786582947
# max: 12
# Training: On Tick: 12 loss 0.6433914303779602
# max: 14
# Training: On Tick: 13 loss 0.6141235828399658
# max: 14
# Training: On Tick: 14 loss 0.564889669418335
# max: 18
# Training: On Tick: 15 loss 0.5367212891578674
# max: 17
# Training: On Tick: 16 loss 0.5408029556274414
# max: 18
# Training: On Tick: 17 loss 0.6576911807060242
# max: 7
# Training: On Tick: 18 loss 0.6410303711891174
# max: 8
# Training: On Tick: 19 loss 0.5589308738708496
# max: 15
# Training: On Tick: 20 loss 0.7905775904655457
# max: 18
# Training: On Tick: 21 loss 0.647712230682373
# max: 15
# Training: On Tick: 22 loss 0.7207801342010498
# Epoch: 14 Loss: 0.6223985928556194
# Starting Epoch 15
# max: 20
# Training: On Tick: 0 loss 0.5806627869606018
# max: 0
# Training: On Tick: 1 loss 0.6778044104576111
# max: 3
# Training: On Tick: 2 loss 0.6615373492240906
# max: 4
# Training: On Tick: 3 loss 0.5646040439605713
# max: 0
# Training: On Tick: 4 loss 0.6034901738166809
# max: 14
# Training: On Tick: 5 loss 0.53973388671875
# max: 18
# Training: On Tick: 6 loss 0.5823261737823486
# max: 20
# Training: On Tick: 7 loss 0.5703477263450623
# max: 1
# Training: On Tick: 8 loss 0.6352159976959229
# max: 19
# Training: On Tick: 9 loss 0.5129167437553406
# max: 18
# Training: On Tick: 10 loss 0.6873536705970764
# max: 18
# Training: On Tick: 11 loss 0.6211671233177185
# max: 12
# Training: On Tick: 12 loss 0.6764439940452576
# max: 1
# Training: On Tick: 13 loss 0.7362261414527893
# max: 15
# Training: On Tick: 14 loss 0.6664674878120422
# max: 14
# Training: On Tick: 15 loss 0.5929587483406067
# max: 18
# Training: On Tick: 16 loss 0.6992871165275574
# max: 15
# Training: On Tick: 17 loss 0.6517904996871948
# max: 12
# Training: On Tick: 18 loss 0.6048407554626465
# max: 19
# Training: On Tick: 19 loss 0.706996500492096
# max: 15
# Training: On Tick: 20 loss 0.5914071798324585
# max: 20
# Training: On Tick: 21 loss 0.5528637766838074
# max: 15
# Training: On Tick: 22 loss 0.5696672797203064
# Epoch: 15 Loss: 0.6211351985516755
# Starting Epoch 16
# max: 17
# Training: On Tick: 0 loss 0.6931449770927429
# max: 12
# Training: On Tick: 1 loss 0.5549803972244263
# max: 15
# Training: On Tick: 2 loss 0.5994997620582581
# max: 18
# Training: On Tick: 3 loss 0.45462220907211304
# max: 12
# Training: On Tick: 4 loss 0.48220202326774597
# max: 18
# Training: On Tick: 5 loss 0.7193944454193115
# max: 19
# Training: On Tick: 6 loss 0.6216487884521484
# max: 0
# Training: On Tick: 7 loss 0.6529669761657715
# max: 6
# Training: On Tick: 8 loss 0.6177657246589661
# max: 15
# Training: On Tick: 9 loss 0.6372902393341064
# max: 19
# Training: On Tick: 10 loss 0.5933970212936401
# max: 14
# Training: On Tick: 11 loss 0.5526576638221741
# max: 18
# Training: On Tick: 12 loss 0.6359056234359741
# max: 15
# Training: On Tick: 13 loss 0.5803304314613342
# max: 15
# Training: On Tick: 14 loss 0.6382691860198975
# max: 15
# Training: On Tick: 15 loss 0.6585422158241272
# max: 8
# Training: On Tick: 16 loss 0.5691144466400146
# max: 15
# Training: On Tick: 17 loss 0.586245596408844
# max: 15
# Training: On Tick: 18 loss 0.5289463996887207
# max: 18
# Training: On Tick: 19 loss 0.5972076058387756
# max: 17
# Training: On Tick: 20 loss 0.6446781158447266
# max: 9
# Training: On Tick: 21 loss 0.5932600498199463
# max: 12
# Training: On Tick: 22 loss 0.5226318836212158
# Epoch: 16 Loss: 0.5971609470636948
# Starting Epoch 17
# max: 8
# Training: On Tick: 0 loss 0.5782366991043091
# max: 17
# Training: On Tick: 1 loss 0.5611582398414612
# max: 18
# Training: On Tick: 2 loss 0.5696970820426941
# max: 13
# Training: On Tick: 3 loss 0.5539252161979675
# max: 18
# Training: On Tick: 4 loss 0.6671208143234253
# max: 15
# Training: On Tick: 5 loss 0.6327440142631531
# max: 4
# Training: On Tick: 6 loss 0.5047726035118103
# max: 19
# Training: On Tick: 7 loss 0.5527803301811218
# max: 15
# Training: On Tick: 8 loss 0.5902917385101318
# max: 15
# Training: On Tick: 9 loss 0.5843266844749451
# max: 19
# Training: On Tick: 10 loss 0.4995376765727997
# max: 15
# Training: On Tick: 11 loss 0.5544711351394653
# max: 20
# Training: On Tick: 12 loss 0.6741883158683777
# max: 15
# Training: On Tick: 13 loss 0.482619047164917
# max: 20
# Training: On Tick: 14 loss 0.6402853727340698
# max: 20
# Training: On Tick: 15 loss 0.64774489402771
# max: 0
# Training: On Tick: 16 loss 0.5730475783348083
# max: 7
# Training: On Tick: 17 loss 0.5768322944641113
# max: 15
# Training: On Tick: 18 loss 0.5890231728553772
# max: 18
# Training: On Tick: 19 loss 0.5137835741043091
# max: 6
# Training: On Tick: 20 loss 0.5622861981391907
# max: 20
# Training: On Tick: 21 loss 0.5019926428794861
# max: 19
# Training: On Tick: 22 loss 0.529437243938446
# Epoch: 17 Loss: 0.5713175029858298
# Starting Epoch 18
# max: 15
# Training: On Tick: 0 loss 0.5390856862068176
# max: 15
# Training: On Tick: 1 loss 0.5911517143249512
# max: 14
# Training: On Tick: 2 loss 0.4455980360507965
# max: 19
# Training: On Tick: 3 loss 0.6463429927825928
# max: 7
# Training: On Tick: 4 loss 0.5076243877410889
# max: 15
# Training: On Tick: 5 loss 0.5745602250099182
# max: 14
# Training: On Tick: 6 loss 0.46583160758018494
# max: 0
# Training: On Tick: 7 loss 0.41834595799446106
# max: 4
# Training: On Tick: 8 loss 0.4967248737812042
# max: 18
# Training: On Tick: 9 loss 0.5022304654121399
# max: 17
# Training: On Tick: 10 loss 0.5404861569404602
# max: 7
# Training: On Tick: 11 loss 0.41205066442489624
# max: 7
# Training: On Tick: 12 loss 0.4563315510749817
# max: 13
# Training: On Tick: 13 loss 0.5963108539581299
# max: 7
# Training: On Tick: 14 loss 0.6035561561584473
# max: 12
# Training: On Tick: 15 loss 0.6775792241096497
# max: 20
# Training: On Tick: 16 loss 0.5173108577728271
# max: 16
# Training: On Tick: 17 loss 0.46811896562576294
# max: 4
# Training: On Tick: 18 loss 0.48924973607063293
# max: 20
# Training: On Tick: 19 loss 0.6462557911872864
# max: 15
# Training: On Tick: 20 loss 0.5159181952476501
# max: 7
# Training: On Tick: 21 loss 0.5341510772705078
# max: 16
# Training: On Tick: 22 loss 0.5260253548622131
# Epoch: 18 Loss: 0.5291669796342435
# Starting Epoch 19
# max: 20
# Training: On Tick: 0 loss 0.457929402589798
# max: 6
# Training: On Tick: 1 loss 0.46461471915245056
# max: 16
# Training: On Tick: 2 loss 0.4846879839897156
# max: 19
# Training: On Tick: 3 loss 0.4310208559036255
# max: 18
# Training: On Tick: 4 loss 0.5392687320709229
# max: 1
# Training: On Tick: 5 loss 0.4478012025356293
# max: 15
# Training: On Tick: 6 loss 0.5152236819267273
# max: 18
# Training: On Tick: 7 loss 0.5480522513389587
# max: 0
# Training: On Tick: 8 loss 0.49533432722091675
# max: 15
# Training: On Tick: 9 loss 0.5711596608161926
# max: 15
# Training: On Tick: 10 loss 0.564508855342865
# max: 12
# Training: On Tick: 11 loss 0.5052264332771301
# max: 17
# Training: On Tick: 12 loss 0.5150608420372009
# max: 15
# Training: On Tick: 13 loss 0.5053041577339172
# max: 15
# Training: On Tick: 14 loss 0.5404006242752075
# max: 15
# Training: On Tick: 15 loss 0.6111378073692322
# max: 17
# Training: On Tick: 16 loss 0.4599306583404541
# max: 15
# Training: On Tick: 17 loss 0.5284830927848816
# max: 10
# Training: On Tick: 18 loss 0.48126962780952454
# max: 14
# Training: On Tick: 19 loss 0.6320703625679016
# max: 15
# Training: On Tick: 20 loss 0.5343331098556519
# max: 15
# Training: On Tick: 21 loss 0.47640788555145264
# max: 20
# Training: On Tick: 22 loss 0.5042973160743713
# Epoch: 19 Loss: 0.5136314604593359
# Starting Epoch 20
# max: 12
# Training: On Tick: 0 loss 0.4084455966949463
# max: 15
# Training: On Tick: 1 loss 0.48215439915657043
# max: 0
# Training: On Tick: 2 loss 0.4664773643016815
# max: 20
# Training: On Tick: 3 loss 0.6844909191131592
# max: 20
# Training: On Tick: 4 loss 0.39508843421936035
# max: 19
# Training: On Tick: 5 loss 0.45462197065353394
# max: 7
# Training: On Tick: 6 loss 0.5157613158226013
# max: 15
# Training: On Tick: 7 loss 0.4761509895324707
# max: 4
# Training: On Tick: 8 loss 0.41081875562667847
# max: 14
# Training: On Tick: 9 loss 0.5664186477661133
# max: 3
# Training: On Tick: 10 loss 0.46767088770866394
# max: 13
# Training: On Tick: 11 loss 0.49887847900390625
# max: 8
# Training: On Tick: 12 loss 0.4335225820541382
# max: 12
# Training: On Tick: 13 loss 0.5015503764152527
# max: 11
# Training: On Tick: 14 loss 0.4555402398109436
# max: 8
# Training: On Tick: 15 loss 0.43551477789878845
# max: 15
# Training: On Tick: 16 loss 0.4279513657093048
# max: 16
# Training: On Tick: 17 loss 0.4839957058429718
# max: 6
# Training: On Tick: 18 loss 0.5335389375686646
# max: 14
# Training: On Tick: 19 loss 0.5138147473335266
# max: 19
# Training: On Tick: 20 loss 0.4739467203617096
# max: 19
# Training: On Tick: 21 loss 0.5472739934921265
# max: 0
# Training: On Tick: 22 loss 0.5131313800811768
# Epoch: 20 Loss: 0.48464167765949084
# Starting Epoch 21
# max: 15
# Training: On Tick: 0 loss 0.40614601969718933
# max: 17
# Training: On Tick: 1 loss 0.4301375448703766
# max: 15
# Training: On Tick: 2 loss 0.43670082092285156
# max: 15
# Training: On Tick: 3 loss 0.41961362957954407
# max: 15
# Training: On Tick: 4 loss 0.4285919964313507
# max: 8
# Training: On Tick: 5 loss 0.43807452917099
# max: 18
# Training: On Tick: 6 loss 0.565338671207428
# max: 0
# Training: On Tick: 7 loss 0.49169641733169556
# max: 8
# Training: On Tick: 8 loss 0.48766109347343445
# max: 13
# Training: On Tick: 9 loss 0.4558274745941162
# max: 18
# Training: On Tick: 10 loss 0.5715022087097168
# max: 17
# Training: On Tick: 11 loss 0.47486695647239685
# max: 18
# Training: On Tick: 12 loss 0.6242886185646057
# max: 1
# Training: On Tick: 13 loss 0.4675585925579071
# max: 17
# Training: On Tick: 14 loss 0.4587442874908447
# max: 12
# Training: On Tick: 15 loss 0.6152377724647522
# max: 8
# Training: On Tick: 16 loss 0.3873521387577057
# max: 20
# Training: On Tick: 17 loss 0.45675572752952576
# max: 20
# Training: On Tick: 18 loss 0.5229348540306091
# max: 18
# Training: On Tick: 19 loss 0.5052366256713867
# max: 18
# Training: On Tick: 20 loss 0.5363330245018005
# max: 15
# Training: On Tick: 21 loss 0.4614771604537964
# max: 18
# Training: On Tick: 22 loss 0.6042919158935547
# Epoch: 21 Loss: 0.4889725252338078
# Starting Epoch 22
# max: 4
# Training: On Tick: 0 loss 0.4512268602848053
# max: 20
# Training: On Tick: 1 loss 0.5154457688331604
# max: 18
# Training: On Tick: 2 loss 0.4725419580936432
# max: 15
# Training: On Tick: 3 loss 0.5212960839271545
# max: 15
# Training: On Tick: 4 loss 0.5487834215164185
# max: 14
# Training: On Tick: 5 loss 0.5572637915611267
# max: 18
# Training: On Tick: 6 loss 0.51160728931427
# max: 20
# Training: On Tick: 7 loss 0.5374124646186829
# max: 0
# Training: On Tick: 8 loss 0.5267846584320068
# max: 14
# Training: On Tick: 9 loss 0.5820561051368713
# max: 17
# Training: On Tick: 10 loss 0.41050097346305847
# max: 4
# Training: On Tick: 11 loss 0.4013863801956177
# max: 0
# Training: On Tick: 12 loss 0.5624358654022217
# max: 15
# Training: On Tick: 13 loss 0.4597322642803192
# max: 0
# Training: On Tick: 14 loss 0.6231983304023743
# max: 15
# Training: On Tick: 15 loss 0.5712682604789734
# max: 7
# Training: On Tick: 16 loss 0.4170287549495697
# max: 8
# Training: On Tick: 17 loss 0.45699137449264526
# max: 19
# Training: On Tick: 18 loss 0.5160990357398987
# max: 12
# Training: On Tick: 19 loss 0.48702484369277954
# max: 20
# Training: On Tick: 20 loss 0.3943173587322235
# max: 17
# Training: On Tick: 21 loss 0.5655446648597717
# max: 20
# Training: On Tick: 22 loss 0.45964887738227844
# Epoch: 22 Loss: 0.5021563211212987
# Starting Epoch 23
# max: 19
# Training: On Tick: 0 loss 0.637036144733429
# max: 0
# Training: On Tick: 1 loss 0.512502908706665
# max: 16
# Training: On Tick: 2 loss 0.4671644866466522
# max: 19
# Training: On Tick: 3 loss 0.40582507848739624
# max: 15
# Training: On Tick: 4 loss 0.5145956873893738
# max: 19
# Training: On Tick: 5 loss 0.5020497441291809
# max: 15
# Training: On Tick: 6 loss 0.4899338185787201
# max: 16
# Training: On Tick: 7 loss 0.4660390019416809
# max: 17
# Training: On Tick: 8 loss 0.3500445783138275
# max: 15
# Training: On Tick: 9 loss 0.45027050375938416
# max: 4
# Training: On Tick: 10 loss 0.5092418193817139
# max: 0
# Training: On Tick: 11 loss 0.5275754332542419
# max: 18
# Training: On Tick: 12 loss 0.46868714690208435
# max: 19
# Training: On Tick: 13 loss 0.4235747158527374
# max: 15
# Training: On Tick: 14 loss 0.5761790871620178
# max: 19
# Training: On Tick: 15 loss 0.4374573528766632
# max: 7
# Training: On Tick: 16 loss 0.42545151710510254
# max: 7
# Training: On Tick: 17 loss 0.4621548652648926
# max: 6
# Training: On Tick: 18 loss 0.4937190115451813
# max: 11
# Training: On Tick: 19 loss 0.37327784299850464
# max: 1
# Training: On Tick: 20 loss 0.4588020443916321
# max: 14
# Training: On Tick: 21 loss 0.43489789962768555
# max: 18
# Training: On Tick: 22 loss 0.4168313443660736
# Epoch: 23 Loss: 0.46970921884412353
# Starting Epoch 24
# max: 15
# Training: On Tick: 0 loss 0.4141633212566376
# max: 0
# Training: On Tick: 1 loss 0.4217093884944916
# max: 0
# Training: On Tick: 2 loss 0.44008052349090576
# max: 15
# Training: On Tick: 3 loss 0.54683518409729
# max: 15
# Training: On Tick: 4 loss 0.4871501922607422
# max: 19
# Training: On Tick: 5 loss 0.456173837184906
# max: 18
# Training: On Tick: 6 loss 0.42047643661499023
# max: 18
# Training: On Tick: 7 loss 0.41073277592658997
# max: 1
# Training: On Tick: 8 loss 0.42768362164497375
# max: 19
# Training: On Tick: 9 loss 0.3828296363353729
# max: 15
# Training: On Tick: 10 loss 0.449697881937027
# max: 11
# Training: On Tick: 11 loss 0.5070769786834717
# max: 15
# Training: On Tick: 12 loss 0.4107891619205475
# max: 16
# Training: On Tick: 13 loss 0.3928252160549164
# max: 19
# Training: On Tick: 14 loss 0.47678831219673157
# max: 19
# Training: On Tick: 15 loss 0.4424353837966919
# max: 1
# Training: On Tick: 16 loss 0.4445471465587616
# max: 15
# Training: On Tick: 17 loss 0.41955673694610596
# max: 16
# Training: On Tick: 18 loss 0.35806047916412354
# max: 3
# Training: On Tick: 19 loss 0.35162368416786194
# max: 15
# Training: On Tick: 20 loss 0.35363003611564636
# max: 15
# Training: On Tick: 21 loss 0.40641599893569946
# max: 13
# Training: On Tick: 22 loss 0.47825366258621216
# Epoch: 24 Loss: 0.43041459114655206
# Starting Epoch 25
# max: 13
# Training: On Tick: 0 loss 0.4353649914264679
# max: 15
# Training: On Tick: 1 loss 0.36557793617248535
# max: 19
# Training: On Tick: 2 loss 0.42017707228660583
# max: 4
# Training: On Tick: 3 loss 0.46713051199913025
# max: 15
# Training: On Tick: 4 loss 0.4034411311149597
# max: 12
# Training: On Tick: 5 loss 0.3335453271865845
# max: 18
# Training: On Tick: 6 loss 0.39509472250938416
# max: 16
# Training: On Tick: 7 loss 0.35974642634391785
# max: 15
# Training: On Tick: 8 loss 0.4181663393974304
# max: 0
# Training: On Tick: 9 loss 0.48249080777168274
# max: 0
# Training: On Tick: 10 loss 0.456394225358963
# max: 19
# Training: On Tick: 11 loss 0.4474973678588867
# max: 13
# Training: On Tick: 12 loss 0.3454195261001587
# max: 1
# Training: On Tick: 13 loss 0.3485862910747528
# max: 19
# Training: On Tick: 14 loss 0.37569448351860046
# max: 12
# Training: On Tick: 15 loss 0.4626169800758362
# max: 13
# Training: On Tick: 16 loss 0.4068743586540222
# max: 15
# Training: On Tick: 17 loss 0.40507179498672485
# max: 11
# Training: On Tick: 18 loss 0.3933550715446472
# max: 15
# Training: On Tick: 19 loss 0.346162348985672
# max: 1
# Training: On Tick: 20 loss 0.48641496896743774
# max: 14
# Training: On Tick: 21 loss 0.39084041118621826
# max: 15
# Training: On Tick: 22 loss 0.38875889778137207
# Epoch: 25 Loss: 0.40584443444791046
# Starting Epoch 26
# max: 15
# Training: On Tick: 0 loss 0.37954777479171753
# max: 15
# Training: On Tick: 1 loss 0.4016845226287842
# max: 20
# Training: On Tick: 2 loss 0.46271178126335144
# max: 18
# Training: On Tick: 3 loss 0.39261525869369507
# max: 18
# Training: On Tick: 4 loss 0.4265579283237457
# max: 18
# Training: On Tick: 5 loss 0.45924779772758484
# max: 1
# Training: On Tick: 6 loss 0.3709530830383301
# max: 18
# Training: On Tick: 7 loss 0.35406816005706787
# max: 15
# Training: On Tick: 8 loss 0.4732532799243927
# max: 16
# Training: On Tick: 9 loss 0.33749282360076904
# max: 15
# Training: On Tick: 10 loss 0.34005239605903625
# max: 15
# Training: On Tick: 11 loss 0.3992817997932434
# max: 15
# Training: On Tick: 12 loss 0.32695838809013367
# max: 20
# Training: On Tick: 13 loss 0.3878033757209778
# max: 11
# Training: On Tick: 14 loss 0.34580808877944946
# max: 7
# Training: On Tick: 15 loss 0.3807526230812073
# max: 7
# Training: On Tick: 16 loss 0.42941975593566895
# max: 18
# Training: On Tick: 17 loss 0.37023261189460754
# max: 15
# Training: On Tick: 18 loss 0.3708643913269043
# max: 12
# Training: On Tick: 19 loss 0.3866021931171417
# max: 13
# Training: On Tick: 20 loss 0.3385060131549835
# max: 18
# Training: On Tick: 21 loss 0.3384639024734497
# max: 7
# Training: On Tick: 22 loss 0.3410874605178833
# Epoch: 26 Loss: 0.38321588739104895
# Starting Epoch 27
# max: 15
# Training: On Tick: 0 loss 0.3210752308368683
# max: 15
# Training: On Tick: 1 loss 0.39093559980392456
# max: 18
# Training: On Tick: 2 loss 0.3847928047180176
# max: 7
# Training: On Tick: 3 loss 0.3612450361251831
# max: 18
# Training: On Tick: 4 loss 0.4014344811439514
# max: 0
# Training: On Tick: 5 loss 0.30455824732780457
# max: 19
# Training: On Tick: 6 loss 0.3616822063922882
# max: 15
# Training: On Tick: 7 loss 0.3777786195278168
# max: 15
# Training: On Tick: 8 loss 0.3452124297618866
# max: 15
# Training: On Tick: 9 loss 0.40229296684265137
# max: 7
# Training: On Tick: 10 loss 0.33243197202682495
# max: 0
# Training: On Tick: 11 loss 0.33816099166870117
# max: 20
# Training: On Tick: 12 loss 0.3882405161857605
# max: 13
# Training: On Tick: 13 loss 0.3359811305999756
# max: 18
# Training: On Tick: 14 loss 0.3943364918231964
# max: 16
# Training: On Tick: 15 loss 0.35283079743385315
# max: 18
# Training: On Tick: 16 loss 0.37438833713531494
# max: 7
# Training: On Tick: 17 loss 0.4319365918636322
# max: 20
# Training: On Tick: 18 loss 0.38468340039253235
# max: 17
# Training: On Tick: 19 loss 0.3393562138080597
# max: 19
# Training: On Tick: 20 loss 0.4022752642631531
# max: 15
# Training: On Tick: 21 loss 0.3956305980682373
# max: 15
# Training: On Tick: 22 loss 0.3569905161857605
# Epoch: 27 Loss: 0.3686195845189302
# Starting Epoch 28
# max: 0
# Training: On Tick: 0 loss 0.41008496284484863
# max: 19
# Training: On Tick: 1 loss 0.36676105856895447
# max: 3
# Training: On Tick: 2 loss 0.3251994550228119
# max: 10
# Training: On Tick: 3 loss 0.34411391615867615
# max: 15
# Training: On Tick: 4 loss 0.35974785685539246
# max: 18
# Training: On Tick: 5 loss 0.3192501962184906
# max: 6
# Training: On Tick: 6 loss 0.41903093457221985
# max: 13
# Training: On Tick: 7 loss 0.3616432547569275
# max: 7
# Training: On Tick: 8 loss 0.4259302318096161
# max: 20
# Training: On Tick: 9 loss 0.3154395818710327
# max: 14
# Training: On Tick: 10 loss 0.3525676429271698
# max: 7
# Training: On Tick: 11 loss 0.33903270959854126
# max: 15
# Training: On Tick: 12 loss 0.35557782649993896
# max: 20
# Training: On Tick: 13 loss 0.36579078435897827
# max: 13
# Training: On Tick: 14 loss 0.3683730661869049
# max: 15
# Training: On Tick: 15 loss 0.35009336471557617
# max: 4
# Training: On Tick: 16 loss 0.2923750579357147
# max: 15
# Training: On Tick: 17 loss 0.3387603163719177
# max: 14
# Training: On Tick: 18 loss 0.3448558449745178
# max: 16
# Training: On Tick: 19 loss 0.45859843492507935
# max: 15
# Training: On Tick: 20 loss 0.38825082778930664
# max: 0
# Training: On Tick: 21 loss 0.3251315951347351
# max: 15
# Training: On Tick: 22 loss 0.33654534816741943
# Epoch: 28 Loss: 0.35926757688107697
# Starting Epoch 29
# max: 18
# Training: On Tick: 0 loss 0.41888290643692017
# max: 8
# Training: On Tick: 1 loss 0.40870270133018494
# max: 15
# Training: On Tick: 2 loss 0.31029224395751953
# max: 7
# Training: On Tick: 3 loss 0.3914959728717804
# max: 10
# Training: On Tick: 4 loss 0.30020788311958313
# max: 15
# Training: On Tick: 5 loss 0.31961238384246826
# max: 15
# Training: On Tick: 6 loss 0.39433905482292175
# max: 4
# Training: On Tick: 7 loss 0.3433734178543091
# max: 15
# Training: On Tick: 8 loss 0.32950225472450256
# max: 15
# Training: On Tick: 9 loss 0.4187154471874237
# max: 18
# Training: On Tick: 10 loss 0.3806755840778351
# max: 15
# Training: On Tick: 11 loss 0.3632502853870392
# max: 8
# Training: On Tick: 12 loss 0.3765653073787689
# max: 17
# Training: On Tick: 13 loss 0.338575154542923
# max: 17
# Training: On Tick: 14 loss 0.33832746744155884
# max: 15
# Training: On Tick: 15 loss 0.4179646372795105
# max: 15
# Training: On Tick: 16 loss 0.335170716047287
# max: 13
# Training: On Tick: 17 loss 0.332486093044281
# max: 16
# Training: On Tick: 18 loss 0.3811804950237274
# max: 15
# Training: On Tick: 19 loss 0.3146994411945343
# max: 18
# Training: On Tick: 20 loss 0.35457494854927063
# max: 14
# Training: On Tick: 21 loss 0.37979698181152344
# max: 15
# Training: On Tick: 22 loss 0.4142104685306549
# Epoch: 29 Loss: 0.3635913846285447
# CPU times: user 3min 14s, sys: 2min 2s, total: 5min 17s
# Wall time: 23min 14s

# %% [markdown]
# #### (g) Qualitative and quantitative evaluation of predictions (OVERFIT_NET vs TRAINED_NET):

# %%
# switch back to evaluation mode
trained_net.eval()

sample_img, sample_target = sanity_joint_transform(*sample1)
if USE_GPU:
    sample_img = sample_img.cuda()
sample_output_O = overfit_net.forward(sample_img[None])
sample_output_T = trained_net.forward(sample_img[None])

print(sample_output_T.shape)

# computing mIOU (quantitative measure of accuracy for network predictions)
pred_T = torch.argmax(sample_output_T, dim=1).cpu().numpy()[0]
pred_O = torch.argmax(sample_output_O, dim=1).cpu().numpy()[0]
print(pred_T.max())
gts = torch.from_numpy(np.array(sample1[1].convert('P'), dtype=np.int32)).long().numpy()
gts[gts == 255] = -1
conf_T = eval_semantic_segmentation(pred_T[None], gts[None])
conf_O = eval_semantic_segmentation(pred_O[None], gts[None])


fig = plt.figure(figsize=(14,10))
ax1 = fig.add_subplot(2,2,1)
plt.title('image sample')
ax1.imshow(sample1[0])
ax2 = fig.add_subplot(2,2,2)
plt.title('ground truth (target)')
ax2.imshow(sample1[1])
ax3 = fig.add_subplot(2,2,3)
plt.title('OVERFIT_NET prediction (for its training image)')
ax3.text(10, 25, 'mIoU = {:_>8.6f}'.format(conf_O['miou']), fontsize=20, color='white')
ax3.imshow(colorize_mask(torch.argmax(sample_output_O, dim=1).cpu().numpy()[0]))
ax4 = fig.add_subplot(2,2,4)
plt.title('TRAINED_NET prediction (for one of its training images)')
ax4.text(10, 25, 'mIoU = {:_>8.6f}'.format(conf_T['miou']), fontsize=20, color='white')
ax4.imshow(colorize_mask(torch.argmax(sample_output_T, dim=1).cpu().numpy()[0]))
# Out:
# max: 15
# max: 15
# torch.Size([1, 21, 375, 500])
# 15
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:91: RuntimeWarning: invalid value encountered in true_divide
#   iou = np.diag(confusion) / iou_denominator
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:168: RuntimeWarning: invalid value encountered in true_divide
#   class_accuracy = np.diag(confusion) / np.sum(confusion, axis=1)

# %%
sample_img, sample_target = sanity_joint_transform(*sample2)
if USE_GPU:
    sample_img = sample_img.cuda()
sample_output_O = overfit_net.forward(sample_img[None])
sample_output_T = trained_net.forward(sample_img[None])

# computing mIOU (quantitative measure of accuracy for network predictions)
pred_O = torch.argmax(sample_output_O, dim=1).cpu().numpy()[0]
pred_T = torch.argmax(sample_output_T, dim=1).cpu().numpy()[0]
gts = torch.from_numpy(np.array(sample2[1].convert('P'), dtype=np.int32)).long().numpy()
gts[gts == 255] = -1
conf_O = eval_semantic_segmentation(pred_O[None], gts[None])
conf_T = eval_semantic_segmentation(pred_T[None], gts[None])


fig = plt.figure(figsize=(14,10))
ax1 = fig.add_subplot(2,2,1)
plt.title('image sample')
ax1.imshow(sample2[0])
ax2 = fig.add_subplot(2,2,2)
plt.title('ground truth (target)')
ax2.imshow(sample2[1])
ax3 = fig.add_subplot(2,2,3)
plt.title('OVERFIT_NET prediction (for image it has not seen)')
ax3.text(10, 25, 'mIoU = {:_>8.6f}'.format(conf_O['miou']), fontsize=20, color='white')
ax3.imshow(colorize_mask(torch.argmax(sample_output_O, dim=1).cpu().numpy()[0]))
ax4 = fig.add_subplot(2,2,4)
plt.title('TRAINED_NET prediction (for image it has not seen)')
ax4.text(10, 25, 'mIoU = {:_>8.6f}'.format(conf_T['miou']), fontsize=20, color='white')
ax4.imshow(colorize_mask(torch.argmax(sample_output_T, dim=1).cpu().numpy()[0]))
# Out:
# max: 20
# max: 17
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:168: RuntimeWarning: invalid value encountered in true_divide
#   class_accuracy = np.diag(confusion) / np.sum(confusion, axis=1)
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:91: RuntimeWarning: invalid value encountered in true_divide
#   iou = np.diag(confusion) / iou_denominator

# %%
some_img = VOCSegmentation(DATASET_PATH, image_set='train', download = False)[500]

sample_img, sample_target = JointNormalize(*norm)(*JointToTensor()(*some_img))
if USE_GPU:
    sample_img = sample_img.cuda()
sample_output_O = overfit_net.forward(sample_img[None])
sample_output_T = trained_net.forward(sample_img[None])

# computing mIOU (quantitative measure of accuracy for network predictions)
pred_O = torch.argmax(sample_output_O, dim=1).cpu().numpy()[0]
pred_T = torch.argmax(sample_output_T, dim=1).cpu().numpy()[0]
gts = torch.from_numpy(np.array(some_img[1].convert('P'), dtype=np.int32)).long().numpy()
gts[gts == 255] = -1
conf_O = eval_semantic_segmentation(pred_O[None], gts[None])
conf_T = eval_semantic_segmentation(pred_T[None], gts[None])


fig = plt.figure(figsize=(14,10))
ax1 = fig.add_subplot(2,2,1)
plt.title('image sample')
ax1.imshow(some_img[0])
ax2 = fig.add_subplot(2,2,2)
plt.title('ground truth (target)')
ax2.imshow(some_img[1])
ax3 = fig.add_subplot(2,2,3)
plt.title('OVERFIT_NET prediction (for image it has not seen)')
ax3.text(10, 25, 'mIoU = {:_>8.6f}'.format(conf_O['miou']), fontsize=20, color='white')
ax3.imshow(colorize_mask(torch.argmax(sample_output_O, dim=1).cpu().numpy()[0]))
ax4 = fig.add_subplot(2,2,4)
plt.title('TRAINED_NET prediction (for image it has not seen)')
ax4.text(10, 25, 'mIoU = {:_>8.6f}'.format(conf_T['miou']), fontsize=20, color='white')
ax4.imshow(colorize_mask(torch.argmax(sample_output_T, dim=1).cpu().numpy()[0]))
# Out:
# VOC Root: drive/My Drive/cs484/dataset
# max: 20
# max: 15
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:91: RuntimeWarning: invalid value encountered in true_divide
#   iou = np.diag(confusion) / iou_denominator
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:168: RuntimeWarning: invalid value encountered in true_divide
#   class_accuracy = np.diag(confusion) / np.sum(confusion, axis=1)

# %% [markdown]
# #### (h) Evaluate TRAINED_NET on validation dataset.
# ##### Run the validation loop for TRAINED_NET against the validation dataset (it has not seen):

# %%
# %%time
# This will be slow on CPU (around 1 hour). On GPU it should take only a few minutes (depending on your GPU).
print("mIoU for TRAINED_NET over the validation dataset:{}".format(validate(val_loader, trained_net)[1]))

# %%
# !pip install torchviz
# from torchviz import make_dot
# output = trained_net(JointToTensor()(*sample1)[0].unsqueeze(0))
# make_dot()

# %% [markdown]
# # Problem 6
#
# #### For the network that you implemented, write a paragraph or two about limitations / bottlenecks about the work. What could be improved? What seems to be some obvious issues with the existing works?
