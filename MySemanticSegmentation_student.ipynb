# %% [markdown]
# <a href="https://colab.research.google.com/github/ArjunNarayan2066/Test/blob/master/MySemanticSegmentation_student.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from os.path import exists
if (exists('images') == False):
    print('Copying Images')
    # !cp -r "drive/My Drive/cs484/images/" .
if (exists('lib') == False):
    print('Copying Lib')
    # !cp -r "drive/My Drive/cs484/lib/" .

# %% [markdown]
# ### CS 484/684 Computational Vision
# #### credits: many thanks for the design of this assignemnt go to <a href="https://tovacinni.github.io/" target = "_blank">Towaki Takikawa</a>
#
# # Homework Assignment #5 - Supervised Deep Learning for Segmentation
#
# This assignment will test your understanding of applying deep learning by having you apply (fully supervised) deep learning to semantic segmentation, a well studied problem in computer vision.
#
# You can get most of the work done using only CPU, however, the use of GPU will be helpful in later parts. Programming and debugging everything upto and including problem 5c should be fine on CPU. You will notice the benefit of GPU mostly in later parts (d-h) of problem 5, but they are mainly implemenmted and test your code written and debugged earlier. If you do not have a GPU readily accesible to you, we recommend that you use Google Colaboratory to get access to a GPU. Once you are satisfied with your code upto and including 5(c), simply upload this Jupyter Notebook to Google Colaboratory to run the tests in later parts of Problem 5.
#
# Proficiency with PyTorch is required. Working through the PyTorch tutorials will make this assignment significantly easier. https://pytorch.org/tutorials/

# %%
# %matplotlib inline

# It is best to start with USE_GPU = False (implying CPU). Switch USE_GPU to True only if you want to use GPU. However... 
# we strongly recommend to wait until you are absolutely sure your CPU-based code works (at least on single image dataset)
USE_GPU = True

# %%
# Python Libraries
import random
import math
import numbers
import platform
import copy
from IPython.core.debugger import set_trace

# Importing essential libraries for basic image manipulations.
import numpy as np
import PIL
from PIL import Image, ImageOps
import matplotlib.pyplot as plt
from tqdm import tqdm

# We import some of the main PyTorch and TorchVision libraries used for HW4.
# Detailed installation instructions are here: https://pytorch.org/get-started/locally/
# That web site should help you to select the right 'conda install' command to be run in 'Anaconda Prompt'.
# In particular, select the right version of CUDA. Note that prior to installing PyTorch, you should  
# install the latest driver for your GPU and CUDA (9.2 or 10.1), assuming your GPU supports it. 
# For more information about pytorch refer to 
# https://pytorch.org/docs/stable/nn.functional.html
# https://pytorch.org/docs/stable/data.html.
# and https://pytorch.org/docs/stable/torchvision/transforms.html
import torch
import torch.nn.functional as F
from torch import nn
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
import torchvision.transforms.functional as tF
import torch.optim as optim

# !export CUDA_LAUNCH_BLOCKING=1
print(torch.cuda.is_available())
print(torch.cuda.get_device_name())

# Note class labels used in Pascal dataset:
# 0:    background,
# 1-20: aeroplane, bicycle, bird, boat, bottle, bus, car, cat, chair, cow, diningtable, dog, horse, motorbike,
#       person, pottedplant, sheep, sofa, train, TV_monitor
# 255: "void", which means class for pixel is undefined
# Out:
# True
# Tesla P100-PCIE-16GB

# %%
# !pip install chainercv # Need to manualy install this in the colab environment

# ChainerCV is a library similar to TorchVision, created and maintained by Preferred Networks. 
# Chainer, the base library, inspired and led to the creation of PyTorch! 
# Although Chainer and PyTorch are different, there are some nice functionalities in ChainerCV 
# that are useful, so we include it as an excersice on learning other libraries.
# To install ChainerCV, normally it suffices to run "pip install chainercv" inside "Anaconda Prompt".
# For more detailed installation instructions, see https://chainercv.readthedocs.io/en/stable/install.html
# For other information about ChainerCV library, refer to https://chainercv.readthedocs.io/en/stable/ 
from chainercv.evaluations import eval_semantic_segmentation
from chainercv.datasets import VOCSemanticSegmentationDataset
# Out:
# Requirement already satisfied: chainercv in /usr/local/lib/python3.6/dist-packages (0.13.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (from chainercv) (7.0.0)
# Requirement already satisfied: chainer>=6.0 in /usr/local/lib/python3.6/dist-packages (from chainercv) (7.4.0)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from chainer>=6.0->chainercv) (1.18.5)
# Requirement already satisfied: protobuf>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from chainer>=6.0->chainercv) (3.12.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from chainer>=6.0->chainercv) (3.7.4.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from chainer>=6.0->chainercv) (50.3.2)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from chainer>=6.0->chainercv) (1.15.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/dist-packages (from chainer>=6.0->chainercv) (3.0.12)

# %%
# This colorize_mask class takes in a numpy segmentation mask,
#  and then converts it to a PIL Image for visualization.
#  Since by default the numpy matrix contains integers from
#  0,1,...,num_classes, we need to apply some color to this
#  so we can visualize easier! Refer to:
#  https://pillow.readthedocs.io/en/4.1.x/reference/Image.html#PIL.Image.Image.putpalette
palette = [0, 0, 0, 128, 0, 0, 0, 128, 0, 128, 128, 0, 0, 0, 128, 128, 0, 128, 0, 128, 128,
           128, 128, 128, 64, 0, 0, 192, 0, 0, 64, 128, 0, 192, 128, 0, 64, 0, 128, 192, 0, 128,
           64, 128, 128, 192, 128, 128, 0, 64, 0, 128, 64, 0, 0, 192, 0, 128, 192, 0, 0, 64, 128]

def colorize_mask(mask):
    new_mask = Image.fromarray(mask.astype(np.uint8)).convert('P')
    new_mask.putpalette(palette)

    return new_mask

# %%
# Below we will use a sample image-target pair from VOC training dataset to test your joint transforms. 
# Running this block will automatically download the PASCAL VOC Dataset (3.7GB) to DATASET_PATH if "download = True".
# The code below creates subdirectory "datasets" in the same location as the notebook file, but
# you can modify DATASET_PATH to download the dataset to any custom directory. Download takes a few minutes.
# On subsequent runs you may save time by setting "download = False" (the default value of this flag)

# We provide our own implementation of torchvision.datasets.voc (containing popular "Pascal" dataset)
# that allows us to easily create single-image datasets
from lib.voc import VOCSegmentation
DATASET_PATH = 'drive/My Drive/cs484/dataset'

# Here, we obtain and visualize one sample (img, target) pair from VOC training dataset and one from validation dataset. 
# Note that operator [...] extracts the sample corresponding to the specified index. 
# Also, note the parameter download = True. Set this to False after you download to save time on later runs.
sample1 = VOCSegmentation(DATASET_PATH, image_set='train', download = False)[200]
sample2 = VOCSegmentation(DATASET_PATH, image_set='val')[20]

# We demonstrate two different (equivalent) ways to access image and target inside the samples.
img1, target1 = sample1
img2 = sample2[0]
target2 = sample2[1]

fig = plt.figure(figsize=(14,10))
ax1 = fig.add_subplot(2,2,1)
plt.title('sample1 - image')
ax1.imshow(img1)
ax2 = fig.add_subplot(2,2,2)
plt.title('sample1 - target')
ax2.imshow(target1)
ax3 = fig.add_subplot(2,2,3)
plt.title('sample2 - image')
ax3.imshow(img2)
ax4 = fig.add_subplot(2,2,4)
plt.title('sample2 - target')
ax4.imshow(target2)
# Out:
# VOC Root: drive/My Drive/cs484/dataset
# VOC Root: drive/My Drive/cs484/dataset

# %%
some_img = VOCSegmentation(DATASET_PATH, image_set='train', download = False)[300]
fig = plt.figure(figsize=(14,10))
ax1 = fig.add_subplot(1,2,1)
plt.title('sample1 - image')
ax1.imshow(some_img[0])
ax2 = fig.add_subplot(1,2,2)
plt.title('sample1 - target')
ax2.imshow(some_img[1])
# Out:
# VOC Root: drive/My Drive/cs484/dataset

# %% [markdown]
# # Problem 1
#
# #### Implement a set of "Joint Transform" functions to perform data augmentation in your dataset.
#
# Neural networks are typically applied to transformed images. There are several important reasons for this:
#
# 1. The image data should is in certain required format (i.e. consistent spacial resolution to batch). The images should also be normalized and converted to the "tensor" data format expected by pytorch libraries.
#
# 2. Some transforms are used to perform randomized image domain transformations with the purpose of "data augmentation".
#
# In this exercise, you will implement a set of different transform functions to do both of these things. Note that unlike classification nets, training semantic segmentation networks requires that some of the transforms are applied to both image and the corresponding "target" (Ground Truth segmentation mask). We refer to such transforms and their compositions as "Joint". In general, your Transform classes should take as the input both the image and the target, and return a tuple of the transformed input image and target. Be sure to use critical thinking to determine if you can apply the same transform function to both the input and the output.
#
# For this problem you may use any of the `torchvision.transforms.functional` functions. For inspiration, refer to:
# #### https://pytorch.org/tutorials/beginner/data_loading_tutorial.html
# #### https://pytorch.org/docs/stable/torchvision/transforms.html#module-torchvision.transforms.functional

# %% [markdown]
# #### Example 1
#
# This class takes a img, target pair, and then transform the pair such that they are in `Torch.Tensor()` format.
#
# #### Solution:

# %%
class JointToTensor(object):
    def __call__(self, img, target):
        # print(target.max())
        return tF.to_tensor(img), torch.from_numpy(np.array(target.convert('P'), dtype=np.int32)).long()

# %%
# Check the transform by passing the image-target sample.

img, target = JointToTensor()(*sample2)
print(target[target!=255].max())
fig = plt.figure(figsize=(12,6))
ax1 = fig.add_subplot(2,2,1)
ax1.imshow(img.permute(1,2,0))
ax2 = fig.add_subplot(2,2,2)
ax2.imshow(colorize_mask(target.numpy()))
# Out:
# tensor(17)

# %% [markdown]
# #### Example 2:
#
# This class implements CenterCrop that takes an img, target pair, and then apply a crop about the center of the image such that the output resolution is $\mbox{size} \times \mbox{size}$.
#
# #### Solution:

# %%
class JointCenterCrop(object):
    def __init__(self, size):
        """
        params:
            size (int) : size of the center crop
        """
        self.size = size
        
    def __call__(self, img, target):
        return (tF.five_crop(img, self.size)[4], 
                tF.five_crop(target, self.size)[4])
    
img, target = JointCenterCrop(100)(*sample1)
fig = plt.figure(figsize=(12,6))
ax1 = fig.add_subplot(2,2,1)
ax1.imshow(img)
ax2 = fig.add_subplot(2,2,2)
ax2.imshow(target)

# %% [markdown]
# #### (a) Implement RandomFlip
#
# This class should take a img, target pair and then apply a horizontal flip across the vertical axis at random.
#
# #### Solution:

# %%
class JointRandomFlip(object): 
    def __call__(self, img, target):
        if not isinstance(img, torch.Tensor):
            img, target = JointToTensor()(img, target)

        if np.random.randint(2):
            return (tF.hflip(img), tF.hflip(target))
        else:
            return (img, target)

# %%
img, target = JointRandomFlip()(*sample2)
print(target[target!=255].max())
fig = plt.figure(figsize=(12,6))
ax1 = fig.add_subplot(2,2,1)
ax1.imshow(img.permute(1,2,0))
ax2 = fig.add_subplot(2,2,2)
ax2.imshow(colorize_mask(target.numpy()))
# Out:
# tensor(17)

# %% [markdown]
# #### (b) Implement RandomResizeCrop
#
# This class should take a img, target pair and then resize the images by a random scale between $[\mbox{minimum_scale}, \mbox{maximum_scale}]$, crop a random location of the image by $\min(\mbox{size}, \mbox{image_height}, \mbox{image_width})$ (where the size is passed in as an integer in the constructor), and then resize to $\mbox{size} \times \mbox{size}$ (again, the size passed in). The crop box should fit within the image.
#
# #### Solution:

# %%
class JointRandomResizeCrop(object):
    def __init__(self, min_scale, max_scale, size):
        self.min_scale = min_scale
        self.max_scale = max_scale
        self.size = size

        self.scale_len = self.max_scale - self.min_scale

    def __call__(self, img, target):
        if not isinstance(img, PIL.Image.Image):
            target = transforms.ToPILImage()(target.type(torch.IntTensor))
            img = transforms.ToPILImage()(img)

        # Select Random Resize Scale
        scale = (np.random.rand() * (self.scale_len)) + self.min_scale
        rescaled_size = (int(img.size[0]*scale), int(img.size[1]*scale))
        print(rescaled_size[::-1])
        rescaled_img = tF.resize(img, rescaled_size[::-1])
        rescaled_target = tF.resize(target, rescaled_size[::-1], interpolation=PIL.Image.NEAREST)

        # Crop Then Resize
        crop_size = min((self.size, rescaled_img.size[0]-1, rescaled_img.size[1]-1))
        crop_c = np.random.randint(0, rescaled_img.size[0] - crop_size)
        crop_r = np.random.randint(0, rescaled_img.size[1] - crop_size)

        final_img = tF.resized_crop(rescaled_img, crop_r, crop_c, crop_size, crop_size, self.size)
        final_target= tF.resized_crop(rescaled_target, crop_r, crop_c, crop_size, crop_size, self.size)

        final_img, final_target = JointToTensor()(final_img, final_target)
        return final_img, final_target.type(torch.LongTensor)

# %%
# print(sample1[0].size)
final_img, final_target = JointRandomResizeCrop(1.1, 1.4, 400)(*JointToTensor()(*sample2))
print(final_target[final_target!=255].max())
# print(final_img.size)
fig = plt.figure(figsize=(12,6))
ax1 = fig.add_subplot(2,2,1)
# ax1.imshow(colorize_mask(target.numpy()))
ax1.imshow(final_img.permute(1,2,0))
ax2 = fig.add_subplot(2,2,2)
ax2.imshow(colorize_mask(final_target.numpy()))
# Out:
# (472, 629)
# tensor(17)

# %% [markdown]
# #### (c) Implement Normalize

# %% [markdown]
# This class should take a img, target pair and then normalize the images by subtracting the mean and dividing variance.
#
# #### Solution:

# %%
class JointResize(object):
    def __init__(self, size):
        self.size = size
    
    def __call__(self, img, target):
        if not isinstance(img, torch.Tensor):
            img, target = JointToTensor()(img, target)

        # print(img[None].shape)
        img = tF.resize(img[None], self.size)[0]#self.size)
        target = tF.resize(target[None], self.size, interpolation=PIL.Image.NEAREST)[0]
        # print(img.shape)

        return img, target

# %%
norm = ([0.485, 0.456, 0.406], 
        [0.229, 0.224, 0.225]) 
# means = [0.485, 0.456, 0.406]
# std = [0.229, 0.224, 0.225] 

class JointNormalize(object): 
    def __init__(self, mean, std):
        self.mean = mean
        self.std = std
          
    def __call__(self, img, target):
        if not isinstance(img, torch.Tensor):
            img, target = JointToTensor()(img, target)
        # target = target.double()
        # img_means = [img[:,:,0].mean(), img[:,:,1].mean(), img[:,:,2].mean()]
        # img_std = [img[:,:,0].std(), img[:,:,1].std(), img[:,:,2].img_std()]
        # target_means = [target[:,:,0].mean(), target[:,:,1].mean(), target[:,:,2].mean()]
        # target_std = [target[:,:,0].std(), target[:,:,1].std(), target[:,:,2].std()]

        # Normalize
        norm_img = tF.normalize(img, self.mean, self.std)
        # Rescale to 0-1
        norm_img -= norm_img.min()
        norm_img /= norm_img.max()

        # norm_target = tF.normalize(target, target.mean(), target.std())
        # norm_target = ((target - target.mean()) / target.std()).long()
        # print(norm_target)

        return norm_img, target

# %%
# fixed_img, fixed_target = JointNormalize(*norm)(*sample1)
fixed_img, fixed_target = JointResize((375,500))(*sample2)
print(fixed_target[fixed_target!=255].max())
fig = plt.figure(figsize=(12,6))
ax1 = fig.add_subplot(2,2,1)
ax1.imshow(fixed_img.permute(1,2,0))
ax2 = fig.add_subplot(2,2,2)
ax2.imshow(colorize_mask(fixed_target.numpy()))
# Out:
# tensor(17)

# %% [markdown]
# #### (d) Compose the transforms together:
# ##### Use `JointCompose` (fully implemeted below) to compose the implemented transforms together in some random order. Verify the output makes sense and visualize it.

# %%
# This class composes transofrmations from a given list of image transforms (expected in the argument). Such compositions 
# will be applied to the dataset during training. This cell is fully implemented.

class JointCompose(object):
    def __init__(self, transforms):
        """
        params: 
           transforms (list) : list of transforms
        """
        self.transforms = transforms

    # We override the __call__ function such that this class can be
    # called as a function i.e. JointCompose(transforms)(img, target)
    # Such classes are known as "functors"
    def __call__(self, img, target):
        """
        params:
            img (PIL.Image)    : input image
            target (PIL.Image) : ground truth label 
        """
        assert img.size == target.size
        for t in self.transforms:
            img, target = t(img, target)
        return img, target

# %%
# Student Answer:
tfs = [JointToTensor(), JointRandomResizeCrop(0.5, 0.8, 100), JointRandomFlip()]

img, target = JointCompose(tfs)(*sample1)
print(img.size)
fig = plt.figure(figsize=(12,6))
ax1 = fig.add_subplot(2,2,1)
ax1.imshow(img.permute(1,2,0))
ax2 = fig.add_subplot(2,2,2)
ax2.imshow(colorize_mask(target.numpy()))
# Out:
# (207, 276)
# <built-in method size of Tensor object at 0x7f52f71a9ee8>

# %% [markdown]
# #### (e) Compose the transforms together: use `JointCompose` to compose the implemented transforms for:
# #### 1. A sanity dataset that will contain 1 single image. Your objective is to overfit on this 1 image, so choose your transforms and parameters accordingly.
# #### 2. A training dataset that will contain the training images. The goal here is to generalize to the validation set, which is unseen.
# #### 3. A validation dataset that will contain the validation images. The goal here is to measure the 'true' performance.

# %%
# Student Answer:

sanity_joint_transform  = JointCompose([JointToTensor(), JointResize((375,500)), JointNormalize(*norm)])

train_joint_transform   = JointCompose([JointToTensor(), JointResize((375,500)), JointNormalize(*norm)])#, JointRandomFlip()])

val_joint_transform     = JointCompose([JointToTensor(), JointResize((375,500))])#, JointRandomFlip()])#, JointRandomResizeCrop(0.5, 1.5, 300)])

# %% [markdown]
# This code below will then apply `train_joint_transform` to the entire dataset.

# %%
# Apply the Joint-Compose transformations above to create three datasets and the corresponding Data-Loaders.
# This cell is fully implemented.

# This single image data(sub)set can help to better understand and to debug the network training process. 
# Optional integer parameter 'sanity_check' specifies the index of the image-target pair and creates a single image dataset.
# Note that we use the same image (index=200) as used for sample1.
sanity_data = VOCSegmentation(
    DATASET_PATH, 
    image_set = 'train',
    transforms = sanity_joint_transform,
    sanity_check = 200
)

# This is a standard VOC data(sub)set used for training semantic segmentation networks
train_data = VOCSegmentation(
    DATASET_PATH, 
    image_set = 'train', 
    transforms = sanity_joint_transform,
    # sanity_check=300,
)

# This is a standard VOC data(sub)set used for validating semantic segmentation networks
val_data = VOCSegmentation(
    DATASET_PATH, 
    image_set='val',
    transforms = val_joint_transform
)

# Increase TRAIN_BATCH_SIZE if you are using GPU to speed up training. 
# When batch size changes, the learning rate may also need to be adjusted. 
# Note that batch size maybe limited by your GPU memory, so adjust if you get "run out of GPU memory" error.
TRAIN_BATCH_SIZE = 1 # 4 default

# If you are NOT using Windows, set NUM_WORKERS to anything you want, e.g. NUM_WORKERS = 4,
# but Windows has issues with multi-process dataloaders, so NUM_WORKERS must be 0 for Windows.
NUM_WORKERS =  0# default

sanity_loader = DataLoader(sanity_data, batch_size=1, num_workers=NUM_WORKERS, shuffle=False)
train_loader = DataLoader(train_data, batch_size=4, num_workers=NUM_WORKERS, shuffle=False)
val_loader = DataLoader(val_data, batch_size=1, num_workers=NUM_WORKERS, shuffle=False)
# Out:
# VOC Root: drive/My Drive/cs484/dataset
# VOC Root: drive/My Drive/cs484/dataset
# VOC Root: drive/My Drive/cs484/dataset

# %% [markdown]
# # Problem 2
#
# #### (a) Implement encoder/decoder segmentation CNN using PyTorch.
#
# You must follow the general network architecture specified in the image below. Note that since convolutional layers are the main building blocks in common network architectures for image analysis, the corresponding blocks are typically unlabeled in the network diagrams. The network should have 5 (pre-trained) convolutional layers (residual blocks) from "resnet" in the encoder part, two upsampling layers, and one skip connection. For the layer before the final upsampling layer, lightly experiment with some combination of Conv, ReLU, BatchNorm, and/or other layers to see how it affects performance.
# <img src="images\deeplabv2_overview.png">
# You should choose specific parameters for all layers, but the overall structure should be restricted to what is shown in the illustration above. For inspiration, you can refer to papers in the citation section of the following link to DeepLab (e.g. specific parameters for each layer): http://liangchiehchen.com/projects/DeepLab.html. The first two papers in the citation section are particularly relevant.
#
# In your implementation, you can use a base model of choice (you can use `torchvision.models` as a starting point), but we suggest that you learn the properties of each base model and choose one according to the computational resources available to you.
#
# ##### Note: do not apply any post-processing (such as DenseCRF) to the output of your net.
#
# #### Solution:

# %%
import torchvision.models as models

class MyNet(nn.Module):
    def __init__(self, num_classes, img_size, criterion=None):
        super(MyNet, self).__init__()
        # Implement me

        # Get initial few layers + 6 res blocks in packs of 2
        self.encoder1 = nn.Sequential(*list(models.resnet18(pretrained=True).children())[:5])
        self.encoder2 = nn.Sequential(*list(models.resnet18(pretrained=True).children())[5:7])

        self.up1 = nn.ConvTranspose2d(256, 256, kernel_size=(6,5), stride=(4,4), dilation=(1,1), padding=(2,2))
        self.relu = nn.ReLU()

        self.conv1 = nn.Conv2d(320,256,kernel_size=3,stride=2,dilation=2)
        self.conv2 = nn.Conv2d(256,128,kernel_size=3,stride=2,dilation=2)
        self.up2 = nn.ConvTranspose2d(128, 64, kernel_size=3,stride=2,dilation=2)
        self.bn1 = nn.BatchNorm2d(128)
        self.bn2 = nn.BatchNorm2d(64)

        self.conv3 = nn.Conv2d(64,num_classes, kernel_size=4,stride=2,dilation=2)
        self.final_up = nn.Upsample(size=img_size, mode='bilinear', align_corners=True)

        # self.sf = nn.Softmax(dim=1)

    def forward(self, inp, gts=None):

        # Assuming using GPU on colab

        ## Encoder
        x = self.encoder1(inp) # batch x 64 x 94 x 125
        skip = x
        x = self.encoder2(x) # batch x 256 x 24 x 32

        ## Decoder Step 1
        x = self.up1(x) # batch x 256 x 94 x 125

        # Skip Connection
        x = torch.cat((x, skip), dim=1) # batch x 320 x 94 x 125
        x = self.relu(self.conv1(x)) # batch x 256 x 91 x 122
        x = self.relu(self.conv2(x)) # batch x 128 x 88 x 119
        x = self.bn1(x)
        # print(x.size())

        ## Decoder Step 2
        x = self.up2(x) # Transpose conv, 64 channels now
        # print(x.size())

        x = self.bn2(x)
        x = self.conv3(x) # 21 channels

        ## Final Decoder Step
        lfinal = self.final_up(x) # batch x 21 x 375 x 500

        # lfinal = self.sf(x) # softmax, batch x 21 x 375 x 500

        test_val = torch.argmax(lfinal, dim=1)[0].cpu().numpy()
        print("max: {}".format(test_val.max()))

        # if self.training:
        #     # Return the loss if in training mode
        #     return self.criterion(lfinal, gts)              
        # else:
        #     # Return the actual prediction otherwise
        return lfinal

# %%
import torchvision.models as models

class MyOldNet(nn.Module):
    def __init__(self, num_classes, img_size, criterion=None):
        super(MyNet, self).__init__()
        # Implement me

        # Get initial few layers + 6 res blocks in packs of 2
        self.encoder1 = nn.Sequential(*list(models.resnet18(pretrained=True).children())[:5])
        self.encoder2 = nn.Sequential(*list(models.resnet18(pretrained=True).children())[5:7])

        self.up1 = nn.Upsample(size=(94, 125), mode='bilinear')
        self.relu = nn.ReLU()
        self.conv1 = nn.Conv2d(320,128,kernel_size=4)
        # self.bn1 = nn.BatchNorm2d(128)

        self.conv2 = nn.Conv2d(128,num_classes, kernel_size=4)
        self.final_up = nn.Upsample(size=img_size, mode='bilinear', align_corners=True)

        self.sf = nn.Softmax(dim=1)

    def forward(self, inp, gts=None):

        # Assuming using GPU on colab

        x = self.encoder1(inp) # batch x 64 x 94 x 125
        skip = x
        x = self.encoder2(x) # batch x 256 x 24 x 32

        x = self.relu(self.up1(x)) # batch x 256 x 94 x 125

        # Skip Connection
        x = torch.cat((x, skip), dim=1) # batch x 320 x 94 x 125

        x = self.relu(self.conv1(x)) # batch x 128 x 91 x 122

        x = self.relu(self.conv2(x)) # batch x 128 x 88 x 119

        x = self.relu(self.final_up(x)) # batch x 21 x 375 x 500

        lfinal = self.sf(x) # softmax, batch x 21 x 375 x 500

        test_val = torch.argmax(lfinal, dim=1)[0].cpu().numpy()
        print("max: {}".format(test_val.max()))

        # if self.training:
        #     # Return the loss if in training mode
        #     return self.criterion(lfinal, gts)              
        # else:
        #     # Return the actual prediction otherwise
        return lfinal

# %%
list(models.resnet18(pretrained=True).children())[:5]
# Out:
# [Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False),
#  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
#  ReLU(inplace=True),
#  MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False),
#  Sequential(
#    (0): BasicBlock(
#      (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#      (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      (relu): ReLU(inplace=True)
#      (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#      (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#    )
#    (1): BasicBlock(
#      (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#      (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      (relu): ReLU(inplace=True)
#      (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#      (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#    )
#  )]

# %% [markdown]
# #### (b) Create UNTRAINED_NET and run on a sample image

# %%
print(torch.cuda.get_device_name())

untrained_net = MyNet(21, (375,500)).eval()
sample_img, sample_target = JointNormalize(*norm)(*JointToTensor()(*sample1))
# sample_img, sample_target = JointCenterCrop(224)(sample_img, sample_target)
# print(sample_img[None].size())
untrained_output = untrained_net.forward(sample_img[None])

# Convert to 375 x 500 image of int classes
sample_output = torch.argmax(untrained_output, dim=1).numpy()

fig = plt.figure(figsize=(14,10))
ax = fig.add_subplot(1,3,1)
plt.title('image sample')
ax.imshow(sample1[0])
ax = fig.add_subplot(1,3,2)
plt.title('ground truth (target)')
ax.imshow(sample1[1])
ax = fig.add_subplot(1,3,3)
plt.title('UNTRAINED_NET output/prediction')
# print(untrained_output.size())
ax.imshow(colorize_mask(sample_output[0]))
# ax.imshow(colorize_mask(untrained_output.numpy()[0]))
# Out:
# Tesla P100-PCIE-16GB
# max: 18

# %% [markdown]
# # Problem 3
#
# #### (a) Implement the loss function (Cross Entropy Loss). Do not use already implemented versions of this loss function.
#
# Feel free to use functions like `F.log_softmax` and `F.nll_loss` (if you want to, or you can just implement the math).

# %%
# Student Answer:

# class MyCrossEntropyLoss(...):

# %% [markdown]
# #### (b) Compare against the existing CrossEntropyLoss function on your sample output from your neural network.

# %%
criterion = nn.CrossEntropyLoss(ignore_index=255)
print(criterion)
print(sample_target[None].size())
print(untrained_output[0].size())
print(sample_target.size())
print(criterion(untrained_output, sample_target[None]))

# my_criterion = MyCrossEntropyLoss(ignore_index=255)

# print(my_criterion(untrained_output, sample_target[None]))
# Out:
# CrossEntropyLoss()
# torch.Size([1, 375, 500])
# torch.Size([21, 375, 500])
# torch.Size([375, 500])
# tensor(3.0334, grad_fn=<NllLoss2DBackward>)

# %% [markdown]
# # Problem 4
#
# #### (a) Use standard function `eval_semantic_segmentation` (already imported from chainerCV) to compute "mean intersection over union" for the output of UNTRAINED_NET on sample1 (`untrained_output`) using the target for sample1. Read documentations for function  `eval_semantic_segmentation` to properly set its input parameters.

# %%
# Write code to propely compute 'pred' and 'gts' as arguments for function 'eval_semantic_segemntation'

np_target = sample_target.numpy().astype(np.int32)
np_target[np_target==255] = -1
initial_gts = np.array([np_target])

initial_pred = sample_output
print(initial_pred.shape)
initial_conf = eval_semantic_segmentation(initial_pred, initial_gts)

print("mIoU for the sample image / ground truth pair: {}".format(initial_conf['miou']))
# Out:
# (1, 375, 500)
# mIoU for the sample image / ground truth pair: 0.0
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:91: RuntimeWarning: invalid value encountered in true_divide
#   iou = np.diag(confusion) / iou_denominator
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:168: RuntimeWarning: invalid value encountered in true_divide
#   class_accuracy = np.diag(confusion) / np.sum(confusion, axis=1)

# %% [markdown]
# #### (b) Write the validation loop.

# %%
def validate(val_data_loader, net):
    iou_arr = []
    val_loss = []

    if USE_GPU:
        net = net.cuda()
    
    with torch.no_grad():
        for i, data in enumerate(val_data_loader):
            print("Tick: {}".format(i))
            inputs, masks = data

            print("shape: {}".format(masks.shape))

            if USE_GPU:
                masks = masks.cuda()
                inputs = inputs.cuda()

            outputs = net(inputs)

            np_target = masks[0].cpu().numpy().astype(np.int32)
            np_target[np_target == 255] = -1

            gts = np.array([np_target])
            preds = torch.argmax(outputs, dim=1).cpu().numpy()

            val_loss.append(criterion(outputs, masks))
            # Write menearest

            # Hint: make sure the range of values of the ground truth is what you expect
            print(gts.shape)
            print(preds.shape)
            conf = eval_semantic_segmentation(preds, gts)

            iou_arr.append(conf['miou'])
    
    print(iou_arr)
    return val_loss, (sum(iou_arr) / len(iou_arr))

# %% [markdown]
# #### (c) Run the validation loop for UNTRAINED_NET against the sanity validation dataset.

# %%
# %%time
print("mIoU over the sanity dataset:{}".format(validate(sanity_loader, untrained_net)[1]))
# Out:
# Tick: 0
# shape: torch.Size([1, 375, 500])
# max: 18
# (1, 375, 500)
# (1, 375, 500)
# [0.0]
# mIoU over the sanity dataset:0.0
# CPU times: user 35.1 ms, sys: 5.09 ms, total: 40.2 ms
# Wall time: 48.1 ms
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:91: RuntimeWarning: invalid value encountered in true_divide
#   iou = np.diag(confusion) / iou_denominator
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:168: RuntimeWarning: invalid value encountered in true_divide
#   class_accuracy = np.diag(confusion) / np.sum(confusion, axis=1)

# %% [markdown]
# # Problem 5
#
# #### (a) Define an optimizer to train the given loss function.
#
# Feel free to choose your optimizer of choice from https://pytorch.org/docs/stable/optim.html.

# %%
def get_optimizer(net):
    optimizer = optim.Adam(net.parameters(), lr=1e-4)
    return optimizer

# %% [markdown]
# #### (b) Write the training loop to train the network.

# %%
import time

def train(train_data_loader, net, optimizer, loss_graph):
    for i, data in enumerate(train_data_loader):
        inputs, masks = data
    
        if USE_GPU:
            net = net.cuda()
            inputs = inputs.cuda()
            masks = masks.cuda()

        # print("mask max:{}".format(masks[masks!=255].max()))
        
        # Write me
        outputs = net(inputs)
        # print(net.criterion)
        loss = net.criterion(outputs, masks)
        print("Training: On Tick: {} loss {}".format(i, loss))
        #  = criterion(outputs, labels)
        loss_graph.append(loss)

        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

        # loss_graph.append() Populate this list to graph the loss
    
    # print("All Loses: {}".format(loss_graph))
    return (sum(loss_graph) / len(loss_graph))

# %% [markdown]
# #### (c) Create OVERFIT_NET and train it on the single image dataset.
# ##### Single image training is helpful for debugging and hyper-parameter tuning (e.g. learning rate, etc.) as it is fast even on a single CPU. In particular, you can work with a single image until your loss function is consistently decreasing during training loop and the network starts producing a reasonable output for this training image. Training on a single image also teaches about overfitting, particualrly when comparing it with more thorough forms of network training.

# %%
# %%time
# %matplotlib notebook
import time

# The whole training on a single image (20-40 epochs) should take only a minute or two on a CPU (and a few seconds on GPU). 
# Below we create a (deep) copy of untrained_net and train it on a single training image (leading to gross overfitting).
# Later, we will create a separate (deep) copy of untrained_net to be trained on full training dataset.
# NOTE: Normally, one can create a new net via declaration new_net = MyNet(21). But, randomization of weights when new nets 
# are declared that way creates *different* untrained nets. This notebook compares different versions of network training. 
# For this comparison to be direct and fair, it is better to train (deep) copies of the exact same untrained_net. 
overfit_net = copy.deepcopy(untrained_net)

# set loss function for the net
overfit_net.criterion = nn.CrossEntropyLoss(ignore_index=255)

# You can change the number of EPOCHS
EPOCH = 100

# switch to train mode (original untrained_net was set to eval mode)
overfit_net.train()

optimizer = get_optimizer(overfit_net)

print("Starting Training...")

loss_graph = []

fig = plt.figure(figsize=(12,6))
plt.subplots_adjust(bottom=0.2,right=0.85,top=0.95)
ax = fig.add_subplot(1,1,1)

for e in range(EPOCH):
    loss = train(sanity_loader, overfit_net, optimizer, loss_graph)
    ax.clear()
    ax.set_xlabel('iterations')
    ax.set_ylabel('loss value')
    ax.set_title('Training loss curve for OVERFIT_NET')
    ax.plot(loss_graph, label='training loss')
    ax.legend(loc='upper right')
    fig.canvas.draw()
    print("Epoch: {} Loss: {}".format(e, loss))
print("Final Loss: {}".format(loss))
# %matplotlib inline
plt.show()
# Out:
# Starting Training...
# <div id='63a931d3-7e07-4d3d-bd11-824be8fd2342'></div>
# max: 20
# Training: On Tick: 0 loss 3.45074462890625
# Epoch: 0 Loss: 3.45074462890625
# max: 20
# Training: On Tick: 0 loss 2.5539674758911133
# Epoch: 1 Loss: 3.0023560523986816
# max: 20
# Training: On Tick: 0 loss 1.8876625299453735
# Epoch: 2 Loss: 2.630791664123535
# max: 20
# Training: On Tick: 0 loss 1.3941457271575928
# Epoch: 3 Loss: 2.3216300010681152
# max: 20
# Training: On Tick: 0 loss 1.0359171628952026
# Epoch: 4 Loss: 2.0644874572753906
# max: 20
# Training: On Tick: 0 loss 0.7883416414260864
# Epoch: 5 Loss: 1.8517965078353882
# max: 20
# Training: On Tick: 0 loss 0.6184285879135132
# Epoch: 6 Loss: 1.6756011247634888
# max: 20
# Training: On Tick: 0 loss 0.501652181148529
# Epoch: 7 Loss: 1.5288573503494263
# max: 20
# Training: On Tick: 0 loss 0.4172848165035248
# Epoch: 8 Loss: 1.4053493738174438
# max: 20
# Training: On Tick: 0 loss 0.35327208042144775
# Epoch: 9 Loss: 1.30014169216156
# max: 20
# Training: On Tick: 0 loss 0.30254143476486206
# Epoch: 10 Loss: 1.2094507217407227
# max: 20
# Training: On Tick: 0 loss 0.2615515887737274
# Epoch: 11 Loss: 1.130459189414978
# max: 16
# Training: On Tick: 0 loss 0.227843776345253
# Epoch: 12 Loss: 1.0610272884368896
# max: 16
# Training: On Tick: 0 loss 0.2001386135816574
# Epoch: 13 Loss: 0.9995352625846863
# max: 19
# Training: On Tick: 0 loss 0.17756140232086182
# Epoch: 14 Loss: 0.9447370171546936
# max: 15
# Training: On Tick: 0 loss 0.15877392888069153
# Epoch: 15 Loss: 0.8956143260002136
# max: 15
# Training: On Tick: 0 loss 0.1422470360994339
# Epoch: 16 Loss: 0.8512986302375793
# max: 15
# Training: On Tick: 0 loss 0.12725795805454254
# Epoch: 17 Loss: 0.8110741376876831
# max: 15
# Training: On Tick: 0 loss 0.11332883685827255
# Epoch: 18 Loss: 0.7743507027626038
# max: 15
# Training: On Tick: 0 loss 0.10044793039560318
# Epoch: 19 Loss: 0.7406556010246277
# max: 15
# Training: On Tick: 0 loss 0.08897560089826584
# Epoch: 20 Loss: 0.7096232175827026
# max: 15
# Training: On Tick: 0 loss 0.07905546575784683
# Epoch: 21 Loss: 0.6809610724449158
# max: 15
# Training: On Tick: 0 loss 0.07073237001895905
# Epoch: 22 Loss: 0.6544293761253357
# max: 15
# Training: On Tick: 0 loss 0.06388366222381592
# Epoch: 23 Loss: 0.6298233270645142
# max: 15
# Training: On Tick: 0 loss 0.05830955132842064
# Epoch: 24 Loss: 0.6069627404212952
# max: 15
# Training: On Tick: 0 loss 0.0537969209253788
# Epoch: 25 Loss: 0.5856871604919434
# max: 15
# Training: On Tick: 0 loss 0.050137247890233994
# Epoch: 26 Loss: 0.5658519864082336
# max: 15
# Training: On Tick: 0 loss 0.0471527986228466
# Epoch: 27 Loss: 0.5473269820213318
# max: 15
# Training: On Tick: 0 loss 0.04464506357908249
# Epoch: 28 Loss: 0.5299931168556213
# max: 15
# Training: On Tick: 0 loss 0.04244934022426605
# Epoch: 29 Loss: 0.513741672039032
# max: 15
# Training: On Tick: 0 loss 0.04043132811784744
# Epoch: 30 Loss: 0.49847355484962463
# max: 15
# Training: On Tick: 0 loss 0.03852023556828499
# Epoch: 31 Loss: 0.48410001397132874
# max: 15
# Training: On Tick: 0 loss 0.03670444339513779
# Epoch: 32 Loss: 0.4705425798892975
# max: 15
# Training: On Tick: 0 loss 0.03498811647295952
# Epoch: 33 Loss: 0.4577321410179138
# max: 15
# Training: On Tick: 0 loss 0.03337862715125084
# Epoch: 34 Loss: 0.4456077516078949
# max: 15
# Training: On Tick: 0 loss 0.03189178183674812
# Epoch: 35 Loss: 0.4341156482696533
# max: 15
# Training: On Tick: 0 loss 0.030538275837898254
# Epoch: 36 Loss: 0.42320817708969116
# max: 15
# Training: On Tick: 0 loss 0.02931968681514263
# Epoch: 37 Loss: 0.41284269094467163
# max: 15
# Training: On Tick: 0 loss 0.028237946331501007
# Epoch: 38 Loss: 0.4029810428619385
# max: 15
# Training: On Tick: 0 loss 0.02726566419005394
# Epoch: 39 Loss: 0.3935881555080414
# max: 15
# Training: On Tick: 0 loss 0.026384349912405014
# Epoch: 40 Loss: 0.3846319317817688
# max: 15
# Training: On Tick: 0 loss 0.02557041123509407
# Epoch: 41 Loss: 0.3760828673839569
# max: 15
# Training: On Tick: 0 loss 0.02480323798954487
# Epoch: 42 Loss: 0.3679135739803314
# max: 15
# Training: On Tick: 0 loss 0.024069415405392647
# Epoch: 43 Loss: 0.3600989580154419
# max: 15
# Training: On Tick: 0 loss 0.02336585894227028
# Epoch: 44 Loss: 0.35261601209640503
# max: 15
# Training: On Tick: 0 loss 0.02269463986158371
# Epoch: 45 Loss: 0.3454437851905823
# max: 15
# Training: On Tick: 0 loss 0.022063981741666794
# Epoch: 46 Loss: 0.33856335282325745
# max: 15
# Training: On Tick: 0 loss 0.02148420363664627
# Epoch: 47 Loss: 0.3319575786590576
# max: 15
# Training: On Tick: 0 loss 0.020955529063940048
# Epoch: 48 Loss: 0.32561054825782776
# max: 15
# Training: On Tick: 0 loss 0.020475681871175766
# Epoch: 49 Loss: 0.3195078670978546
# max: 15
# Training: On Tick: 0 loss 0.020035583525896072
# Epoch: 50 Loss: 0.3136358857154846
# max: 15
# Training: On Tick: 0 loss 0.019624827429652214
# Epoch: 51 Loss: 0.30798181891441345
# max: 15
# Training: On Tick: 0 loss 0.019234349951148033
# Epoch: 52 Loss: 0.30253374576568604
# max: 15
# Training: On Tick: 0 loss 0.018858205527067184
# Epoch: 53 Loss: 0.297280490398407
# max: 15
# Training: On Tick: 0 loss 0.018493689596652985
# Epoch: 54 Loss: 0.2922116219997406
# max: 15
# Training: On Tick: 0 loss 0.018141474574804306
# Epoch: 55 Loss: 0.28731751441955566
# max: 15
# Training: On Tick: 0 loss 0.01780303195118904
# Epoch: 56 Loss: 0.2825891971588135
# max: 15
# Training: On Tick: 0 loss 0.017480429261922836
# Epoch: 57 Loss: 0.27801835536956787
# max: 15
# Training: On Tick: 0 loss 0.017174983397126198
# Epoch: 58 Loss: 0.2735973000526428
# max: 15
# Training: On Tick: 0 loss 0.016886861994862556
# Epoch: 59 Loss: 0.2693188190460205
# max: 15
# Training: On Tick: 0 loss 0.01661423034965992
# Epoch: 60 Loss: 0.26517608761787415
# max: 15
# Training: On Tick: 0 loss 0.016354884952306747
# Epoch: 61 Loss: 0.2611628770828247
# max: 15
# Training: On Tick: 0 loss 0.016105536371469498
# Epoch: 62 Loss: 0.2572731077671051
# max: 15
# Training: On Tick: 0 loss 0.01586475409567356
# Epoch: 63 Loss: 0.2535010874271393
# max: 15
# Training: On Tick: 0 loss 0.015632353723049164
# Epoch: 64 Loss: 0.249841570854187
# max: 15
# Training: On Tick: 0 loss 0.015407858416438103
# Epoch: 65 Loss: 0.24628955125808716
# max: 15
# Training: On Tick: 0 loss 0.015190785750746727
# Epoch: 66 Loss: 0.24284029006958008
# max: 15
# Training: On Tick: 0 loss 0.01498158648610115
# Epoch: 67 Loss: 0.23948945105075836
# max: 15
# Training: On Tick: 0 loss 0.014780684374272823
# Epoch: 68 Loss: 0.23623278737068176
# max: 15
# Training: On Tick: 0 loss 0.014588186517357826
# Epoch: 69 Loss: 0.23306642472743988
# max: 15
# Training: On Tick: 0 loss 0.014403745532035828
# Epoch: 70 Loss: 0.22998666763305664
# max: 15
# Training: On Tick: 0 loss 0.014226390980184078
# Epoch: 71 Loss: 0.2269900143146515
# max: 15
# Training: On Tick: 0 loss 0.014054886996746063
# Epoch: 72 Loss: 0.22407309710979462
# max: 15
# Training: On Tick: 0 loss 0.013888328336179256
# Epoch: 73 Loss: 0.22123275697231293
# max: 15
# Training: On Tick: 0 loss 0.01372589636594057
# Epoch: 74 Loss: 0.21846598386764526
# max: 15
# Training: On Tick: 0 loss 0.013567091897130013
# Epoch: 75 Loss: 0.2157699465751648
# max: 15
# Training: On Tick: 0 loss 0.01341212633997202
# Epoch: 76 Loss: 0.21314191818237305
# max: 15
# Training: On Tick: 0 loss 0.013261224143207073
# Epoch: 77 Loss: 0.21057936549186707
# max: 15
# Training: On Tick: 0 loss 0.01311470102518797
# Epoch: 78 Loss: 0.20807981491088867
# max: 15
# Training: On Tick: 0 loss 0.012972808443009853
# Epoch: 79 Loss: 0.20564095675945282
# max: 15
# Training: On Tick: 0 loss 0.012835185043513775
# Epoch: 80 Loss: 0.2032606303691864
# max: 15
# Training: On Tick: 0 loss 0.012701560743153095
# Epoch: 81 Loss: 0.20093673467636108
# max: 15
# Training: On Tick: 0 loss 0.012571644969284534
# Epoch: 82 Loss: 0.1986672729253769
# max: 15
# Training: On Tick: 0 loss 0.01244519092142582
# Epoch: 83 Loss: 0.1964503526687622
# max: 15
# Training: On Tick: 0 loss 0.01232169196009636
# Epoch: 84 Loss: 0.194284126162529
# max: 15
# Training: On Tick: 0 loss 0.012200938537716866
# Epoch: 85 Loss: 0.19216687977313995
# max: 15
# Training: On Tick: 0 loss 0.012082979083061218
# Epoch: 86 Loss: 0.19009695947170258
# max: 15
# Training: On Tick: 0 loss 0.011967628262937069
# Epoch: 87 Loss: 0.18807275593280792
# max: 15
# Training: On Tick: 0 loss 0.011854881420731544
# Epoch: 88 Loss: 0.18609276413917542
# max: 15
# Training: On Tick: 0 loss 0.011744724586606026
# Epoch: 89 Loss: 0.18415556848049164
# max: 15
# Training: On Tick: 0 loss 0.011637016199529171
# Epoch: 90 Loss: 0.18225976824760437
# max: 15
# Training: On Tick: 0 loss 0.011531658470630646
# Epoch: 91 Loss: 0.18040402233600616
# max: 15
# Training: On Tick: 0 loss 0.011428624391555786
# Epoch: 92 Loss: 0.17858707904815674
# max: 15
# Training: On Tick: 0 loss 0.011327838525176048
# Epoch: 93 Loss: 0.1768077164888382
# max: 15
# Training: On Tick: 0 loss 0.011229264549911022
# Epoch: 94 Loss: 0.1750648021697998
# max: 15
# Training: On Tick: 0 loss 0.011132744140923023
# Epoch: 95 Loss: 0.17335717380046844
# max: 15
# Training: On Tick: 0 loss 0.011038110591471195
# Epoch: 96 Loss: 0.17168377339839935
# max: 15
# Training: On Tick: 0 loss 0.01094525121152401
# Epoch: 97 Loss: 0.17004357278347015
# max: 15
# Training: On Tick: 0 loss 0.010854075662791729
# Epoch: 98 Loss: 0.16843560338020325
# max: 15
# Training: On Tick: 0 loss 0.010764597915112972
# Epoch: 99 Loss: 0.16685889661312103
# Final Loss: 0.16685889661312103
# CPU times: user 9.86 s, sys: 281 ms, total: 10.1 s
# Wall time: 10.6 s

# %% [markdown]
# #### Qualitative and quantitative evaluation of predictions (untrained vs overfit nets) - fully implemented.

# %%
# switch back to evaluation mode
overfit_net.eval()

sample_img, sample_target = JointNormalize(*norm)(*JointToTensor()(*sample1))
if USE_GPU:
    sample_img = sample_img.cuda()
sample_output_O = overfit_net.forward(sample_img[None])
sample_output_U = untrained_net.forward(sample_img[None])

# computing mIOU (quantitative measure of accuracy for network predictions)
if USE_GPU:
    pred_O = torch.argmax(sample_output_O, dim=1).cpu().numpy()[0]
    pred_U = torch.argmax(sample_output_U, dim=1).cpu().numpy()[0]
else:
    pred_O = torch.argmax(sample_output_O, dim=1).numpy()[0]
    pred_U = torch.argmax(sample_output_U, dim=1).numpy()[0]

gts = torch.from_numpy(np.array(sample1[1].convert('P'), dtype=np.int32)).long().numpy()
gts[gts == 255] = -1
print(pred_O[None].shape)
conf_O = eval_semantic_segmentation(pred_O[None], gts[None])
conf_U = eval_semantic_segmentation(pred_U[None], gts[None])


fig = plt.figure(figsize=(14,10))
ax1 = fig.add_subplot(2,2,1)
plt.title('image sample')
ax1.imshow(sample1[0])
ax2 = fig.add_subplot(2,2,2)
plt.title('ground truth (target)')
ax2.imshow(sample1[1])
ax3 = fig.add_subplot(2,2,3)
plt.title('UNTRAINED_NET prediction')
ax3.text(10, 25, 'mIoU = {:_>8.6f}'.format(conf_U['miou']), fontsize=20, color='white')
ax3.imshow(colorize_mask(torch.argmax(sample_output_U, dim=1).cpu().numpy()[0]))
ax4 = fig.add_subplot(2,2,4)
plt.title('OVERFIT_NET prediction (for its training image)')
ax4.text(10, 25, 'mIoU = {:_>8.6f}'.format(conf_O['miou']), fontsize=20, color='white')
ax4.imshow(colorize_mask(torch.argmax(sample_output_O, dim=1).cpu().numpy()[0]))
# Out:
# max: 15
# max: 18
# (1, 375, 500)
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:91: RuntimeWarning: invalid value encountered in true_divide
#   iou = np.diag(confusion) / iou_denominator
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:168: RuntimeWarning: invalid value encountered in true_divide
#   class_accuracy = np.diag(confusion) / np.sum(confusion, axis=1)

# %%
img, target = JointResize((375,500))(*sample2)
sample_img, sample_target = JointNormalize(*norm)(img, target)
if USE_GPU:
    sample_img = sample_img.cuda()
sample_output_O = overfit_net.forward(sample_img[None])
sample_output_U = untrained_net.forward(sample_img[None])

# computing mIOU (quantitative measure of accuracy for network predictions)
if USE_GPU:
    pred_O = torch.argmax(sample_output_O, dim=1).cpu().numpy()[0]
    pred_U = torch.argmax(sample_output_U, dim=1).cpu().numpy()[0]
else:
    pred_O = torch.argmax(sample_output_O, dim=1).numpy()[0]
    pred_U = torch.argmax(sample_output_U, dim=1).numpy()[0]

gts = target.numpy()#torch.from_numpy(np.array(target.convert('P'), dtype=np.int32)).long().numpy()
gts[gts == 255] = -1
conf_O = eval_semantic_segmentation(pred_O[None], gts[None])
conf_U = eval_semantic_segmentation(pred_U[None], gts[None])

fig = plt.figure(figsize=(14,10))
ax1 = fig.add_subplot(2,2,1)
plt.title('image sample')
ax1.imshow(sample2[0])
ax2 = fig.add_subplot(2,2,2)
plt.title('ground truth (target)')
ax2.imshow(sample2[1])
ax3 = fig.add_subplot(2,2,3)
plt.title('UNTRAINED_NET prediction')
ax3.text(10, 25, 'mIoU = {:_>8.6f}'.format(conf_U['miou']), fontsize=20, color='white')
ax3.imshow(colorize_mask(torch.argmax(sample_output_U, dim=1).cpu().numpy()[0]))
ax4 = fig.add_subplot(2,2,4)
plt.title('OVERFIT_NET prediction (for image it has not seen)')
ax4.text(10, 25, 'mIoU = {:_>8.6f}'.format(conf_O['miou']), fontsize=20, color='white')
ax4.imshow(colorize_mask(torch.argmax(sample_output_O, dim=1).cpu().numpy()[0]))
# Out:
# max: 15
# max: 13
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:91: RuntimeWarning: invalid value encountered in true_divide
#   iou = np.diag(confusion) / iou_denominator
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:168: RuntimeWarning: invalid value encountered in true_divide
#   class_accuracy = np.diag(confusion) / np.sum(confusion, axis=1)

# %% [markdown]
# #### Run the validation loop for OVERFIT_NET against the sanity dataset (an image it was trained on) - fully implemented

# %%
# %%time
print("mIoU for OVERFIT_NET over its training image:{}".format(validate(sanity_loader, overfit_net)[1]))
# Out:
# Tick: 0
# shape: torch.Size([1, 375, 500])
# max: 15
# (1, 375, 500)
# (1, 375, 500)
# [0.9746416016616524]
# mIoU for OVERFIT_NET over its training image:0.9746416016616524
# CPU times: user 38.9 ms, sys: 1.88 ms, total: 40.8 ms
# Wall time: 62.8 ms
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:91: RuntimeWarning: invalid value encountered in true_divide
#   iou = np.diag(confusion) / iou_denominator
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:168: RuntimeWarning: invalid value encountered in true_divide
#   class_accuracy = np.diag(confusion) / np.sum(confusion, axis=1)

# %% [markdown]
# ### WARNING: For the remaining part of the assignment (below) it is advisable to switch to GPU mode as running each validation and training loop on the whole training set takes over an hour on CPU (there are several such loops below). Note that GPU mode is helpful only if you have a sufficiently good NVIDIA gpu (not older than 2-3 years) and cuda installed on your computer. If you do not have a sufficiently good graphics card available, you can still finish the remaining part in CPU mode (takes a few hours), as the cells below are mostly implemented and test your code written and debugged in the earlier parts above. You can also switch to Google Colaboratory to run the remaining parts below.
#
# ### You can use validation-data experiments below to tune your hyper-parameters. Normally, validation data is used exactly for this purpose. For actual competitions, testing data is not public and you can not tune hyper-parameters on in.

# %% [markdown]
# #### (d) Evaluate UNTRAINED_NET and OVERFIT_NET on validation dataset.
# ##### Run the validation loop for UNTRAINED_NET against the validation dataset:

# %%
# %%time
# This will be slow on CPU (around 1 hour or more). On GPU it should take only a few minutes (depending on your GPU).
# Takes 15min on Colab, 1500 images in validation set
# print("mIoU for UNTRAINED_NET over the entire dataset:{}".format(validate(val_loader, untrained_net)[1]))
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.01 µs

# %% [markdown]
# ##### Run the validation loop for OVERFIT_NET against the validation dataset (it has not seen):

# %%
# %%time
# This will be slow on CPU (around 1 hour or more). On GPU it should take only a few minutes (depending on your GPU).
# print("mIoU for OVERFIT_NET over the validation dataset:{}".format(validate(val_loader, overfit_net)[1]))
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs

# %% [markdown]
# #### (e) Explain in a few sentences the quantitative results observed in (c) and (d):

# %% [markdown]
# Student answer:

# %% [markdown]
# #### (f) Create TRAINED_NET and train it on the full training dataset:

# %% [markdown]
# #### (g) Qualitative and quantitative evaluation of predictions (OVERFIT_NET vs TRAINED_NET):

# %%
# %%time
# %matplotlib notebook

# This training will be very slow on a CPU (>1hour per epoch). Ideally, this should be run in GPU mode (USE_GPU=True) 
# taking only a few minutes per epoch (depending on your GPU and batch size). Thus, before proceeding with this excercise,
# it is highly advisable that you first finish debugging your net code. In particular, make sure that OVERFIT_NET behaves 
# reasonably, e.g. its loss monotonically decreases during training and its output is OK (for the image it was trained on). 
# Below we create another (deep) copy of untrained_net. Unlike OVERFIT_NET it will be trained on a full training dataset.
trained_net = copy.deepcopy(untrained_net)
# overfit_net = copy.deepcopy(untrained_net)

# set loss function for the net
trained_net.criterion = nn.CrossEntropyLoss(ignore_index=255)

# You can change the number of EPOCHS below. Since each epoch for TRAINED_NET iterates over all training dataset images,
# the number of required epochs could be smaller compared to OFERFIT_NET where each epoch iterates over one-image-dataset)
EPOCH = 3

# switch to train mode (original untrained_net was set to eval mode)
trained_net.train()

optimizer = get_optimizer(trained_net)
# optimizer = optim.SGD(trained_net.parameters(), lr=0.002, momentum=0.9)

print("Starting Training...")

loss_graph = []

fig = plt.figure(figsize=(12,6))
plt.subplots_adjust(bottom=0.2,right=0.85,top=0.95)
ax = fig.add_subplot(1,1,1)

for e in range(EPOCH):
    print("Starting Epoch {}".format(e))
    loss = train(train_loader, trained_net, optimizer, loss_graph)
    ax.clear()
    ax.set_xlabel('iterations')
    ax.set_ylabel('loss value')
    ax.set_title('Training loss curve for TRAINED_NET')
    ax.plot(loss_graph, label='training loss')
    ax.legend(loc='upper right')
    fig.canvas.draw()
    plt.show()
    print("Epoch: {} Loss: {}".format(e, loss))
    
# %matplotlib inline
# Out:
# Starting Training...
# <div id='36620e02-977e-446e-a768-81870795853a'></div>
# Starting Epoch 0
# max: 20
# Training: On Tick: 0 loss 3.3958780765533447
# max: 20
# Training: On Tick: 1 loss 3.3035647869110107
# max: 20
# Training: On Tick: 2 loss 3.2604126930236816
# max: 20
# Training: On Tick: 3 loss 3.137817621231079
# max: 20
# Training: On Tick: 4 loss 3.530482530593872
# max: 20
# Training: On Tick: 5 loss 2.9728524684906006
# max: 20
# Training: On Tick: 6 loss 2.837932586669922
# max: 20
# Training: On Tick: 7 loss 2.8992092609405518
# max: 20
# Training: On Tick: 8 loss 2.781404972076416
# max: 20
# Training: On Tick: 9 loss 2.6895923614501953
# max: 20
# Training: On Tick: 10 loss 2.489262819290161
# max: 20
# Training: On Tick: 11 loss 2.7066168785095215
# max: 20
# Training: On Tick: 12 loss 2.266309976577759
# max: 20
# Training: On Tick: 13 loss 2.793806314468384
# max: 20
# Training: On Tick: 14 loss 2.2537295818328857
# max: 20
# Training: On Tick: 15 loss 2.1278774738311768
# max: 20
# Training: On Tick: 16 loss 2.159806728363037
# max: 20
# Training: On Tick: 17 loss 2.1785776615142822
# max: 20
# Training: On Tick: 18 loss 1.9502438306808472
# max: 20
# Training: On Tick: 19 loss 1.942529320716858
# max: 20
# Training: On Tick: 20 loss 2.317484140396118
# max: 20
# Training: On Tick: 21 loss 1.4528199434280396
# max: 20
# Training: On Tick: 22 loss 2.1431734561920166
# max: 20
# Training: On Tick: 23 loss 1.4163482189178467
# max: 20
# Training: On Tick: 24 loss 1.4888076782226562
# max: 20
# Training: On Tick: 25 loss 1.949466586112976
# max: 20
# Training: On Tick: 26 loss 1.4927823543548584
# max: 20
# Training: On Tick: 27 loss 1.5200049877166748
# max: 20
# Training: On Tick: 28 loss 1.6463855504989624
# max: 20
# Training: On Tick: 29 loss 2.1624341011047363
# max: 20
# Training: On Tick: 30 loss 1.3067415952682495
# max: 20
# Training: On Tick: 31 loss 1.3497910499572754
# max: 20
# Training: On Tick: 32 loss 1.3435170650482178
# max: 20
# Training: On Tick: 33 loss 1.1293401718139648
# max: 20
# Training: On Tick: 34 loss 1.1847412586212158
# max: 20
# Training: On Tick: 35 loss 1.351538062095642
# max: 20
# Training: On Tick: 36 loss 1.0104897022247314
# max: 20
# Training: On Tick: 37 loss 1.0260071754455566
# max: 20
# Training: On Tick: 38 loss 1.8621516227722168
# max: 20
# Training: On Tick: 39 loss 0.9429081678390503
# max: 20
# Training: On Tick: 40 loss 1.2308496236801147
# max: 20
# Training: On Tick: 41 loss 1.5885955095291138
# max: 19
# Training: On Tick: 42 loss 1.3243955373764038
# max: 20
# Training: On Tick: 43 loss 1.023830533027649
# max: 20
# Training: On Tick: 44 loss 0.7902312874794006
# max: 20
# Training: On Tick: 45 loss 0.8793467879295349
# max: 20
# Training: On Tick: 46 loss 1.061409831047058
# max: 20
# Training: On Tick: 47 loss 1.7173508405685425
# max: 20
# Training: On Tick: 48 loss 0.7233232259750366
# max: 19
# Training: On Tick: 49 loss 0.8270885348320007
# max: 17
# Training: On Tick: 50 loss 1.0501207113265991
# max: 20
# Training: On Tick: 51 loss 1.3559800386428833
# max: 20
# Training: On Tick: 52 loss 1.746473789215088
# max: 20
# Training: On Tick: 53 loss 1.7117679119110107
# max: 17
# Training: On Tick: 54 loss 0.7509163618087769
# max: 20
# Training: On Tick: 55 loss 1.799190640449524
# max: 15
# Training: On Tick: 56 loss 1.1498332023620605
# max: 1
# Training: On Tick: 57 loss 0.9605769515037537
# max: 15
# Training: On Tick: 58 loss 1.2072417736053467
# max: 17
# Training: On Tick: 59 loss 0.966454267501831
# max: 0
# Training: On Tick: 60 loss 1.094961404800415
# max: 20
# Training: On Tick: 61 loss 0.7634535431861877
# max: 20
# Training: On Tick: 62 loss 0.6767378449440002
# max: 18
# Training: On Tick: 63 loss 0.7479627132415771
# max: 17
# Training: On Tick: 64 loss 0.9048997759819031
# max: 15
# Training: On Tick: 65 loss 1.0895644426345825
# max: 19
# Training: On Tick: 66 loss 1.0103803873062134
# max: 15
# Training: On Tick: 67 loss 1.1398869752883911
# max: 20
# Training: On Tick: 68 loss 0.9540922045707703
# max: 19
# Training: On Tick: 69 loss 1.2693730592727661
# max: 19
# Training: On Tick: 70 loss 1.0886904001235962
# max: 19
# Training: On Tick: 71 loss 0.9603627324104309
# max: 19
# Training: On Tick: 72 loss 0.5973691940307617
# max: 14
# Training: On Tick: 73 loss 0.8142366409301758
# max: 0
# Training: On Tick: 74 loss 1.4524662494659424
# max: 15
# Training: On Tick: 75 loss 1.5671260356903076
# max: 15
# Training: On Tick: 76 loss 1.0951851606369019
# max: 19
# Training: On Tick: 77 loss 1.3855724334716797
# max: 17
# Training: On Tick: 78 loss 0.6963230967521667
# max: 15
# Training: On Tick: 79 loss 0.6501561999320984
# max: 19
# Training: On Tick: 80 loss 1.0830767154693604
# max: 0
# Training: On Tick: 81 loss 0.49822452664375305
# max: 15
# Training: On Tick: 82 loss 1.1580910682678223
# max: 15
# Training: On Tick: 83 loss 0.9422509074211121
# max: 7
# Training: On Tick: 84 loss 0.8280168175697327
# max: 15
# Training: On Tick: 85 loss 0.5714568495750427
# max: 15
# Training: On Tick: 86 loss 0.8047627210617065
# max: 15
# Training: On Tick: 87 loss 1.6221530437469482
# max: 15
# Training: On Tick: 88 loss 0.9375057220458984
# max: 15
# Training: On Tick: 89 loss 0.684929370880127
# max: 15
# Training: On Tick: 90 loss 1.1811350584030151
# max: 19
# Training: On Tick: 91 loss 0.9857468008995056
# max: 15
# Training: On Tick: 92 loss 0.8033033609390259
# max: 11
# Training: On Tick: 93 loss 0.7544947862625122
# max: 19
# Training: On Tick: 94 loss 0.8517974615097046
# max: 20
# Training: On Tick: 95 loss 0.6452693939208984
# max: 19
# Training: On Tick: 96 loss 0.5235483050346375
# max: 15
# Training: On Tick: 97 loss 0.5724582672119141
# max: 19
# Training: On Tick: 98 loss 0.8219510912895203
# max: 15
# Training: On Tick: 99 loss 0.7385525703430176
# max: 15
# Training: On Tick: 100 loss 0.6155976057052612
# max: 15
# Training: On Tick: 101 loss 0.3735237121582031
# max: 15
# Training: On Tick: 102 loss 0.8571604490280151
# max: 15
# Training: On Tick: 103 loss 0.8950656056404114
# max: 19
# Training: On Tick: 104 loss 0.6506944894790649
# max: 15
# Training: On Tick: 105 loss 0.9453486800193787
# max: 15
# Training: On Tick: 106 loss 1.4650706052780151
# max: 12
# Training: On Tick: 107 loss 0.8987822532653809
# max: 15
# Training: On Tick: 108 loss 0.5775343775749207
# max: 15
# Training: On Tick: 109 loss 0.7577692866325378
# max: 19
# Training: On Tick: 110 loss 0.2730657160282135
# max: 19
# Training: On Tick: 111 loss 0.6550215482711792
# max: 19
# Training: On Tick: 112 loss 1.1208113431930542
# max: 15
# Training: On Tick: 113 loss 1.1901823282241821
# max: 7
# Training: On Tick: 114 loss 0.7298824787139893
# max: 19
# Training: On Tick: 115 loss 0.4722094237804413
# max: 19
# Training: On Tick: 116 loss 0.7204538583755493
# max: 12
# Training: On Tick: 117 loss 1.3601264953613281
# max: 7
# Training: On Tick: 118 loss 0.5962608456611633
# max: 15
# Training: On Tick: 119 loss 0.880586564540863
# max: 0
# Training: On Tick: 120 loss 0.5724788904190063
# max: 7
# Training: On Tick: 121 loss 0.7121973037719727
# max: 0
# Training: On Tick: 122 loss 1.5406253337860107
# max: 15
# Training: On Tick: 123 loss 1.124520182609558
# max: 7
# Training: On Tick: 124 loss 0.47219496965408325
# max: 15
# Training: On Tick: 125 loss 0.6730055809020996
# max: 15
# Training: On Tick: 126 loss 1.3256062269210815
# max: 15
# Training: On Tick: 127 loss 0.8379405736923218
# max: 7
# Training: On Tick: 128 loss 1.1360540390014648
# max: 19
# Training: On Tick: 129 loss 1.7153276205062866
# max: 20
# Training: On Tick: 130 loss 0.703278124332428
# max: 0
# Training: On Tick: 131 loss 0.6380024552345276
# max: 19
# Training: On Tick: 132 loss 1.0717898607254028
# max: 15
# Training: On Tick: 133 loss 0.6785213351249695
# max: 20
# Training: On Tick: 134 loss 0.6121218204498291
# max: 15
# Training: On Tick: 135 loss 0.6303455829620361
# max: 12
# Training: On Tick: 136 loss 0.7754274010658264
# max: 19
# Training: On Tick: 137 loss 0.5777303576469421
# max: 15
# Training: On Tick: 138 loss 0.750742495059967
# max: 15
# Training: On Tick: 139 loss 1.3301256895065308
# max: 15
# Training: On Tick: 140 loss 1.158423900604248
# max: 0
# Training: On Tick: 141 loss 0.8010038733482361
# max: 15
# Training: On Tick: 142 loss 2.3903768062591553
# max: 15
# Training: On Tick: 143 loss 0.9447389245033264
# max: 19
# Training: On Tick: 144 loss 0.8125680088996887
# max: 19
# Training: On Tick: 145 loss 1.0141534805297852
# max: 20
# Training: On Tick: 146 loss 1.1406607627868652
# max: 19
# Training: On Tick: 147 loss 0.6905009746551514
# max: 20
# Training: On Tick: 148 loss 1.3883349895477295
# max: 0
# Training: On Tick: 149 loss 0.42822757363319397
# max: 19
# Training: On Tick: 150 loss 0.9895731806755066
# max: 17
# Training: On Tick: 151 loss 0.8974625468254089
# max: 0
# Training: On Tick: 152 loss 0.4798581600189209
# max: 20
# Training: On Tick: 153 loss 0.6499134302139282
# max: 17
# Training: On Tick: 154 loss 1.2683064937591553
# max: 19
# Training: On Tick: 155 loss 0.5721132755279541
# max: 17
# Training: On Tick: 156 loss 0.48806339502334595
# max: 17
# Training: On Tick: 157 loss 0.7722780704498291
# max: 12
# Training: On Tick: 158 loss 1.1817588806152344
# max: 18
# Training: On Tick: 159 loss 0.6080479621887207
# max: 15
# Training: On Tick: 160 loss 0.7237517833709717
# max: 19
# Training: On Tick: 161 loss 0.5357738733291626
# max: 17
# Training: On Tick: 162 loss 0.7310013771057129
# max: 17
# Training: On Tick: 163 loss 1.1116818189620972
# max: 19
# Training: On Tick: 164 loss 0.4559236168861389
# max: 15
# Training: On Tick: 165 loss 1.09682035446167
# max: 12
# Training: On Tick: 166 loss 0.5218361020088196
# max: 0
# Training: On Tick: 167 loss 0.4985213279724121
# max: 19
# Training: On Tick: 168 loss 0.5106642246246338
# max: 0
# Training: On Tick: 169 loss 0.8180896043777466
# max: 19
# Training: On Tick: 170 loss 0.6904901266098022
# max: 19
# Training: On Tick: 171 loss 0.9298157691955566
# max: 19
# Training: On Tick: 172 loss 0.7328359484672546
# max: 0
# Training: On Tick: 173 loss 0.8793402314186096
# max: 12
# Training: On Tick: 174 loss 0.696296751499176
# max: 15
# Training: On Tick: 175 loss 0.8726459741592407
# max: 19
# Training: On Tick: 176 loss 0.6709499359130859
# max: 19
# Training: On Tick: 177 loss 0.5217064023017883
# max: 10
# Training: On Tick: 178 loss 0.6038051247596741
# max: 19
# Training: On Tick: 179 loss 0.441723108291626
# max: 15
# Training: On Tick: 180 loss 1.3760401010513306
# max: 15
# Training: On Tick: 181 loss 0.8611065149307251
# max: 19
# Training: On Tick: 182 loss 0.9776358604431152
# max: 19
# Training: On Tick: 183 loss 1.0401498079299927
# max: 17
# Training: On Tick: 184 loss 0.8380753993988037
# max: 15
# Training: On Tick: 185 loss 0.5766184329986572
# max: 15
# Training: On Tick: 186 loss 0.9316953420639038
# max: 15
# Training: On Tick: 187 loss 1.2308820486068726
# max: 15
# Training: On Tick: 188 loss 0.7863619327545166
# max: 20
# Training: On Tick: 189 loss 0.5726481080055237
# max: 17
# Training: On Tick: 190 loss 0.8196513652801514
# max: 18
# Training: On Tick: 191 loss 0.9739888310432434
# max: 13
# Training: On Tick: 192 loss 0.7556461691856384
# max: 0
# Training: On Tick: 193 loss 0.5463165640830994
# max: 20
# Training: On Tick: 194 loss 0.9316453337669373
# max: 19
# Training: On Tick: 195 loss 0.491820365190506
# max: 17
# Training: On Tick: 196 loss 0.5389527082443237
# max: 15
# Training: On Tick: 197 loss 1.2800953388214111
# max: 18
# Training: On Tick: 198 loss 0.8858282566070557
# max: 13
# Training: On Tick: 199 loss 0.8723898530006409
# max: 19
# Training: On Tick: 200 loss 1.2656770944595337
# max: 17
# Training: On Tick: 201 loss 0.5525723099708557
# max: 18
# Training: On Tick: 202 loss 0.666176438331604
# max: 17
# Training: On Tick: 203 loss 1.5998200178146362
# max: 17
# Training: On Tick: 204 loss 0.8484330177307129
# max: 14
# Training: On Tick: 205 loss 1.4719198942184448
# max: 20
# Training: On Tick: 206 loss 1.1642875671386719
# max: 13
# Training: On Tick: 207 loss 0.42651087045669556
# max: 19
# Training: On Tick: 208 loss 0.5966731309890747
# max: 17
# Training: On Tick: 209 loss 0.8329968452453613
# max: 16
# Training: On Tick: 210 loss 0.6001474261283875
# max: 6
# Training: On Tick: 211 loss 1.1344813108444214
# max: 15
# Training: On Tick: 212 loss 0.5825884938240051
# max: 20
# Training: On Tick: 213 loss 1.7850747108459473
# max: 15
# Training: On Tick: 214 loss 0.945812463760376
# max: 19
# Training: On Tick: 215 loss 1.2026727199554443
# max: 18
# Training: On Tick: 216 loss 2.5052428245544434
# max: 19
# Training: On Tick: 217 loss 0.6935160160064697
# max: 19
# Training: On Tick: 218 loss 0.6866169571876526
# max: 16
# Training: On Tick: 219 loss 0.7217382788658142
# max: 18
# Training: On Tick: 220 loss 0.8122633695602417
# max: 19
# Training: On Tick: 221 loss 0.8724052906036377
# max: 6
# Training: On Tick: 222 loss 0.5595197677612305
# max: 18
# Training: On Tick: 223 loss 0.7735573053359985
# max: 18
# Training: On Tick: 224 loss 0.7954338788986206
# max: 17
# Training: On Tick: 225 loss 1.005681037902832
# max: 18
# Training: On Tick: 226 loss 1.4060286283493042
# max: 14
# Training: On Tick: 227 loss 0.5593384504318237
# max: 14
# Training: On Tick: 228 loss 0.9683379530906677
# max: 13
# Training: On Tick: 229 loss 0.6990954279899597
# max: 0
# Training: On Tick: 230 loss 0.45850563049316406
# max: 18
# Training: On Tick: 231 loss 1.0922348499298096
# max: 16
# Training: On Tick: 232 loss 1.0218696594238281
# max: 18
# Training: On Tick: 233 loss 0.9795606136322021
# max: 19
# Training: On Tick: 234 loss 0.7489676475524902
# max: 19
# Training: On Tick: 235 loss 1.1380831003189087
# max: 18
# Training: On Tick: 236 loss 0.5186219215393066
# max: 12
# Training: On Tick: 237 loss 0.7525268197059631
# max: 18
# Training: On Tick: 238 loss 1.284719705581665
# max: 0
# Training: On Tick: 239 loss 0.7220920920372009
# max: 18
# Training: On Tick: 240 loss 0.8932320475578308
# max: 19
# Training: On Tick: 241 loss 0.8336119651794434
# max: 1
# Training: On Tick: 242 loss 0.4045146107673645
# max: 19
# Training: On Tick: 243 loss 0.6427732706069946
# max: 15
# Training: On Tick: 244 loss 0.8289399147033691
# max: 16
# Training: On Tick: 245 loss 0.6833011507987976
# max: 11
# Training: On Tick: 246 loss 0.9986829161643982
# max: 0
# Training: On Tick: 247 loss 0.6083933711051941
# max: 0
# Training: On Tick: 248 loss 0.39720088243484497
# max: 14
# Training: On Tick: 249 loss 1.1515313386917114
# max: 18
# Training: On Tick: 250 loss 0.8051310777664185
# max: 15
# Training: On Tick: 251 loss 0.5418509244918823
# max: 8
# Training: On Tick: 252 loss 0.6429138779640198
# max: 8
# Training: On Tick: 253 loss 0.476641982793808
# max: 14
# Training: On Tick: 254 loss 0.530755877494812
# max: 18
# Training: On Tick: 255 loss 1.5479487180709839
# max: 19
# Training: On Tick: 256 loss 1.1506025791168213
# max: 15
# Training: On Tick: 257 loss 0.5965234041213989
# max: 8
# Training: On Tick: 258 loss 0.966676652431488
# max: 8
# Training: On Tick: 259 loss 1.2257360219955444
# max: 19
# Training: On Tick: 260 loss 1.956723690032959
# max: 15
# Training: On Tick: 261 loss 1.2511399984359741
# max: 7
# Training: On Tick: 262 loss 0.6599616408348083
# max: 11
# Training: On Tick: 263 loss 0.9303235411643982
# max: 15
# Training: On Tick: 264 loss 0.6944392323493958
# max: 11
# Training: On Tick: 265 loss 1.2540398836135864
# max: 17
# Training: On Tick: 266 loss 1.7695084810256958
# max: 7
# Training: On Tick: 267 loss 0.5282790660858154
# max: 0
# Training: On Tick: 268 loss 1.0650959014892578
# max: 1
# Training: On Tick: 269 loss 0.7825104594230652
# max: 12
# Training: On Tick: 270 loss 0.8662925362586975
# max: 15
# Training: On Tick: 271 loss 0.3576117753982544
# max: 15
# Training: On Tick: 272 loss 0.9537059664726257
# max: 19
# Training: On Tick: 273 loss 0.6097585558891296
# max: 17
# Training: On Tick: 274 loss 0.48388102650642395
# max: 15
# Training: On Tick: 275 loss 0.8636864423751831
# max: 15
# Training: On Tick: 276 loss 0.3795313239097595
# max: 15
# Training: On Tick: 277 loss 0.7478843331336975
# max: 18
# Training: On Tick: 278 loss 0.9994099736213684
# max: 15
# Training: On Tick: 279 loss 0.41605499386787415
# max: 20
# Training: On Tick: 280 loss 1.5728373527526855
# max: 19
# Training: On Tick: 281 loss 1.2082194089889526
# max: 19
# Training: On Tick: 282 loss 1.680105209350586
# max: 15
# Training: On Tick: 283 loss 0.6214538812637329
# max: 19
# Training: On Tick: 284 loss 0.6310325264930725
# max: 15
# Training: On Tick: 285 loss 1.3324663639068604
# max: 15
# Training: On Tick: 286 loss 1.1043815612792969
# max: 15
# Training: On Tick: 287 loss 0.6037453413009644
# max: 0
# Training: On Tick: 288 loss 0.8901664614677429
# max: 15
# Training: On Tick: 289 loss 0.505083441734314
# max: 19
# Training: On Tick: 290 loss 0.8341534733772278
# max: 19
# Training: On Tick: 291 loss 0.7032562494277954
# max: 7
# Training: On Tick: 292 loss 1.1697301864624023
# max: 12
# Training: On Tick: 293 loss 0.5887677669525146
# max: 15
# Training: On Tick: 294 loss 1.5922385454177856
# max: 18
# Training: On Tick: 295 loss 1.3814570903778076
# max: 18
# Training: On Tick: 296 loss 1.2605165243148804
# max: 17
# Training: On Tick: 297 loss 0.9949017763137817
# max: 19
# Training: On Tick: 298 loss 0.7435954213142395
# max: 18
# Training: On Tick: 299 loss 0.7662035226821899
# max: 0
# Training: On Tick: 300 loss 0.7917147874832153
# max: 0
# Training: On Tick: 301 loss 0.7238616347312927
# max: 19
# Training: On Tick: 302 loss 0.39888185262680054
# max: 17
# Training: On Tick: 303 loss 1.081408143043518
# max: 18
# Training: On Tick: 304 loss 0.734140932559967
# max: 19
# Training: On Tick: 305 loss 0.729453444480896
# max: 19
# Training: On Tick: 306 loss 0.7328328490257263
# max: 17
# Training: On Tick: 307 loss 0.4341951608657837
# max: 17
# Training: On Tick: 308 loss 0.5030100345611572
# max: 19
# Training: On Tick: 309 loss 0.6154190897941589
# max: 0
# Training: On Tick: 310 loss 1.5507252216339111
# max: 12
# Training: On Tick: 311 loss 0.7471970915794373
# max: 7
# Training: On Tick: 312 loss 0.7917616367340088
# max: 15
# Training: On Tick: 313 loss 1.6954119205474854
# max: 17
# Training: On Tick: 314 loss 1.4745713472366333
# max: 15
# Training: On Tick: 315 loss 1.6276663541793823
# max: 0
# Training: On Tick: 316 loss 0.7810569405555725
# max: 1
# Training: On Tick: 317 loss 0.8948349356651306
# max: 15
# Training: On Tick: 318 loss 0.7938429713249207
# max: 17
# Training: On Tick: 319 loss 0.9129608869552612
# max: 18
# Training: On Tick: 320 loss 1.1594101190567017
# max: 15
# Training: On Tick: 321 loss 1.647424578666687
# max: 15
# Training: On Tick: 322 loss 1.1040680408477783
# max: 1
# Training: On Tick: 323 loss 0.4961727261543274
# max: 19
# Training: On Tick: 324 loss 0.9321534633636475
# max: 0
# Training: On Tick: 325 loss 0.9929372072219849
# max: 12
# Training: On Tick: 326 loss 1.6425527334213257
# max: 15
# Training: On Tick: 327 loss 1.265675663948059
# max: 18
# Training: On Tick: 328 loss 0.8029662370681763
# max: 19
# Training: On Tick: 329 loss 1.0016413927078247
# max: 17
# Training: On Tick: 330 loss 0.6557580232620239
# max: 19
# Training: On Tick: 331 loss 1.3564954996109009
# max: 18
# Training: On Tick: 332 loss 0.6329293251037598
# max: 18
# Training: On Tick: 333 loss 1.5038225650787354
# max: 15
# Training: On Tick: 334 loss 1.3869351148605347
# max: 18
# Training: On Tick: 335 loss 0.5034457445144653
# max: 19
# Training: On Tick: 336 loss 0.633831262588501
# max: 18
# Training: On Tick: 337 loss 3.1874563694000244
# max: 15
# Training: On Tick: 338 loss 1.0597344636917114
# max: 19
# Training: On Tick: 339 loss 0.9084106087684631
# max: 18
# Training: On Tick: 340 loss 1.0574063062667847
# max: 19
# Training: On Tick: 341 loss 0.8180758357048035
# max: 19
# Training: On Tick: 342 loss 0.7071506977081299
# max: 18
# Training: On Tick: 343 loss 1.387324571609497
# max: 19
# Training: On Tick: 344 loss 0.6336234211921692
# max: 18
# Training: On Tick: 345 loss 1.2290982007980347
# max: 0
# Training: On Tick: 346 loss 0.597240149974823
# max: 15
# Training: On Tick: 347 loss 0.6473386883735657
# max: 16
# Training: On Tick: 348 loss 0.593947172164917
# max: 18
# Training: On Tick: 349 loss 1.087449550628662
# max: 19
# Training: On Tick: 350 loss 1.568975567817688
# max: 15
# Training: On Tick: 351 loss 0.4717755913734436
# max: 15
# Training: On Tick: 352 loss 0.45968911051750183
# max: 18
# Training: On Tick: 353 loss 0.665284276008606
# max: 14
# Training: On Tick: 354 loss 0.7387300729751587
# max: 18
# Training: On Tick: 355 loss 1.0338321924209595
# max: 17
# Training: On Tick: 356 loss 0.8098800182342529
# max: 17
# Training: On Tick: 357 loss 1.3115878105163574
# max: 17
# Training: On Tick: 358 loss 1.3079489469528198
# max: 17
# Training: On Tick: 359 loss 0.823921799659729
# max: 17
# Training: On Tick: 360 loss 0.7855256795883179
# max: 17
# Training: On Tick: 361 loss 0.6612561345100403
# max: 15
# Training: On Tick: 362 loss 0.9696620106697083
# max: 18
# Training: On Tick: 363 loss 1.5172045230865479
# max: 14
# Training: On Tick: 364 loss 0.9686164259910583
# max: 17
# Training: On Tick: 365 loss 0.6341517567634583
# Epoch: 0 Loss: 1.0492804050445557
# Starting Epoch 1
# max: 6
# Training: On Tick: 0 loss 0.7946749925613403
# max: 17
# Training: On Tick: 1 loss 0.7838389277458191
# max: 15
# Training: On Tick: 2 loss 1.0052202939987183
# max: 15
# Training: On Tick: 3 loss 0.7098423838615417
# max: 14
# Training: On Tick: 4 loss 0.8613896369934082
# max: 17
# Training: On Tick: 5 loss 0.7151252031326294
# max: 15
# Training: On Tick: 6 loss 0.7533233761787415
# max: 14
# Training: On Tick: 7 loss 0.7278798818588257
# max: 19
# Training: On Tick: 8 loss 0.7295296788215637
# max: 15
# Training: On Tick: 9 loss 0.7888121604919434
# max: 17
# Training: On Tick: 10 loss 0.552222490310669
# max: 15
# Training: On Tick: 11 loss 1.5470315217971802
# max: 15
# Training: On Tick: 12 loss 0.9950823783874512
# max: 17
# Training: On Tick: 13 loss 1.8965703248977661
# max: 0
# Training: On Tick: 14 loss 0.432390034198761
# max: 17
# Training: On Tick: 15 loss 0.8504024744033813
# max: 18
# Training: On Tick: 16 loss 0.5112330317497253
# max: 14
# Training: On Tick: 17 loss 0.6286101937294006
# max: 19
# Training: On Tick: 18 loss 0.8092287182807922
# max: 19
# Training: On Tick: 19 loss 0.43130776286125183
# max: 17
# Training: On Tick: 20 loss 1.2557177543640137
# max: 17
# Training: On Tick: 21 loss 0.4153587222099304
# max: 15
# Training: On Tick: 22 loss 0.8747540712356567
# max: 15
# Training: On Tick: 23 loss 0.34701430797576904
# max: 19
# Training: On Tick: 24 loss 0.48637092113494873
# max: 18
# Training: On Tick: 25 loss 1.157681941986084
# max: 19
# Training: On Tick: 26 loss 0.5717430710792542
# max: 18
# Training: On Tick: 27 loss 0.521233856678009
# max: 15
# Training: On Tick: 28 loss 0.9231318235397339
# max: 19
# Training: On Tick: 29 loss 1.2028210163116455
# max: 0
# Training: On Tick: 30 loss 0.5017358064651489
# max: 0
# Training: On Tick: 31 loss 0.7382044792175293
# max: 15
# Training: On Tick: 32 loss 0.7003740668296814
# max: 18
# Training: On Tick: 33 loss 0.5363256931304932
# max: 18
# Training: On Tick: 34 loss 0.6393757462501526
# max: 0
# Training: On Tick: 35 loss 0.6782470941543579
# max: 11
# Training: On Tick: 36 loss 0.3769461512565613
# max: 7
# Training: On Tick: 37 loss 0.37515345215797424
# max: 17
# Training: On Tick: 38 loss 1.2892143726348877
# max: 18
# Training: On Tick: 39 loss 0.578468918800354
# max: 7
# Training: On Tick: 40 loss 0.8346387147903442
# max: 15
# Training: On Tick: 41 loss 0.958729088306427
# max: 0
# Training: On Tick: 42 loss 0.7208907604217529
# max: 17
# Training: On Tick: 43 loss 0.5995972752571106
# max: 15
# Training: On Tick: 44 loss 0.43918395042419434
# max: 15
# Training: On Tick: 45 loss 0.6406216025352478
# max: 15
# Training: On Tick: 46 loss 0.7187265157699585
# max: 17
# Training: On Tick: 47 loss 1.2882927656173706
# max: 17
# Training: On Tick: 48 loss 0.4447503387928009
# max: 15
# Training: On Tick: 49 loss 0.5788182020187378
# max: 15
# Training: On Tick: 50 loss 0.6791908144950867
# max: 0
# Training: On Tick: 51 loss 0.9717572331428528
# max: 17
# Training: On Tick: 52 loss 1.1678870916366577
# max: 17
# Training: On Tick: 53 loss 1.0094645023345947
# max: 17
# Training: On Tick: 54 loss 0.40347927808761597
# max: 15
# Training: On Tick: 55 loss 1.2296767234802246
# max: 15
# Training: On Tick: 56 loss 0.7637494206428528
# max: 0
# Training: On Tick: 57 loss 0.6980392336845398
# max: 15
# Training: On Tick: 58 loss 0.9471713900566101
# max: 17
# Training: On Tick: 59 loss 0.5365400314331055
# max: 0
# Training: On Tick: 60 loss 0.848343014717102
# max: 13
# Training: On Tick: 61 loss 0.3947488069534302
# max: 19
# Training: On Tick: 62 loss 0.5430004000663757
# max: 18
# Training: On Tick: 63 loss 0.5450931191444397
# max: 17
# Training: On Tick: 64 loss 0.7057852149009705
# max: 19
# Training: On Tick: 65 loss 0.8216239809989929
# max: 15
# Training: On Tick: 66 loss 0.9393535852432251
# max: 17
# Training: On Tick: 67 loss 0.7250034213066101
# max: 19
# Training: On Tick: 68 loss 0.5860927104949951
# max: 17
# Training: On Tick: 69 loss 1.0837655067443848
# max: 15
# Training: On Tick: 70 loss 0.8348456025123596
# max: 19
# Training: On Tick: 71 loss 0.7539387941360474
# max: 14
# Training: On Tick: 72 loss 0.461834579706192
# max: 19
# Training: On Tick: 73 loss 0.5825802683830261
# max: 17
# Training: On Tick: 74 loss 1.2334202527999878
# max: 12
# Training: On Tick: 75 loss 1.1830662488937378
# max: 17
# Training: On Tick: 76 loss 0.8776007890701294
# max: 15
# Training: On Tick: 77 loss 1.0992401838302612
# max: 17
# Training: On Tick: 78 loss 0.42942488193511963
# max: 20
# Training: On Tick: 79 loss 0.4609312415122986
# max: 17
# Training: On Tick: 80 loss 0.8545250296592712
# max: 1
# Training: On Tick: 81 loss 0.27448174357414246
# max: 15
# Training: On Tick: 82 loss 0.9853350520133972
# max: 15
# Training: On Tick: 83 loss 0.6091380715370178
# max: 20
# Training: On Tick: 84 loss 0.5320187211036682
# max: 17
# Training: On Tick: 85 loss 0.34974655508995056
# max: 15
# Training: On Tick: 86 loss 0.5075001120567322
# max: 8
# Training: On Tick: 87 loss 1.497145652770996
# max: 15
# Training: On Tick: 88 loss 0.7290932536125183
# max: 19
# Training: On Tick: 89 loss 0.5919689536094666
# max: 15
# Training: On Tick: 90 loss 0.7981370091438293
# max: 4
# Training: On Tick: 91 loss 0.7008254528045654
# max: 15
# Training: On Tick: 92 loss 0.6048086285591125
# max: 20
# Training: On Tick: 93 loss 0.5615626573562622
# max: 20
# Training: On Tick: 94 loss 0.5269384384155273
# max: 19
# Training: On Tick: 95 loss 0.5126869678497314
# max: 19
# Training: On Tick: 96 loss 0.4019765257835388
# max: 15
# Training: On Tick: 97 loss 0.49952518939971924
# max: 14
# Training: On Tick: 98 loss 0.6165854930877686
# max: 18
# Training: On Tick: 99 loss 0.5468553304672241
# max: 15
# Training: On Tick: 100 loss 0.4913586974143982
# max: 15
# Training: On Tick: 101 loss 0.31922173500061035
# max: 3
# Training: On Tick: 102 loss 0.6910033822059631
# max: 15
# Training: On Tick: 103 loss 0.5875741839408875
# max: 15
# Training: On Tick: 104 loss 0.38819432258605957
# max: 15
# Training: On Tick: 105 loss 0.7832045555114746
# max: 15
# Training: On Tick: 106 loss 1.078224539756775
# max: 3
# Training: On Tick: 107 loss 0.626417875289917
# max: 15
# Training: On Tick: 108 loss 0.404153048992157
# max: 3
# Training: On Tick: 109 loss 0.46941494941711426
# max: 14
# Training: On Tick: 110 loss 0.17295271158218384
# max: 14
# Training: On Tick: 111 loss 0.41827598214149475
# max: 15
# Training: On Tick: 112 loss 0.9035145044326782
# max: 19
# Training: On Tick: 113 loss 1.0027589797973633
# max: 7
# Training: On Tick: 114 loss 0.5040901899337769
# max: 14
# Training: On Tick: 115 loss 0.338074654340744
# max: 19
# Training: On Tick: 116 loss 0.5420798659324646
# max: 17
# Training: On Tick: 117 loss 1.0526080131530762
# max: 20
# Training: On Tick: 118 loss 0.42224210500717163
# max: 18
# Training: On Tick: 119 loss 0.7696585059165955
# max: 0
# Training: On Tick: 120 loss 0.39559948444366455
# max: 19
# Training: On Tick: 121 loss 0.5537904500961304
# max: 7
# Training: On Tick: 122 loss 1.1844323873519897
# max: 20
# Training: On Tick: 123 loss 0.8083545565605164
# max: 7
# Training: On Tick: 124 loss 0.338851660490036
# max: 15
# Training: On Tick: 125 loss 0.5538895726203918
# max: 15
# Training: On Tick: 126 loss 1.0755252838134766
# max: 20
# Training: On Tick: 127 loss 0.6163926124572754
# max: 14
# Training: On Tick: 128 loss 0.8101656436920166
# max: 15
# Training: On Tick: 129 loss 1.4286929368972778
# max: 20
# Training: On Tick: 130 loss 0.5626465082168579
# max: 11
# Training: On Tick: 131 loss 0.5122466087341309
# max: 15
# Training: On Tick: 132 loss 0.8313584923744202
# max: 15
# Training: On Tick: 133 loss 0.5235917568206787
# max: 19
# Training: On Tick: 134 loss 0.46972060203552246
# max: 0
# Training: On Tick: 135 loss 0.4511778652667999
# max: 12
# Training: On Tick: 136 loss 0.6119890809059143
# max: 7
# Training: On Tick: 137 loss 0.38807860016822815
# max: 15
# Training: On Tick: 138 loss 0.5872547626495361
# max: 15
# Training: On Tick: 139 loss 1.0173711776733398
# max: 15
# Training: On Tick: 140 loss 0.6613033413887024
# max: 14
# Training: On Tick: 141 loss 0.5917519330978394
# max: 18
# Training: On Tick: 142 loss 1.7750078439712524
# max: 15
# Training: On Tick: 143 loss 0.7159219980239868
# max: 19
# Training: On Tick: 144 loss 0.6697080135345459
# max: 20
# Training: On Tick: 145 loss 0.7941867709159851
# max: 20
# Training: On Tick: 146 loss 0.7633050084114075
# max: 20
# Training: On Tick: 147 loss 0.5241129398345947
# max: 20
# Training: On Tick: 148 loss 0.9616585373878479
# max: 17
# Training: On Tick: 149 loss 0.2718707323074341
# max: 19
# Training: On Tick: 150 loss 0.8587702512741089
# max: 17
# Training: On Tick: 151 loss 0.6058586239814758
# max: 0
# Training: On Tick: 152 loss 0.2694915235042572
# max: 19
# Training: On Tick: 153 loss 0.4778740108013153
# max: 17
# Training: On Tick: 154 loss 0.9660857915878296
# max: 20
# Training: On Tick: 155 loss 0.4189019501209259
# max: 17
# Training: On Tick: 156 loss 0.36069557070732117
# max: 17
# Training: On Tick: 157 loss 0.6131429076194763
# max: 12
# Training: On Tick: 158 loss 0.9417034983634949
# max: 18
# Training: On Tick: 159 loss 0.4462747573852539
# max: 18
# Training: On Tick: 160 loss 0.6941633224487305
# max: 4
# Training: On Tick: 161 loss 0.3829478919506073
# max: 17
# Training: On Tick: 162 loss 0.5145907998085022
# max: 18
# Training: On Tick: 163 loss 0.8339748382568359
# max: 19
# Training: On Tick: 164 loss 0.3749925196170807
# max: 18
# Training: On Tick: 165 loss 0.8224079608917236
# max: 12
# Training: On Tick: 166 loss 0.39107397198677063
# max: 18
# Training: On Tick: 167 loss 0.3701089024543762
# max: 19
# Training: On Tick: 168 loss 0.42676931619644165
# max: 0
# Training: On Tick: 169 loss 0.6874378323554993
# max: 19
# Training: On Tick: 170 loss 0.5310124158859253
# max: 20
# Training: On Tick: 171 loss 0.577700674533844
# max: 19
# Training: On Tick: 172 loss 0.5730844140052795
# max: 15
# Training: On Tick: 173 loss 0.7189030051231384
# max: 12
# Training: On Tick: 174 loss 0.5226800441741943
# max: 17
# Training: On Tick: 175 loss 0.5790387392044067
# max: 19
# Training: On Tick: 176 loss 0.4733138382434845
# max: 19
# Training: On Tick: 177 loss 0.33933767676353455
# max: 17
# Training: On Tick: 178 loss 0.5096854567527771
# max: 19
# Training: On Tick: 179 loss 0.3608037233352661
# max: 17
# Training: On Tick: 180 loss 0.9846072793006897
# max: 15
# Training: On Tick: 181 loss 0.5934435725212097
# max: 19
# Training: On Tick: 182 loss 0.7972858548164368
# max: 20
# Training: On Tick: 183 loss 0.6449497938156128
# max: 17
# Training: On Tick: 184 loss 0.5832503437995911
# max: 15
# Training: On Tick: 185 loss 0.3891584575176239
# max: 15
# Training: On Tick: 186 loss 0.742390513420105
# max: 16
# Training: On Tick: 187 loss 0.7060002088546753
# max: 0
# Training: On Tick: 188 loss 0.6002583503723145
# max: 20
# Training: On Tick: 189 loss 0.5100441575050354
# max: 17
# Training: On Tick: 190 loss 0.6036615371704102
# max: 15
# Training: On Tick: 191 loss 0.6740002632141113
# max: 15
# Training: On Tick: 192 loss 0.8201896548271179
# max: 15
# Training: On Tick: 193 loss 0.3589874505996704
# max: 20
# Training: On Tick: 194 loss 0.7683780193328857
# max: 16
# Training: On Tick: 195 loss 0.39963218569755554
# max: 18
# Training: On Tick: 196 loss 0.4538554251194
# max: 14
# Training: On Tick: 197 loss 1.0206633806228638
# max: 18
# Training: On Tick: 198 loss 0.7461296916007996
# max: 18
# Training: On Tick: 199 loss 0.6739667057991028
# max: 19
# Training: On Tick: 200 loss 1.174329400062561
# max: 17
# Training: On Tick: 201 loss 0.4653925597667694
# max: 18
# Training: On Tick: 202 loss 0.40682530403137207
# max: 17
# Training: On Tick: 203 loss 1.4842445850372314
# max: 17
# Training: On Tick: 204 loss 0.6254135966300964
# max: 14
# Training: On Tick: 205 loss 1.1387213468551636
# max: 20
# Training: On Tick: 206 loss 0.8502742648124695
# max: 13
# Training: On Tick: 207 loss 0.3475262522697449
# max: 15
# Training: On Tick: 208 loss 0.45410701632499695
# max: 19
# Training: On Tick: 209 loss 0.6965973377227783
# max: 15
# Training: On Tick: 210 loss 0.5855716466903687
# max: 20
# Training: On Tick: 211 loss 0.7236917018890381
# max: 15
# Training: On Tick: 212 loss 0.3878067135810852
# max: 20
# Training: On Tick: 213 loss 1.2893420457839966
# max: 16
# Training: On Tick: 214 loss 0.5874955058097839
# max: 19
# Training: On Tick: 215 loss 0.8225980401039124
# max: 16
# Training: On Tick: 216 loss 2.0399258136749268
# max: 16
# Training: On Tick: 217 loss 0.5333913564682007
# max: 14
# Training: On Tick: 218 loss 0.5334727168083191
# max: 16
# Training: On Tick: 219 loss 0.5496269464492798
# max: 18
# Training: On Tick: 220 loss 0.5892933011054993
# max: 19
# Training: On Tick: 221 loss 0.5736109614372253
# max: 18
# Training: On Tick: 222 loss 0.432564914226532
# max: 19
# Training: On Tick: 223 loss 0.5936555862426758
# max: 15
# Training: On Tick: 224 loss 0.5613237023353577
# max: 17
# Training: On Tick: 225 loss 0.7672532796859741
# max: 18
# Training: On Tick: 226 loss 1.0500892400741577
# max: 14
# Training: On Tick: 227 loss 0.4247599244117737
# max: 14
# Training: On Tick: 228 loss 0.7493573427200317
# max: 18
# Training: On Tick: 229 loss 0.4727436602115631
# max: 0
# Training: On Tick: 230 loss 0.3800305724143982
# max: 0
# Training: On Tick: 231 loss 0.7723507881164551
# max: 18
# Training: On Tick: 232 loss 0.8553942441940308
# max: 8
# Training: On Tick: 233 loss 0.5875999331474304
# max: 19
# Training: On Tick: 234 loss 0.6111788749694824
# max: 19
# Training: On Tick: 235 loss 0.8950667977333069
# max: 18
# Training: On Tick: 236 loss 0.33892834186553955
# max: 18
# Training: On Tick: 237 loss 0.5380590558052063
# max: 18
# Training: On Tick: 238 loss 0.9202015995979309
# max: 0
# Training: On Tick: 239 loss 0.4834696054458618
# max: 18
# Training: On Tick: 240 loss 0.6641928553581238
# max: 11
# Training: On Tick: 241 loss 0.5687859058380127
# max: 1
# Training: On Tick: 242 loss 0.24862463772296906
# max: 19
# Training: On Tick: 243 loss 0.5109720826148987
# max: 15
# Training: On Tick: 244 loss 0.6662231683731079
# max: 0
# Training: On Tick: 245 loss 0.5587660074234009
# max: 11
# Training: On Tick: 246 loss 0.775790810585022
# max: 0
# Training: On Tick: 247 loss 0.47208595275878906
# max: 0
# Training: On Tick: 248 loss 0.27319514751434326
# max: 14
# Training: On Tick: 249 loss 0.6520255208015442
# max: 18
# Training: On Tick: 250 loss 0.6852587461471558
# max: 18
# Training: On Tick: 251 loss 0.33787378668785095
# max: 8
# Training: On Tick: 252 loss 0.4829520285129547
# max: 8
# Training: On Tick: 253 loss 0.39152002334594727
# max: 4
# Training: On Tick: 254 loss 0.3694896697998047
# max: 18
# Training: On Tick: 255 loss 1.2535207271575928
# max: 15
# Training: On Tick: 256 loss 0.8765248656272888
# max: 15
# Training: On Tick: 257 loss 0.44991540908813477
# max: 8
# Training: On Tick: 258 loss 0.7166748642921448
# max: 8
# Training: On Tick: 259 loss 1.0775775909423828
# max: 19
# Training: On Tick: 260 loss 1.5579534769058228
# max: 16
# Training: On Tick: 261 loss 1.0494881868362427
# max: 19
# Training: On Tick: 262 loss 0.5007877349853516
# max: 16
# Training: On Tick: 263 loss 0.7625604271888733
# max: 17
# Training: On Tick: 264 loss 0.588241696357727
# max: 19
# Training: On Tick: 265 loss 0.9055953025817871
# max: 13
# Training: On Tick: 266 loss 1.4756804704666138
# max: 7
# Training: On Tick: 267 loss 0.42340078949928284
# max: 11
# Training: On Tick: 268 loss 0.8915643095970154
# max: 1
# Training: On Tick: 269 loss 0.4870859682559967
# max: 12
# Training: On Tick: 270 loss 0.7094036936759949
# max: 15
# Training: On Tick: 271 loss 0.30943411588668823
# max: 16
# Training: On Tick: 272 loss 0.8269580602645874
# max: 19
# Training: On Tick: 273 loss 0.4201776385307312
# max: 17
# Training: On Tick: 274 loss 0.45272794365882874
# max: 15
# Training: On Tick: 275 loss 0.6846110820770264
# max: 15
# Training: On Tick: 276 loss 0.2948731780052185
# max: 18
# Training: On Tick: 277 loss 0.6355334520339966
# max: 18
# Training: On Tick: 278 loss 0.8119975328445435
# max: 18
# Training: On Tick: 279 loss 0.342180997133255
# max: 12
# Training: On Tick: 280 loss 1.2925766706466675
# max: 19
# Training: On Tick: 281 loss 0.934698224067688
# max: 18
# Training: On Tick: 282 loss 1.3605756759643555
# max: 15
# Training: On Tick: 283 loss 0.40083256363868713
# max: 14
# Training: On Tick: 284 loss 0.5490716099739075
# max: 15
# Training: On Tick: 285 loss 1.0911864042282104
# max: 15
# Training: On Tick: 286 loss 0.9436282515525818
# max: 7
# Training: On Tick: 287 loss 0.3926234543323517
# max: 18
# Training: On Tick: 288 loss 0.7448345422744751
# max: 19
# Training: On Tick: 289 loss 0.46920958161354065
# max: 19
# Training: On Tick: 290 loss 0.6439785957336426
# max: 19
# Training: On Tick: 291 loss 0.8481158018112183
# max: 19
# Training: On Tick: 292 loss 0.9018514752388
# max: 12
# Training: On Tick: 293 loss 0.5887250304222107
# max: 19
# Training: On Tick: 294 loss 1.3319261074066162
# max: 18
# Training: On Tick: 295 loss 0.7793575525283813
# max: 18
# Training: On Tick: 296 loss 1.0735492706298828
# max: 17
# Training: On Tick: 297 loss 0.8610871434211731
# max: 19
# Training: On Tick: 298 loss 0.631686270236969
# max: 18
# Training: On Tick: 299 loss 0.5958224534988403
# max: 0
# Training: On Tick: 300 loss 0.7372287511825562
# max: 0
# Training: On Tick: 301 loss 0.5053471326828003
# max: 19
# Training: On Tick: 302 loss 0.3470275402069092
# max: 17
# Training: On Tick: 303 loss 0.9064821600914001
# max: 18
# Training: On Tick: 304 loss 0.5632701516151428
# max: 19
# Training: On Tick: 305 loss 0.4993628263473511
# max: 19
# Training: On Tick: 306 loss 0.5745528936386108
# max: 0
# Training: On Tick: 307 loss 0.33811020851135254
# max: 17
# Training: On Tick: 308 loss 0.33256110548973083
# max: 19
# Training: On Tick: 309 loss 0.5210147500038147
# max: 20
# Training: On Tick: 310 loss 1.2123420238494873
# max: 17
# Training: On Tick: 311 loss 0.6068115830421448
# max: 19
# Training: On Tick: 312 loss 0.6992781758308411
# max: 12
# Training: On Tick: 313 loss 1.3974252939224243
# max: 17
# Training: On Tick: 314 loss 1.3522205352783203
# max: 15
# Training: On Tick: 315 loss 1.4025585651397705
# max: 0
# Training: On Tick: 316 loss 0.5530053377151489
# max: 1
# Training: On Tick: 317 loss 0.803632915019989
# max: 19
# Training: On Tick: 318 loss 0.6413663625717163
# max: 17
# Training: On Tick: 319 loss 0.7989283204078674
# max: 18
# Training: On Tick: 320 loss 0.9348344802856445
# max: 18
# Training: On Tick: 321 loss 1.2557841539382935
# max: 15
# Training: On Tick: 322 loss 0.9123831391334534
# max: 16
# Training: On Tick: 323 loss 0.41274112462997437
# max: 20
# Training: On Tick: 324 loss 0.8344417810440063
# max: 4
# Training: On Tick: 325 loss 0.6986538767814636
# max: 20
# Training: On Tick: 326 loss 1.4936258792877197
# max: 16
# Training: On Tick: 327 loss 0.951928436756134
# max: 18
# Training: On Tick: 328 loss 0.6432201862335205
# max: 20
# Training: On Tick: 329 loss 0.9160861968994141
# max: 19
# Training: On Tick: 330 loss 0.5681993365287781
# max: 19
# Training: On Tick: 331 loss 1.010650634765625
# max: 18
# Training: On Tick: 332 loss 0.6224710941314697
# max: 18
# Training: On Tick: 333 loss 1.3379875421524048
# max: 15
# Training: On Tick: 334 loss 1.2442915439605713
# max: 18
# Training: On Tick: 335 loss 0.3549802601337433
# max: 19
# Training: On Tick: 336 loss 0.5149416327476501
# max: 18
# Training: On Tick: 337 loss 2.869572639465332
# max: 16
# Training: On Tick: 338 loss 0.868975043296814
# max: 19
# Training: On Tick: 339 loss 0.6999980807304382
# max: 17
# Training: On Tick: 340 loss 0.8198534846305847
# max: 19
# Training: On Tick: 341 loss 0.6351058483123779
# max: 19
# Training: On Tick: 342 loss 0.6034007668495178
# max: 18
# Training: On Tick: 343 loss 1.172966718673706
# max: 19
# Training: On Tick: 344 loss 0.5009161233901978
# max: 18
# Training: On Tick: 345 loss 0.9307878017425537
# max: 1
# Training: On Tick: 346 loss 0.4696820378303528
# max: 18
# Training: On Tick: 347 loss 0.4727824926376343
# max: 14
# Training: On Tick: 348 loss 0.44264253973960876
# max: 18
# Training: On Tick: 349 loss 0.8525053858757019
# max: 19
# Training: On Tick: 350 loss 1.328818440437317
# max: 15
# Training: On Tick: 351 loss 0.32017987966537476
# max: 6
# Training: On Tick: 352 loss 0.3862279951572418
# max: 18
# Training: On Tick: 353 loss 0.5588761568069458
# max: 14
# Training: On Tick: 354 loss 0.6317117214202881
# max: 18
# Training: On Tick: 355 loss 0.7372018694877625
# max: 18
# Training: On Tick: 356 loss 0.7498106956481934
# max: 17
# Training: On Tick: 357 loss 1.142013430595398
# max: 15
# Training: On Tick: 358 loss 1.1913652420043945
# max: 13
# Training: On Tick: 359 loss 0.5795383453369141
# max: 17
# Training: On Tick: 360 loss 0.5939463376998901
# max: 17
# Training: On Tick: 361 loss 0.5869316458702087
# max: 18
# Training: On Tick: 362 loss 0.8361964225769043
# max: 18
# Training: On Tick: 363 loss 1.1768287420272827
# max: 14
# Training: On Tick: 364 loss 0.6930673122406006
# max: 17
# Training: On Tick: 365 loss 0.5484158992767334
# Epoch: 1 Loss: 0.8812727332115173
# Starting Epoch 2
# max: 19
# Training: On Tick: 0 loss 0.7248827815055847
# max: 17
# Training: On Tick: 1 loss 0.6118788719177246
# max: 18
# Training: On Tick: 2 loss 0.7535153031349182
# max: 15
# Training: On Tick: 3 loss 0.558249831199646
# max: 0
# Training: On Tick: 4 loss 0.7235687375068665
# max: 17
# Training: On Tick: 5 loss 0.6539223790168762
# max: 15
# Training: On Tick: 6 loss 0.5298564434051514
# max: 14
# Training: On Tick: 7 loss 0.6481297016143799
# max: 15
# Training: On Tick: 8 loss 0.5440504550933838
# max: 15
# Training: On Tick: 9 loss 0.6879577040672302
# max: 17
# Training: On Tick: 10 loss 0.38661909103393555
# max: 19
# Training: On Tick: 11 loss 1.1211036443710327
# max: 15
# Training: On Tick: 12 loss 0.9085196852684021
# max: 17
# Training: On Tick: 13 loss 1.4194518327713013
# max: 17
# Training: On Tick: 14 loss 0.36090415716171265
# max: 17
# Training: On Tick: 15 loss 0.8033530712127686
# max: 18
# Training: On Tick: 16 loss 0.4273897409439087
# max: 19
# Training: On Tick: 17 loss 0.48246094584465027
# max: 19
# Training: On Tick: 18 loss 0.6089261770248413
# max: 20
# Training: On Tick: 19 loss 0.3771151006221771
# max: 18
# Training: On Tick: 20 loss 1.2317248582839966
# max: 17
# Training: On Tick: 21 loss 0.32937660813331604
# max: 15
# Training: On Tick: 22 loss 0.6405224800109863
# max: 15
# Training: On Tick: 23 loss 0.30536967515945435
# max: 19
# Training: On Tick: 24 loss 0.3989126682281494
# max: 18
# Training: On Tick: 25 loss 0.9224008321762085
# max: 19
# Training: On Tick: 26 loss 0.4200245141983032
# max: 18
# Training: On Tick: 27 loss 0.4274301528930664
# max: 15
# Training: On Tick: 28 loss 0.6598091721534729
# max: 19
# Training: On Tick: 29 loss 0.9942166209220886
# max: 0
# Training: On Tick: 30 loss 0.4671865701675415
# max: 1
# Training: On Tick: 31 loss 0.5958161354064941
# max: 15
# Training: On Tick: 32 loss 0.5444435477256775
# max: 19
# Training: On Tick: 33 loss 0.4452541768550873
# max: 18
# Training: On Tick: 34 loss 0.5026957988739014
# max: 11
# Training: On Tick: 35 loss 0.5450149774551392
# max: 7
# Training: On Tick: 36 loss 0.23297156393527985
# max: 7
# Training: On Tick: 37 loss 0.30292654037475586
# max: 17
# Training: On Tick: 38 loss 0.9421047568321228
# max: 11
# Training: On Tick: 39 loss 0.4853931665420532
# max: 7
# Training: On Tick: 40 loss 0.7074271440505981
# max: 15
# Training: On Tick: 41 loss 0.8129175305366516
# max: 15
# Training: On Tick: 42 loss 0.5947310328483582
# max: 17
# Training: On Tick: 43 loss 0.4591822624206543
# max: 15
# Training: On Tick: 44 loss 0.3894559442996979
# max: 20
# Training: On Tick: 45 loss 0.5286967158317566
# max: 19
# Training: On Tick: 46 loss 0.4983961284160614
# max: 17
# Training: On Tick: 47 loss 1.0818673372268677
# max: 17
# Training: On Tick: 48 loss 0.38986441493034363
# max: 18
# Training: On Tick: 49 loss 0.46654441952705383
# max: 15
# Training: On Tick: 50 loss 0.5164692401885986
# max: 1
# Training: On Tick: 51 loss 0.6721099019050598
# max: 17
# Training: On Tick: 52 loss 0.8861861824989319
# max: 17
# Training: On Tick: 53 loss 0.8180604577064514
# max: 17
# Training: On Tick: 54 loss 0.35423964262008667
# max: 15
# Training: On Tick: 55 loss 0.9321378469467163
# max: 18
# Training: On Tick: 56 loss 0.6248970627784729
# max: 0
# Training: On Tick: 57 loss 0.5545151233673096
# max: 17
# Training: On Tick: 58 loss 0.6459534168243408
# max: 17
# Training: On Tick: 59 loss 0.4444653391838074
# max: 16
# Training: On Tick: 60 loss 0.6187990307807922
# max: 17
# Training: On Tick: 61 loss 0.2931046485900879
# max: 15
# Training: On Tick: 62 loss 0.4732568860054016
# max: 20
# Training: On Tick: 63 loss 0.40343013405799866
# max: 18
# Training: On Tick: 64 loss 0.6672201752662659
# max: 19
# Training: On Tick: 65 loss 0.7292068600654602
# max: 15
# Training: On Tick: 66 loss 0.7762048840522766
# max: 17
# Training: On Tick: 67 loss 0.5901474952697754
# max: 19
# Training: On Tick: 68 loss 0.5255319476127625
# max: 15
# Training: On Tick: 69 loss 0.9891212582588196
# max: 15
# Training: On Tick: 70 loss 0.5869207978248596
# max: 20
# Training: On Tick: 71 loss 0.5438246726989746
# max: 14
# Training: On Tick: 72 loss 0.4102919399738312
# max: 19
# Training: On Tick: 73 loss 0.4150349795818329
# max: 17
# Training: On Tick: 74 loss 0.9871475100517273
# max: 8
# Training: On Tick: 75 loss 0.748182475566864
# max: 17
# Training: On Tick: 76 loss 0.7718046307563782
# max: 15
# Training: On Tick: 77 loss 0.8590685725212097
# max: 17
# Training: On Tick: 78 loss 0.3699371814727783
# max: 20
# Training: On Tick: 79 loss 0.3992180824279785
# max: 15
# Training: On Tick: 80 loss 0.6351302266120911
# max: 4
# Training: On Tick: 81 loss 0.22486141324043274
# max: 15
# Training: On Tick: 82 loss 0.7361197471618652
# max: 18
# Training: On Tick: 83 loss 0.502029299736023
# max: 20
# Training: On Tick: 84 loss 0.3751702606678009
# max: 17
# Training: On Tick: 85 loss 0.2551940679550171
# max: 15
# Training: On Tick: 86 loss 0.33553454279899597
# max: 16
# Training: On Tick: 87 loss 1.1083735227584839
# max: 15
# Training: On Tick: 88 loss 0.5407891869544983
# max: 19
# Training: On Tick: 89 loss 0.5023820996284485
# max: 15
# Training: On Tick: 90 loss 0.5943953394889832
# max: 4
# Training: On Tick: 91 loss 0.6588708162307739
# max: 15
# Training: On Tick: 92 loss 0.47891342639923096
# max: 19
# Training: On Tick: 93 loss 0.5065604448318481
# max: 18
# Training: On Tick: 94 loss 0.34878140687942505
# max: 19
# Training: On Tick: 95 loss 0.43861082196235657
# max: 19
# Training: On Tick: 96 loss 0.31933897733688354
# max: 18
# Training: On Tick: 97 loss 0.44476544857025146
# max: 14
# Training: On Tick: 98 loss 0.5214011669158936
# max: 18
# Training: On Tick: 99 loss 0.47910231351852417
# max: 16
# Training: On Tick: 100 loss 0.368789404630661
# max: 15
# Training: On Tick: 101 loss 0.25675058364868164
# max: 17
# Training: On Tick: 102 loss 0.5586323738098145
# max: 15
# Training: On Tick: 103 loss 0.41315561532974243
# max: 15
# Training: On Tick: 104 loss 0.2987509071826935
# max: 15
# Training: On Tick: 105 loss 0.5979045629501343
# max: 15
# Training: On Tick: 106 loss 0.8245242834091187
# max: 3
# Training: On Tick: 107 loss 0.48888227343559265
# max: 15
# Training: On Tick: 108 loss 0.30418282747268677
# max: 3
# Training: On Tick: 109 loss 0.3840552866458893
# max: 14
# Training: On Tick: 110 loss 0.1387307345867157
# max: 7
# Training: On Tick: 111 loss 0.3209098279476166
# max: 15
# Training: On Tick: 112 loss 0.751992404460907
# max: 19
# Training: On Tick: 113 loss 0.8022834658622742
# max: 7
# Training: On Tick: 114 loss 0.4273565709590912
# max: 14
# Training: On Tick: 115 loss 0.28487107157707214
# max: 15
# Training: On Tick: 116 loss 0.46199822425842285
# max: 17
# Training: On Tick: 117 loss 0.8814638257026672
# max: 20
# Training: On Tick: 118 loss 0.339668333530426
# max: 18
# Training: On Tick: 119 loss 0.5086542367935181
# max: 0
# Training: On Tick: 120 loss 0.3415212631225586
# max: 19
# Training: On Tick: 121 loss 0.5287917256355286
# max: 1
# Training: On Tick: 122 loss 0.8957334756851196
# max: 20
# Training: On Tick: 123 loss 0.5591959357261658
# max: 20
# Training: On Tick: 124 loss 0.2836301624774933
# max: 15
# Training: On Tick: 125 loss 0.44563665986061096
# max: 15
# Training: On Tick: 126 loss 0.8334581255912781
# max: 20
# Training: On Tick: 127 loss 0.5340226888656616
# max: 14
# Training: On Tick: 128 loss 0.5387260913848877
# max: 15
# Training: On Tick: 129 loss 1.123379111289978
# max: 20
# Training: On Tick: 130 loss 0.3541058599948883
# max: 20
# Training: On Tick: 131 loss 0.45984527468681335
# max: 19
# Training: On Tick: 132 loss 0.7203761339187622
# max: 15
# Training: On Tick: 133 loss 0.4432079493999481
# max: 14
# Training: On Tick: 134 loss 0.38078773021698
# max: 11
# Training: On Tick: 135 loss 0.40102991461753845
# max: 15
# Training: On Tick: 136 loss 0.4615291953086853
# max: 7
# Training: On Tick: 137 loss 0.30785512924194336
# max: 15
# Training: On Tick: 138 loss 0.4183834493160248
# max: 15
# Training: On Tick: 139 loss 0.76896071434021
# max: 13
# Training: On Tick: 140 loss 0.542182445526123
# max: 18
# Training: On Tick: 141 loss 0.4575841724872589
# max: 18
# Training: On Tick: 142 loss 1.3407399654388428
# max: 15
# Training: On Tick: 143 loss 0.586432933807373
# max: 19
# Training: On Tick: 144 loss 0.49235785007476807
# max: 20
# Training: On Tick: 145 loss 0.5860306024551392
# max: 19
# Training: On Tick: 146 loss 0.5994463562965393
# max: 20
# Training: On Tick: 147 loss 0.3851863741874695
# max: 20
# Training: On Tick: 148 loss 0.7839090824127197
# max: 17
# Training: On Tick: 149 loss 0.20214125514030457
# max: 19
# Training: On Tick: 150 loss 0.6789470314979553
# max: 17
# Training: On Tick: 151 loss 0.3888571858406067
# max: 17
# Training: On Tick: 152 loss 0.1848493218421936
# max: 19
# Training: On Tick: 153 loss 0.3678431808948517
# max: 17
# Training: On Tick: 154 loss 0.7599412798881531
# max: 20
# Training: On Tick: 155 loss 0.38467612862586975
# max: 17
# Training: On Tick: 156 loss 0.3150613605976105
# max: 17
# Training: On Tick: 157 loss 0.506219208240509
# max: 17
# Training: On Tick: 158 loss 0.7707095742225647
# max: 20
# Training: On Tick: 159 loss 0.3590873181819916
# max: 18
# Training: On Tick: 160 loss 0.5264043807983398
# max: 4
# Training: On Tick: 161 loss 0.28986963629722595
# max: 18
# Training: On Tick: 162 loss 0.4155057966709137
# max: 12
# Training: On Tick: 163 loss 0.6673543453216553
# max: 20
# Training: On Tick: 164 loss 0.25603336095809937
# max: 18
# Training: On Tick: 165 loss 0.6357648372650146
# max: 12
# Training: On Tick: 166 loss 0.2870939075946808
# max: 18
# Training: On Tick: 167 loss 0.3491673767566681
# max: 19
# Training: On Tick: 168 loss 0.3603147864341736
# max: 0
# Training: On Tick: 169 loss 0.6107551455497742
# max: 19
# Training: On Tick: 170 loss 0.40216684341430664
# max: 20
# Training: On Tick: 171 loss 0.4597679674625397
# max: 19
# Training: On Tick: 172 loss 0.4868703782558441
# max: 15
# Training: On Tick: 173 loss 0.5647991895675659
# max: 12
# Training: On Tick: 174 loss 0.4689459204673767
# max: 13
# Training: On Tick: 175 loss 0.41030287742614746
# max: 19
# Training: On Tick: 176 loss 0.42417705059051514
# max: 19
# Training: On Tick: 177 loss 0.26206132769584656
# max: 13
# Training: On Tick: 178 loss 0.4405522346496582
# max: 19
# Training: On Tick: 179 loss 0.2838839888572693
# max: 18
# Training: On Tick: 180 loss 0.7272759675979614
# max: 15
# Training: On Tick: 181 loss 0.42606738209724426
# max: 19
# Training: On Tick: 182 loss 0.611886203289032
# max: 20
# Training: On Tick: 183 loss 0.37021759152412415
# max: 13
# Training: On Tick: 184 loss 0.455779492855072
# max: 15
# Training: On Tick: 185 loss 0.26028889417648315
# max: 13
# Training: On Tick: 186 loss 0.5934062004089355
# max: 18
# Training: On Tick: 187 loss 0.5093576312065125
# max: 16
# Training: On Tick: 188 loss 0.47542157769203186
# max: 20
# Training: On Tick: 189 loss 0.38936761021614075
# max: 17
# Training: On Tick: 190 loss 0.5084030628204346
# max: 15
# Training: On Tick: 191 loss 0.5022964477539062
# max: 8
# Training: On Tick: 192 loss 0.6240659356117249
# max: 15
# Training: On Tick: 193 loss 0.2746601104736328
# max: 20
# Training: On Tick: 194 loss 0.5861796140670776
# max: 20
# Training: On Tick: 195 loss 0.3245251476764679
# max: 17
# Training: On Tick: 196 loss 0.45104506611824036
# max: 16
# Training: On Tick: 197 loss 0.5727819204330444
# max: 18
# Training: On Tick: 198 loss 0.5176690816879272
# max: 20
# Training: On Tick: 199 loss 0.544965922832489
# max: 14
# Training: On Tick: 200 loss 0.9894900321960449
# max: 13
# Training: On Tick: 201 loss 0.3120535910129547
# max: 20
# Training: On Tick: 202 loss 0.275861918926239
# max: 17
# Training: On Tick: 203 loss 1.2115083932876587
# max: 17
# Training: On Tick: 204 loss 0.5263271331787109
# max: 15
# Training: On Tick: 205 loss 0.8105812072753906
# max: 20
# Training: On Tick: 206 loss 0.6972169280052185
# max: 13
# Training: On Tick: 207 loss 0.3162962794303894
# max: 20
# Training: On Tick: 208 loss 0.4074864387512207
# max: 17
# Training: On Tick: 209 loss 0.5906729102134705
# max: 16
# Training: On Tick: 210 loss 0.47946053743362427
# max: 20
# Training: On Tick: 211 loss 0.487223356962204
# max: 14
# Training: On Tick: 212 loss 0.26165464520454407
# max: 20
# Training: On Tick: 213 loss 0.9434198141098022
# max: 16
# Training: On Tick: 214 loss 0.4328325688838959
# max: 19
# Training: On Tick: 215 loss 0.5677952170372009
# max: 20
# Training: On Tick: 216 loss 1.4458999633789062
# max: 16
# Training: On Tick: 217 loss 0.44984689354896545
# max: 15
# Training: On Tick: 218 loss 0.4174225926399231
# max: 18
# Training: On Tick: 219 loss 0.4258405566215515
# max: 18
# Training: On Tick: 220 loss 0.4641595780849457
# max: 19
# Training: On Tick: 221 loss 0.4197304844856262
# max: 4
# Training: On Tick: 222 loss 0.29826927185058594
# max: 20
# Training: On Tick: 223 loss 0.40406203269958496
# max: 15
# Training: On Tick: 224 loss 0.387534499168396
# max: 17
# Training: On Tick: 225 loss 0.6043652892112732
# max: 18
# Training: On Tick: 226 loss 0.8160435557365417
# max: 14
# Training: On Tick: 227 loss 0.31579795479774475
# max: 14
# Training: On Tick: 228 loss 0.5746160745620728
# max: 17
# Training: On Tick: 229 loss 0.34590423107147217
# max: 0
# Training: On Tick: 230 loss 0.2735340893268585
# max: 16
# Training: On Tick: 231 loss 0.5400797128677368
# max: 18
# Training: On Tick: 232 loss 0.7108721137046814
# max: 8
# Training: On Tick: 233 loss 0.39248329401016235
# max: 19
# Training: On Tick: 234 loss 0.5368955135345459
# max: 19
# Training: On Tick: 235 loss 0.558426558971405
# max: 18
# Training: On Tick: 236 loss 0.2892118990421295
# max: 18
# Training: On Tick: 237 loss 0.4366283714771271
# max: 18
# Training: On Tick: 238 loss 0.6938220262527466
# max: 0
# Training: On Tick: 239 loss 0.29339873790740967
# max: 18
# Training: On Tick: 240 loss 0.48042032122612
# max: 4
# Training: On Tick: 241 loss 0.4539872109889984
# max: 1
# Training: On Tick: 242 loss 0.20728395879268646
# max: 11
# Training: On Tick: 243 loss 0.4214150011539459
# max: 15
# Training: On Tick: 244 loss 0.5620291829109192
# max: 15
# Training: On Tick: 245 loss 0.48766762018203735
# max: 12
# Training: On Tick: 246 loss 0.6011655330657959
# max: 0
# Training: On Tick: 247 loss 0.3142707347869873
# max: 0
# Training: On Tick: 248 loss 0.21467053890228271
# max: 14
# Training: On Tick: 249 loss 0.46234872937202454
# max: 18
# Training: On Tick: 250 loss 0.607853889465332
# max: 18
# Training: On Tick: 251 loss 0.2167120724916458
# max: 8
# Training: On Tick: 252 loss 0.41560789942741394
# max: 8
# Training: On Tick: 253 loss 0.32531389594078064
# max: 4
# Training: On Tick: 254 loss 0.2878980040550232
# max: 18
# Training: On Tick: 255 loss 1.024300456047058
# max: 14
# Training: On Tick: 256 loss 0.5298985242843628
# max: 15
# Training: On Tick: 257 loss 0.34841132164001465
# max: 15
# Training: On Tick: 258 loss 0.5466298460960388
# max: 17
# Training: On Tick: 259 loss 0.8242441415786743
# max: 16
# Training: On Tick: 260 loss 1.2527023553848267
# max: 16
# Training: On Tick: 261 loss 0.6896729469299316
# max: 11
# Training: On Tick: 262 loss 0.37386730313301086
# max: 19
# Training: On Tick: 263 loss 0.6256101131439209
# max: 15
# Training: On Tick: 264 loss 0.5072424411773682
# max: 19
# Training: On Tick: 265 loss 0.5822767019271851
# max: 20
# Training: On Tick: 266 loss 1.1498101949691772
# max: 7
# Training: On Tick: 267 loss 0.3528572618961334
# max: 11
# Training: On Tick: 268 loss 0.6313249468803406
# max: 4
# Training: On Tick: 269 loss 0.34529733657836914
# max: 16
# Training: On Tick: 270 loss 0.5767251253128052
# max: 15
# Training: On Tick: 271 loss 0.2752242088317871
# max: 15
# Training: On Tick: 272 loss 0.6185190677642822
# max: 19
# Training: On Tick: 273 loss 0.29729849100112915
# max: 15
# Training: On Tick: 274 loss 0.39595159888267517
# max: 15
# Training: On Tick: 275 loss 0.6007335782051086
# max: 18
# Training: On Tick: 276 loss 0.23971720039844513
# max: 18
# Training: On Tick: 277 loss 0.4812791347503662
# max: 18
# Training: On Tick: 278 loss 0.5814883708953857
# max: 18
# Training: On Tick: 279 loss 0.27048102021217346
# max: 12
# Training: On Tick: 280 loss 1.0535658597946167
# max: 20
# Training: On Tick: 281 loss 0.6924387216567993
# max: 18
# Training: On Tick: 282 loss 1.0626131296157837
# max: 15
# Training: On Tick: 283 loss 0.25549745559692383
# max: 3
# Training: On Tick: 284 loss 0.5115563869476318
# max: 18
# Training: On Tick: 285 loss 0.8666603565216064
# max: 18
# Training: On Tick: 286 loss 0.6177260875701904
# max: 7
# Training: On Tick: 287 loss 0.3369296193122864
# max: 0
# Training: On Tick: 288 loss 0.47704315185546875
# max: 19
# Training: On Tick: 289 loss 0.33724069595336914
# max: 19
# Training: On Tick: 290 loss 0.5040584206581116
# max: 19
# Training: On Tick: 291 loss 0.7918720841407776
# max: 20
# Training: On Tick: 292 loss 0.6381562948226929
# max: 16
# Training: On Tick: 293 loss 0.5217928290367126
# max: 18
# Training: On Tick: 294 loss 0.9582093358039856
# max: 18
# Training: On Tick: 295 loss 0.524420440196991
# max: 18
# Training: On Tick: 296 loss 0.9375515580177307
# max: 17
# Training: On Tick: 297 loss 0.5934750437736511
# max: 19
# Training: On Tick: 298 loss 0.47462737560272217
# max: 17
# Training: On Tick: 299 loss 0.3882791996002197
# max: 0
# Training: On Tick: 300 loss 0.6499409675598145
# max: 0
# Training: On Tick: 301 loss 0.329287588596344
# max: 19
# Training: On Tick: 302 loss 0.2876795530319214
# max: 16
# Training: On Tick: 303 loss 0.6378787159919739
# max: 18
# Training: On Tick: 304 loss 0.5257577896118164
# max: 19
# Training: On Tick: 305 loss 0.3567352890968323
# max: 19
# Training: On Tick: 306 loss 0.39983931183815
# max: 0
# Training: On Tick: 307 loss 0.27631327509880066
# max: 17
# Training: On Tick: 308 loss 0.21472743153572083
# max: 19
# Training: On Tick: 309 loss 0.38712090253829956
# max: 20
# Training: On Tick: 310 loss 0.9128098487854004
# max: 17
# Training: On Tick: 311 loss 0.465801477432251
# max: 19
# Training: On Tick: 312 loss 0.5421963334083557
# max: 15
# Training: On Tick: 313 loss 1.089765191078186
# max: 17
# Training: On Tick: 314 loss 1.1268036365509033
# max: 15
# Training: On Tick: 315 loss 1.2608147859573364
# max: 4
# Training: On Tick: 316 loss 0.34657901525497437
# max: 20
# Training: On Tick: 317 loss 0.6787911653518677
# max: 18
# Training: On Tick: 318 loss 0.5149303674697876
# max: 17
# Training: On Tick: 319 loss 0.5982793569564819
# max: 18
# Training: On Tick: 320 loss 0.8262807726860046
# max: 18
# Training: On Tick: 321 loss 0.7997279167175293
# max: 15
# Training: On Tick: 322 loss 0.6356483101844788
# max: 16
# Training: On Tick: 323 loss 0.3518121838569641
# max: 20
# Training: On Tick: 324 loss 0.5625818967819214
# max: 9
# Training: On Tick: 325 loss 0.5397770404815674
# max: 20
# Training: On Tick: 326 loss 1.0588066577911377
# max: 16
# Training: On Tick: 327 loss 0.7343007326126099
# max: 18
# Training: On Tick: 328 loss 0.46709585189819336
# max: 20
# Training: On Tick: 329 loss 0.6050995588302612
# max: 17
# Training: On Tick: 330 loss 0.4259997606277466
# max: 19
# Training: On Tick: 331 loss 0.644152820110321
# max: 18
# Training: On Tick: 332 loss 0.4587945342063904
# max: 18
# Training: On Tick: 333 loss 1.0633049011230469
# max: 15
# Training: On Tick: 334 loss 0.8681597709655762
# max: 15
# Training: On Tick: 335 loss 0.30309024453163147
# max: 19
# Training: On Tick: 336 loss 0.4996735751628876
# max: 18
# Training: On Tick: 337 loss 2.076502799987793
# max: 16
# Training: On Tick: 338 loss 0.6832107901573181
# max: 19
# Training: On Tick: 339 loss 0.4867427349090576
# max: 18
# Training: On Tick: 340 loss 0.6919028162956238
# max: 19
# Training: On Tick: 341 loss 0.5438117384910583
# max: 19
# Training: On Tick: 342 loss 0.5102234482765198
# max: 18
# Training: On Tick: 343 loss 1.0297918319702148
# max: 19
# Training: On Tick: 344 loss 0.3661251366138458
# max: 18
# Training: On Tick: 345 loss 0.6542930006980896
# max: 1
# Training: On Tick: 346 loss 0.4406295120716095
# max: 18
# Training: On Tick: 347 loss 0.38077065348625183
# max: 14
# Training: On Tick: 348 loss 0.34647268056869507
# max: 17
# Training: On Tick: 349 loss 0.6264527440071106
# max: 19
# Training: On Tick: 350 loss 1.0816386938095093
# max: 15
# Training: On Tick: 351 loss 0.22076919674873352
# max: 6
# Training: On Tick: 352 loss 0.2881678640842438
# max: 18
# Training: On Tick: 353 loss 0.4946664571762085
# max: 15
# Training: On Tick: 354 loss 0.4705302119255066
# max: 18
# Training: On Tick: 355 loss 0.5928043723106384
# max: 17
# Training: On Tick: 356 loss 0.7895638942718506
# max: 17
# Training: On Tick: 357 loss 0.9272518157958984
# max: 18
# Training: On Tick: 358 loss 1.1441301107406616
# max: 3
# Training: On Tick: 359 loss 0.4026376008987427
# max: 15
# Training: On Tick: 360 loss 0.35452035069465637
# max: 17
# Training: On Tick: 361 loss 0.515228807926178
# max: 18
# Training: On Tick: 362 loss 0.7202315330505371
# max: 18
# Training: On Tick: 363 loss 0.9069823622703552
# max: 7
# Training: On Tick: 364 loss 0.5234740972518921
# max: 17
# Training: On Tick: 365 loss 0.48344388604164124
# Epoch: 2 Loss: 0.7731515765190125
# CPU times: user 1min 29s, sys: 7.65 s, total: 1min 37s
# Wall time: 1min 43s

# %%
# switch back to evaluation mode
trained_net.eval()

sample_img, sample_target = JointNormalize(*norm)(*JointToTensor()(*sample1))
if USE_GPU:
    sample_img = sample_img.cuda()
sample_output_O = overfit_net.forward(sample_img[None])
sample_output_T = trained_net.forward(sample_img[None])
print(sample_output_T.shape)

# computing mIOU (quantitative measure of accuracy for network predictions)
pred_T = torch.argmax(sample_output_T, dim=1).cpu().numpy()[0]
pred_O = torch.argmax(sample_output_O, dim=1).cpu().numpy()[0]
print(pred_T.max())
gts = torch.from_numpy(np.array(sample1[1].convert('P'), dtype=np.int32)).long().numpy()
gts[gts == 255] = -1
conf_T = eval_semantic_segmentation(pred_T[None], gts[None])
conf_O = eval_semantic_segmentation(pred_O[None], gts[None])


fig = plt.figure(figsize=(14,10))
ax1 = fig.add_subplot(2,2,1)
plt.title('image sample')
ax1.imshow(sample1[0])
ax2 = fig.add_subplot(2,2,2)
plt.title('ground truth (target)')
ax2.imshow(sample1[1])
ax3 = fig.add_subplot(2,2,3)
plt.title('OVERFIT_NET prediction (for its training image)')
ax3.text(10, 25, 'mIoU = {:_>8.6f}'.format(conf_O['miou']), fontsize=20, color='white')
ax3.imshow(colorize_mask(torch.argmax(sample_output_O, dim=1).cpu().numpy()[0]))
ax4 = fig.add_subplot(2,2,4)
plt.title('TRAINED_NET prediction (for one of its training images)')
ax4.text(10, 25, 'mIoU = {:_>8.6f}'.format(conf_T['miou']), fontsize=20, color='white')
ax4.imshow(colorize_mask(torch.argmax(sample_output_T, dim=1).cpu().numpy()[0]))
# Out:
# max: 15
# max: 18
# torch.Size([1, 21, 375, 500])
# 18
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:91: RuntimeWarning: invalid value encountered in true_divide
#   iou = np.diag(confusion) / iou_denominator
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:168: RuntimeWarning: invalid value encountered in true_divide
#   class_accuracy = np.diag(confusion) / np.sum(confusion, axis=1)

# %%
sample_img, sample_target = JointNormalize(*norm)(*JointToTensor()(*sample2))
if USE_GPU:
    sample_img = sample_img.cuda()
sample_output_O = overfit_net.forward(sample_img[None])
sample_output_T = trained_net.forward(sample_img[None])

# computing mIOU (quantitative measure of accuracy for network predictions)
pred_O = torch.argmax(sample_output_O, dim=1).cpu().numpy()[0]
pred_T = torch.argmax(sample_output_T, dim=1).cpu().numpy()[0]
gts = torch.from_numpy(np.array(sample2[1].convert('P'), dtype=np.int32)).long().numpy()
gts[gts == 255] = -1
conf_O = eval_semantic_segmentation(pred_O[None], gts[None])
conf_T = eval_semantic_segmentation(pred_T[None], gts[None])


fig = plt.figure(figsize=(14,10))
ax1 = fig.add_subplot(2,2,1)
plt.title('image sample')
ax1.imshow(sample2[0])
ax2 = fig.add_subplot(2,2,2)
plt.title('ground truth (target)')
ax2.imshow(sample2[1])
ax3 = fig.add_subplot(2,2,3)
plt.title('OVERFIT_NET prediction (for image it has not seen)')
ax3.text(10, 25, 'mIoU = {:_>8.6f}'.format(conf_O['miou']), fontsize=20, color='white')
ax3.imshow(colorize_mask(torch.argmax(sample_output_O, dim=1).cpu().numpy()[0]))
ax4 = fig.add_subplot(2,2,4)
plt.title('TRAINED_NET prediction (for image it has not seen)')
ax4.text(10, 25, 'mIoU = {:_>8.6f}'.format(conf_T['miou']), fontsize=20, color='white')
ax4.imshow(colorize_mask(torch.argmax(sample_output_T, dim=1).cpu().numpy()[0]))
# Out:
# max: 20
# max: 18
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:91: RuntimeWarning: invalid value encountered in true_divide
#   iou = np.diag(confusion) / iou_denominator
# /usr/local/lib/python3.6/dist-packages/chainercv/evaluations/eval_semantic_segmentation.py:168: RuntimeWarning: invalid value encountered in true_divide
#   class_accuracy = np.diag(confusion) / np.sum(confusion, axis=1)

# %% [markdown]
# #### (h) Evaluate TRAINED_NET on validation dataset.
# ##### Run the validation loop for TRAINED_NET against the validation dataset (it has not seen):

# %%
# %%time
# This will be slow on CPU (around 1 hour). On GPU it should take only a few minutes (depending on your GPU).
print("mIoU for TRAINED_NET over the validation dataset:{}".format(validate(val_loader, trained_net)[1]))

# %% [markdown]
# # Problem 6
#
# #### For the network that you implemented, write a paragraph or two about limitations / bottlenecks about the work. What could be improved? What seems to be some obvious issues with the existing works?
